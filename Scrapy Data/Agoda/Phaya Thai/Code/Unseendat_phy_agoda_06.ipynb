# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %%
#ลบ ข้อความส่วนไม่ต้องการออก รีวิว
def abstract_review(review_ls):
    for i in review_ls:
        lenght = 0
        for j in i.split():
            if j == 'รีวิว':
                sentence = ' '.join(i.split()[0:lenght])
            lenght +=1
        Reviews_list.append(sentence)
    return Reviews_list

# %%
#ลบ ข้อความส่วนไม่ต้องการออก /5
def abstract_rating(rating_ls):
    for i in ratings_list:
        lenght = 0
        for j in i.split():
            if j == '/5':
                rating = ' '.join(i.split()[0:lenght])
            lenght +=1
        Ratings_list.append(rating)
    return Ratings_list

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.agoda.com/th-th/vm1-hostel/hotel/bangkok-th.html?finalPriceView=1&isShowMobileAppPrice=false&cid=1891472&numberOfBedrooms=&familyMode=false&adults=2&children=0&rooms=1&maxRooms=0&checkIn=2023-04-12&isCalendarCallout=false&childAges=&numberOfGuest=0&missingChildAges=false&travellerType=1&showReviewSubmissionEntry=false&currencyCode=THB&isFreeOccSearch=false&tag=eaf6d170-a4ad-da05-a61b-35b1cf5d63da&isCityHaveAsq=false&los=4&searchrequestid=0ab4d6f8-38e6-4a78-bdf2-61220c5568b1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_23572\1225743963.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'โอโย 75332 วีเอ็ม 1 โฮสเทล - อัปเดตราคาล่าสุด'

# %%
driver.execute_script("window.scrollTo(0,11750)")

# %%
#เลือกภาษา ไทย
lang = driver.find_element(By.XPATH,"/html/body/div[9]/div/div[6]/div/div[2]/div/div[7]/div[3]/div[2]/div[1]/div[3]")
lang.click()

# %%
time.sleep(2)
th = driver.find_element(By.XPATH,"/html/body/div[9]/div/div[6]/div/div[2]/div/div[7]/div[3]/div[2]/div[1]/div[3]/div/ul/li[3]")
th.click()

# %%
driver.execute_script("window.scrollTo(0,22900)")

# %%
for comement in driver.find_elements(By.CLASS_NAME,'Review-comment-bodyText'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'Review-comment-leftScore'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list,reviews_list)
save_rating2mainList(Ratings_list,ratings_list)
# Out:
# มีอยู่วันนึงก่อนกลับบ้าน แบบว่าเพลินดี☺️ระหว่างรอผ้าที่ซักอยู่ มานั่งถักผ้าพันคอ ฟังเพลง มันเป็นมุมที่รีแล็กซ์จริง ๆ ...ด้านหน้ามองnature และด้านหลังก็มีน้ำพุน้อย ๆ ฟังเสียงน้ำ...ชอบ ๆ ได้ทั้งอาหารตา อาหารหู มันดีต่อใจจริง ๆ เรามาพักที่นี่ 2 สัปดาห์ การบริการพนักงานดีมากค่ะ สิ่งที่สังเกตหรือเห็นในทุกวันที่พักที่นี่คือ ความสะอาด ของพื้นในห้อง นอกห้อง ในห้องน้ำ ฯลฯ อยากบอกว่าสะอาดจริง ๆ ค่ะ เวลาเราขึ้นห้องพัก(เราพักแบบนอนรวมค่ะ) ถอดรองเท้าเดินได้สบายค่ะ จะไปอาบน้ำ หรือไปเข้าห้องน้ำ เราไม่ใส่รองเท้าเลยค่ะ เรื่องความสะอาดยกย่องให้เลยค่ะ แล้วก็เรื่องที่นอน มีการเปลี่ยนผ้าปู ปลอกหมอน ผ้าห่มและจัดเตียงให้สวยงามทุกวันค่ะ แม้จะมีคนพักต่อแบบเรา ...พนักงานก็เปลี่ยนให้ใหม่หมดในทุกวัน ชอบมากค่ะ บางโฮสเทลนะ ถ้ารู้ว่ามีการพักหลายวันแบบเรานะ จะไม่มีการเปลี่ยนอะไรบนที่นอนเลยค่ะ โอเคค่ะสำหรับที่นี่ ขอบอกเลยค่ะ...ผ่าน^^ สิ่งที่อยากให้แก้ไข คืออยากให้มีราวบันไดสำหรับชั้นแรกค่ะ เพื่อความปลอดภัยของลูกค้า บางคนอาจจะเดินลงมามากกว่า 1 คนเพื่อลงมาชั้นล่างโดยไม่ได้ระวัง มันเสี่ยงต่อการตกลงมาจากบันได
# โฮสเทลอยู่ในซอยพหลโยธิน 1 เป็นทางวันเวย์ ซอยค่อนข้างแคบ มีที่จอดรถให้ (ขับเลยโรงแรมไป 4 ห้อง เลี้ยวขวาเข้าซอย ที่จอดรถอยู่ทางด้านขวา) แต่ถ้ามาช่วงค่ำ อาจจะต้องโทรแจ้งโรงแรมให้เปิดประตูเข้าที่จอดรถให้ การเช็คอินและเช็คเอาท์ง่ายและรวดเร็ว ห้องนอนและห้องน้ำสะอาด มีไดร์เป่าผมให้ในห้องน้ำรวม แต่สามารถยืมเพื่อใช้ในห้องต่างหากได้ (เสียค่ามัดจำ 200 บาท) ในห้องไม่มีตู้เย็น, สำหรับผู้ที่พักห้องเดี่ยว จะมีอาหารเช้าเป็นอาหารตามสั่งให้ รอบโรงแรมหาของกินง่ายมาก และมีร้านสะดวกซื้ออยู่ใกล้โรงแรม การบริการของพนักงานดีมาก
# เราเข้าพักที่นี่มา 2 สัปดาห์ เนื่องจากเราเกิดอุบัติเหตุที่บ้าน เลยทำให้ขาเจ็บ และไม่สามารถเดินทางไป-กลับบ้านได้ในช่วงนี้ เลยต้องมาพักที่ VM1 hotel เนื่องจากอยู่ใกล้ที่ทำงานเรา ตลอดที่พักที่นี่สะดวกสบายดีค่ะ ห้องพักมีการเปลี่ยนผ้าปูและผ้าห่มใหม่ทุกวัน ราคานี้มีอาหารเช้าด้วยค่ะ พนักงานพูดเพราะ และให้ข้อมูล สถานที่โดยรวมให้บรรยากาศรีแล็กซ์ดีค่ะทั้งข้างนอกและภายในโฮสเทลแห่งนี้ ธรรมชาติดีค่ะ มองแล้วสบายตา...โดยส่วนตัวชอบโฮสเทลแห่งนี้มากค่ะ
# ที่พักใกล้อนุสาวรีย์ชัย ลักษณะ hostel แต่ไปพักห้องที่มีห้องน้ำส่วนตัว ราคาไม่แพงคุ้มค่า แต่ต้องเดินขึ้นบันไดสูงหน่อยเพราะอยู่ชั้น 4 ชั้นบนสุด ตัวห้องพักใช้ได้เลย มีผ้าเช็ดตัวกับไดร์เป่าผมให้พร้อม มีอาหารเช้าเป็นอาหารจานเดียวให้เลือก และชา กาแฟ ขนมปัง โดยรวมมาถ้าไม่ติดเรื่องต้องเดินขึ้นบันไดกับที่จอดรถ แนะนำเลย
# ที่พักมีที่จอดรถ ด้านหลัง แต่รถวิ่งทางเดียว วนไปออกอนุสาวรีย์ และพหลโยธินได้ ที่พักดี พนักงานดีมาก มีอาหารเช้า ห้องเตียงสองชั้นมีความสูงดีค่ะ หักคะแนนอย่างเดียว บันไดขึ้นเตียงชั้นบนมันปีนยากไม่มีที่เกาะ และไม่มีที่กั้นกันตกที่ขอบเตียง โดยรวมชอบค่ะ จะมาพักอีก
# พึ่งเข้าพักครั้งแรก ดีกว่าที่คิดไว้ค่ะ ที่พักเป็นแบบสไตส์ Loft ให้ความรู้สึกสบาย บรรยากาศดี เงียบสงบ ถึงแม้จะตั้งอยู่ใจกลางเมือง ใกล้ๆมีทั้งของกินและ 7-11 เดินทางสะดวกทั้งรถโดยสารและ BTS พนักงานบริการดีทุกคน ประทับใจเลยค่ะ หากมีโอกาสจะเข้่าพักอีกแน่นอนค่ะ
# ที่พักสะอาด ใกล้ BTS สนามเป้า อนุสาวรีย์ชัย ใกล้ the season mall อาหารการกินแถวที่พักเยอะมาก ราคาไม่แพง ใกล้แหล่งท่องเที่ยว ราคาห้องพักไม่เเพง สะดวก สะอาด พนักงานให้บริการโอเคดีค่ะ
# ห้องพักสวย บรรยากาศในโรงแรมดี สวยงาม คุ้มราคา อาหารเช้าเรียบๆ เดินทางสะดวกไม่ไกลจาก รถไฟฟ้า ท่จอดรถปลอดภัย ไฟในห้องน้อยไปนิด มุมห้องบางมุม มืด อาจจะเป็นแนวขึ้นอยู่กับความชอบมั่ง
# เพิ่งเคยพักห้องรวมคนเดียวครั้งแรก พนักงานให้ความช่วยเหลือดีมากค่ะ ห้องพักรวมก็นอนสบาย เป็นสัดส่วน อยู่ไม่ไกลจากรถไฟฟ้าด้วย สะดวกมากๆ
# โรงแรมอยู่ในซอยเล็ก แต่หาไม่ยาก ไม่มีที่จอดรถ ไม่เหมาะสำหรับผู้สูงอายุ เพราะขึ้นบันไดชันและสูง นอกนั้นดีหมด
# ห้องพักดีมากกว้างกำลังเฝดี ห้องน้ำสะอาด พนักงานต้อนรับดีมาก เอาใจใส่มาแถวนี้ทีไรต้องมาพักโรงแรมนี้
# check in หลังเที่ยงคืน เข้าไปอาบน้ำแล้วไม่ไหล ต้องแจ้งพนักงาน ตอนเช้าก้อยังไม่ไหลอีก ต้องแจ้งพนักงานอีก หัวเสียเล็กน้อย แต่โรงแรมตกแต่งสวยงาม อาหารเช้าน้อยไปนิด แต่แถวนั้นของกินเยอะ ไม่ต้องห่วงเรื่องอาหาร ห้องพักและห้องน้ำสะอาดดี แต่แขกที่พักด้วยน่าจะสูบบุหรี่ เลยเหม็นไปทั้งห้อง เกือบนอนไม่ได้ และไม่มีผ้าเช็ดตัวให้
# เดินทางสะดวกมาก ราคาค่อนข้างสูงแต่ได้เปรียบเรื่องทำเล ห้องพักสะอาดเสียงรบกวนดังเข้ามาค่อนข้างง่าย ถ้าไม่ซีเรียสอะไรนอนได้ค่ะ มีของว่างให้ทานตอนเช้าด้วย
# ห้องพักและห้องน้ำสะอาดมากกก พนักงานต้อนรับดี มีอาหารเช้า เดินทางสะดวก ใกล้แหล่งของกิน
# ห้องพักอยู่ชั้น 4 ไม่ลิฟ อย่างอื่นดีหมด สถานที่ตกแต่งน่ารัก พนักงานบริการน่ารัก
# ซอยที่ตั้งของกินเยอะมาก นอนชั้น 4 เงียบไม่มีเสียงอะไรให้รำคาญ มีอาหารเช้า
# มีที่จอดรถให้ (แจ้งล่วงหน้าก่อนเข้าพัก) อาหารเช้าอร่อย คุ้มค่ากับราคา
# ห้องพักดีมาก บรรยากาศดีติดกับห้างสรรพสินค้า ตลาดริมทาง และ โรงพยาบาล เดินสะดวก รถตู้ bts มอไซค์รับจ้าง
# ห้องพักสะอาด ห้องน้ำก็ดี บรรยากาศภายในดีแต่รอบข้างเสียงดังได้ยินเสียงรถวิ่งตลอดทั้งวันทั้งคืน ใกล้btsอนุของกินเยอะ
# ขับรถไปครั้งแรกจะงงๆทางหน่อยค่ะมันเป็นวันเวย์
# 10.0
# 9.2
# 10.0
# 9.6
# 9.2
# 9.2
# 10.0
# 8.8
# 10.0
# 9.6
# 9.6
# 7.6
# 8.4
# 10.0
# 9.6
# 9.6
# 9.2
# 8.4
# 8.0
# 9.6

# %%
next_page = driver.find_element(By.XPATH,'/html/body/div[9]/div/div[6]/div/div[2]/div/div[7]/div[6]/div/span[3]')
next_page.click()

# %%
driver.execute_script("window.scrollTo(0,23000)")
clear_list(ratings_list,reviews_list)

time.sleep(3)
for comement in driver.find_elements(By.CLASS_NAME,'Review-comment-bodyText'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'Review-comment-leftScore'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list,reviews_list)
save_rating2mainList(Ratings_list,ratings_list)
# Out:
# ห้องprivateอยู่ชั้น4ต้องเดินหน่อย
# ข้างล่างจัดสวย แต่ห้องข้างบนเป็นแบบ ไม่เหมือนในรูป ห้องไม่เก็บเสียง เสียงวอคุยกันเข้ามาให้ห้องหรือเสียงห้องข้างๆ บันไดสูงมาก สูงจนเหนือยมากเวลาขึ้น รวมแล้วโอเคถ้ายังต้องมาพักอีก คิดว่ายังไม่ตอบโจทย์ โรงแรมเอเชียร์น่าจะดีกว่า
# อยู่ไม่ไกลจากอนุสาวรีย์ มีร้านสะดวกซื้ออยู่หน้าที่พัก
# สะอาด สะดวก ปลอดภัย
# ข้อเสีย ไม่มีที่กั้นเตียง กลัวตก
# ทำเลดีเดินทางสะดวก ห้องพักสะอาด
# แนะนำที่นี่เลยครับ. มาพักบ่อยๆ.
# ห้องนอนดีมาก อยู่ใกล้โรงพยาบาล พญาไท2
# 7.2
# 6.8
# 8.8
# 8.4
# 8.0
# 8.4
# 10.0
# 9.2

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 48
# Reviews_list : 48

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   มีอยู่วันนึงก่อนกลับบ้าน แบบว่าเพลินดี☺️ระหว่า...   10.0
# 1   โฮสเทลอยู่ในซอยพหลโยธิน 1 เป็นทางวันเวย์ ซอยค่...    9.2
# 2   เราเข้าพักที่นี่มา 2 สัปดาห์ เนื่องจากเราเกิดอ...   10.0
# 3   ที่พักใกล้อนุสาวรีย์ชัย ลักษณะ hostel แต่ไปพัก...    9.6
# 4   ที่พักมีที่จอดรถ ด้านหลัง แต่รถวิ่งทางเดียว วน...    9.2
# 5   พึ่งเข้าพักครั้งแรก ดีกว่าที่คิดไว้ค่ะ ที่พักเ...    9.2
# 6   ที่พักสะอาด ใกล้ BTS สนามเป้า อนุสาวรีย์ชัย ใก...   10.0
# 7   ห้องพักสวย บรรยากาศในโรงแรมดี สวยงาม คุ้มราคา ...    8.8
# 8   เพิ่งเคยพักห้องรวมคนเดียวครั้งแรก พนักงานให้คว...   10.0
# 9   โรงแรมอยู่ในซอยเล็ก แต่หาไม่ยาก ไม่มีที่จอดรถ ...    9.6
# 10  ห้องพักดีมากกว้างกำลังเฝดี ห้องน้ำสะอาด พนักงา...    9.6
# 11  check in หลังเที่ยงคืน เข้าไปอาบน้ำแล้วไม่ไหล ...    7.6
# 12  เดินทางสะดวกมาก ราคาค่อนข้างสูงแต่ได้เปรียบเรื...    8.4
# 13  ห้องพักและห้องน้ำสะอาดมากกก พนักงานต้อนรับดี ม...   10.0
# 14  ห้องพักอยู่ชั้น 4 ไม่ลิฟ อย่างอื่นดีหมด สถานที...    9.6
# 15  ซอยที่ตั้งของกินเยอะมาก นอนชั้น 4 เงียบไม่มีเส...    9.6
# 16  มีที่จอดรถให้ (แจ้งล่วงหน้าก่อนเข้าพัก) อาหารเ...    9.2
# 17  ห้องพักดีมาก บรรยากาศดีติดกับห้างสรรพสินค้า ตล...    8.4
# 18  ห้องพักสะอาด ห้องน้ำก็ดี บรรยากาศภายในดีแต่รอบ...    8.0
# 19      ขับรถไปครั้งแรกจะงงๆทางหน่อยค่ะมันเป็นวันเวย์    9.6
# 20  สะอาด มีที่จอดรถ ติดแค่เป็นห้องน้ำรวมจึงไม่ค่อ...    7.6
# 21  วันที่ไปพักเลือกห้องครอบครัวขนาดห้องใหญ่กว่าที...   10.0
# 22  อยู่ใกล้ BTS สนามเป้า เดินมาโรงแรมได้เลยไม่ใกล...   10.0
# 23  สะอาด สะดวก ปลอดภัย พนักงานดูแลดีมาก อาหารหาทา...   10.0
# 24  ขนาดห้องพอได้ ทุกอย่างโอเค สวยเรียบเนียนสไตล์ล...   10.0
# 25  โรงแรมอยู่ในดงของกินเยอะมาก เดินทางสะดวก ไม่มี...    6.0
# 26  พักชั้น3 ที่นอนมีมดแดงเยอะมากออกมาเรื่อยๆเลย ห...    6.8
# 27  จองง่าย ราคาโดนใจ ใกล้BTSทั้งอนุสาวรีย์ชัย, สน...   10.0
# 28  เดินทางไปง่าย แถวที่พักของกินเพียบ คึกคักสุดๆ ...   10.0
# 29                        สะอาดของกินเยอะเดินทางสะดวก   10.0
# 30                                                 OK   10.0
# 31                 สะอาด การบริการดี ใกล้โรงพยาบาลค่ะ   10.0
# 32             ที่พักสะอาด พนักงานบริการดี ราคาไม่แพง    9.2
# 33                              บริการดี ห้องเงียบสงบ    9.2
# 34  ในละเอียดบอกว่ามีอาหารเช้าให้ แต่ปรากฏว่ามีแค่...    4.8
# 35  พักห้องส่วนตัว ห้องน้ำส่วนตัว พอเข้าห้องน้ำ มี...    4.0
# 36             โดยรวมทุกอย่างดีมาก เป็นอีกที่ที่แนะนำ    9.6
# 37                          นอนที่เตียงแล้วรู้สึดคันๆ    6.0
# 38       พนักงานต้อนรับดี บริการดี มีอาหารเช้าให้ด้วย    9.2
# 39                             ทำเลดี อาหารการกินเยอะ    6.8
# 40                  ห้องprivateอยู่ชั้น4ต้องเดินหน่อย    7.2
# 41  ข้างล่างจัดสวย แต่ห้องข้างบนเป็นแบบ ไม่เหมือนใ...    6.8
# 42  อยู่ไม่ไกลจากอนุสาวรีย์ มีร้านสะดวกซื้ออยู่หน้...    8.8
# 43                                สะอาด สะดวก ปลอดภัย    8.4
# 44                   ข้อเสีย ไม่มีที่กั้นเตียง กลัวตก    8.0
# 45                    ทำเลดีเดินทางสะดวก ห้องพักสะอาด    8.4
# 46                    แนะนำที่นี่เลยครับ. มาพักบ่อยๆ.   10.0
# 47              ห้องนอนดีมาก อยู่ใกล้โรงพยาบาล พญาไท2    9.2

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  มีอยู่วันนึงก่อนกลับบ้าน แบบว่าเพลินดี☺️ระหว่า...   10.0
# 1       1  โฮสเทลอยู่ในซอยพหลโยธิน 1 เป็นทางวันเวย์ ซอยค่...    9.2
# 2       2  เราเข้าพักที่นี่มา 2 สัปดาห์ เนื่องจากเราเกิดอ...   10.0
# 3       3  ที่พักใกล้อนุสาวรีย์ชัย ลักษณะ hostel แต่ไปพัก...    9.6
# 4       4  ที่พักมีที่จอดรถ ด้านหลัง แต่รถวิ่งทางเดียว วน...    9.2
# 5       5  พึ่งเข้าพักครั้งแรก ดีกว่าที่คิดไว้ค่ะ ที่พักเ...    9.2
# 6       6  ที่พักสะอาด ใกล้ BTS สนามเป้า อนุสาวรีย์ชัย ใก...   10.0
# 7       7  ห้องพักสวย บรรยากาศในโรงแรมดี สวยงาม คุ้มราคา ...    8.8
# 8       8  เพิ่งเคยพักห้องรวมคนเดียวครั้งแรก พนักงานให้คว...   10.0
# 9       9  โรงแรมอยู่ในซอยเล็ก แต่หาไม่ยาก ไม่มีที่จอดรถ ...    9.6
# 10     10  ห้องพักดีมากกว้างกำลังเฝดี ห้องน้ำสะอาด พนักงา...    9.6
# 11     11  check in หลังเที่ยงคืน เข้าไปอาบน้ำแล้วไม่ไหล ...    7.6
# 12     12  เดินทางสะดวกมาก ราคาค่อนข้างสูงแต่ได้เปรียบเรื...    8.4
# 13     13  ห้องพักและห้องน้ำสะอาดมากกก พนักงานต้อนรับดี ม...   10.0
# 14     14  ห้องพักอยู่ชั้น 4 ไม่ลิฟ อย่างอื่นดีหมด สถานที...    9.6
# 15     15  ซอยที่ตั้งของกินเยอะมาก นอนชั้น 4 เงียบไม่มีเส...    9.6
# 16     16  มีที่จอดรถให้ (แจ้งล่วงหน้าก่อนเข้าพัก) อาหารเ...    9.2
# 17     17  ห้องพักดีมาก บรรยากาศดีติดกับห้างสรรพสินค้า ตล...    8.4
# 18     18  ห้องพักสะอาด ห้องน้ำก็ดี บรรยากาศภายในดีแต่รอบ...    8.0
# 19     19      ขับรถไปครั้งแรกจะงงๆทางหน่อยค่ะมันเป็นวันเวย์    9.6
# 20     20  สะอาด มีที่จอดรถ ติดแค่เป็นห้องน้ำรวมจึงไม่ค่อ...    7.6
# 21     21  วันที่ไปพักเลือกห้องครอบครัวขนาดห้องใหญ่กว่าที...   10.0
# 22     22  อยู่ใกล้ BTS สนามเป้า เดินมาโรงแรมได้เลยไม่ใกล...   10.0
# 23     23  สะอาด สะดวก ปลอดภัย พนักงานดูแลดีมาก อาหารหาทา...   10.0
# 24     24  ขนาดห้องพอได้ ทุกอย่างโอเค สวยเรียบเนียนสไตล์ล...   10.0
# 25     25  โรงแรมอยู่ในดงของกินเยอะมาก เดินทางสะดวก ไม่มี...    6.0
# 26     26  พักชั้น3 ที่นอนมีมดแดงเยอะมากออกมาเรื่อยๆเลย ห...    6.8
# 27     27  จองง่าย ราคาโดนใจ ใกล้BTSทั้งอนุสาวรีย์ชัย, สน...   10.0
# 28     28  เดินทางไปง่าย แถวที่พักของกินเพียบ คึกคักสุดๆ ...   10.0
# 29     29                        สะอาดของกินเยอะเดินทางสะดวก   10.0
# 30     30                                                 OK   10.0
# 31     31                 สะอาด การบริการดี ใกล้โรงพยาบาลค่ะ   10.0
# 32     32             ที่พักสะอาด พนักงานบริการดี ราคาไม่แพง    9.2
# 33     33                              บริการดี ห้องเงียบสงบ    9.2
# 34     34  ในละเอียดบอกว่ามีอาหารเช้าให้ แต่ปรากฏว่ามีแค่...    4.8
# 35     35  พักห้องส่วนตัว ห้องน้ำส่วนตัว พอเข้าห้องน้ำ มี...    4.0
# 36     36             โดยรวมทุกอย่างดีมาก เป็นอีกที่ที่แนะนำ    9.6
# 37     37                          นอนที่เตียงแล้วรู้สึดคันๆ    6.0
# 38     38       พนักงานต้อนรับดี บริการดี มีอาหารเช้าให้ด้วย    9.2
# 39     39                             ทำเลดี อาหารการกินเยอะ    6.8
# 40     40                  ห้องprivateอยู่ชั้น4ต้องเดินหน่อย    7.2
# 41     41  ข้างล่างจัดสวย แต่ห้องข้างบนเป็นแบบ ไม่เหมือนใ...    6.8
# 42     42  อยู่ไม่ไกลจากอนุสาวรีย์ มีร้านสะดวกซื้ออยู่หน้...    8.8
# 43     43                                สะอาด สะดวก ปลอดภัย    8.4
# 44     44                   ข้อเสีย ไม่มีที่กั้นเตียง กลัวตก    8.0
# 45     45                    ทำเลดีเดินทางสะดวก ห้องพักสะอาด    8.4
# 46     46                    แนะนำที่นี่เลยครับ. มาพักบ่อยๆ.   10.0
# 47     47              ห้องนอนดีมาก อยู่ใกล้โรงพยาบาล พญาไท2    9.2

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   มีอยู่วันนึงก่อนกลับบ้าน แบบว่าเพลินดี☺️ระหว่า...   10.0
# 1   โฮสเทลอยู่ในซอยพหลโยธิน 1 เป็นทางวันเวย์ ซอยค่...    9.2
# 2   เราเข้าพักที่นี่มา 2 สัปดาห์ เนื่องจากเราเกิดอ...   10.0
# 3   ที่พักใกล้อนุสาวรีย์ชัย ลักษณะ hostel แต่ไปพัก...    9.6
# 4   ที่พักมีที่จอดรถ ด้านหลัง แต่รถวิ่งทางเดียว วน...    9.2
# 5   พึ่งเข้าพักครั้งแรก ดีกว่าที่คิดไว้ค่ะ ที่พักเ...    9.2
# 6   ที่พักสะอาด ใกล้ BTS สนามเป้า อนุสาวรีย์ชัย ใก...   10.0
# 7   ห้องพักสวย บรรยากาศในโรงแรมดี สวยงาม คุ้มราคา ...    8.8
# 8   เพิ่งเคยพักห้องรวมคนเดียวครั้งแรก พนักงานให้คว...   10.0
# 9   โรงแรมอยู่ในซอยเล็ก แต่หาไม่ยาก ไม่มีที่จอดรถ ...    9.6
# 10  ห้องพักดีมากกว้างกำลังเฝดี ห้องน้ำสะอาด พนักงา...    9.6
# 11  check in หลังเที่ยงคืน เข้าไปอาบน้ำแล้วไม่ไหล ...    7.6
# 12  เดินทางสะดวกมาก ราคาค่อนข้างสูงแต่ได้เปรียบเรื...    8.4
# 13  ห้องพักและห้องน้ำสะอาดมากกก พนักงานต้อนรับดี ม...   10.0
# 14  ห้องพักอยู่ชั้น 4 ไม่ลิฟ อย่างอื่นดีหมด สถานที...    9.6
# 15  ซอยที่ตั้งของกินเยอะมาก นอนชั้น 4 เงียบไม่มีเส...    9.6
# 16  มีที่จอดรถให้ (แจ้งล่วงหน้าก่อนเข้าพัก) อาหารเ...    9.2
# 17  ห้องพักดีมาก บรรยากาศดีติดกับห้างสรรพสินค้า ตล...    8.4
# 18  ห้องพักสะอาด ห้องน้ำก็ดี บรรยากาศภายในดีแต่รอบ...    8.0
# 19      ขับรถไปครั้งแรกจะงงๆทางหน่อยค่ะมันเป็นวันเวย์    9.6
# 20  สะอาด มีที่จอดรถ ติดแค่เป็นห้องน้ำรวมจึงไม่ค่อ...    7.6
# 21  วันที่ไปพักเลือกห้องครอบครัวขนาดห้องใหญ่กว่าที...   10.0
# 22  อยู่ใกล้ BTS สนามเป้า เดินมาโรงแรมได้เลยไม่ใกล...   10.0
# 23  สะอาด สะดวก ปลอดภัย พนักงานดูแลดีมาก อาหารหาทา...   10.0
# 24  ขนาดห้องพอได้ ทุกอย่างโอเค สวยเรียบเนียนสไตล์ล...   10.0
# 25  โรงแรมอยู่ในดงของกินเยอะมาก เดินทางสะดวก ไม่มี...    6.0
# 26  พักชั้น3 ที่นอนมีมดแดงเยอะมากออกมาเรื่อยๆเลย ห...    6.8
# 27  จองง่าย ราคาโดนใจ ใกล้BTSทั้งอนุสาวรีย์ชัย, สน...   10.0
# 28  เดินทางไปง่าย แถวที่พักของกินเพียบ คึกคักสุดๆ ...   10.0
# 29                        สะอาดของกินเยอะเดินทางสะดวก   10.0
# 30                                                 OK   10.0
# 31                 สะอาด การบริการดี ใกล้โรงพยาบาลค่ะ   10.0
# 32             ที่พักสะอาด พนักงานบริการดี ราคาไม่แพง    9.2
# 33                              บริการดี ห้องเงียบสงบ    9.2
# 34  ในละเอียดบอกว่ามีอาหารเช้าให้ แต่ปรากฏว่ามีแค่...    4.8
# 35  พักห้องส่วนตัว ห้องน้ำส่วนตัว พอเข้าห้องน้ำ มี...    4.0
# 36             โดยรวมทุกอย่างดีมาก เป็นอีกที่ที่แนะนำ    9.6
# 37                          นอนที่เตียงแล้วรู้สึดคันๆ    6.0
# 38       พนักงานต้อนรับดี บริการดี มีอาหารเช้าให้ด้วย    9.2
# 39                             ทำเลดี อาหารการกินเยอะ    6.8
# 40                  ห้องprivateอยู่ชั้น4ต้องเดินหน่อย    7.2
# 41  ข้างล่างจัดสวย แต่ห้องข้างบนเป็นแบบ ไม่เหมือนใ...    6.8
# 42  อยู่ไม่ไกลจากอนุสาวรีย์ มีร้านสะดวกซื้ออยู่หน้...    8.8
# 43                                สะอาด สะดวก ปลอดภัย    8.4
# 44                   ข้อเสีย ไม่มีที่กั้นเตียง กลัวตก    8.0
# 45                    ทำเลดีเดินทางสะดวก ห้องพักสะอาด    8.4
# 46                    แนะนำที่นี่เลยครับ. มาพักบ่อยๆ.   10.0
# 47              ห้องนอนดีมาก อยู่ใกล้โรงพยาบาล พญาไท2    9.2

# %%
table.to_csv("Unseen_6.csv", encoding="utf-8")
