# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %%
#ลบ ข้อความส่วนไม่ต้องการออก รีวิว
def abstract_review(review_ls):
    for i in review_ls:
        lenght = 0
        for j in i.split():
            if j == 'รีวิว':
                sentence = ' '.join(i.split()[0:lenght])
            lenght +=1
        Reviews_list.append(sentence)
    return Reviews_list

# %%
#ลบ ข้อความส่วนไม่ต้องการออก /5
def abstract_rating(rating_ls):
    for i in ratings_list:
        lenght = 0
        for j in i.split():
            if j == '/5':
                rating = ' '.join(i.split()[0:lenght])
            lenght +=1
        Ratings_list.append(rating)
    return Ratings_list

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.agoda.com/th-th/le-bonheur-poshtel/hotel/bangkok-th.html?finalPriceView=1&isShowMobileAppPrice=false&cid=1891472&numberOfBedrooms=&familyMode=false&adults=2&children=0&rooms=1&maxRooms=0&checkIn=2023-04-13&isCalendarCallout=false&childAges=&numberOfGuest=0&missingChildAges=false&travellerType=1&showReviewSubmissionEntry=false&currencyCode=THB&isFreeOccSearch=false&tag=b4ef7822-82f3-9df5-be77-0bc9f4c1349e&isCityHaveAsq=false&los=2&searchrequestid=4393e413-fa37-4b63-8a1c-d74e31b951c5'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_11176\1442835822.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'Le Bonheur Poshtel - อัปเดตราคาล่าสุด'

# %%
driver.execute_script("window.scrollTo(0,8700)")

# %%
#เลือกภาษา ไทย
lang = driver.find_element(By.XPATH,"/html/body/div[9]/div/div[6]/div/div[2]/div/div[8]/div[3]/div[2]/div[1]/div[3]")
lang.click()

# %%
time.sleep(2)
th = driver.find_element(By.XPATH,"/html/body/div[9]/div/div[6]/div/div[2]/div/div[8]/div[3]/div[2]/div[1]/div[3]/div/ul/li[3]")
th.click()

# %%
driver.execute_script("window.scrollTo(0,22900)")

# %%
for comement in driver.find_elements(By.CLASS_NAME,'Review-comment-bodyText'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'Review-comment-leftScore'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list,reviews_list)
save_rating2mainList(Ratings_list,ratings_list)
# Out:
# ห้องเล็ก ไม่เก็บเสียง ได้ยินเสียงเดินชัดมาก แอร์เย็นดี ห้องน้ำแบ่งโซนเปียกชัดเจน สามารถกรอกน้ำดื่มใส่ขวดไปดื่มบนห้องได้ เป็นนโยบายของที่พัก ไม่มีขวดน้ำดื่มให้ในห้อง หน้าปากซอยมี7-11 เดินถึงbtsสะพานควายเพียง1-2นาที มีร้านนวดใกล้ๆ ซอยข้างๆมีอาหาร ร้านอาหารขาย
# เดินทางสะดวกใกล้bts สะพานควาย ห้องพักเหมาะสมกับราคา ห้องน้ำ เตียงสะอาดดี แต่ห้องแคบ ควรจะมีบานกระจก หน้าต่าง ลูกค้าจะได้ไม่รู้สึกอึดอัด ประตูต้องออกแรงบิดปิด-เปิด พนักงานบริการดี ให้คำแนะนำดี โดยรวมแล้วดี คุ้มค่าถ้ามีโอกาสอาจจะไปพักอีก
# ห้องพักไม่กว้างแต่นอนหลับสบายไม่มีเสียงรบกวน ภายในที่พักเงียบมากแม้ห้องพักจะเต็ม ทำความสะอาดดี มีตู้เย็นและน้ำดื่มให้กดที่ชั้นล่าง ภายในห้องไม่มีตู้เย็น สตาฟบริการดีมาก การเดินทางใกล้บีทีเอสสะพานควาย กลับมาพักอีกแน่นอน
# บริการดีมากๆๆๆๆๆเลยค่ะ มีที่จอดรถสำหรับคนมาพัก ห้องพักถือว่าโอเคมากๆเลยสำหรับสองคน สะอาด ห้องน้ำก็สะอาดค่ะ ปกติไปพักก็จะดูน้ำในห้องน้ำว่าแรงดีไหม ที่นี่น้ำแรงมากก แต่เสียอย่างไม่มีอาหารเช้าฟรี
# ห้องพักดี สะอาด สิ่งอำนวยความสะดวกที่จำเป็นครบ มีไดร์เป่าผม ห้องน้ำดี เตียงนอนสบาย ผ้าห่มดีมาก ที่สำคัญระบบรักษาความปลอดภัยดีมากๆ และที่น่าชื่นชมคือ staff ทุกคนน่ารักและมี service mind มากๆ
# ห้องพักค่อนข้างเล็ก โรงแรมอยู่ในซอย แต่ไม่ลึกมาก ของกินหาง่าย เดินทางสะดวก
# ทำเลที่ตั้งดีมากอยู่ในย่านช้อปปิ้ง ที่พักสะอาด แอร์เย็นห้องน้ำสะอาด
# ที่พักใกล้รถไฟฟ้าพนักงานบริการดีมาก ขนมด้านหน้าก็อร่อยค่ะ
# ห้องเล็กกะทัดรัดดีครับ ความสะอาดดี ติสองเรื่องในห้องน้ำ 1. ฝารองนั่งชำรุด ขยับได้เกือบหลุดออกจากชักโครก 2. ฝักบัวน้ำกระจายมาก คิดว่าน่าจะตัน
# ม่านปิดได้แค่ครึ่งเตียง ไม่มีที่นั่งเล่นที่เป็นห้องแอร์ เราพักhostel มาหลายที่ ไม่ค่อยชอบที่นี่เท่าไหร่ ดูแปลกๆ จองหักส่วนลดผ่านอโกด้า 2คืน 811฿ไม่มีอาหารเช้า เราว่าไม่คุ้มค่ากับเงินที่เสียไป
# 9.2
# 9.6
# 9.6
# 9.2
# 10.0
# 8.8
# 10.0
# 10.0
# 10.0
# 10.0
# 9.2
# 6.4
# 9.2
# 8.8
# 8.4
# 10.0
# 10.0
# 9.2
# 8.0
# 7.2

# %%
next_page = driver.find_element(By.XPATH,'/html/body/div[9]/div/div[6]/div/div[2]/div/div[8]/div[6]/div/span[3]')
next_page.click()

# %%
driver.execute_script("window.scrollTo(0,23000)")
clear_list(ratings_list,reviews_list)

time.sleep(3)
for comement in driver.find_elements(By.CLASS_NAME,'Review-comment-bodyText'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'Review-comment-leftScore'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list,reviews_list)
save_rating2mainList(Ratings_list,ratings_list)
# Out:
# เสียงดัง
# ที่พักสะอาด มีเครื่องซักผ้าล่างโฮสเทล กับให้กรอกน้ำขึ้นมากินเองได้
# ใกล้ BTS เดินทางง่าย
# ไม่มีลิฟท์พักชั้นสูงอาจจะไม่ค่อยสะดวก
# 5.6
# 7.6
# 8.0
# 6.8

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 44
# Reviews_list : 44

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   ห้องเล็ก ไม่เก็บเสียง ได้ยินเสียงเดินชัดมาก แอ...    9.2
# 1   เดินทางสะดวกใกล้bts สะพานควาย ห้องพักเหมาะสมกั...    9.6
# 34                            ประตูเปิดปิดเสียงดังมาก    5.2
# 35                 ขนาดห้องกำลังดี บรรยากาศโอเค สะอาด    8.4
# 36                              ใกล้ BTS, แต่ไม่มีลิฟ    8.8
# 37                             ห้องพักดีแต่แคบไปหน่อย    7.2
# 38                            ใกล้ bts เดิน 2 นาทีถึง    8.8
# 39                 เดินทางสะดวก มี7-11ทางลงจากบีทีเอส    6.4
# 40                                           เสียงดัง    5.6
# 41  ที่พักสะอาด มีเครื่องซักผ้าล่างโฮสเทล กับให้กร...    7.6
# 42                               ใกล้ BTS เดินทางง่าย    8.0
# 43              ไม่มีลิฟท์พักชั้นสูงอาจจะไม่ค่อยสะดวก    6.8

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  ห้องเล็ก ไม่เก็บเสียง ได้ยินเสียงเดินชัดมาก แอ...    9.2
# 1       1  เดินทางสะดวกใกล้bts สะพานควาย ห้องพักเหมาะสมกั...    9.6
# 2       2  ห้องพักไม่กว้างแต่นอนหลับสบายไม่มีเสียงรบกวน ภ...    9.6
# 3       3  บริการดีมากๆๆๆๆๆเลยค่ะ มีที่จอดรถสำหรับคนมาพัก...    9.2
# 4       4  ห้องพักดี สะอาด สิ่งอำนวยความสะดวกที่จำเป็นครบ...   10.0
# 5       5  ข้อดี - ทำเลดี ใกล้ BTS รอบๆมีร้านอาหารตามสั่ง...    8.8
# 6       6  อยู่ใกล้บีทีเอสสะพานควายมาๆค่ะ แค่เดินลงมาจากบ...   10.0
# 7       7  Staffบริการดี ห้องสะอาด มาพักหลายครั้งแล้ว นอน...   10.0
# 8       8  ใกล้บีทีเอสมากๆ ลงมาเลี้ยวเข้าซอย ถึงเลย มีของ...   10.0
# 9       9  ที่พักสะอาดค่ะ พักห้องเดี่ยวอาจจะแคบไปหน่อยแต่...   10.0
# 10     10  ทำเลดี ติดรถไฟฟ้า bts เดินทางสะดวก มีที่จอดรถ ...    9.2
# 11     11  ที่พักสะดวกในการเดินทางลงจาก btsสะพานควาย (exi...    6.4
# 12     12  พนักงานเป็นกันเองดีค่ะ…ระบบความปลอดภัยดีมากค่ะ...    9.2
# 13     13  ดี : ใกล้ bts สะพานควาย เดิน 3 นาทีถึง, staff ...    8.8
# 14     14  เดินทางสะดวกมากค่ะ ติดบีทีเอสสะพานควาย เดินใกล...    8.4
# 15     15  ห้องพักค่อนข้างเล็ก โรงแรมอยู่ในซอย แต่ไม่ลึกม...   10.0
# 16     16  ทำเลที่ตั้งดีมากอยู่ในย่านช้อปปิ้ง ที่พักสะอาด...   10.0
# 17     17  ที่พักใกล้รถไฟฟ้าพนักงานบริการดีมาก ขนมด้านหน้...    9.2
# 18     18  ห้องเล็กกะทัดรัดดีครับ ความสะอาดดี ติสองเรื่อง...    8.0
# 19     19  ม่านปิดได้แค่ครึ่งเตียง ไม่มีที่นั่งเล่นที่เป็...    7.2
# 20     20  ห้องสะอาด ห้องน้ำแบ่งสัดส่วน ห้องอาบน้ำมีผนังก...   10.0
# 21     21  เตียงมีรอยเปื้อนแดงๆ เหมือนรอยลิป ไม่มีแปรงสีฟ...    3.6
# 22     22                                เดินทางสะดวกมากๆค่ะ   10.0
# 23     23                          บริการดีมากครับ ห้องสะอาด   10.0
# 24     24  ทำเลดี ใกล้รถไฟฟ้า เจ้าของร้านบริการดี ห้องนอน...    9.2
# 25     25                          เมาแล้วหาที่นอน แนะนำครับ    8.0
# 26     26  ห้องพักสะอาด มีไดร์เป่าผมให้ ที่พักก็อยู่ใกล้B...   10.0
# 27     27                                               อยู่   10.0
# 28     28  เครื่องทำน้ำอุ่น ไม่ร้อนเลย ทีวี จอเล็ก ค่ะ กร...    6.8
# 29     29                   แอร์มีกลิ่นเหม็นเวลาเปิดไปสักพัก    4.8
# 30     30  ทำเลดีครับ คิด BTS สะพานควาย เดินไม่ถึง 1 นาที...    8.4
# 31     31  อยู่ติดบีทีเอสสะพานควายเลยค่ะ เดินออกทางประตูห...    7.6
# 32     32                                  ไม่มีทิชชู่ในห้อง    8.0
# 33     33                         ใกล้ bts เดินทางง่าย สะดวก    8.8
# 34     34                            ประตูเปิดปิดเสียงดังมาก    5.2
# 35     35                 ขนาดห้องกำลังดี บรรยากาศโอเค สะอาด    8.4
# 36     36                              ใกล้ BTS, แต่ไม่มีลิฟ    8.8
# 37     37                             ห้องพักดีแต่แคบไปหน่อย    7.2
# 38     38                            ใกล้ bts เดิน 2 นาทีถึง    8.8
# 39     39                 เดินทางสะดวก มี7-11ทางลงจากบีทีเอส    6.4
# 40     40                                           เสียงดัง    5.6
# 41     41  ที่พักสะอาด มีเครื่องซักผ้าล่างโฮสเทล กับให้กร...    7.6
# 42     42                               ใกล้ BTS เดินทางง่าย    8.0
# 43     43              ไม่มีลิฟท์พักชั้นสูงอาจจะไม่ค่อยสะดวก    6.8

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   ห้องเล็ก ไม่เก็บเสียง ได้ยินเสียงเดินชัดมาก แอ...    9.2
# 1   เดินทางสะดวกใกล้bts สะพานควาย ห้องพักเหมาะสมกั...    9.6
# 2   ห้องพักไม่กว้างแต่นอนหลับสบายไม่มีเสียงรบกวน ภ...    9.6
# 3   บริการดีมากๆๆๆๆๆเลยค่ะ มีที่จอดรถสำหรับคนมาพัก...    9.2
# 4   ห้องพักดี สะอาด สิ่งอำนวยความสะดวกที่จำเป็นครบ...   10.0
# 5   ข้อดี - ทำเลดี ใกล้ BTS รอบๆมีร้านอาหารตามสั่ง...    8.8
# 6   อยู่ใกล้บีทีเอสสะพานควายมาๆค่ะ แค่เดินลงมาจากบ...   10.0
# 7   Staffบริการดี ห้องสะอาด มาพักหลายครั้งแล้ว นอน...   10.0
# 8   ใกล้บีทีเอสมากๆ ลงมาเลี้ยวเข้าซอย ถึงเลย มีของ...   10.0
# 9   ที่พักสะอาดค่ะ พักห้องเดี่ยวอาจจะแคบไปหน่อยแต่...   10.0
# 10  ทำเลดี ติดรถไฟฟ้า bts เดินทางสะดวก มีที่จอดรถ ...    9.2
# 11  ที่พักสะดวกในการเดินทางลงจาก btsสะพานควาย (exi...    6.4
# 12  พนักงานเป็นกันเองดีค่ะ…ระบบความปลอดภัยดีมากค่ะ...    9.2
# 13  ดี : ใกล้ bts สะพานควาย เดิน 3 นาทีถึง, staff ...    8.8
# 14  เดินทางสะดวกมากค่ะ ติดบีทีเอสสะพานควาย เดินใกล...    8.4
# 15  ห้องพักค่อนข้างเล็ก โรงแรมอยู่ในซอย แต่ไม่ลึกม...   10.0
# 16  ทำเลที่ตั้งดีมากอยู่ในย่านช้อปปิ้ง ที่พักสะอาด...   10.0
# 17  ที่พักใกล้รถไฟฟ้าพนักงานบริการดีมาก ขนมด้านหน้...    9.2
# 18  ห้องเล็กกะทัดรัดดีครับ ความสะอาดดี ติสองเรื่อง...    8.0
# 19  ม่านปิดได้แค่ครึ่งเตียง ไม่มีที่นั่งเล่นที่เป็...    7.2
# 20  ห้องสะอาด ห้องน้ำแบ่งสัดส่วน ห้องอาบน้ำมีผนังก...   10.0
# 21  เตียงมีรอยเปื้อนแดงๆ เหมือนรอยลิป ไม่มีแปรงสีฟ...    3.6
# 22                                เดินทางสะดวกมากๆค่ะ   10.0
# 23                          บริการดีมากครับ ห้องสะอาด   10.0
# 24  ทำเลดี ใกล้รถไฟฟ้า เจ้าของร้านบริการดี ห้องนอน...    9.2
# 25                          เมาแล้วหาที่นอน แนะนำครับ    8.0
# 26  ห้องพักสะอาด มีไดร์เป่าผมให้ ที่พักก็อยู่ใกล้B...   10.0
# 27                                               อยู่   10.0
# 28  เครื่องทำน้ำอุ่น ไม่ร้อนเลย ทีวี จอเล็ก ค่ะ กร...    6.8
# 29                   แอร์มีกลิ่นเหม็นเวลาเปิดไปสักพัก    4.8
# 30  ทำเลดีครับ คิด BTS สะพานควาย เดินไม่ถึง 1 นาที...    8.4
# 31  อยู่ติดบีทีเอสสะพานควายเลยค่ะ เดินออกทางประตูห...    7.6
# 32                                  ไม่มีทิชชู่ในห้อง    8.0
# 33                         ใกล้ bts เดินทางง่าย สะดวก    8.8
# 34                            ประตูเปิดปิดเสียงดังมาก    5.2
# 35                 ขนาดห้องกำลังดี บรรยากาศโอเค สะอาด    8.4
# 36                              ใกล้ BTS, แต่ไม่มีลิฟ    8.8
# 37                             ห้องพักดีแต่แคบไปหน่อย    7.2
# 38                            ใกล้ bts เดิน 2 นาทีถึง    8.8
# 39                 เดินทางสะดวก มี7-11ทางลงจากบีทีเอส    6.4
# 40                                           เสียงดัง    5.6
# 41  ที่พักสะอาด มีเครื่องซักผ้าล่างโฮสเทล กับให้กร...    7.6
# 42                               ใกล้ BTS เดินทางง่าย    8.0
# 43              ไม่มีลิฟท์พักชั้นสูงอาจจะไม่ค่อยสะดวก    6.8

# %%
table.to_csv("Unseen_7.csv", encoding="utf-8")
