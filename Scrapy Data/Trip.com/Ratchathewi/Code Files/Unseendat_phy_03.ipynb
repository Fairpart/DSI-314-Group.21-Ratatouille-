# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %%
#ลบ ข้อความส่วนไม่ต้องการออก รีวิว
def abstract_review(review_ls):
    for i in review_ls:
        lenght = 0
        for j in i.split():
            if j == 'รีวิว':
                sentence = ' '.join(i.split()[0:lenght])
            lenght +=1
        Reviews_list.append(sentence)
    return Reviews_list

# %%
#ลบ ข้อความส่วนไม่ต้องการออก /5
def abstract_rating(rating_ls):
    for i in ratings_list:
        lenght = 0
        for j in i.split():
            if j == '/5':
                rating = ' '.join(i.split()[0:lenght])
            lenght +=1
        Ratings_list.append(rating)
    return Ratings_list

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://th.trip.com/hotels/detail/?cityId=359&hotelId=996754&checkIn=2022-12-11&checkOut=2022-12-12&adult=2&children=0&subStamp=480&crn=1&ages=&travelpurpose=0&curr=THB&link=title&hoteluniquekey=H4sIAAAAAAAAAOP6yMjFJMEkxMTBKPWMkWPJzpmvWYRYDU3NDIwMFgpb3K5wtOW6vrjgbIGDp3zr68Adx4odAngKGUCgwcthEqMt55vAHXKt3V4Ogt4n2G1n87o6KCkqsGjCVBjCGBbPOIPYOG6cY5RgiWJwYuP4tIBbgmUG46TXNhsZQTbYnnJ32MHIdIDxPwwwnmDcx7WA6c_TCXq7mKAaDgEZp3cCzTjFxHCJieEWE8MjJqipr5gYPjEx_IKpbGJm6GJmmMQMVT-LGapsETODFG9aqqWlUaJZsoFhmoGFgpDG2xdX57AZyUxiZArxOMUoYmhmZm5ibmphYA6k9IzyzHKN862YpRjdPBiD2AydzS3NLKO0uJhDg10EhT85nk-7Ku0gxRzi4aRofGSjXt7ik_ZaIJ4hjJfEWpKhG-KRsYC7gLGLkUOA0YMxgrGC8RUjSBUArJ3LloEBAAA&subChannel=&masterhotelid_tracelogid=fe992a6c01f08&barcurr=THB'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_6264\3462446407.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'รีวิวอะบลูม เอ็กซ์คลูซีฟ เซอร์วิส อพาร์ทเมนท์ - โปรโมชั่นโรงแรม 4 ดาวในกรุงเทพฯ | Trip.com'

# %%
driver.execute_script("window.scrollTo(0,1650)")

# %%
#Click all Review
sel = driver.find_element(By.XPATH,"/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[1]/div[2]/div/button[1]")
sel.click()

# %%
driver.execute_script("window.scrollTo(0,5400)")

# %%
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)
# Out:
# ทำเลที่ตั้งดีมากค่ะ อยู่ในซ.พหลโยธิน3 ขับรถไปสะดวก มีที่จอดรถเยอะมากค่ะ ห้องพักกว้างมากๆ สิ่งอำนวยความสะดวกครบ พนง.ดูแลดี แต่ติดอย่างเดียวเรื่องความสะอาดค่ะ เพราะห้องที่ไปพักตอนไปบนโซฟายังมีเส้นผมติดอยู่เลย และก็แม่บ้านลืมให้ผ้าเช็ดตัวไว้ค่ะ แต่ก็โทรไปขอตอนเที่ยงคืนกว่าๆ พนง.ก็รีบเอามาให้อย่างเร็วเลย ถือว่าแก้ปัญหาได้ดีเยี่ยมค่ะ แต่ถือว่าดีมาก คุ้มค่า ไว้ไปแถวนั้นจะพักที่เดิมแน่นอนค่ะ
# มีประโยชน์
# รีวิว 12 ตุลาคม 2022
# เป็นอีกสถานที่ที่มาบ่อยและก็จะมาใช้ยริการอีกต่อๆ เพราะติดใจบรรยากาศ ให้ความรู้สึกเหมือนอยู่บ้าน
# รีวิว 5 มีนาคม 2022
# ไปนอนห้อง 1105 ได้ยินเสียงเครื่องทำน้ำอุ่น หรือเสียงเปิดน้ำของห้องข้างๆ 1104 เสียงแอร์ดังในห้องนอน แต่โดยรวมสะดวกสบายดี เป็นส่วนตัว คราวหน้าก็จะไปพักอีกค่ะ
# รีวิว 30 ธันวาคม 2021
# โรงแรมสภาพโอเค โลเคชั่นดีมากๆ สะอาด เตียงยวบยาบไปนิดแต่พอนอนได้ รวมๆโอเค สำหรับนอนแค่คืนเดียว ไม่แย่นะ โอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอโอ
# รีวิว 21 ธันวาคม 2021
# ห้องพักสะอาดมากคะ
# มีประโยชน์
# รีวิว 25 มิถุนายน 2022
# ทำเลใกล้สถานีรถไฟฟ้า แต่ไม่มีอะไรอื่น มีรถบัสรับส่งสนามบินโดยตรง พนักงานเป็นกันเองสุด ๆ ห้องใหญ่มาก แต่ควรปรับปรุงเรื่องความสะอาด บริเวณสระว่ายน้ำสวยมากพร้อมบริการรถรับส่งฟรีไปยังสถานี
# ข้อความเดิม
# แปลโดย Google
# รีวิว 1 พฤศจิกายน 2022
# ที่ตั้งของโรงแรมอยู่ใกล้กับอารีย์ซึ่งก็โอเค ห้องพักเก่าและจำเป็นต้องปรับปรุง พนักงานไม่เป็นมิตร ขอกุญแจดอกที่สอง แต่พวกเขาไม่ปฏิบัติตามคำขอของฉัน ให้กุญแจแก่ฉันเพียงดอกเดียว เตียงควรจะเป็นราชินี แต่มันเล็กกว่าราชินี เครื่องปรับอากาศแย่มาก ห้องน้ำมีกลิ่นเหม็นบางครั้ง ฉันจะไม่จองที่นี่อีก
# ข้อความเดิม
# แปลโดย Google
# รีวิว 6 พฤศจิกายน 2022
# ถือว่า 3 ดาวก็โอเคนะ ห้องอาหาร Hungry Brown ในโรงแรมคือ มีความแตกต่างของแต่ละบุคคล แต่อาหารเป็นอย่างมาก โปรดทราบว่าไม่สามารถรับประทานได้โดยการบีบ
# ข้อความเดิม
# แปลโดย Google
# รีวิว 5 กันยายน 2022
# โรงแรมสะอาดเงียบสงบและสะดวกสบาย ผู้คนใจดี นี่ไม่ใช่ครั้งแรกที่ฉันมาพักที่นี่ จะกลับมาอีกแน่นอน
# ข้อความเดิม
# แปลโดย Google
# รีวิว 29 สิงหาคม 2022
# โรงแรมค่อนข้างเก่า ดูแลรักษาดี เป็นแบบบ้านที่ชอบ แอร์ดังเกินไป คนข้างบนได้ยินชัด (ข้อเสียใหญ่สุด)
# ข้อความเดิม
# แปลโดย Google
# รีวิว 26 กรกฎาคม 2022
# 4.7
# /5
# 5.0
# /5
# 5.0
# /5
# 4.0
# /5
# 5.0
# /5
# 4.2
# /5
# 3.0
# /5
# 3.0
# /5
# 5.0
# /5
# 4.0
# /5
# ['4.7', '5.0', '5.0', '4.0', '5.0', '4.2', '3.0', '3.0', '5.0', '4.0']

# %%
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()

# %%
driver.execute_script("window.scrollTo(0,4100)")
clear_list(ratings_list,reviews_list)

time.sleep(3)
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)

time.sleep(3)
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()
# Out:
# 酒店位置離開BTS站5分鐘步行。環境不錯。前台服務熱情。
# แปล
# รีวิว 16 ธันวาคม 2019
# 非常舒適，環境也好，出行方便。
# แปล
# รีวิว 6 มีนาคม 2020
# 每次來都住這裏，已經習慣了！很好的！
# แปล
# รีวิว 13 มกราคม 2020
# 很好，房間好大，泳池也很大，早餐一般
# แปล
# รีวิว 7 มกราคม 2020
# 很好，當晚很晚入住還可以免費升級房間
# แปล
# รีวิว 5 มกราคม 2020
# 空調聲音有點大其它都不錯
# แปล
# รีวิว 22 มกราคม 2020
# 什麼都好 好好好
# แปล
# รีวิว 27 มกราคม 2020
# 酒店非常好我很喜歡
# แปล
# รีวิว 26 กุมภาพันธ์ 2020
# 感覺一般般
# แปล
# รีวิว 18 กุมภาพันธ์ 2020
# 4.0
# /5
# 5.0
# /5
# 5.0
# /5
# 3.7
# /5
# 4.0
# /5
# 4.7
# /5
# 5.0
# /5
# 5.0
# /5
# 3.0
# /5
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6264\2624150784.py in <module>
#      18
#      19 time.sleep(3)
# ---> 20 next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
#      21 next_page.click()
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     859             value = '[name="%s"]' % value
#     860
# --> 861         return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#     862
#     863     def find_elements(self, by=By.ID, value: Optional[str] = None) -> List[WebElement]:
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     442         response = self.command_executor.execute(driver_command, params)
#     443         if response:
# --> 444             self.error_handler.check_response(response)
#     445             response["value"] = self._unwrap_value(response.get("value", None))
#     446             return response
#
# ~\anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     247                 alert_text = value["alert"].get("text")
#     248             raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 249         raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a"}
#   (Session info: MicrosoftEdge=108.0.1462.46)
# Stacktrace:
# Backtrace:
# 	Microsoft::Applications::Events::EventProperties::SetProperty [0x00007FF7F3E88542+9986]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3E25D72+1445218]
# 	Ordinal0 [0x00007FF7F3A0FC8C+654476]
# 	Ordinal0 [0x00007FF7F3A536C2+931522]
# 	Ordinal0 [0x00007FF7F3A53B10+932624]
# 	Ordinal0 [0x00007FF7F3A8FC17+1178647]
# 	Ordinal0 [0x00007FF7F3A73BDF+1063903]
# 	Ordinal0 [0x00007FF7F3A45FF4+876532]
# 	Ordinal0 [0x00007FF7F3A8CF70+1167216]
# 	Ordinal0 [0x00007FF7F3A739B3+1063347]
# 	Ordinal0 [0x00007FF7F3A4506A+872554]
# 	Ordinal0 [0x00007FF7F3A4402E+868398]
# 	Ordinal0 [0x00007FF7F3A4570F+874255]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3CE6108+135416]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3CD02CF+45759]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3CD374C+59196]
# 	Ordinal0 [0x00007FF7F3B1B1F4+1749492]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3E2B66A+1467994]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3E2FF04+1486580]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3E3005D+1486925]
# 	Microsoft::Applications::Events::EventProperty::EventProperty [0x00007FF7F3E37E1B+1519115]
# 	BaseThreadInitThunk [0x00007FFB85D7244D+29]
# 	RtlUserThreadStart [0x00007FFB8706DFB8+40]

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 39
# Reviews_list : 39

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   ทำเลที่ตั้งดีมากค่ะ อยู่ในซ.พหลโยธิน3 ขับรถไปส...    4.7
# 1   เป็นอีกสถานที่ที่มาบ่อยและก็จะมาใช้ยริการอีกต่...    5.0
# 2   ไปนอนห้อง 1105 ได้ยินเสียงเครื่องทำน้ำอุ่น หรื...    5.0
# 3   โรงแรมสภาพโอเค โลเคชั่นดีมากๆ สะอาด เตียงยวบยา...    4.0
# 4                        ห้องพักสะอาดมากคะ มีประโยชน์    5.0
# 5   ทำเลใกล้สถานีรถไฟฟ้า แต่ไม่มีอะไรอื่น มีรถบัสร...    4.2
# 6   ที่ตั้งของโรงแรมอยู่ใกล้กับอารีย์ซึ่งก็โอเค ห้...    3.0
# 7   ถือว่า 3 ดาวก็โอเคนะ ห้องอาหาร Hungry Brown ใน...    3.0
# 8   โรงแรมสะอาดเงียบสงบและสะดวกสบาย ผู้คนใจดี นี่ไ...    5.0
# 9   โรงแรมค่อนข้างเก่า ดูแลรักษาดี เป็นแบบบ้านที่ช...    4.0
# 10  แย่เพียงเล็กน้อยไกลจากศูนย์กลาง อพาร์ทเมนต์ที่...    4.5
# 11  ทำเลที่ตั้งดี ประตูห้องน้ำไม่สะอาด พบฝุ่นบนเฟอ...    3.7
# 12  ห้องใหญ่และสะอาดในห้องของเราไม่มีเสียงรบกวนมีค...    5.0
# 13  ที่ตั้งโรงแรม การบริการ ความสะอาด สิ่งอำนวยควา...    3.0
# 14   ทำเลดี บริการดีเยี่ยม. ข้อความเดิม แปลโดย Google    4.2
# 15  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@...    4.2
# 16                   ทำเลดี ข้อความเดิม แปลโดย Google    4.0
# 17  อัตราส่วนราคาประสิทธิภาพสูง ถูกสุขอนามัย การตก...    5.0
# 18  โรงแรมมีความสะดวกในการเดินทางมาก ใช้เวลาเพียง ...    4.5
# 19  ห้องพักมีขนาดใหญ่และทำเลที่ตั้งดี เฟอร์นิเจอร์...    4.7
# 20        บริการดีและทำเลดี ข้อความเดิม แปลโดย Google    5.0
# 21  สิบปีที่ไปกรุงเทพผมจะเลือก Bloom Hotel เฉพาะเพ...    3.5
# 22  นี่เป็นครั้งที่สองที่ฉันพัก โดยทั่วไป ฉันรู้สึ...    4.0
# 23  ฉันจองห้อง 2 ห้อง ห้องไม่เหมือนในรูป ความสะอาด...    2.5
# 24       ไม่เลวฉันชอบมันมาก ข้อความเดิม แปลโดย Google    5.0
# 25  รร พื้นไม้เสียงดังตึงตังโครมครามเป็นระยะ ห้องก...    4.0
# 26  방크기 .침대크기는 크고. 전철역에서 150m떨어진것이 장점입니다. 아침식사는 푸짐...    4.5
# 27  酒店稍舊，但是總體還可以。有一些房間有不好的氣味，有一些還好，看運氣吧！總體來說，對得起這個...    4.2
# 28    早餐很一般，品種很少。能加床，酒店式公寓適合帶孩子。酒店旁邊有地鐵，去哪地鐵還是可以的 แปล    3.5
# 29               水量不夠大，洗澡水，忽冷忽熱 泳池很大 景色美 交通方便 房間大 แปล    4.0
# 30                   酒店位置離開BTS站5分鐘步行。環境不錯。前台服務熱情。 แปล    4.0
# 31                                非常舒適，環境也好，出行方便。 แปล    5.0
# 32                             每次來都住這裏，已經習慣了！很好的！ แปล    5.0
# 33                             很好，房間好大，泳池也很大，早餐一般 แปล    3.7
# 34                             很好，當晚很晚入住還可以免費升級房間 แปล    4.0
# 35                                   空調聲音有點大其它都不錯 แปล    4.7
# 36                                       什麼都好 好好好 แปล    5.0
# 37                                      酒店非常好我很喜歡 แปล    5.0
# 38                                          感覺一般般 แปล    3.0

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  ทำเลที่ตั้งดีมากค่ะ อยู่ในซ.พหลโยธิน3 ขับรถไปส...    4.7
# 1       1  เป็นอีกสถานที่ที่มาบ่อยและก็จะมาใช้ยริการอีกต่...    5.0
# 2       2  ไปนอนห้อง 1105 ได้ยินเสียงเครื่องทำน้ำอุ่น หรื...    5.0
# 3       3  โรงแรมสภาพโอเค โลเคชั่นดีมากๆ สะอาด เตียงยวบยา...    4.0
# 4       4                       ห้องพักสะอาดมากคะ มีประโยชน์    5.0
# 5       5  ทำเลใกล้สถานีรถไฟฟ้า แต่ไม่มีอะไรอื่น มีรถบัสร...    4.2
# 6       6  ที่ตั้งของโรงแรมอยู่ใกล้กับอารีย์ซึ่งก็โอเค ห้...    3.0
# 7       7  ถือว่า 3 ดาวก็โอเคนะ ห้องอาหาร Hungry Brown ใน...    3.0
# 8       8  โรงแรมสะอาดเงียบสงบและสะดวกสบาย ผู้คนใจดี นี่ไ...    5.0
# 9       9  โรงแรมค่อนข้างเก่า ดูแลรักษาดี เป็นแบบบ้านที่ช...    4.0
# 10     10  แย่เพียงเล็กน้อยไกลจากศูนย์กลาง อพาร์ทเมนต์ที่...    4.5
# 11     11  ทำเลที่ตั้งดี ประตูห้องน้ำไม่สะอาด พบฝุ่นบนเฟอ...    3.7
# 12     12  ห้องใหญ่และสะอาดในห้องของเราไม่มีเสียงรบกวนมีค...    5.0
# 13     13  ที่ตั้งโรงแรม การบริการ ความสะอาด สิ่งอำนวยควา...    3.0
# 14     14   ทำเลดี บริการดีเยี่ยม. ข้อความเดิม แปลโดย Google    4.2
# 15     15  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@...    4.2
# 16     16                   ทำเลดี ข้อความเดิม แปลโดย Google    4.0
# 17     17  อัตราส่วนราคาประสิทธิภาพสูง ถูกสุขอนามัย การตก...    5.0
# 18     18  โรงแรมมีความสะดวกในการเดินทางมาก ใช้เวลาเพียง ...    4.5
# 19     19  ห้องพักมีขนาดใหญ่และทำเลที่ตั้งดี เฟอร์นิเจอร์...    4.7
# 20     20        บริการดีและทำเลดี ข้อความเดิม แปลโดย Google    5.0
# 21     21  สิบปีที่ไปกรุงเทพผมจะเลือก Bloom Hotel เฉพาะเพ...    3.5
# 22     22  นี่เป็นครั้งที่สองที่ฉันพัก โดยทั่วไป ฉันรู้สึ...    4.0
# 23     23  ฉันจองห้อง 2 ห้อง ห้องไม่เหมือนในรูป ความสะอาด...    2.5
# 24     24       ไม่เลวฉันชอบมันมาก ข้อความเดิม แปลโดย Google    5.0
# 25     25  รร พื้นไม้เสียงดังตึงตังโครมครามเป็นระยะ ห้องก...    4.0
# 26     26  방크기 .침대크기는 크고. 전철역에서 150m떨어진것이 장점입니다. 아침식사는 푸짐...    4.5
# 27     27  酒店稍舊，但是總體還可以。有一些房間有不好的氣味，有一些還好，看運氣吧！總體來說，對得起這個...    4.2
# 28     28    早餐很一般，品種很少。能加床，酒店式公寓適合帶孩子。酒店旁邊有地鐵，去哪地鐵還是可以的 แปล    3.5
# 29     29               水量不夠大，洗澡水，忽冷忽熱 泳池很大 景色美 交通方便 房間大 แปล    4.0
# 30     30                   酒店位置離開BTS站5分鐘步行。環境不錯。前台服務熱情。 แปล    4.0
# 31     31                                非常舒適，環境也好，出行方便。 แปล    5.0
# 32     32                             每次來都住這裏，已經習慣了！很好的！ แปล    5.0
# 33     33                             很好，房間好大，泳池也很大，早餐一般 แปล    3.7
# 34     34                             很好，當晚很晚入住還可以免費升級房間 แปล    4.0
# 35     35                                   空調聲音有點大其它都不錯 แปล    4.7
# 36     36                                       什麼都好 好好好 แปล    5.0
# 37     37                                      酒店非常好我很喜歡 แปล    5.0
# 38     38                                          感覺一般般 แปล    3.0

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   ทำเลที่ตั้งดีมากค่ะ อยู่ในซ.พหลโยธิน3 ขับรถไปส...    4.7
# 1   เป็นอีกสถานที่ที่มาบ่อยและก็จะมาใช้ยริการอีกต่...    5.0
# 2   ไปนอนห้อง 1105 ได้ยินเสียงเครื่องทำน้ำอุ่น หรื...    5.0
# 3   โรงแรมสภาพโอเค โลเคชั่นดีมากๆ สะอาด เตียงยวบยา...    4.0
# 4                        ห้องพักสะอาดมากคะ มีประโยชน์    5.0
# 5   ทำเลใกล้สถานีรถไฟฟ้า แต่ไม่มีอะไรอื่น มีรถบัสร...    4.2
# 6   ที่ตั้งของโรงแรมอยู่ใกล้กับอารีย์ซึ่งก็โอเค ห้...    3.0
# 7   ถือว่า 3 ดาวก็โอเคนะ ห้องอาหาร Hungry Brown ใน...    3.0
# 8   โรงแรมสะอาดเงียบสงบและสะดวกสบาย ผู้คนใจดี นี่ไ...    5.0
# 9   โรงแรมค่อนข้างเก่า ดูแลรักษาดี เป็นแบบบ้านที่ช...    4.0
# 10  แย่เพียงเล็กน้อยไกลจากศูนย์กลาง อพาร์ทเมนต์ที่...    4.5
# 11  ทำเลที่ตั้งดี ประตูห้องน้ำไม่สะอาด พบฝุ่นบนเฟอ...    3.7
# 12  ห้องใหญ่และสะอาดในห้องของเราไม่มีเสียงรบกวนมีค...    5.0
# 13  ที่ตั้งโรงแรม การบริการ ความสะอาด สิ่งอำนวยควา...    3.0
# 14   ทำเลดี บริการดีเยี่ยม. ข้อความเดิม แปลโดย Google    4.2
# 15  @@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@@...    4.2
# 16                   ทำเลดี ข้อความเดิม แปลโดย Google    4.0
# 17  อัตราส่วนราคาประสิทธิภาพสูง ถูกสุขอนามัย การตก...    5.0
# 18  โรงแรมมีความสะดวกในการเดินทางมาก ใช้เวลาเพียง ...    4.5
# 19  ห้องพักมีขนาดใหญ่และทำเลที่ตั้งดี เฟอร์นิเจอร์...    4.7
# 20        บริการดีและทำเลดี ข้อความเดิม แปลโดย Google    5.0
# 21  สิบปีที่ไปกรุงเทพผมจะเลือก Bloom Hotel เฉพาะเพ...    3.5
# 22  นี่เป็นครั้งที่สองที่ฉันพัก โดยทั่วไป ฉันรู้สึ...    4.0
# 23  ฉันจองห้อง 2 ห้อง ห้องไม่เหมือนในรูป ความสะอาด...    2.5
# 24       ไม่เลวฉันชอบมันมาก ข้อความเดิม แปลโดย Google    5.0
# 25  รร พื้นไม้เสียงดังตึงตังโครมครามเป็นระยะ ห้องก...    4.0
# 26  방크기 .침대크기는 크고. 전철역에서 150m떨어진것이 장점입니다. 아침식사는 푸짐...    4.5
# 27  酒店稍舊，但是總體還可以。有一些房間有不好的氣味，有一些還好，看運氣吧！總體來說，對得起這個...    4.2
# 28    早餐很一般，品種很少。能加床，酒店式公寓適合帶孩子。酒店旁邊有地鐵，去哪地鐵還是可以的 แปล    3.5
# 29               水量不夠大，洗澡水，忽冷忽熱 泳池很大 景色美 交通方便 房間大 แปล    4.0
# 30                   酒店位置離開BTS站5分鐘步行。環境不錯。前台服務熱情。 แปล    4.0
# 31                                非常舒適，環境也好，出行方便。 แปล    5.0
# 32                             每次來都住這裏，已經習慣了！很好的！ แปล    5.0
# 33                             很好，房間好大，泳池也很大，早餐一般 แปล    3.7
# 34                             很好，當晚很晚入住還可以免費升級房間 แปล    4.0
# 35                                   空調聲音有點大其它都不錯 แปล    4.7
# 36                                       什麼都好 好好好 แปล    5.0
# 37                                      酒店非常好我很喜歡 แปล    5.0
# 38                                          感覺一般般 แปล    3.0

# %%
table.to_csv("Unseen_3.csv", encoding="utf-8")
