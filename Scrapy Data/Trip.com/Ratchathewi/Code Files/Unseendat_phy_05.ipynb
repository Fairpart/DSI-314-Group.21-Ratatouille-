# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %%
#ลบ ข้อความส่วนไม่ต้องการออก รีวิว
def abstract_review(review_ls):
    for i in review_ls:
        lenght = 0
        for j in i.split():
            if j == 'รีวิว':
                sentence = ' '.join(i.split()[0:lenght])
            lenght +=1
        Reviews_list.append(sentence)
    return Reviews_list

# %%
#ลบ ข้อความส่วนไม่ต้องการออก /5
def abstract_rating(rating_ls):
    for i in ratings_list:
        lenght = 0
        for j in i.split():
            if j == '/5':
                rating = ' '.join(i.split()[0:lenght])
            lenght +=1
        Ratings_list.append(rating)
    return Ratings_list

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://th.trip.com/hotels/detail/?cityId=359&hotelId=25825890&checkIn=2022-12-11&checkOut=2022-12-12&adult=2&children=0&subStamp=480&crn=1&ages=&travelpurpose=0&curr=THB&link=title&hoteluniquekey=H4sIAAAAAAAAAOOaxsTFJMEkxMTBKNXNxLFqxuVai9-Cjq2vA3fIba1w8Ly-uMCWS7zWIYCnkAEEDoQ7TGLM4ASz7yx1EDx7BghqFjoo6XDc_tAlLqAlcefhfUsFVk2wCgYRB0MYw-KyQBArx35BCZYoBiVFBRZNmHmGMIbFM84gNo7575lASpyYOd6JzmB8tGQFz0ZGj4dVIuvaAx12MDIdYPwPA4wnGHfxL2B6CFSyiwmk_BATG8eBiUDtp5hYOQ4KS7BcYmK4xcTwiAlq6ismhk9MDL_AapuYIUq6mBkmMUO1zWKGKlzEzCDFm5ZqaWmUaJZsYJhmYKEgpPH2xdU5bEYykxiZQjxOMYoYmpmZm5ibWhiYAyk9ozyzXON8K2YpRjcPxiA2Z1M3Z0ujKC0u5hAPJ0HjIxv18haftJcC8RRhPC0QzxDGS2ItydAN8chYwF3A2MXIIcDowRjBWMH4ihGkCgAr_0tWpgEAAA&subChannel=&masterhotelid_tracelogid=fe992a6c01f08&barcurr=THB'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_20508\2049343154.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'รีวิวไวบ์ เบสท์เวสเทิร์น สนามเป้า - โปรโมชั่นโรงแรม 3 ดาวในกรุงเทพฯ | Trip.com'

# %%
driver.execute_script("window.scrollTo(0,1650)")

# %%
#Click all Review
sel = driver.find_element(By.XPATH,"/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[1]/div[2]/div/button[1]")
sel.click()

# %%
driver.execute_script("window.scrollTo(0,5400)")

# %%
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)
# Out:
# การบริการดีมากดีค่ะ ทั้งฝ่ายบริการ ห้อง ครบ ไม่มีอะไรที่ต้องหักค่ะ บรรยากาศดีมากด้วยค่ะ
# รีวิว 25 กรกฎาคม 2022
# บริการดีค่ะ สมราคา ใกล้บีทีเอส เดินทางสะดวก
# รีวิว 20 สิงหาคม 2022
# ชุดเครื่องนอนดี มีคุณภาพมากครับ หลับสบาย 😍
# รีวิว 7 สิงหาคม 2022
# ดีมากค่ะ ชอบมาก เดินทางสะดวก ติด bts เลย ห้องพักเก็บเสียงมาก ข้างๆเป็นผับ แล้วฝนก็ตกหนักมาก ไม่ได้ยินเสียงอะไรเลยค่ะ
# มีประโยชน์
# รีวิว 7 ตุลาคม 2022
# โรงแรมสะอาด พนักงานดูแลดีมากๆ ติดกับBTS แต่ไม่มีที่จอดรถของโรงแรม เหมาะกับผู้ที่เดินทางโดยไม่ได้ขับรถมาเองค่ะ
# มีประโยชน์ (1)
# รีวิว 2 กันยายน 2022
# สะดวกสบายใกล้แหล่งรวมสถานที่เที่ยวต่างๆ โรงแรมสะอาดมาก4ดาวไปเลย ใกล้ BTS ใกล้ทุกอย่าง ชอบมาก ห้องสะอาด คือแบบดีไปเลย ประทับใจ❤️
# มีประโยชน์ (1)
# รีวิว 15 สิงหาคม 2022
# โรงแรมขนาดไม่ใหญ่มากแต่สะอาด มีบริการฟิตเนสและห้องนั่งเล่น คุณภาพของห้องพักดีมีสิ่งอำนวยความสะดวกพร้อมและติดสถานีรถไฟฟ้า BTS สนามเป้า ทำให้เดินทางไปไหนสะดวกรวดเร็ว การให้บริการของพนักงานดี ภาพโดยรวมถือว่าดี
# มีประโยชน์
# รีวิว 30 กรกฎาคม 2022
# พักต่อเนื่องอีกคืนเพราะไม่ได้แพลนไว้ โดดยจองผ่านทริปสะดวกและโรงแรมก็ทราบโดยอัตโนมัตอ แนะนำพักที่นี่เงียบสงบและเดินทางสะดวก
# มีประโยชน์
# รีวิว 19 กรกฎาคม 2022
# ทำเลดี ติดรถไฟฟ้าสนามเป้า ห้องมีขนาดเล็ก แต่สะดวกสบาย มีตู้เย็น เตารีดไอน้ำ ไดร์เป่าผม ไว้บริการ
# มีประโยชน์
# รีวิว 14 กรกฎาคม 2022
# ไม่มีไดร์เป่าผม ไม่มีเตารีด ไม่มีแปรงสีฟัน แต่ทุกอย่างโอเค ห้องสะอาด เดินทางง่าย แต่ไม่โอเคกับเครื่องตรวจจับควันแสงไฟมันกระพริบทั้งคืนเลยนอนไม่ค่อยหลับ
# มีประโยชน์
# รีวิว 4 กรกฎาคม 2022
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 4.5
# /5
# 3.7
# /5
# 4.5
# /5
# 4.5
# /5
# ['5.0', '5.0', '5.0', '5.0', '5.0', '5.0', '4.5', '3.7', '4.5', '4.5']

# %%
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()

# %%
driver.execute_script("window.scrollTo(0,4100)")
clear_list(ratings_list,reviews_list)

time.sleep(3)
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)
# Out:
# สถานที่ที่ดีและดีพร้อมพนักงานที่เป็นมิตร
# ข้อความเดิม
# แปลโดย Google
# รีวิว 17 กันยายน 2022
# ผิวหนังคันและเกิดผื่นขึ้นจากผ้าปูที่นอน
# ข้อความเดิม
# แปลโดย Google
# รีวิว 31 กรกฎาคม 2022
# ที่จอดรถค่อนข้างจำกัดต้องแจ้งที่จอดรถ
# ข้อความเดิม
# แปลโดย Google
# รีวิว 23 มิถุนายน 2022
# โรงแรมใหม่ที่ดีเยี่ยม สะอาด ใกล้รถไฟฟ้าใต้ดินมากจริงๆ 2 นาที ห้องพักมีทุกสิ่งที่คุณต้องการ คุณสามารถชงกาแฟในห้องได้ฟรีในเครื่องชงกาแฟแคปซูล นอกจากนี้ คุณสามารถสั่งอาหารเช้าได้ ซึ่งอยู่ห่างจากร้าน 7-11 ในระยะที่สามารถเดินไปถึงได้ ตัวเลขดูใหญ่ขึ้นในภาพ คุ้มค่ากับเงินที่เสียไป
# ข้อความเดิม
# แปลโดย Google
# รีวิว 13 มกราคม 2020
# ห้องพักสะอาดและทันสมัยมาก อย่างไรก็ตาม มันไม่กว้างขวางมากนัก สถานที่ตั้งสะดวกมาก. ตั้งอยู่ใกล้สถานีรถไฟฟ้า BTS สนามเป้า
# ข้อความเดิม
# แปลโดย Google
# รีวิว 24 มิถุนายน 2020
# เตียงก็ดี
# ข้อความเดิม
# แปลโดย Google
# รีวิว 21 กุมภาพันธ์ 2022
# โรงแรมที่ยอดเยี่ยมมาก ยกเว้นห้องที่เล็กกว่าเล็กน้อย ใกล้รถไฟฟ้าใต้ดิน การจราจรค่อนข้างสะดวก เหมาะสำหรับเพื่อนครั้งแรก คราวหน้าจะมาพักอีก
# ข้อความเดิม
# แปลโดย Google
# รีวิว 28 กุมภาพันธ์ 2020
# โรงแรมนี้ใกล้ BTS สนามเป้ามาก เดินเพียง 5 ก้าว ห้องพักสะดวกสบายและสะอาดมาก พนักงานช่วยเหลือดีและเป็นกันเองมาก ฉันจะแนะนำโรงแรมนี้และจะกลับมาอีกครั้ง
# ข้อความเดิม
# แปลโดย Google
# รีวิว 26 กุมภาพันธ์ 2020
# อาหารเช้าก็ธรรมดาทุกวันเหมือนกันไม่มีอะไรเปลี่ยนแปลง ทำเลที่ตั้งสะดวกติดกับบีทีเอส ห้องพักเล็กมากและแออัด ฉันรู้สึกว่าฉันไม่สามารถเก็บกระเป๋าได้เยอะ มันมีเสียงดังมากในตอนกลางคืนใกล้กับริมถนนและหัวรถจักรก็ดังสุด ๆ ราคาที่อยู่อาศัยในเดือนมกราคมนั้นสูงมาก
# ข้อความเดิม
# แปลโดย Google
# รีวิว 15 มกราคม 2020
# ไม่มีห้องหันหน้าเข้าหาถนนเงียบมาก โรงแรมมีขนาดเล็ก แต่มีรายละเอียดประณีตมาก อาหารเช้าเรียบง่าย การรับประทานอาหารในบริเวณใกล้เคียงไม่สะดวกเกินไปมีประตูถัดไป 7-11 และมีห้องนวด อยู่ห่างจากย่านธุรกิจสยาม BTS 4-5 นาที 30-33 บาทสะดวกมาก ที่จอดรถสะดวก
# ข้อความเดิม
# แปลโดย Google
# รีวิว 17 ธันวาคม 2019
# 5.0
# /5
# 2.0
# /5
# 3.7
# /5
# 5.0
# /5
# 4.0
# /5
# 4.0
# /5
# 4.0
# /5
# 5.0
# /5
# 4.5
# /5
# 5.0
# /5
# ['5.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '4.5',
#  '3.7',
#  '4.5',
#  '4.5',
#  '4.7',
#  '5.0',
#  '1.0',
#  '4.0',
#  '4.7',
#  '5.0',
#  '4.0',
#  '5.0',
#  '5.0',
#  '4.7',
#  '5.0',
#  '4.2',
#  '4.2',
#  '4.7',
#  '5.0',
#  '4.7',
#  '4.7',
#  '3.0',
#  '5.0',
#  '4.5',
#  '5.0',
#  '2.0',
#  '3.7',
#  '5.0',
#  '4.0',
#  '4.0',
#  '4.0',
#  '5.0',
#  '4.5',
#  '5.0']

# %%
time.sleep(3)
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 40
# Reviews_list : 40

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   การบริการดีมากดีค่ะ ทั้งฝ่ายบริการ ห้อง ครบ ไม...    5.0
# 1         บริการดีค่ะ สมราคา ใกล้บีทีเอส เดินทางสะดวก    5.0
# 2          ชุดเครื่องนอนดี มีคุณภาพมากครับ หลับสบาย 😍    5.0
# 3   ดีมากค่ะ ชอบมาก เดินทางสะดวก ติด bts เลย ห้องพ...    5.0
# 4   โรงแรมสะอาด พนักงานดูแลดีมากๆ ติดกับBTS แต่ไม่...    5.0
# 5   สะดวกสบายใกล้แหล่งรวมสถานที่เที่ยวต่างๆ โรงแรม...    5.0
# 6   โรงแรมขนาดไม่ใหญ่มากแต่สะอาด มีบริการฟิตเนสและ...    4.5
# 7   พักต่อเนื่องอีกคืนเพราะไม่ได้แพลนไว้ โดดยจองผ่...    3.7
# 8   ทำเลดี ติดรถไฟฟ้าสนามเป้า ห้องมีขนาดเล็ก แต่สะ...    4.5
# 9   ไม่มีไดร์เป่าผม ไม่มีเตารีด ไม่มีแปรงสีฟัน แต่...    4.5
# 10  เป็นโรงแรมที่ส่วนตัวมาก ทางเดินคือโรงหนังเลยค่...    4.7
# 11  โรงแรมดี ติดรถไฟฟ้า bts เดินทางสะดวก กลับมืดกล...    5.0
# 12  พนักงานที่จุดเช็คอิน ไม่แจ้งรายละเอียดเรื่องเง...    1.0
# 13  เป็นโรงแรมที่สวย ทางเดินคล้ายๆกับโรงหนัง ห้องพ...    4.0
# 14  บริการดีมาก แต่ค่ามัดจำแพงไปนิด ห้องเขล็ก แต่ส...    4.7
# 15  คือ ห้องหลักร้อย บริการความปลอดภัยระดับเพลตนิน...    5.0
# 16  โรงแรมสะอาด เจ้าหน้า บริการดี เดินทางสะดวก มีป...    4.0
# 17     เหมาะกับการแวะพัก เพราะเดินทางสะดวก มีประโยชน์    5.0
# 18                        ทำเลดี เตียงสบาย มีประโยชน์    5.0
# 19     อธิบายน้อยไปหน่อย อาหารดี อร่อยมากๆ มีประโยชน์    4.7
# 20  ดีมากเลยค่ะ ที่พักสะอาด พนักงานและแม่บ้านน่ารั...    5.0
# 21  สถานที่ตั้งดีมาก อยู่ติดสถานีรถไฟฟ้าเลย มีประโ...    4.2
# 22  ราคาไม่แพงและทำเลดีมากใกล้สถานีรถไฟฟ้า จะมาที่...    4.2
# 23  โรงแรมเล็กแต่สะดวกสบายมาก มีอุปกรณ์ครบทุกอย่าง...    4.7
# 24  ที่ตั้งโรงแรมดีมาก ติด BTS แต่ย่านไม่มีเสียงดั...    5.0
# 25           แบน สวย คิดบวก ข้อความเดิม แปลโดย Google    4.7
# 26  โรงแรมมีทำเลที่ดีเยี่ยมติดกับสถานีรถไฟฟ้าบีทีเ...    4.7
# 27  ห้องกลางๆ โลเคชั่นดี แต่ห้องเล็กกว่าที่คิดและค...    3.0
# 28  พนักงานดี สะอาด และใกล้สถานีรถไฟฟ้า โดยรวมโอเค...    5.0
# 29        ดีใกล้btsสนามเป้า ข้อความเดิม แปลโดย Google    4.5
# 30  สถานที่ที่ดีและดีพร้อมพนักงานที่เป็นมิตร ข้อคว...    5.0
# 31  ผิวหนังคันและเกิดผื่นขึ้นจากผ้าปูที่นอน ข้อควา...    2.0
# 32  ที่จอดรถค่อนข้างจำกัดต้องแจ้งที่จอดรถ ข้อความเ...    3.7
# 33  โรงแรมใหม่ที่ดีเยี่ยม สะอาด ใกล้รถไฟฟ้าใต้ดินม...    5.0
# 34  ห้องพักสะอาดและทันสมัยมาก อย่างไรก็ตาม มันไม่ก...    4.0
# 35                เตียงก็ดี ข้อความเดิม แปลโดย Google    4.0
# 36  โรงแรมที่ยอดเยี่ยมมาก ยกเว้นห้องที่เล็กกว่าเล็...    4.0
# 37  โรงแรมนี้ใกล้ BTS สนามเป้ามาก เดินเพียง 5 ก้าว...    5.0
# 38  อาหารเช้าก็ธรรมดาทุกวันเหมือนกันไม่มีอะไรเปลี่...    4.5
# 39  ไม่มีห้องหันหน้าเข้าหาถนนเงียบมาก โรงแรมมีขนาด...    5.0

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  การบริการดีมากดีค่ะ ทั้งฝ่ายบริการ ห้อง ครบ ไม...    5.0
# 1       1        บริการดีค่ะ สมราคา ใกล้บีทีเอส เดินทางสะดวก    5.0
# 2       2         ชุดเครื่องนอนดี มีคุณภาพมากครับ หลับสบาย 😍    5.0
# 3       3  ดีมากค่ะ ชอบมาก เดินทางสะดวก ติด bts เลย ห้องพ...    5.0
# 4       4  โรงแรมสะอาด พนักงานดูแลดีมากๆ ติดกับBTS แต่ไม่...    5.0
# 5       5  สะดวกสบายใกล้แหล่งรวมสถานที่เที่ยวต่างๆ โรงแรม...    5.0
# 6       6  โรงแรมขนาดไม่ใหญ่มากแต่สะอาด มีบริการฟิตเนสและ...    4.5
# 7       7  พักต่อเนื่องอีกคืนเพราะไม่ได้แพลนไว้ โดดยจองผ่...    3.7
# 8       8  ทำเลดี ติดรถไฟฟ้าสนามเป้า ห้องมีขนาดเล็ก แต่สะ...    4.5
# 9       9  ไม่มีไดร์เป่าผม ไม่มีเตารีด ไม่มีแปรงสีฟัน แต่...    4.5
# 10     10  เป็นโรงแรมที่ส่วนตัวมาก ทางเดินคือโรงหนังเลยค่...    4.7
# 11     11  โรงแรมดี ติดรถไฟฟ้า bts เดินทางสะดวก กลับมืดกล...    5.0
# 12     12  พนักงานที่จุดเช็คอิน ไม่แจ้งรายละเอียดเรื่องเง...    1.0
# 13     13  เป็นโรงแรมที่สวย ทางเดินคล้ายๆกับโรงหนัง ห้องพ...    4.0
# 14     14  บริการดีมาก แต่ค่ามัดจำแพงไปนิด ห้องเขล็ก แต่ส...    4.7
# 15     15  คือ ห้องหลักร้อย บริการความปลอดภัยระดับเพลตนิน...    5.0
# 16     16  โรงแรมสะอาด เจ้าหน้า บริการดี เดินทางสะดวก มีป...    4.0
# 17     17     เหมาะกับการแวะพัก เพราะเดินทางสะดวก มีประโยชน์    5.0
# 18     18                        ทำเลดี เตียงสบาย มีประโยชน์    5.0
# 19     19     อธิบายน้อยไปหน่อย อาหารดี อร่อยมากๆ มีประโยชน์    4.7
# 20     20  ดีมากเลยค่ะ ที่พักสะอาด พนักงานและแม่บ้านน่ารั...    5.0
# 21     21  สถานที่ตั้งดีมาก อยู่ติดสถานีรถไฟฟ้าเลย มีประโ...    4.2
# 22     22  ราคาไม่แพงและทำเลดีมากใกล้สถานีรถไฟฟ้า จะมาที่...    4.2
# 23     23  โรงแรมเล็กแต่สะดวกสบายมาก มีอุปกรณ์ครบทุกอย่าง...    4.7
# 24     24  ที่ตั้งโรงแรมดีมาก ติด BTS แต่ย่านไม่มีเสียงดั...    5.0
# 25     25           แบน สวย คิดบวก ข้อความเดิม แปลโดย Google    4.7
# 26     26  โรงแรมมีทำเลที่ดีเยี่ยมติดกับสถานีรถไฟฟ้าบีทีเ...    4.7
# 27     27  ห้องกลางๆ โลเคชั่นดี แต่ห้องเล็กกว่าที่คิดและค...    3.0
# 28     28  พนักงานดี สะอาด และใกล้สถานีรถไฟฟ้า โดยรวมโอเค...    5.0
# 29     29        ดีใกล้btsสนามเป้า ข้อความเดิม แปลโดย Google    4.5
# 30     30  สถานที่ที่ดีและดีพร้อมพนักงานที่เป็นมิตร ข้อคว...    5.0
# 31     31  ผิวหนังคันและเกิดผื่นขึ้นจากผ้าปูที่นอน ข้อควา...    2.0
# 32     32  ที่จอดรถค่อนข้างจำกัดต้องแจ้งที่จอดรถ ข้อความเ...    3.7
# 33     33  โรงแรมใหม่ที่ดีเยี่ยม สะอาด ใกล้รถไฟฟ้าใต้ดินม...    5.0
# 34     34  ห้องพักสะอาดและทันสมัยมาก อย่างไรก็ตาม มันไม่ก...    4.0
# 35     35                เตียงก็ดี ข้อความเดิม แปลโดย Google    4.0
# 36     36  โรงแรมที่ยอดเยี่ยมมาก ยกเว้นห้องที่เล็กกว่าเล็...    4.0
# 37     37  โรงแรมนี้ใกล้ BTS สนามเป้ามาก เดินเพียง 5 ก้าว...    5.0
# 38     38  อาหารเช้าก็ธรรมดาทุกวันเหมือนกันไม่มีอะไรเปลี่...    4.5
# 39     39  ไม่มีห้องหันหน้าเข้าหาถนนเงียบมาก โรงแรมมีขนาด...    5.0

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   การบริการดีมากดีค่ะ ทั้งฝ่ายบริการ ห้อง ครบ ไม...    5.0
# 1         บริการดีค่ะ สมราคา ใกล้บีทีเอส เดินทางสะดวก    5.0
# 2          ชุดเครื่องนอนดี มีคุณภาพมากครับ หลับสบาย 😍    5.0
# 3   ดีมากค่ะ ชอบมาก เดินทางสะดวก ติด bts เลย ห้องพ...    5.0
# 4   โรงแรมสะอาด พนักงานดูแลดีมากๆ ติดกับBTS แต่ไม่...    5.0
# 5   สะดวกสบายใกล้แหล่งรวมสถานที่เที่ยวต่างๆ โรงแรม...    5.0
# 6   โรงแรมขนาดไม่ใหญ่มากแต่สะอาด มีบริการฟิตเนสและ...    4.5
# 7   พักต่อเนื่องอีกคืนเพราะไม่ได้แพลนไว้ โดดยจองผ่...    3.7
# 8   ทำเลดี ติดรถไฟฟ้าสนามเป้า ห้องมีขนาดเล็ก แต่สะ...    4.5
# 9   ไม่มีไดร์เป่าผม ไม่มีเตารีด ไม่มีแปรงสีฟัน แต่...    4.5
# 10  เป็นโรงแรมที่ส่วนตัวมาก ทางเดินคือโรงหนังเลยค่...    4.7
# 11  โรงแรมดี ติดรถไฟฟ้า bts เดินทางสะดวก กลับมืดกล...    5.0
# 12  พนักงานที่จุดเช็คอิน ไม่แจ้งรายละเอียดเรื่องเง...    1.0
# 13  เป็นโรงแรมที่สวย ทางเดินคล้ายๆกับโรงหนัง ห้องพ...    4.0
# 14  บริการดีมาก แต่ค่ามัดจำแพงไปนิด ห้องเขล็ก แต่ส...    4.7
# 15  คือ ห้องหลักร้อย บริการความปลอดภัยระดับเพลตนิน...    5.0
# 16  โรงแรมสะอาด เจ้าหน้า บริการดี เดินทางสะดวก มีป...    4.0
# 17     เหมาะกับการแวะพัก เพราะเดินทางสะดวก มีประโยชน์    5.0
# 18                        ทำเลดี เตียงสบาย มีประโยชน์    5.0
# 19     อธิบายน้อยไปหน่อย อาหารดี อร่อยมากๆ มีประโยชน์    4.7
# 20  ดีมากเลยค่ะ ที่พักสะอาด พนักงานและแม่บ้านน่ารั...    5.0
# 21  สถานที่ตั้งดีมาก อยู่ติดสถานีรถไฟฟ้าเลย มีประโ...    4.2
# 22  ราคาไม่แพงและทำเลดีมากใกล้สถานีรถไฟฟ้า จะมาที่...    4.2
# 23  โรงแรมเล็กแต่สะดวกสบายมาก มีอุปกรณ์ครบทุกอย่าง...    4.7
# 24  ที่ตั้งโรงแรมดีมาก ติด BTS แต่ย่านไม่มีเสียงดั...    5.0
# 25           แบน สวย คิดบวก ข้อความเดิม แปลโดย Google    4.7
# 26  โรงแรมมีทำเลที่ดีเยี่ยมติดกับสถานีรถไฟฟ้าบีทีเ...    4.7
# 27  ห้องกลางๆ โลเคชั่นดี แต่ห้องเล็กกว่าที่คิดและค...    3.0
# 28  พนักงานดี สะอาด และใกล้สถานีรถไฟฟ้า โดยรวมโอเค...    5.0
# 29        ดีใกล้btsสนามเป้า ข้อความเดิม แปลโดย Google    4.5
# 30  สถานที่ที่ดีและดีพร้อมพนักงานที่เป็นมิตร ข้อคว...    5.0
# 31  ผิวหนังคันและเกิดผื่นขึ้นจากผ้าปูที่นอน ข้อควา...    2.0
# 32  ที่จอดรถค่อนข้างจำกัดต้องแจ้งที่จอดรถ ข้อความเ...    3.7
# 33  โรงแรมใหม่ที่ดีเยี่ยม สะอาด ใกล้รถไฟฟ้าใต้ดินม...    5.0
# 34  ห้องพักสะอาดและทันสมัยมาก อย่างไรก็ตาม มันไม่ก...    4.0
# 35                เตียงก็ดี ข้อความเดิม แปลโดย Google    4.0
# 36  โรงแรมที่ยอดเยี่ยมมาก ยกเว้นห้องที่เล็กกว่าเล็...    4.0
# 37  โรงแรมนี้ใกล้ BTS สนามเป้ามาก เดินเพียง 5 ก้าว...    5.0
# 38  อาหารเช้าก็ธรรมดาทุกวันเหมือนกันไม่มีอะไรเปลี่...    4.5
# 39  ไม่มีห้องหันหน้าเข้าหาถนนเงียบมาก โรงแรมมีขนาด...    5.0

# %%
table.to_csv("Unseen_5.csv", encoding="utf-8")
