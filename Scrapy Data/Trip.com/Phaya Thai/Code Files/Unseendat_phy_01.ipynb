# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %%
#ลบ ข้อความส่วนไม่ต้องการออก รีวิว
def abstract_review(review_ls):
    for i in review_ls:
        lenght = 0
        for j in i.split():
            if j == 'รีวิว':
                sentence = ' '.join(i.split()[0:lenght])
            lenght +=1
        Reviews_list.append(sentence)
    return Reviews_list

# %%
#ลบ ข้อความส่วนไม่ต้องการออก /5
def abstract_rating(rating_ls):
    for i in ratings_list:
        lenght = 0
        for j in i.split():
            if j == '/5':
                rating = ' '.join(i.split()[0:lenght])
            lenght +=1
        Ratings_list.append(rating)
    return Ratings_list

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://th.trip.com/hotels/detail/?cityId=359&hotelId=996752&checkIn=2022-12-10&checkOut=2022-12-11&adult=2&children=0&subStamp=1340&crn=1&ages=&travelpurpose=0&curr=THB&link=button&hoteluniquekey=H4sIAAAAAAAAAOP6ysjFJMEkxMTBKPWKkWP--9ePWIQ4jc1NTAwNjIBwC6vFQm3HNBAQqnHwXOf-sEqkrcEhgKeQAQxCHSYx2nIuKbDlus4c5iB49gwQzAl0UFJUYNGEqTCEMSyecQaxcfw7wiTBEsXgxMbx_6qQBMsMxgmvbTYyXl8MNON5sMMORqYDjP9hgPEE4zHBBUy9LX3iu5igGg4BGYe2Ac04xcRwiYnhFhPDIyaoqa-YGD4xMfyCqWxiZuhiZpjEDFU_ixmqbBEzgxSvgVGyRZqFuaVZUpJlooKQxu2Fl-awGclMYmQK8TjFKGJoZmZuYm5qYWAOpPSM8sxyjfOtmKUY3TwYg9gMLBzNzU2jtLiYQ4NdBIU_OZ5PuyrtIMUc4uGkaHxko17e4pP2WiCeIYyXxFqSoRvikTGfu4Cxi5FDgNGDMYKxgvEVI0gVABkdTKOFAQAA&subChannel=&masterhotelid_tracelogid=02c8f8796bb9a'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_19748\2470350783.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'รีวิววิค ทรี แบงคอก (SHA Plus+) - โปรโมชั่นโรงแรม 4 ดาวในกรุงเทพฯ | Trip.com'

# %%
driver.execute_script("window.scrollTo(0,1650)")

# %%
#Click all Review
sel = driver.find_element(By.XPATH,"/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[1]/div[2]/div/button[1]")
sel.click()

# %%
driver.execute_script("window.scrollTo(0,5400)")

# %%
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)
# Out:
# มาพักเป็นครั้งที่ 3 แล้วค่ะ ประทับใจตั้งแต่ทำเลของโรงแรม การบริการ ห้องพัก ความสะอาด
# รีวิว 6 ธันวาคม 2022
# บริการดี ประทับใจ เดินทางสะดวกครับ ใกล้แหล่งของกิน ใกล้รถไฟฟ้า มาพัก 2 ครั้งแล้ว
# รีวิว 1 ธันวาคม 2022
# การบริการดีเเละห้องสวยงามห้องน้ำสะอาดมีที่จอดรถใต้ดินสองชั้น
# รีวิว 12 พฤศจิกายน 2022
# ทำเลโรงแรมดีมากค่ะ ห้องกว้างห้องน้ำก็กว้างสมราคา ทางเดินห้องอาจจะมืดๆไปหน่อย แต่ภายในห้องสวยค่ะไม่ได้แย่เลย พนักงานบริการดีพูดจาเพราะไม่เหวี่ยง ไปไหนสะดวกมาคนเดียวก็ไม่น่ากลัวค่ะ ใกล้สถานที่ คาเฟ่ ร้านอาหารต่างๆ *ติดตรงเข้าพักคืนแรกที่นอนมีฝุ่นนิดหน่อย เหมือนไม่ได้ใช้งาน แต่คืนต่อไปแม่บ้านทำความสะอาดคือดีมากค่ะ ทุกอย่างสะอาดเอื่ยม *แต่เสียดายสัญญาณเน็ตภายในโรงแรมไม่แรง นอกนั้นดีหมด
# รีวิว 20 กรกฎาคม 2022
# ห้องดีมากสะอาดห้องน้ำสะอาดเเอร์เย็นฉ่ำพนักงานบริการดีติดรถไฟฟ้าBTS
# รีวิว 22 สิงหาคม 2022
# ห้องสะอาด แอร์เย็นไม่หนาวมาก อากาศปลอดกลิ่นบุหรี่ ปลอดภัย
# รีวิว 29 สิงหาคม 2022
# ใกล้bts เดินไม่นานก็ถึง พนักงานบริการดี สะดวกสบายชอบมาก
# รีวิว 13 กรกฎาคม 2022
# ใช่บริการประจำห้องสะอาดเตียงนุ่มมีที่จอดรถ มีร้านอาหารเดินทางสะดวกใกล้บีทีเอส ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️🍂🍂🍂🍂🍂🍂🍂❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️ชอบมากๆค่ะ ประทับใจจจจจจจ ❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️❤️
# รีวิว 22 กุมภาพันธ์ 2022
# โดยรวมดีมากคะ ห้องสะอาด หองกว้าง เตียงนอนหลับสบาย แอร์เย็นการเดินทางมารร.สะดวกและไม่ไกล แนะนำเลยคะว่าควรกลับมาพักอีก
# รีวิว 20 กุมภาพันธ์ 2022
# อยากให้ขยายที่จอดรถเพิ่มขึ้น ที่จอดน้อยไป ทุกอย่างดี ยกเว้น ที่จอดรถ
# มีประโยชน์
# รีวิว 2 ธันวาคม 2022
# 4.5
# /5
# 5.0
# /5
# 3.7
# /5
# 4.7
# /5
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 4.5
# /5
# 3.7
# /5
# ['4.5', '5.0', '3.7', '4.7', '5.0', '5.0', '5.0', '5.0', '4.5', '3.7']

# %%
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()

# %%
driver.execute_script("window.scrollTo(0,4100)")
clear_list(ratings_list,reviews_list)

time.sleep(3)
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()

time.sleep(3)
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)
# Out:
# สะดวก ดี
# มีประโยชน์
# รีวิว 1 เมษายน 2022
# เยี่ยม
# มีประโยชน์
# รีวิว 6 มกราคม 2022
# สะอาด ราคาถูก เสียงไม่รบกวน
# มีประโยชน์
# รีวิว 27 กันยายน 2020
# ฟรีบัตรบีทีเอสหนึ่งใบ ทำเลดีใกล้บีทีเอสและเข้าถึงห้างสรรพสินค้ามากมายได้อย่างสม่ำเสมอ
# ข้อความเดิม
# แปลโดย Google
# รีวิว 11 พฤศจิกายน 2022
# ที่ตั้ง: เดินทางสะดวกมาก ใกล้โรงพยาบาลพญาไท 2 และห้างสรรพสินค้าอื่นๆ ห้องพัก: สะอาดและสะดวกสบาย พนักงาน: เป็นกันเองและมีความรับผิดชอบ ราคา: ยอมรับได้
# ข้อความเดิม
# แปลโดย Google
# รีวิว 7 ตุลาคม 2022
# ห้องพักมีขนาดเล็กและสะอาดเล็กน้อย แต่การคมนาคมสะดวก ใกล้สถานีรถไฟฟ้าใต้ดิน ห่างออกไปเพียงสองป้ายเท่านั้น เหมาะสำหรับนักธุรกิจที่เดินทางมาทำธุรกิจหรือทริปครอบครัว ฉันจะพิจารณากลับมาอีกในอนาคต !
# ข้อความเดิม
# แปลโดย Google
# รีวิว 6 สิงหาคม 2022
# โรงแรมมีทำเลที่ดีมากด้านหน้าและการทำความสะอาดก็เป็นมืออาชีพมาก
# ข้อความเดิม
# แปลโดย Google
# รีวิว 2 ตุลาคม 2022
# โรงแรมนี้มีประโยชน์ใช้สอยและเรียบง่าย ใช่ ห้องพักมีสิ่งที่คุณต้องการ แต่มีขนาดเล็กมากและโรงแรมรู้สึกเหมือนเป็นโฮสเทลไม่ใช่โรงแรม มันเงียบและทำเลโอเค แต่ตอนนี้หลังโควิด มีโรงแรมที่ดีกว่านี้ออกมาในราคาเท่ากัน
# ข้อความเดิม
# แปลโดย Google
# รีวิว 31 พฤษภาคม 2022
# โรงแรมอยู่ใกล้สถานีรถไฟฟ้าถึงแม้จะไม่มี￼ร้านอาหาร￼อยู่รอบๆ แต่มีร้านสะดวกซื้ออยู่ริมถนน ห้องพักสะอาด สบาย และสิ่งแวดล้อมเงียบสงบ สามารถนั่ง BTS ได้สองสถานี￼ สถานีรถไฟสนามบิน￼
# ข้อความเดิม
# แปลโดย Google
# รีวิว 1 พฤศจิกายน 2022
# โรงแรมเรียบง่าย ตั้งอยู่ที่สถานีรถไฟฟ้า BTS สถานีสนามเป้า มีลิฟต์ที่ทางออก และใช้เวลาเดินเพียง 3 นาทีจากสถานี มี 7-11 อยู่บริเวณใกล้เคียง แท็กซี่ทั่วไปและรถตุ๊กตุ๊กรู้ทาง ประมาณ 300 บาทจาก สนามบินไปยังโรงแรม
# ข้อความเดิม
# แปลโดย Google
# รีวิว 4 พฤศจิกายน 2022
# 4.0
# /5
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 5.0
# /5
# 4.5
# /5
# 4.7
# /5
# 3.2
# /5
# 4.5
# /5
# 4.0
# /5
# ['4.5',
#  '5.0',
#  '3.7',
#  '4.7',
#  '5.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '4.5',
#  '3.7',
#  '5.0',
#  '5.0',
#  '4.5',
#  '3.2',
#  '4.0',
#  '5.0',
#  '5.0',
#  '4.0',
#  '4.0',
#  '4.5',
#  '4.7',
#  '4.0',
#  '3.5',
#  '4.5',
#  '4.2',
#  '4.0',
#  '5.0',
#  '4.0',
#  '4.0',
#  '5.0',
#  '4.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '4.5',
#  '4.7',
#  '3.2',
#  '4.5',
#  '4.0']

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 40
# Reviews_list : 40

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   มาพักเป็นครั้งที่ 3 แล้วค่ะ ประทับใจตั้งแต่ทำเ...    4.5
# 1   บริการดี ประทับใจ เดินทางสะดวกครับ ใกล้แหล่งขอ...    5.0
# 2   การบริการดีเเละห้องสวยงามห้องน้ำสะอาดมีที่จอดร...    3.7
# 3   ทำเลโรงแรมดีมากค่ะ ห้องกว้างห้องน้ำก็กว้างสมรา...    4.7
# 4   ห้องดีมากสะอาดห้องน้ำสะอาดเเอร์เย็นฉ่ำพนักงานบ...    5.0
# 5   ห้องสะอาด แอร์เย็นไม่หนาวมาก อากาศปลอดกลิ่นบุห...    5.0
# 6   ใกล้bts เดินไม่นานก็ถึง พนักงานบริการดี สะดวกส...    5.0
# 7   ใช่บริการประจำห้องสะอาดเตียงนุ่มมีที่จอดรถ มีร...    5.0
# 8   โดยรวมดีมากคะ ห้องสะอาด หองกว้าง เตียงนอนหลับส...    4.5
# 9   อยากให้ขยายที่จอดรถเพิ่มขึ้น ที่จอดน้อยไป ทุกอ...    3.7
# 10  โรงแรมดีมาก สะอาด พนักงานบริการดีทุกคน ใกล้bts...    5.0
# 11  โรงแรมดี ได้มาตรฐาน SHA Plus+ มั่นใจได้ว่า สะอ...    5.0
# 12      ที่พักอยู่ใกล้ถนนใหญ่ เดินทางสะดวก มีประโยชน์    4.5
# 13  ห้องน้ำและผ้าเช็ดตัวเก่า ที่นอนและหมอนไม่นุ่ม ...    3.2
# 14         ห้องพักสะอาด พนักงานบริการดีค่ะ มีประโยชน์    4.0
# 15          ไม่ไกลจากร้านสะดวกซื้อ และ BTS มีประโยชน์    5.0
# 16  พนักงานบริการดี ระบบรักษาความปลอดภัยที่ดี เดิน...    5.0
# 17  โรงแรมสะอาด เจ้าหน้า บริการดี เดินทางสะดวก มีป...    4.0
# 18  รร เดินทางสะดวก ใกล้บีทีเอส สถานที่ภายในห้องสะ...    4.0
# 19                       ดีค่ะ ทำเลดีสะดวก มีประโยชน์    4.5
# 20                  บริการค่อนข้างดี สะอาด มีประโยชน์    4.7
# 21  สถานที่ดีไกล้รถไฟฟ้าที่จอดรถพอเพียงร้านอาหาาอร...    4.0
# 22  ทุกอย่างโดยรวมดี ใกล้สถานที่ๆไปติดต่องาน เดินท...    3.5
# 23                            เดินทางสะดวก มีประโยชน์    4.5
# 24  เป็นโรงแรม ที่เดินทางสะดวกใกล้รถไฟฟ้า BTS สนาม...    4.2
# 25                          โดยรวมโอเคครับ มีประโยชน์    4.0
# 26                                ประทับใจ มีประโยชน์    5.0
# 27                   ดี ใกล้ bts สะดวกสบาย มีประโยชน์    4.0
# 28                          ดี ดี ดี ดี ดี มีประโยชน์    4.0
# 29                        สะอาดแล้วคุ้มค่า มีประโยชน์    5.0
# 30                                สะดวก ดี มีประโยชน์    4.0
# 31                                  เยี่ยม มีประโยชน์    5.0
# 32             สะอาด ราคาถูก เสียงไม่รบกวน มีประโยชน์    5.0
# 33  ฟรีบัตรบีทีเอสหนึ่งใบ ทำเลดีใกล้บีทีเอสและเข้า...    5.0
# 34  ที่ตั้ง: เดินทางสะดวกมาก ใกล้โรงพยาบาลพญาไท 2 ...    5.0
# 35  ห้องพักมีขนาดเล็กและสะอาดเล็กน้อย แต่การคมนาคม...    4.5
# 36  โรงแรมมีทำเลที่ดีมากด้านหน้าและการทำความสะอาดก...    4.7
# 37  โรงแรมนี้มีประโยชน์ใช้สอยและเรียบง่าย ใช่ ห้อง...    3.2
# 38  โรงแรมอยู่ใกล้สถานีรถไฟฟ้าถึงแม้จะไม่มี￼ร้านอา...    4.5
# 39  โรงแรมเรียบง่าย ตั้งอยู่ที่สถานีรถไฟฟ้า BTS สถ...    4.0

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  มาพักเป็นครั้งที่ 3 แล้วค่ะ ประทับใจตั้งแต่ทำเ...    4.5
# 1       1  บริการดี ประทับใจ เดินทางสะดวกครับ ใกล้แหล่งขอ...    5.0
# 2       2  การบริการดีเเละห้องสวยงามห้องน้ำสะอาดมีที่จอดร...    3.7
# 3       3  ทำเลโรงแรมดีมากค่ะ ห้องกว้างห้องน้ำก็กว้างสมรา...    4.7
# 4       4  ห้องดีมากสะอาดห้องน้ำสะอาดเเอร์เย็นฉ่ำพนักงานบ...    5.0
# 5       5  ห้องสะอาด แอร์เย็นไม่หนาวมาก อากาศปลอดกลิ่นบุห...    5.0
# 6       6  ใกล้bts เดินไม่นานก็ถึง พนักงานบริการดี สะดวกส...    5.0
# 7       7  ใช่บริการประจำห้องสะอาดเตียงนุ่มมีที่จอดรถ มีร...    5.0
# 8       8  โดยรวมดีมากคะ ห้องสะอาด หองกว้าง เตียงนอนหลับส...    4.5
# 9       9  อยากให้ขยายที่จอดรถเพิ่มขึ้น ที่จอดน้อยไป ทุกอ...    3.7
# 10     10  โรงแรมดีมาก สะอาด พนักงานบริการดีทุกคน ใกล้bts...    5.0
# 11     11  โรงแรมดี ได้มาตรฐาน SHA Plus+ มั่นใจได้ว่า สะอ...    5.0
# 12     12      ที่พักอยู่ใกล้ถนนใหญ่ เดินทางสะดวก มีประโยชน์    4.5
# 13     13  ห้องน้ำและผ้าเช็ดตัวเก่า ที่นอนและหมอนไม่นุ่ม ...    3.2
# 14     14         ห้องพักสะอาด พนักงานบริการดีค่ะ มีประโยชน์    4.0
# 15     15          ไม่ไกลจากร้านสะดวกซื้อ และ BTS มีประโยชน์    5.0
# 16     16  พนักงานบริการดี ระบบรักษาความปลอดภัยที่ดี เดิน...    5.0
# 17     17  โรงแรมสะอาด เจ้าหน้า บริการดี เดินทางสะดวก มีป...    4.0
# 18     18  รร เดินทางสะดวก ใกล้บีทีเอส สถานที่ภายในห้องสะ...    4.0
# 19     19                       ดีค่ะ ทำเลดีสะดวก มีประโยชน์    4.5
# 20     20                  บริการค่อนข้างดี สะอาด มีประโยชน์    4.7
# 21     21  สถานที่ดีไกล้รถไฟฟ้าที่จอดรถพอเพียงร้านอาหาาอร...    4.0
# 22     22  ทุกอย่างโดยรวมดี ใกล้สถานที่ๆไปติดต่องาน เดินท...    3.5
# 23     23                            เดินทางสะดวก มีประโยชน์    4.5
# 24     24  เป็นโรงแรม ที่เดินทางสะดวกใกล้รถไฟฟ้า BTS สนาม...    4.2
# 25     25                          โดยรวมโอเคครับ มีประโยชน์    4.0
# 26     26                                ประทับใจ มีประโยชน์    5.0
# 27     27                   ดี ใกล้ bts สะดวกสบาย มีประโยชน์    4.0
# 28     28                          ดี ดี ดี ดี ดี มีประโยชน์    4.0
# 29     29                        สะอาดแล้วคุ้มค่า มีประโยชน์    5.0
# 30     30                                สะดวก ดี มีประโยชน์    4.0
# 31     31                                  เยี่ยม มีประโยชน์    5.0
# 32     32             สะอาด ราคาถูก เสียงไม่รบกวน มีประโยชน์    5.0
# 33     33  ฟรีบัตรบีทีเอสหนึ่งใบ ทำเลดีใกล้บีทีเอสและเข้า...    5.0
# 34     34  ที่ตั้ง: เดินทางสะดวกมาก ใกล้โรงพยาบาลพญาไท 2 ...    5.0
# 35     35  ห้องพักมีขนาดเล็กและสะอาดเล็กน้อย แต่การคมนาคม...    4.5
# 36     36  โรงแรมมีทำเลที่ดีมากด้านหน้าและการทำความสะอาดก...    4.7
# 37     37  โรงแรมนี้มีประโยชน์ใช้สอยและเรียบง่าย ใช่ ห้อง...    3.2
# 38     38  โรงแรมอยู่ใกล้สถานีรถไฟฟ้าถึงแม้จะไม่มี￼ร้านอา...    4.5
# 39     39  โรงแรมเรียบง่าย ตั้งอยู่ที่สถานีรถไฟฟ้า BTS สถ...    4.0

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   มาพักเป็นครั้งที่ 3 แล้วค่ะ ประทับใจตั้งแต่ทำเ...    4.5
# 1   บริการดี ประทับใจ เดินทางสะดวกครับ ใกล้แหล่งขอ...    5.0
# 2   การบริการดีเเละห้องสวยงามห้องน้ำสะอาดมีที่จอดร...    3.7
# 3   ทำเลโรงแรมดีมากค่ะ ห้องกว้างห้องน้ำก็กว้างสมรา...    4.7
# 4   ห้องดีมากสะอาดห้องน้ำสะอาดเเอร์เย็นฉ่ำพนักงานบ...    5.0
# 5   ห้องสะอาด แอร์เย็นไม่หนาวมาก อากาศปลอดกลิ่นบุห...    5.0
# 6   ใกล้bts เดินไม่นานก็ถึง พนักงานบริการดี สะดวกส...    5.0
# 7   ใช่บริการประจำห้องสะอาดเตียงนุ่มมีที่จอดรถ มีร...    5.0
# 8   โดยรวมดีมากคะ ห้องสะอาด หองกว้าง เตียงนอนหลับส...    4.5
# 9   อยากให้ขยายที่จอดรถเพิ่มขึ้น ที่จอดน้อยไป ทุกอ...    3.7
# 10  โรงแรมดีมาก สะอาด พนักงานบริการดีทุกคน ใกล้bts...    5.0
# 11  โรงแรมดี ได้มาตรฐาน SHA Plus+ มั่นใจได้ว่า สะอ...    5.0
# 12      ที่พักอยู่ใกล้ถนนใหญ่ เดินทางสะดวก มีประโยชน์    4.5
# 13  ห้องน้ำและผ้าเช็ดตัวเก่า ที่นอนและหมอนไม่นุ่ม ...    3.2
# 14         ห้องพักสะอาด พนักงานบริการดีค่ะ มีประโยชน์    4.0
# 15          ไม่ไกลจากร้านสะดวกซื้อ และ BTS มีประโยชน์    5.0
# 16  พนักงานบริการดี ระบบรักษาความปลอดภัยที่ดี เดิน...    5.0
# 17  โรงแรมสะอาด เจ้าหน้า บริการดี เดินทางสะดวก มีป...    4.0
# 18  รร เดินทางสะดวก ใกล้บีทีเอส สถานที่ภายในห้องสะ...    4.0
# 19                       ดีค่ะ ทำเลดีสะดวก มีประโยชน์    4.5
# 20                  บริการค่อนข้างดี สะอาด มีประโยชน์    4.7
# 21  สถานที่ดีไกล้รถไฟฟ้าที่จอดรถพอเพียงร้านอาหาาอร...    4.0
# 22  ทุกอย่างโดยรวมดี ใกล้สถานที่ๆไปติดต่องาน เดินท...    3.5
# 23                            เดินทางสะดวก มีประโยชน์    4.5
# 24  เป็นโรงแรม ที่เดินทางสะดวกใกล้รถไฟฟ้า BTS สนาม...    4.2
# 25                          โดยรวมโอเคครับ มีประโยชน์    4.0
# 26                                ประทับใจ มีประโยชน์    5.0
# 27                   ดี ใกล้ bts สะดวกสบาย มีประโยชน์    4.0
# 28                          ดี ดี ดี ดี ดี มีประโยชน์    4.0
# 29                        สะอาดแล้วคุ้มค่า มีประโยชน์    5.0
# 30                                สะดวก ดี มีประโยชน์    4.0
# 31                                  เยี่ยม มีประโยชน์    5.0
# 32             สะอาด ราคาถูก เสียงไม่รบกวน มีประโยชน์    5.0
# 33  ฟรีบัตรบีทีเอสหนึ่งใบ ทำเลดีใกล้บีทีเอสและเข้า...    5.0
# 34  ที่ตั้ง: เดินทางสะดวกมาก ใกล้โรงพยาบาลพญาไท 2 ...    5.0
# 35  ห้องพักมีขนาดเล็กและสะอาดเล็กน้อย แต่การคมนาคม...    4.5
# 36  โรงแรมมีทำเลที่ดีมากด้านหน้าและการทำความสะอาดก...    4.7
# 37  โรงแรมนี้มีประโยชน์ใช้สอยและเรียบง่าย ใช่ ห้อง...    3.2
# 38  โรงแรมอยู่ใกล้สถานีรถไฟฟ้าถึงแม้จะไม่มี￼ร้านอา...    4.5
# 39  โรงแรมเรียบง่าย ตั้งอยู่ที่สถานีรถไฟฟ้า BTS สถ...    4.0

# %%
table.to_csv("Unseen_1.csv", encoding="utf-8")
