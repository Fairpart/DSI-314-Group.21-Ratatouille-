# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -ookiecutter (c:\users\fair\anaconda3\lib\site-packages)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %%
#ลบ ข้อความส่วนไม่ต้องการออก รีวิว
def abstract_review(review_ls):
    for i in review_ls:
        lenght = 0
        for j in i.split():
            if j == 'รีวิว':
                sentence = ' '.join(i.split()[0:lenght])
            lenght +=1
        Reviews_list.append(sentence)
    return Reviews_list

# %%
#ลบ ข้อความส่วนไม่ต้องการออก /5
def abstract_rating(rating_ls):
    for i in ratings_list:
        lenght = 0
        for j in i.split():
            if j == '/5':
                rating = ' '.join(i.split()[0:lenght])
            lenght +=1
        Ratings_list.append(rating)
    return Ratings_list

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://th.trip.com/hotels/detail/?cityId=359&hotelId=701851&checkIn=2022-12-11&checkOut=2022-12-12&adult=2&children=0&subStamp=1314&crn=1&ages=&travelpurpose=0&curr=THB&link=title&hoteluniquekey=H4sIAAAAAAAAAON6xMjFJMEkxMTBKHWdkePom7tvmCx-CzqePQMELkkOnrZc1xcXtKY6BPAUMkCAwyRGG87DXzVi-nW6HQQhYp0OSgoKLJowFYYwhsUzziBWjrUsEixRDE5sHGuXs0qwzGCc_VprI2Pr68AdcqxWDjsYmQ4w_ocBxhOM91gXMD15v4l5FxNUwyEmVo6DqRIsp5gYLjEx3GJieMQEMfMVE8MnJoZfMHVNzAxdzAyTmCGqZzFDFC1iZpDiTTE0MUk0Tk1LTUw2TVQQ0nj86OocNiOZSYxMIR6nGEUMzczMTcxNLQzMgZSeUZ5ZrnG-FbMUo5sHYxCbiZuxsatFlBYXc4iHk6DxkY16eYtP2kuBeIownhaIZwjjJbGWZOiGeGQs4C5g7GLkEGD0YIxgrGB8xQhSBQDRo5Z5cgEAAA&subChannel=&masterhotelid_tracelogid=d144a3efeac5a&barcurr=THB'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_10320\4262920220.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'รีวิวโรงแรมแกรนด์ ทาวเวอร์ อินน์ พระราม 6 (SHA Plus+) - โปรโมชั่นโรงแรม 4 ดาวในกรุงเทพฯ | Trip.com'

# %%
driver.execute_script("window.scrollTo(0,1650)")

# %%
#Click all Review
sel = driver.find_element(By.XPATH,"/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[1]/div[2]/div/button[1]")
sel.click()

# %%
driver.execute_script("window.scrollTo(0,5400)")

# %%
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)
# Out:
# พักทั้งหมด 2 คืน โรงแรมเป็นโรงแรมที่ดูเก่าแล้ว แต่สิ่งอำนวยความสะดวกต่างๆยังโอเค แอร์เย็นแต่ต้องใช้เวลา น้ำอุ่นต้องหามุมให้ดีไม่งั้นน้ำจะร้อนเกินไป สระว่ายน้ำถือว่าดีมีทั้งน้ำตื้นและน้ำลึก 2 เมตร ฟิตเนสเหมือนเป็นที่ชั่วคราวเปลี่ยนห้องพักมาเป็นห้องฟิตเนส ไม่ค่อยมีอะไรเท่าไหร่ ทั้งหมดโดยรวมถือว่าคุ้มค่ากับเงินที่จ่ายไป ส่วนทำเลจะไม่ได้ดีมาก แต่สามารถเรียกรถตุ๊กๆ muvmi ไป BTS/MRT ได้ไม่ยาก มีเซเว่นแต่ต้องเดิน 6-7 นาที หรือสามารถสั่งผ่านแอปให้มาส่งหน้าโรงแรมก็ได้
# รีวิว 15 ตุลาคม 2022
# ดีครับ ชอบมาก ความปลอดภัยในการเข้าออกห้องดี โรงแรมสวย อาจจะช้าเรื่องเช็คอินไปนิดหน่อย ผมยืนรออยู่พักนึงจนมีพี่อีกคนเดินเข้ามาทำเรื่องให้แปปเดียวเสร็จเลย โดยรวมดีครับ วิวสวย นอนสบายเตียงนุ่ม เสียดายน้ำอุ่นมากวันที่ไปใช้ไม่ได้ รอบหน้าไปพักอีกแน่นอนครับ ❤️
# รีวิว 26 สิงหาคม 2022
# -บริการดีตั้งแต่เลี้ยวเข้าโรงแรม พี่ๆ รปภ. พนักงาน ทุกท่านบริการดีมากๆ -ห้องพักสะอาด วิวดี สวย อุปกรณ์อำนวยความสะดวกมีให้ครบ ไม่แน่ใจว่าปกติมีไดร์เป่าผมไหม หาไม่เจอ แต่ก็ไม่ใช่ปัญหาในการเข้าพักค่ะ -แอร์เย็น น้ำอุ่นเปิดได้ง่าย ทีวีดูได้ ชัด น้อยมากที่ะเจอโรงแรมมีทีวีและเปิดได้ บางที่มีทีวีแต่เปิดไม่ได้ wifi ใช้ได้ดี ไม่หลุดเลย -มีโอกาสจะไปพักอีกนะคะ ประทับใจมากๆ
# รีวิว 4 กรกฎาคม 2022
# 9/12
# ห้องชั้นบนวิวสวยครับมองเห็นเมืองหลวง ตึกไยหยก ตึกแมกโนเลียริมแม่น้ำ และอยู่ใกล้ทางขึ้นลงรถไฟฟ้าที่เดินทางสะดวกด้วยรถยนต์
# รีวิว 6 กรกฎาคม 2022
# ที่พักเรียบร้อยดี อาจจะดูเก่าไปบ้างแต่ก็สะอาดดี โทรทัศน์สัญญาณไม่ค่อยดีเท่าไหร่
# รีวิว 26 กรกฎาคม 2022
# เหมาะสำหรับพักชั่วคราว โรงเเรมใหญ่มาก คนพักเยอะค่ะ
# รีวิว 10 กันยายน 2022
# โรงแรมห้องสวย กว้าง สบาย การบริการดี และเดินทางสะดวก แนะนำครับผม
# รีวิว 15 สิงหาคม 2022
# โดยรวมทุกอย่างดีมากค่ะ พนักงานสุภาพเรียบร้อยทุกคนค่ะ
# รีวิว 13 สิงหาคม 2022
# ห้องพักดีมาก วิวสวย คุ้มค่ากับราคา
# รีวิว 6 กันยายน 2022
# ดีมากกกก สะดวก มีที่จอดรถกว้างขวาง ใกล้หมอชิต สะอาด พนักงานบริการดี
# รีวิว 11 กรกฎาคม 2022
# 4.7
# /5
# 4.2
# /5
# 5.0
# /5
# 4.2
# /5
# 3.0
# /5
# 4.5
# /5
# 4.7
# /5
# 4.7
# /5
# 4.7
# /5
# 5.0
# /5
# ['4.7', '4.2', '5.0', '4.2', '3.0', '4.5', '4.7', '4.7', '4.7', '5.0']

# %%
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()

# %%
driver.execute_script("window.scrollTo(0,4100)")
clear_list(ratings_list,reviews_list)

time.sleep(3)
next_page = driver.find_element(By.XPATH,'/html/body/div[3]/section/article/div/div[5]/div[5]/section[1]/div/div/ul[2]/li/div/div[2]/div[2]/div[12]/ul/li[3]/a')
next_page.click()

time.sleep(3)
for comement in driver.find_elements(By.CLASS_NAME,'comment'):
    reviews = comement.text
    print(reviews)
    reviews_list.append(reviews)
    
for score in driver.find_elements(By.CLASS_NAME,'m-score_single'):
    scores = score.text
    print(scores)
    ratings_list.append(scores)

check_list_size(ratings_list,reviews_list)
abstract_review(reviews_list)
abstract_rating(ratings_list)
# Out:
# ค่อนข้างดีสำหรับราคา ร้านกาแฟปิดเมื่อฉันมาถึง แต่บุฟเฟ่ต์อาหารค่ำดูเหมือนจะเป็นที่นิยม แต่มีบาร์ Cafe แบบรูในผนังที่ดีกว่าบนถนนด้านนอกทางด้านขวา ห้องชั้น 15 อยู่ห่างไกลจากเสียงรบกวนบนทางหลวงอย่างมีความสุข พร้อมทิวทัศน์สไตล์ Blade Runner อันยอดเยี่ยมของเมืองที่แออัดเบื้องล่าง อ่างขนาดเต็มได้รับการชื่นชมอย่างมากหลังจากวันที่อากาศร้อนยาวนาน แม้ว่าน้ำในอ่างจะไม่เคยร้อนเลยก็ตาม กาต้มน้ำที่ใช้งานได้และน้ำดื่มปริมาณมากทำให้ตอนเช้ามีความสุข
# ข้อความเดิม
# แปลโดย Google
# รีวิว 4 กรกฎาคม 2022
# ใกล้กับสถานีหมอชิตสำหรับรถบัสของเราสิ่งอำนวยความสะดวกที่ยอดเยี่ยม เตียงนอนสบาย
# ข้อความเดิม
# แปลโดย Google
# รีวิว 29 สิงหาคม 2022
# ไม่มีน้ำร้อน อ่างอาบน้ำจะเย็นกว่าถ้าเปิดเครื่องปรับอากาศในร่ม อย่างอื่นโอเค มีที่จอดรถ
# ข้อความเดิม
# แปลโดย Google
# รีวิว 22 กรกฎาคม 2022
# Trip.com มีส่วนรับผิดชอบต่อประสบการณ์ที่ไม่ดีนี้เช่นกัน ฉันเลือกโรงแรมนี้เพราะในข้อมูลมีสระว่ายน้ำและฟิตเนส แต่เสียดายตอนจ่ายเงินไปเช็คอินแล้ว สระว่ายน้ำกับฟิตเนสอยู่ใกล้กันไม่มีเหตุผล... แม้แต่ในโรงแรมอื่นในกรุงเทพก็เปิดสระตั้งแต่สองสามเดือนก่อน โรงแรมนี้ไม่มีผ้าเช็ดตัวผืนเล็ก ไม่มีรองเท้าแตะ ไม่มีแปรงสีฟัน... ไม่มีของฟรีเหมือนชาหรือกาแฟ บริการแย่มาก... หวังว่าจะไม่มีใครมีประสบการณ์แย่ๆ แบบฉันอีกนะ
# ข้อความเดิม
# แปลโดย Google
# รีวิว 22 พฤศจิกายน 2021
# ดีมาก. พนักงานที่ดี สะอาดและสะดวกสบาย ใกล้สถานที่ท่องเที่ยว.
# ข้อความเดิม
# แปลโดย Google
# รีวิว 29 ธันวาคม 2021
# ประสบการณ์ของฉันดีและพนักงานก็ให้ความร่วมมือ อาหารเช้าดีที่สุด
# ข้อความเดิม
# แปลโดย Google
# รีวิว 17 กันยายน 2022
# พอไปถึงก็รู้ว่าฝักบัวเสีย เลยใช้ไม่ได้ ก็เลยยกเลิกไม่ได้
# ข้อความเดิม
# แปลโดย Google
# รีวิว 26 สิงหาคม 2022
# ทำเลดี. ที่นี่เป็นโรงแรมที่ดีกว่า
# ข้อความเดิม
# แปลโดย Google
# รีวิว 24 กรกฎาคม 2022
# เป็นโรงแรมที่ดีและราคาถูกเมื่อจองผ่าน trip.com ผมชอบมันมาก. เป็นการรักษาความปลอดภัยที่ดีมากและหน้าต่างก็ใหญ่ วิวดีแม้หน้าฝน
# ข้อความเดิม
# แปลโดย Google
# รีวิว 31 ตุลาคม 2020
# โรงแรมที่ดี ล็อบบี้ที่สวยงาม ห้องพักสะอาดและกว้างขวางพร้อมสิ่งอำนวยความสะดวกทั้งหมดรวมอยู่ด้วย
# ข้อความเดิม
# แปลโดย Google
# รีวิว 12 กรกฎาคม 2020
# 4.2
# /5
# 5.0
# /5
# 2.5
# /5
# 1.0
# /5
# 4.7
# /5
# 5.0
# /5
# 2.7
# /5
# 5.0
# /5
# 4.7
# /5
# 4.7
# /5
# ['4.7',
#  '4.2',
#  '5.0',
#  '4.2',
#  '3.0',
#  '4.5',
#  '4.7',
#  '4.7',
#  '4.7',
#  '5.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '3.7',
#  '3.5',
#  '5.0',
#  '5.0',
#  '3.2',
#  '4.0',
#  '5.0',
#  '4.2',
#  '5.0',
#  '5.0',
#  '5.0',
#  '5.0',
#  '4.2',
#  '4.0',
#  '5.0',
#  '4.0',
#  '5.0',
#  '5.0',
#  '4.7',
#  '5.0',
#  '5.0',
#  '3.7',
#  '2.5',
#  '3.5',
#  '3.5',
#  '3.7',
#  '4.0',
#  '4.2',
#  '5.0',
#  '2.5',
#  '1.0',
#  '4.7',
#  '5.0',
#  '2.7',
#  '5.0',
#  '4.7',
#  '4.7']

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 50
# Reviews_list : 50

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   พักทั้งหมด 2 คืน โรงแรมเป็นโรงแรมที่ดูเก่าแล้ว...    4.7
# 1   ดีครับ ชอบมาก ความปลอดภัยในการเข้าออกห้องดี โร...    4.2
# 2   -บริการดีตั้งแต่เลี้ยวเข้าโรงแรม พี่ๆ รปภ. พนั...    5.0
# 3   ห้องชั้นบนวิวสวยครับมองเห็นเมืองหลวง ตึกไยหยก ...    4.2
# 4   ที่พักเรียบร้อยดี อาจจะดูเก่าไปบ้างแต่ก็สะอาดด...    3.0
# 5   เหมาะสำหรับพักชั่วคราว โรงเเรมใหญ่มาก คนพักเยอ...    4.5
# 6   โรงแรมห้องสวย กว้าง สบาย การบริการดี และเดินทา...    4.7
# 7   โดยรวมทุกอย่างดีมากค่ะ พนักงานสุภาพเรียบร้อยทุ...    4.7
# 8                  ห้องพักดีมาก วิวสวย คุ้มค่ากับราคา    4.7
# 9   ดีมากกกก สะดวก มีที่จอดรถกว้างขวาง ใกล้หมอชิต ...    5.0
# 10  พนักงานนิสัยดี เป็นกันเอง ห้องพักสะอาด ความปลอ...    5.0
# 11  ดีมากค่ะ บริการดี สถานที่ดี สะอาดมาก ๆ เลย พนั...    5.0
# 12  ห้องพักดีค่ะ สะอาด ใกล้สถานที่ในเมือง จะกลับมา...    5.0
# 13  ราคาไม่แพง ที่จอดรถเยอะ ห้องค่อนข้างกว้าง สะอา...    3.7
# 14  พนักงานไม่ค่อยตอบคำถามเลยปัดตลอดหน้าไม่ยิ้ม มี...    3.5
# 15  ทำเลดี เดินทาง สะดวก สะอาด เงียบสงบ หาอาหารทาน...    5.0
# 16  ชอบมากค่ะ ในห้องสะอาดมาก ไม่ผิดหวังจริงๆที่เลื...    5.0
# 17                    ฝุ่นตามช่องแอร์สกปรก มีประโยชน์    3.2
# 18                 เดินทางสะดวก บริการดี ห้องพักสะอาด    4.0
# 19                  โรงแรมเก่าแต่สะอาดสะอ้านดีมากกกกก    5.0
# 20  จอดรถค่อนข้างลำบาก แต่มีที่จอดตลอด พนักงานดูแล...    4.2
# 21  ประทับใจมากที่สุดกับพนักงาน ให้บริการอย่างดีเย...    5.0
# 22                             สอาดสบายมาก มีประโยชน์    5.0
# 23  ดีมากมีบริการเตารีด พนักงานต้อนรับดี อาหารลดลง...    5.0
# 24  จองง่ายมากเลยค่ะ กลับมาพักอีกครั้งเพราะ พนักงา...    5.0
# 25                                   คุ้มค่า คุ้มราคา    4.2
# 26                                            คุ้มค่า    4.0
# 27  เดินทางสะดวก เตียงนอนนุ่มมาก บริการดี รู้สึกปร...    5.0
# 28  โอเคเลยครับ ราคาไม่แพงเหมาะสมดี สิ่งอำนวยความส...    4.0
# 29  พนักงานเจ้าหน้าที่บริการดี น่ารักเสมอทุกครั้งท...    5.0
# 30               บริการดี พนักงานเอาใจใส่ สะอาด สะดวก    5.0
# 31                           ที่จอดรถหาที่จอดลำบากมาก    4.7
# 32                          ดีมากครับ พนักงานใส่ใจมาก    5.0
# 33                                          สุดยอดดดด    5.0
# 34  ไกลร้านหรือร้านอาหาร...ต้องเดินทางหน่อย... มีต...    3.7
# 35  แอร์โอเค แต่แอร์มีฝุ่น ต่อให้อ่างอาบน้ำในห้องน...    2.5
# 36  โรงแรม 4 ดาวราคาถูกมาก มีศักยภาพที่ดี อยู่ในพื...    3.5
# 37  ไม่มีเครื่องเป่าลมในห้องและเครื่องทำน้ำอุ่นเสี...    3.5
# 38  โรงแรมตั้งอยู่ในทำเลไม่ค่อยดี คุณต้องเดิน 20-2...    3.7
# 39  มีของให้ชมรอบๆ ตัว เลยแวะมาใหม่ มีเสียงรบกวนระ...    4.0
# 40  ค่อนข้างดีสำหรับราคา ร้านกาแฟปิดเมื่อฉันมาถึง ...    4.2
# 41  ใกล้กับสถานีหมอชิตสำหรับรถบัสของเราสิ่งอำนวยคว...    5.0
# 42  ไม่มีน้ำร้อน อ่างอาบน้ำจะเย็นกว่าถ้าเปิดเครื่อ...    2.5
# 43  Trip.com มีส่วนรับผิดชอบต่อประสบการณ์ที่ไม่ดีน...    1.0
# 44  ดีมาก. พนักงานที่ดี สะอาดและสะดวกสบาย ใกล้สถาน...    4.7
# 45  ประสบการณ์ของฉันดีและพนักงานก็ให้ความร่วมมือ อ...    5.0
# 46  พอไปถึงก็รู้ว่าฝักบัวเสีย เลยใช้ไม่ได้ ก็เลยยก...    2.7
# 47  ทำเลดี. ที่นี่เป็นโรงแรมที่ดีกว่า ข้อความเดิม ...    5.0
# 48  เป็นโรงแรมที่ดีและราคาถูกเมื่อจองผ่าน trip.com...    4.7
# 49  โรงแรมที่ดี ล็อบบี้ที่สวยงาม ห้องพักสะอาดและกว...    4.7

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  พักทั้งหมด 2 คืน โรงแรมเป็นโรงแรมที่ดูเก่าแล้ว...    4.7
# 1       1  ดีครับ ชอบมาก ความปลอดภัยในการเข้าออกห้องดี โร...    4.2
# 2       2  -บริการดีตั้งแต่เลี้ยวเข้าโรงแรม พี่ๆ รปภ. พนั...    5.0
# 3       3  ห้องชั้นบนวิวสวยครับมองเห็นเมืองหลวง ตึกไยหยก ...    4.2
# 4       4  ที่พักเรียบร้อยดี อาจจะดูเก่าไปบ้างแต่ก็สะอาดด...    3.0
# 5       5  เหมาะสำหรับพักชั่วคราว โรงเเรมใหญ่มาก คนพักเยอ...    4.5
# 6       6  โรงแรมห้องสวย กว้าง สบาย การบริการดี และเดินทา...    4.7
# 7       7  โดยรวมทุกอย่างดีมากค่ะ พนักงานสุภาพเรียบร้อยทุ...    4.7
# 8       8                 ห้องพักดีมาก วิวสวย คุ้มค่ากับราคา    4.7
# 9       9  ดีมากกกก สะดวก มีที่จอดรถกว้างขวาง ใกล้หมอชิต ...    5.0
# 10     10  พนักงานนิสัยดี เป็นกันเอง ห้องพักสะอาด ความปลอ...    5.0
# 11     11  ดีมากค่ะ บริการดี สถานที่ดี สะอาดมาก ๆ เลย พนั...    5.0
# 12     12  ห้องพักดีค่ะ สะอาด ใกล้สถานที่ในเมือง จะกลับมา...    5.0
# 13     13  ราคาไม่แพง ที่จอดรถเยอะ ห้องค่อนข้างกว้าง สะอา...    3.7
# 14     14  พนักงานไม่ค่อยตอบคำถามเลยปัดตลอดหน้าไม่ยิ้ม มี...    3.5
# 15     15  ทำเลดี เดินทาง สะดวก สะอาด เงียบสงบ หาอาหารทาน...    5.0
# 16     16  ชอบมากค่ะ ในห้องสะอาดมาก ไม่ผิดหวังจริงๆที่เลื...    5.0
# 17     17                    ฝุ่นตามช่องแอร์สกปรก มีประโยชน์    3.2
# 18     18                 เดินทางสะดวก บริการดี ห้องพักสะอาด    4.0
# 19     19                  โรงแรมเก่าแต่สะอาดสะอ้านดีมากกกกก    5.0
# 20     20  จอดรถค่อนข้างลำบาก แต่มีที่จอดตลอด พนักงานดูแล...    4.2
# 21     21  ประทับใจมากที่สุดกับพนักงาน ให้บริการอย่างดีเย...    5.0
# 22     22                             สอาดสบายมาก มีประโยชน์    5.0
# 23     23  ดีมากมีบริการเตารีด พนักงานต้อนรับดี อาหารลดลง...    5.0
# 24     24  จองง่ายมากเลยค่ะ กลับมาพักอีกครั้งเพราะ พนักงา...    5.0
# 25     25                                   คุ้มค่า คุ้มราคา    4.2
# 26     26                                            คุ้มค่า    4.0
# 27     27  เดินทางสะดวก เตียงนอนนุ่มมาก บริการดี รู้สึกปร...    5.0
# 28     28  โอเคเลยครับ ราคาไม่แพงเหมาะสมดี สิ่งอำนวยความส...    4.0
# 29     29  พนักงานเจ้าหน้าที่บริการดี น่ารักเสมอทุกครั้งท...    5.0
# 30     30               บริการดี พนักงานเอาใจใส่ สะอาด สะดวก    5.0
# 31     31                           ที่จอดรถหาที่จอดลำบากมาก    4.7
# 32     32                          ดีมากครับ พนักงานใส่ใจมาก    5.0
# 33     33                                          สุดยอดดดด    5.0
# 34     34  ไกลร้านหรือร้านอาหาร...ต้องเดินทางหน่อย... มีต...    3.7
# 35     35  แอร์โอเค แต่แอร์มีฝุ่น ต่อให้อ่างอาบน้ำในห้องน...    2.5
# 36     36  โรงแรม 4 ดาวราคาถูกมาก มีศักยภาพที่ดี อยู่ในพื...    3.5
# 37     37  ไม่มีเครื่องเป่าลมในห้องและเครื่องทำน้ำอุ่นเสี...    3.5
# 38     38  โรงแรมตั้งอยู่ในทำเลไม่ค่อยดี คุณต้องเดิน 20-2...    3.7
# 39     39  มีของให้ชมรอบๆ ตัว เลยแวะมาใหม่ มีเสียงรบกวนระ...    4.0
# 40     40  ค่อนข้างดีสำหรับราคา ร้านกาแฟปิดเมื่อฉันมาถึง ...    4.2
# 41     41  ใกล้กับสถานีหมอชิตสำหรับรถบัสของเราสิ่งอำนวยคว...    5.0
# 42     42  ไม่มีน้ำร้อน อ่างอาบน้ำจะเย็นกว่าถ้าเปิดเครื่อ...    2.5
# 43     43  Trip.com มีส่วนรับผิดชอบต่อประสบการณ์ที่ไม่ดีน...    1.0
# 44     44  ดีมาก. พนักงานที่ดี สะอาดและสะดวกสบาย ใกล้สถาน...    4.7
# 45     45  ประสบการณ์ของฉันดีและพนักงานก็ให้ความร่วมมือ อ...    5.0
# 46     46  พอไปถึงก็รู้ว่าฝักบัวเสีย เลยใช้ไม่ได้ ก็เลยยก...    2.7
# 47     47  ทำเลดี. ที่นี่เป็นโรงแรมที่ดีกว่า ข้อความเดิม ...    5.0
# 48     48  เป็นโรงแรมที่ดีและราคาถูกเมื่อจองผ่าน trip.com...    4.7
# 49     49  โรงแรมที่ดี ล็อบบี้ที่สวยงาม ห้องพักสะอาดและกว...    4.7

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   พักทั้งหมด 2 คืน โรงแรมเป็นโรงแรมที่ดูเก่าแล้ว...    4.7
# 1   ดีครับ ชอบมาก ความปลอดภัยในการเข้าออกห้องดี โร...    4.2
# 2   -บริการดีตั้งแต่เลี้ยวเข้าโรงแรม พี่ๆ รปภ. พนั...    5.0
# 3   ห้องชั้นบนวิวสวยครับมองเห็นเมืองหลวง ตึกไยหยก ...    4.2
# 4   ที่พักเรียบร้อยดี อาจจะดูเก่าไปบ้างแต่ก็สะอาดด...    3.0
# 5   เหมาะสำหรับพักชั่วคราว โรงเเรมใหญ่มาก คนพักเยอ...    4.5
# 6   โรงแรมห้องสวย กว้าง สบาย การบริการดี และเดินทา...    4.7
# 7   โดยรวมทุกอย่างดีมากค่ะ พนักงานสุภาพเรียบร้อยทุ...    4.7
# 8                  ห้องพักดีมาก วิวสวย คุ้มค่ากับราคา    4.7
# 9   ดีมากกกก สะดวก มีที่จอดรถกว้างขวาง ใกล้หมอชิต ...    5.0
# 10  พนักงานนิสัยดี เป็นกันเอง ห้องพักสะอาด ความปลอ...    5.0
# 11  ดีมากค่ะ บริการดี สถานที่ดี สะอาดมาก ๆ เลย พนั...    5.0
# 12  ห้องพักดีค่ะ สะอาด ใกล้สถานที่ในเมือง จะกลับมา...    5.0
# 13  ราคาไม่แพง ที่จอดรถเยอะ ห้องค่อนข้างกว้าง สะอา...    3.7
# 14  พนักงานไม่ค่อยตอบคำถามเลยปัดตลอดหน้าไม่ยิ้ม มี...    3.5
# 15  ทำเลดี เดินทาง สะดวก สะอาด เงียบสงบ หาอาหารทาน...    5.0
# 16  ชอบมากค่ะ ในห้องสะอาดมาก ไม่ผิดหวังจริงๆที่เลื...    5.0
# 17                    ฝุ่นตามช่องแอร์สกปรก มีประโยชน์    3.2
# 18                 เดินทางสะดวก บริการดี ห้องพักสะอาด    4.0
# 19                  โรงแรมเก่าแต่สะอาดสะอ้านดีมากกกกก    5.0
# 20  จอดรถค่อนข้างลำบาก แต่มีที่จอดตลอด พนักงานดูแล...    4.2
# 21  ประทับใจมากที่สุดกับพนักงาน ให้บริการอย่างดีเย...    5.0
# 22                             สอาดสบายมาก มีประโยชน์    5.0
# 23  ดีมากมีบริการเตารีด พนักงานต้อนรับดี อาหารลดลง...    5.0
# 24  จองง่ายมากเลยค่ะ กลับมาพักอีกครั้งเพราะ พนักงา...    5.0
# 25                                   คุ้มค่า คุ้มราคา    4.2
# 26                                            คุ้มค่า    4.0
# 27  เดินทางสะดวก เตียงนอนนุ่มมาก บริการดี รู้สึกปร...    5.0
# 28  โอเคเลยครับ ราคาไม่แพงเหมาะสมดี สิ่งอำนวยความส...    4.0
# 29  พนักงานเจ้าหน้าที่บริการดี น่ารักเสมอทุกครั้งท...    5.0
# 30               บริการดี พนักงานเอาใจใส่ สะอาด สะดวก    5.0
# 31                           ที่จอดรถหาที่จอดลำบากมาก    4.7
# 32                          ดีมากครับ พนักงานใส่ใจมาก    5.0
# 33                                          สุดยอดดดด    5.0
# 34  ไกลร้านหรือร้านอาหาร...ต้องเดินทางหน่อย... มีต...    3.7
# 35  แอร์โอเค แต่แอร์มีฝุ่น ต่อให้อ่างอาบน้ำในห้องน...    2.5
# 36  โรงแรม 4 ดาวราคาถูกมาก มีศักยภาพที่ดี อยู่ในพื...    3.5
# 37  ไม่มีเครื่องเป่าลมในห้องและเครื่องทำน้ำอุ่นเสี...    3.5
# 38  โรงแรมตั้งอยู่ในทำเลไม่ค่อยดี คุณต้องเดิน 20-2...    3.7
# 39  มีของให้ชมรอบๆ ตัว เลยแวะมาใหม่ มีเสียงรบกวนระ...    4.0
# 40  ค่อนข้างดีสำหรับราคา ร้านกาแฟปิดเมื่อฉันมาถึง ...    4.2
# 41  ใกล้กับสถานีหมอชิตสำหรับรถบัสของเราสิ่งอำนวยคว...    5.0
# 42  ไม่มีน้ำร้อน อ่างอาบน้ำจะเย็นกว่าถ้าเปิดเครื่อ...    2.5
# 43  Trip.com มีส่วนรับผิดชอบต่อประสบการณ์ที่ไม่ดีน...    1.0
# 44  ดีมาก. พนักงานที่ดี สะอาดและสะดวกสบาย ใกล้สถาน...    4.7
# 45  ประสบการณ์ของฉันดีและพนักงานก็ให้ความร่วมมือ อ...    5.0
# 46  พอไปถึงก็รู้ว่าฝักบัวเสีย เลยใช้ไม่ได้ ก็เลยยก...    2.7
# 47  ทำเลดี. ที่นี่เป็นโรงแรมที่ดีกว่า ข้อความเดิม ...    5.0
# 48  เป็นโรงแรมที่ดีและราคาถูกเมื่อจองผ่าน trip.com...    4.7
# 49  โรงแรมที่ดี ล็อบบี้ที่สวยงาม ห้องพักสะอาดและกว...    4.7

# %%
table.to_csv("Unseen_2.csv", encoding="utf-8")
