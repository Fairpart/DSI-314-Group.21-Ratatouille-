# %% [markdown]
# # Def & Scraping Methods

# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=07-11-2022.08-11-2022.1.1.HOTEL.3000020012319.The%20Quarter%20Ladprao%20by%20UHG.1&contexts=%7B%22inventoryRateKey%22%3A%22EPSy2lMQRUbs4Z%2BpcPzDIQJS%2FRAEhuHYBZQl71KB9Kg%2BiqGLDk2uWjsyHUapF7H3WsIkBdgyaCd6cEzZvSrR%2F31OY7iP7XDpr8nlh5Tt88s%2FqwP5MiR9z%2FOijQGyMrqm8LFDqJMUAphQFLDVj%2FhuCxn2OOhcThrQtYt65LV3gKgmJ1pdc%2FQdHnwmv%2FNphfUL8PNrufM%2BzDUBcMLdKq2XbgFU7aZfCySlLbxy7sg48BPwJtQGJ9zHhs%2FF3KauYQrYAVTtpl8LJKUtvHLuyDjwE85wEA4mUG3V1i%2B1iomrPy5N1ye1a%2FV7BCE7Ocg0TnM3YAOwwyA0tImEpYEuYVhe92qymzFjf%2FFvBWUjrexlmA2vKL4aONpghrZEOswspNd%2BXya8r1wErXp1FTU3tRyyFMJ5bSNwHLCNpcDdin5vdJqa%2Be3EU3ILQdYN4yLJ4Iylt3NHtTMRpGLk%2Bxkg3FEu%2Bfyyw7%2Fp%2Fljf3ZAsWWTSSJUbbKKYapmROdnYU8Z70FEjuikm8GJLDwQsEqfPAhX%2FgzZuuNH1PUmUELxCVefs00FJe2QE48%2FARJb3fooz78txRqqWx00bHxsCXvMbAIEb8%2BjA%2B9z%2F0iNeygbUgF1B%2Bl9j79ctpkSn7rjMyITJtjbrK%2BM5IRfnw7zMKwI4FetNG4Vrr5oThR2EuWyoSJFvAjpygWW9jihZTZE6RCMhINmn%22%7D&prevSearchId=1748750315088280409&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]

time.sleep(3)
driver.execute_script("window.scrollTo(0,6300)")
time.sleep(2)
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[4]/div[3]/div/div[1]")
sel.click()
time.sleep(2)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[4]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()
time.sleep(3)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_23928\3908623325.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)
# 10
# โรงแรมดีมากๆ เดินทางสะดวกใกล้รถไฟฟ้าห้าแยกลาดพร้าว หาของกิน ช็อปปิ้งก็สะดวกตรงข้ามยูเนี่ยนมอลเลยครับ คุ้มค่ากับราคา อาหารเช้าที่โรงแรมนี้อร่อยมาก มีหลากหลาย
# 9.4
# ประทับใจพนักงานเช็คอินมาก หน้าตายิ้มแย้มต้อนรับดี พูดไพเราะ มีการติดต่อมาแจ้งเรื่องพยายามหาห้องที่ใกล้กันมากที่สุดให้เพราะจองมา 3 ห้อง
# 9.7
# ดีมาก เดินทางสะดวกสบาย ใกล้ mrt
# 9.7
# บริการดีค่า พนักงานพูดเพราะ ห้องสะอาด
# 8.5
# พักที่นี่ประจำ พนักงานฟร้อนท์ ดีบ้างไม่ดีบ้าง ที่พักสะดวก เดินทาง
# 9.3
# ห้องดีมากค่ะ พักหลายรอบมากเป็นที่แรกที่จะเลือกใกล้แหล่งช้อปปิ้งเดินทางสะดวกมาก เดินมายังได้ 😆
# 9.7
# โรงแรมสะอาด บริการสะดวกสบาย พนักงานบริการด้วยความเป็นมิตรใส่ใจ
# 8.5
# เป็นโรงแรมที่ดี เดินทางสะดวก ห้องพักสะอาดแต่ไม่ค่อยเก็บเสียง ถ้าอยู่บริเวณหน้าลิฟหรือทางเดินที่คนผ่านบ่อยจะเสียงดัง อาหารเช้าดี ใกล้ห้าง มี7-11 ด้านล่างโรงแรมและร้านกาแฟ ส่วนกลางดี มีทั้งฟิตเนสและสระว่ายน้ำ
# 9.7
# ดีมากครับ มีโอกาสต้องกลับมาใช้บริการอีกแน่นอน
# 8.5
# ชอบมากเรยค่ะ สะอาด พนักงานก็น่ารักค่ะ มารอบหน้า มาใช้บริการอีกแน่นอนค่ะ

# %%
driver.title
# Out:
# 'ค่าห้องพัก The Quarter Ladprao by UHG จอมพล ตั้งแต่ 07-11-2022 ถึง 08-11-2022'

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]')
sel.click()

# %%
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# ที่พักดีมากเหมาะสมกับราคา เดินทางสะดวกมีรถไฟฟ้าทั้ง MRT และ BTS โรงแรมมีบริการอาหารเช้า ที่หลากหลาย ห้องพักตกแต่งสวยงาม อุปกรณ์ในห้องครบครัน จะไปพักอีกครัั้งแน่นอน
# 9.4
# สถานที่ตั้งดีมาก สะดวก ใกล้รถไฟฟ้าใต้ดินและแหล่งช้อปปิ้ง ห้องพักสะอาด อาหารเช้าดี สมราคาค่ะ
# 8.5
# ทำเลดี พนักงานต้อนรับดี ห้องสะอาด ราคาเบาๆ
# 8.5
# ทำเลสุดยอด สะดวกสบาย ห้องพักสะอาด ที่นอนดีมาก
# 10
# ชอบ มาพักบ่อย เดินทางสะดวกมาก พนง.บริการดี
# 8.5
#
# 10
# ห้องพักสะอาด พนักงานบริการด้วยความเป็นมิตร อาหารเช้าหลากหลายรสชาติถูกปาก เครื่องดื่มต้อนรับสุดยอด สระว่ายน้ำสะอาด
# 9.7
#
# 9.4
# รร สวย สะอาด บริการดี เดินทางสะดวก ใกล้ mrt มากๆ ใกล้ห้าง พักบ่อยมากและจะมาใช้บริการอีก
# 9.4
# อาหารเช้าดีมาก พนักงานบริการดี

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 10
# สะดวก สะอาด ห้องดี คุ้มราคา เหมือนอยู่คอนโด มีสระว่ายน้ำ
# 9.7
# ห้องสะอาด วิวสระว่ายน้ำดีมาก โปรดีอีก 1 แถมใกล้แหล่งของกินด้วย สะดวกสุดๆ
# 9.7
# ยอดเยี่ยมมากครับ หรูหรา คุ้มค่าราคามากๆครับ 10/10 ครับผม
# 8.5
# เดินทางสะดวก บริการดี ราคาดีครับ
# 9.7
# สะอาด เป็นส่วนตัว สิ่งอำนวยความสะดวกมีครบ
# 9.4
# ที่พักตรงปก สะอาด บรรยากาศชั้นสระว่ายคือดี มีเซเว่นใต้โรงแรม เดินทางสะดวกมาก ใกล้ Mrt สุดๆ
# 8.5
#
# 8.5
# ห้องพักสะอาด บรรยากาศดี แอร์เย็นมาก สะดวกในการเดินทาง ติดถนนใหญ่
# 8.5
#
# 8.5
# ห้องพักสะอาด ความปลอดภัยดีเยี่ยม

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# ห้องพักสะอาด พนักงานให้บริการดีมาก
# 8.5
# ห้องพักสะอาด จัดได้สวยงาม สระว่ายน้ำวิวดี บริการอาหารเช้ายอดเยี่ยม
# 8.5
# Location สะดวก ราคาดี ยกเว้นความสะอาดยังไม่เรียบร้อยเท่าที่ควร
# 8.5
# ห้องดี เตียงกว่า ใกล้ยูเนี่ยนมาก
# 5.7
# ห้อง ไม่ตรงตามต้องการ เลือกแบบมีระเบียงไป ครับ แต่ไม่ได้ห้องแบบมีระเบียง
# 8.5
#
# 8.5
# โรงแรมสวยบริการดีมากค่ะ พนักงานน่ารัก ยิ้มแย้มตลอด ห้องสวย สะอาด อยู่ใกล้แหล่งช๊อปปิ้ง สะดวกสะบาย ดีเยี่ยมทุกอย่าง เริศค่ะ😊❤
# 8.5
# ห้องสะอาด พนักงานบริการดีมากๆค่ะ
# 8.5
# ดีมาก ๆ สะดวกสบาย คราวหน้ากลับมาพักอีก เตียงนุ่ม
# 8.5
# ได้ห้องวิวสระตามที่ request พนักงานบริการและอัศยาศัยดี

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
#
# 9.7
# สะดวกสุดๆชอบโลเคชั่นที่นี้มากๆ+ราคาก็โดน
# 8.5
# ชอบมากครับมาพักหลายครั้งแล้ว ใกล้กับห้างและสะดวกในการเดินทาง ราคาจับต้องได้ ห้องกว้าง
# 9.7
# เป็นที่พักที่ยอดเยี่ยมมากๆในทุกๆด้าน ห้องใหม่ สะอาด ทำเลดีเยี่ยม จนท.ทุกส่วนบริการดีสุดๆ มีสิ่งอำนวยความสะดวกมากมาย ใกล้ห้างสรรพสินค้า ติดรถไฟฟ้าใต้ดิน เดินทางสะดวกง่ายดาย ชอบและประทับใจที่สุด และจะพักโรงแรมนี้ตลอดไปหากยังคงรักษามาตรฐานได้ดีเช่นนี้ค่ะ
# 8.5
# ดีมากๆค่ะ ใกล้ห้าง ใกล้ mrt bts ไปไหนมาไหนสะดวกค่ะ
# 9.4
# เดินทางสะดวกใกล้ MRT พหลโยธิน มีร้านสะดวกซื้ออยู่ในตัวอาคารของโรงแรม
# 8.4
# สถานที่คุ้มค่ากับราคามากๆ ค่ะ
# 9.7
# ห้องกว้างปลอยภัยดี ที่เด่นสุดคืออยู่ใกล้รถไฟฟ้ามาก บีทีเอสมีทางเชื่อมแล้วด้วย เวลาหิวก็มีเซเว่นในตัวอาคาร ลงMRT ข้ามฝั่งไปยูเนี่ยนกับเซนทรัลลาดพร้าวรึจะต่อไปแถวเกษตรก็ได้ มีwelcome drinkด้วย ฟิตเนสก็ครบครันดี อุปกรณ์คุณภาพสูงกว่าทั่วไป แต่หักคะแนนเรื่องคีย์การ์ด มัดจำ500 เยอะไปหน่อยถือเป็นค่าตกใจ
# 8.5
# สะดวกสบายใกล้รถไฟฟ้า ใกล้ห้างสรรพสินค้าต่างๆ
# 9.4

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# ห้องพักดี สะอาด อาหารอร่อย มาพักเป็นประจำทุกเดือน
# 6.6
# มีเสียงเคาะอะไรก็ไม่รู้ดังมาจากผนังห้องข้างๆ โทรไปถามที่ฟร้อน ฟร้อนบอกไม่มีคนพักนะ งงจะไม่มีคนพักได้ไง เสียงเคาะดังทั้งคืน ยิ่งช่วงดึกๆเคาะดังนึกว่าคนเมาทะเลาะกัน
# 6
# ไฟตก น้ำไหลเอื่อยมาก ลงไปแจ้งปัญหาบอกเป็นทั้งตึก
# 6
# พัก2วัน ทำคีย์การ์ดให้วันเดียว ต้องลงมาแจ้งใหม่เข้าห้องไม่ได้ ขอวิวสระ ก็ได้ห้องสุดท้ายแบบไม่เห็นวิวเลย มื้อเช้า รร. ก็แย่ลงทุกวัน อาหารมีให้เลือกน้อย
# 8.5
# ห้องพักสะอาดได้มาตรฐาน เสียแต่วิวไม่ดีเท่าไร
# 9.4
# โรงแรมดีมาก ดีเหมือนพนักงานเลย เตียงนุ่มสุด แนะนำให้มาพักเลย อย่างชอบ ไว้วันหลังจะไปอีก🥰
# 9.7
# ห้องพักสะอาด การเดินทางสะดวกมากๆ ประทับใจคะ
# 9.7
# ที่พัก ดีมาก สะอาด สวยงาม สิ่งอำนวยความสะดวกครบ เดินทางสะดวก ใกล้ห้างสรรพสินค้า พนักงานน่ารัก
# 8.5
# ดีค่ะ สะอาด เดินทางสะดวกมีMRT อยุ่หน้ารร.
# 8.5
# บริการดีมาก พนักงานยิ้มแย้ม ห้องสะอาด ติดรถไฟฟ้า ติดห้าง

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 6
# ที่จอดรถหายากทุกครั้งที่ไป จนจำแล้วว่าไปพักที่นี่จะต้องขุ่นใจเรื่องที่จอดทุกครั้ง
# 9.7
# เดินทางสะดวก ที่พักสบาย ใกล้เซนทรัลฯ หาของกินง่าย
# 8.5
# ดีมาก ติดอย่างเดียวผนังบางไปนิด
# 6
# พื้นที่ล็อบบี้แคบที่นั่งไม่พอ พอเวลารอก็นานแล้วพนักงานก็พูดไม่ค่อยโอเค ผ้าห่มมีกลิ่นเหม็น ชอบตรงแอร์เย็นสะใจ
# 6
# ไม่ได้เรื่องค่ะ รีเซฟชั่นหน้าตาไม่รับแขกมาก รีเควสเตียงเดี่ยว ก็เอาเตียงคู่มาให้ พอโทรสอบถามตอบมาห้วนๆว่าเต็ม จะไม่กลับมาใช้บริการอีก
# 10
# เดินทางสะดวก ใกล้ mrt อาหารอร่อย บริการประทับใจมากค่ะ
# 10
# ดีมาก ถ้าเข้า กรุงเทพฯ อีก ก็จะเลือกที่นี่
# 8.5
# วิวดี เดินทางสะดวก ใก้ mrt มากๆ มีเซเว่นข้างล่าง เวลาหิวกลางคืน ด้วย 55555 เดินข้ามสะพานก้เจอแหล่งช็อป ใกล้ยูเนี่ยนและเซนทรัลลาดพร้าว
# 9.1
# พนักงานต้อนรับหน้าโรงแรมที่ดูแลกระเป๋าดูแลดีมากกกก พนักงานหน้าฟร้อนท์ควรจะอาย ไม่บอกอะไรนอกจากเบอร์ห้อง ลิฟท์ทางไหน พนักงานที่ส่งกระเป๋าต้องมาคอยบอกว่าห้องยิมอยู่ตรงไหนไปยังไง กินเช้าที่ไหน ห้องพักสะอาดสะอ้านดีมาก เตารีดมีบริการถ้าขอใช้ สถานที่ตั้งคือเป็นเลิศ อยู่ใกล้กับ MRT ตรงข้ามกับยูเนี่ยนมอลล์ กลับไปพักอีกแน่นอน
# 9.7
# ได้ห้องตรงตามที่แจ้งขอไว้ทุกครั้งค่ะ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
#
# 8.5
# ที่พักดี ห้องสวย สะดวกสบาย เดินทางง่าย มี MRT ฝั่งตรงข้ามเป็นยูเนี่ยนมอลล์ และเซ็นทรัลลาดพร้าว คุ้มค่ามากๆค่ะ
# 8.5
# ทำเลดีมากครับ สะดวกมากในการเดินทาง
# 9.4
# มาพักหลายครั้งและประทับใจทุกครั้งเลยค่ะ เดินทางสะดวกใกล้mrt เดินหาของกินง่าย พนง.บริการพูดดีทุกครั้งเลยค่ะ ห้องสวยสะอาดและดูใหม่จริงๆ
# 8.5
# อยู่ติดmrt ตรงข้ามยูเนียนมอลล์ เดินทางสะดวก ปลอดภัย ห้องพักสะอาด พนักงานมีความสุภาพ ยิ้มแย้มแจ่มใส
# 6.4
# ที่จอดรถมีน้อยมาก และให้จอดห้องพักละ 1 คัน มาสองคัน ต้องเสียค่าจอดรถรายชั่วโมง
# 8.5
# โรงแรมบริการดีมากๆค่ะ ที่พักสะอาด
# 9.4
# มาพักครั้งที่สองแล้วพนง.ต้อนรับดีมากๆ ให้ความช่วยเหลือได้ดี ห้องดีเหมือนเดิมแต่ติดตรงที่ในห้องน้ำมีเศษขยะนิดนึงแล้วก็ปลอกหมอนมีรอยเปื้อนนิดๆ เดินทางสะดวกเดินไปกินข้าวซื้อของได้สบายมากๆ
# 8.8
# ไปพักหลายรอบแล้ว ห้องสบายสะอาด และเดินทางสะดวกมากๆ
# 10
# ประทับใจมาก แต่วันเช็คอินค่อยข้างช้า อาจเพราะคนเยอะด้วย มี welcomedrink บัตรส่วนลดค่าอาหาร ห้องพักสะอาด หอมมาก อุปกรณ์ภายในห้องครบ ถ้ามีโอกาศจะมาเข้าพักที่นี้อีกเรื่อยๆ ใกล้ mrt มากที่สุดของที่สุด ลืมชม พนักงานที่นี้น่ารักนะคะ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 6.2
# ที่จอดรถน้อยมาก จอดรถยากมากถึงยากที่สุด
# 6
# ระวังเขาจะว่าคุณทำผ้าเปื้อนแล้วซักไม่ออก คิดผืนละ 200 ผมเช็ดหน้ามีรองพื้นติดประมาณ จุดสองจุด แล้วฟร้อนยังบอกอีกว่าถ้าซักออกก็คิดผืนละ 100 อยู่ดี ผมเลยบอกว่างั้นผมเอาไปซักเอง ถ้าออกผมเอาเรื่อง ถึงยอมคืนมัดจำ แย่มาก ผมพักที่นี้หลายครั้งเพราะเดินทางสะดวก คงต้องหาที่อื่นแล้วละ
# 8.8
#
# 9.7
# ห้องพักสะอาดมาก มีสิ่งอำนวยความสะดวกครบครัน เตียงใหญ่มากๆ ห้องน้ำสะอาด มีโต๊ะให้นั่งทำงานด้วย บรรยากาศโดยรวมดีมาก พนักงานต้อนรับบริการดี
# 8.5
# ห้องพักสะอาด บรรยากาศดี พนักงานต้อนรับบริการดีมาก
# 5.5
# เช็กอิน จองเตียงคิงไซด์ หน้างานบอกเต็ม มื้อเช้าเปิดถึง 10.30 ลงไป 9.30 ไม่เติมอาหาร และของกินไม่หลากหลาย
# 9.1
# ทุกอย่างดีหมด มาเสียตรงเป็นที่พักแท้ๆแต่หมอนไม่ไหวเลย แบนยิ่งกว่าอะไรดีนอนไม่สบายเอามากๆ
# 8.5
# ดีงามมากหรูหราเกินราคา ชอบการบริการดี ห้องพักมีครบ มีได มีร่ม มีทุกอย่าง
# 8.5
#
# 9.4
# ได้ยินเสียงทีวีห้องข้างๆชัดมาก ทำให้รบกวนการนอน นอกนั้นดีหมดค่ะ

# %%
for i in range(3):
    sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
    sel.click()
    time.sleep(2)
    clear_list(reviews_list,ratings_list)
    scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# เดินทางสะดวก ใกล้ mrt โรงแรมสะอาด พนักงานบริการดี อยากให้มีเมนูอาหารเช้าที่หลากหลายกว่านี้ โดยรวมผ่านครับ
# 9.4
# ดีมาก ห้องเป็นสัดส่วน อุปกรณ์ สิ่งอำนวยความสะดวกครบครัน สะอาด เดินทางสะดวก ใกล้ย่านการค้า
# 9.7
# โรงแรมดีมากสะอาดต้อนรับดีมากค่ะ
# 7.2
# ห้องไม่เก็บเสียง ได้ยินเสียงข้างห้องพูดคุยกันพอฟังเข้าใจ ควรปรับปรุงในจุดนี้ เรื่องความเก็บเสียงของห้องพัก
# 9.1
# ห้องสะอาดดีครับ บริการก็ประทับใจ ห้องสวย ใหม่เอี๊ยม วิวดี มีโอกาสจะไปใช้บริการอีกครับ
# 9.4
# ห้องพักสะอาด มีสิ่งอำนวยความสะดวกครบครัน การเดินทางด้วยระบบขนส่งสาธารณะสะดวกมาก
# 9.4
# สิ่งอำนวยความสะดวกครบครัน ห้องสะอาด พนง.ต้อนรับพูดจาดีทั้งกะเช้าและเย็น เดินทางง่าย สะดวก ไม่ต้องเข้าซอยลึก
# 8.5
# น้ำไหลแรง ห้องสวย พนักงานต้อนรับดี เงียบ สงบ เหมาะแก่การพักผ่อน
# 9.3
# ได้ห้องตรงตามที่ระบุขอไว้"วิวสระว่ายน้ำ" ห้องสะอาดเรียบร้อย ครั้งนี้ได้ห้องหน้าลิฟต์ เสียงไม่ดังมาก ดีค่ะ
# 6.4
# พัก10ครั้ง check in และ Check out ช้า10ครั้ง พนักงานในcounter 4-5คน ก็ยังช้า
# 8.5
# ห้องสะอาด หรู ดูดี พักสบาย วิวสวย เซเว่นพร้อมมากกก แนะนำเลย พักสบาย ทำงานก็ได้
# 9.1
#
# 9.7
# เดินทางสะดวก ห้องพักสะอาด พนักงานบริการดีมาก
# 8.5
#
# 10
# มาพักครั้งที่ 2 แล้วถูกใจเหมือนเดิม พนักงานบริการดีทุกคน โดยเฉพาะน้องอุ้มกับน้องฉัตรพูดดีบริการดีมาก รอบหน้าต้องมาอีกแน่ๆ
# 9.7
# ห้องพักดีมากเหมาะสมราคาที่สุด ไม่มีเสียงดังรบกวนหลับสบายมากๆ
# 9.7
# ได้ห้องตามที่ต้องการ ได้เตียงตรงตามที่ขอ
# 9.7
# ได้ห้องตามที่ขอไว้ในคำขอพิเศษ, check in ตามเวลาเท่านั้น 14.00น.
# 8.5
# ผมมาพักที่นี่หลายครั้ง ข้อดีของที่นี่มากมายเริ่มตั้งแต่จุดที่ตั้งอยู่ในทำเลดีมากใกล้ห้างสรรพสินค้า สะดวกในการเดินทางและอาหารการกินขนาดของโรงแรมไม่เล็กและใหญ่อลังการเกินไป พนักงานปฏิบัติหน้าที่ได้มาตรฐานไม่มีข้อตำหนิ ระบบความปลอดภัยดีมาก ไม่มีการ์ดขึ้นลิฟท์ไม่ได้ ภายในห้องพักดีมากแม้จะไม่ใช่ห้องกว้างใหญ่แต่ไม่เล็กกำลังพอดี ในห้องมีทีวี ตู้เย็น โต๊ะทำงาน มินิบาร์ wifi ห้องน้ำสะอาด น้ำแรง อุปกรณ์ครบครัน ระบบไฟในห้องเพียบ ปลั๊กไฟมีให้หลายจุด เขียนชมมาหลายบรรทัดจนเมือยมือยังจาระนัยไม่ครบ เอาเป็นว่าที่นี่ดีที่สุดสำหรับผม สุดท้ายนี้ขอฝากชมแม่บ้านด้วย ผมยืมเตารีดทุกครั้งที่ไปพักโทรยืมปุ๊บมาปั๊บเลย ที่น่สุดยอดครับ
# 9.7
# บริการดีมาก ห้องเงียบมากไม่มีเสียงรบกวน บรรยากาศดี ใกล้ MRT ทางออก 1 มีโอกาสจะกลับไปอีก
# 6
# เช็กอิน เช็คเอ้า ช้าตลอด ทุกครั้ง
# 9.4
# พนักงานบริการดีมาก อยู่ใกล้ mrt พหลโยธิน เดินทางสะดวก
# 9.1
# มาพักหลายครั้งแล้ว ครั้งนี้ไม่ชอบที่สุด ตรงที่เสียงพนักงานแม่บ้านที่ทำความสะอาดห้องคุยกันเสียงดังมากและเป็นเวลานาน ตั้งแต่เริ่ม check in จนถึงเวลาประมาณ 18.00น. เสียงคุยกันจึงเงียบลง (พักชั้น 10)
# 9.4
# พักหลายครั้งแล้ว รู้สึกดีที่มาพักทุกครั้ง ครั้งล่าสุด 3 มิ.ย.2563 แต่ไม่ได้ห้องวิวสระว่ายน้ำตามที่ระบุขอพิเศษไว้ ไม่เป็นไร 4 ก.ค.2563 จองใหม่และขอใหม่(อีกครั้ง) มาดูกันว่าจะได้หรือไม่
# 8.5
# คือตอนนีราคาดีงาม อาหารเช้าดีเวอร์
# 9.7
# ดีมากค่ะ ได้ห้องพักวิวหลักล้านแต่ราคาไม่ถึงพันค่ะ 💓 แล้วจะกลับมาพักใหม่ค่ะ ชอบที่สุด แต่เรามาช่วงโควิดเลยไม่ได้ลงสระน้ำ
# 10
#
# 8.8
# ดีค่ะโดยรวมทุกอย่างที่เป็นอยู่
# 8.5
# ไปทำงานแถววิภาวดี ที่พักสะดวก ตรงข้ามห้างยูเนียนมอล มีสถานี MRT อยู่หน้าโรงแรม มีเซเว่นหน้าโรงแรม คือสะดวกทุกอย่าง อยู่10 วัน พนักงานน่ารัก แม่บ้านทำความสะอาดห้องเยฝนี่ยบมาก แต่ที่จอดรถ เดินไกลนิดนึงเพราะอยู่หลังตึก
# 8.5
# โรงแรมสวย มีระดับ ใกล้MRT ยูเนี่ยนมอล์ เซ็นทรัลลาดพร้าว แต่ห้องไม่ค่อยเก็บเสียง ข้างๆห้องเปิด-ปิดประตูได้ยินหมดเลย

# %%
for i in range(10):
    sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
    sel.click()
    time.sleep(2)
    clear_list(reviews_list,ratings_list)
    scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    print('----------------------------------------------------','\n')
# Out:
# 8.5
# ห้องสะอาด ทำเลดี การต้อนรับที่เป็นกันเอง
# 9.4
# บริการดี ห้องสะอาดเห็นวิวชัด ที่สำคัญอาหารอร่อยค่ะ
# 9.7
# เดินทางสะดวก อยู่ติดกับ MRT อาหารเช้าดี
# 5.7
# พนักงานทำหน้าตาไม่ค่อยดี ควรแจ้งรายละเอียดของโรงแรมให้เยอะกว่านี้
# 9.7
# พนักงานต้อนรับสุภาพมากคับ แล้วก็ประทับใจมากเมื่อพนักงานรู้ว่าเราเคยมาพักที่นี่แล้ว เหมือนเขาเก็บข้อมูลลูกค้าไว้ด้วย
# 8.8
# ห้องสะอาด บริการดี มีเซอร์วิสตลอด24
# 10
# ขอบคุณคุณส้ม ขอบคุณ พนักงาน ที่ดูแลดีมาก ตั้งแต่ให้เช็คอินล่วงหน้า ค่ะ
# 10
#
# 9.1
# ห้องพักดีมาก สถานที่ก็ใกล้ ห้าง ใกล้ MRT เดินทางสะดวก แต่ห้องน้ำมีกลิ่นท่อระบายน้ำอับๆค่ะ
# 8.5
# ห้องพักดี ทำเลดีมากติดรถไฟฟ้า mrt พหลโยธิน อาหารเช้าเย่อะ แต่ติดตรงทีแขกชาวจีนเสียงดังมาก 10/8
# ----------------------------------------------------
#
# 8.5
# ห้องเหมือนในรูป กว้าง สบาย สะอาด ใกล้ยูเนี่ยนมอล มีเซเว่นหน้าตึก
# 10
# นอนหลับสบายดีมากค่ะ เทคเเคร์ดีมาก
# 9.7
# ใกล้แหล่งช้อปปิ้ง เดินทางง่าย พนักงานน่ารัก ห้องพักสะดวกสบาย อาหารเช้าอร่อยมีให้เลือกเยอะ สิ่งอำนวยความสะดวกครบครัน มีโอกาสอยากจะไปอีกคะ
# 9.4
# พักเป็นครั้งที่สองแล้วประทับใจทุกครั้ง แต่ครั้งนี้แอบมีข้อเสียนิดหน่อย
# 9.7
# ห้องกว้าง มีอุปกรณ์ครบครัน ตกแต่งดี อยู่ในทำเลที่ติดรถไฟใต้ดินพหลโยธิน สามารถเดินไปห้างเซนทรัลลาดพร้าว และยูเนี่ยนมอลล์ได้อย่างง่ายดาย มีร้านกาแฟ ร้านชาบู ร้านทำเล็บและเซเว่นอีเลฟเว่นอยู่ด้านล่าง และไม่ไกลจากร้านอาหารตามสั่ง หรือจะสั่งอาหารของทางโรงแรมไปทานบนห้องก็ได้ สะดวกปลอดภัย แต่อยากจะคอมเม้นเรื่องมีเสียงดังรบกวนจากคนเดินและห้องข้างๆมากไปหน่อย ทำให้พักผ่อนได้ไม่สนิท
# 9.7
# ไปกรุงเทพทุกครั้งนึกถึงโรงแรมนี้เป็นอันดับแรก ประทับใจตั้งแต่ครั้งแรกที่ไป ที่ตั้งสะดวกสบาย ห้องสะอาด สบาย พนักงานบริการดียิ้มแย้ม ขอเสนอแนะนิดหนึ่งขอให้เพิ่มเสื้อคลุมในห้องพักก็จะดีมากค่ะ
# 8.5
# ที่พักประจำ เดินทางสะดวก พนักงานน่ารัก กาแฟร้านข้าง อร่อย มี7-11ติด รร
# 9.4
#
# 10
# ประทับใจมากๆ พนักงานบริการดีมากยิ้มแย้มตลอด โดยเฉพาะน้องAUM เอาใจใส่มาก ทักทุกรอบที่เจอเลย ประทับใจมากเลยค่ะ
# 9.7
# เดินทางสะดวกมากไกล้รถไฟฟ้าใต้ดิน ห้องกว้างเหมือนในรูปสะอาดมากบรรยายกาศดีมากค่ะ มีบริการทำความสะอาดห้องพักให้ถ้าพักหลายวัน อาหารหลากหลายรสชาติอร่อย แต่ติดนิดเดียวพนักงานต้อนรับช่วง05.00-06.00สีหน้าคำพูดไม่ค่อยโอเค พนักงานเก็บกระเป๋าบริการดีมากพูดจาดีมาก แต่โดยรวมโรงแรมดีมากๆค่ะ
# ----------------------------------------------------
#
# 10
# ดีมาก ที่ตั้ง ความสะอาด พนักงาน อาหาร ให้ 10 คะแนนเต็ม
# 10
# ห้องสะอาด พนักงานน่ารัก อยู่ใกล้ mrt bts เดินทางสะดวก
# 8.5
# เป็นโรงแรมที่มาพักบ่อยที่สุด สะดวกไปหมดทุกอย่าง อาหารเช้าอร่อย ชั้นล่างมี7-11 คลีนิคทำฟัน ร้านกาแฟ คลีนิคเสริมความงาม ฝั่งตรงข้ามก็ยูเนียลมอล์ แค่นี้ก็สบายมากๆแล้ว
# 8.8
# ใกล้mrtพหลโยธินมากๆ ห้องพักสะอาดดี แต่ผนังห้องค่อนข้างบาง เสียงห้องอื่นลอดเข้ามาบ้างรวมถึงเสียงคนเดิน
# 8.5
# ทำเลดี เดินทางสะดวก ใกล้ห้าง พนง.บริการดี มาพักเป็นประจำค่ะ
# 9.4
# สะดวกมากๆ เซเว่นก็อยู่ด้านล่างโรงแรมเลย จะเดินไปยูเนี่ยนก็รวดเร็ว mrt ก็ไม่ไกล
# 9.7
# พนักงานต้อนรับดูแลดี คอยช่วยเหลือดีมาก
# 9.4
# ห้องพักสวย ไม่มีเสียงรบกวน สะอาด จัดแต่งสไตล์โมเดิร์น เครื่องใช้อำนวยความสะดวกต่างๆพร้อมใช้งาน+ครบวงจร มีความปลอดภัยดี ที่สำคัญเดินทางสะดวก เพียงไม่กี่ก้าวถึง MRT station แล้ว และอยู่ใกล้ศูนย์การค้า หาร้านอาหารง่าย การบริการดี Check in -Check out รวดเร็ว
# 9.1
# พนักงานน่ารักเหมือนเดิม รอบนี้มาตรงกับมีงานคอนเสิร์ตคนเยอะนิดนึง แต่ก็โอเครในความน่ารักของพนักงาน
# 8.5
# สะดวก ใกล้ยูเนียน mrtพหลโยธินทางออก1
# ----------------------------------------------------
#
# 9.7
# โรงแรมสะอาด สวยงามดังรูป ล็อบบี้โรงแรมหรูหรามาก ทางเดินภายในโรงแรมไม่ไกลเกินไป ไม่น่ากลัว ดูดี มีลิฟท์หลายตัว พนักการบริการดีมาก น่ารัก อัธยาศัยดี ห้องพักกว้างพอใช้ได้ มีโต๊ะทำงาน ตู้เย็น ทีวีขนาดใหญ่ มีไฟหลายดวงรวมทั้งโคมไฟแล้วแต่การเลือกใช้ แอร์เป็นแอร์ฝังกับผนัง ห้องน้ำไม่ใหญ่มากอุปกรณ์ภายในห้องน้ำดีครบครัน สบู่ น้ำยาสระผมให้มาเป็นขวดฝากดใช้ง่ายสะดวก ห้องอาหารอยู่ชั้น6 มีเวลคัมดริ้งให้ฟรี ถ้าซื้อในราคารวมอาหารเช้าด้วยก็คุ้มค่า มีสระไหว้น้ำ ฟิตเนส โรงแรมอยู่ตรงข้ามกับหน้ายูเนียนมอลเลยเดินทะลุmrtนิดเดียวก็ถึง เอาเป็นว่าสะดวกมากๆค่ะ ถ้าเต็ม10ก็ให้9.5ค่า หักค่าความไม่ถูกของค่าห้อง55 จริงๆเราว่าก็สมราคาแหละ ถ้ามา2คนก็หารกันออกไม่เกิน1000ต่อคืนแน่นนอนค่า (ปล.เราจองผ่านแอพนะคะ)
# 10
# ห้องสะอาด อุปกรณ์ครบมาก พนักงานบริการดี เดินทางสะดวก มีเซเว่นอยู่ด้านล่างสะดวกมาก สรุปดีมากเว่อค่ะ
# 9.7
# สะอาดดีครับ ห้องใหญ่กว่าที่คิดไว้ ติดกับรถไฟฟ้าใต้ดิน และใกล้กับบีทีเอสห้าแยกลาดพร้าวด้วย เดินทางไปไหนก็สะดวก
# 9.7
# เดินทางสะดวกมากครับ MRT ประตู3 ติดกับโรงแรมเลย
# 9.7
# เดินทางสะดวก พนักงานดูแลดี ⭐
# 9.1
# สะอาด สะดวก สบาย very good service and nice location
# 8.5
# บริการดีมากค่ะ ถ้าได้มา กทม. จะมาพักอีกแน่นอนค่ะ
# 10
# ดีมาก เข้าพักกี่ครั้งไม่เคยผิดหวังเลยค่ะ ดีหมดทุกอย่าง ประทับใจมากๆ
# 6.9
# น้ำร้อนเย็นของฝักบัวไม่สม่ำเสมอ ทำให้เกิดการลวกเมื่อคนอื่นปิดน้ำ แต่เรายังเปิดอาบอยู่ โดนไปหลายครั้งทั้งเจ็บและตกใจ
# 10
# เดินทางสะดวก ติดรถไฟใต้ดิน mrt พหลโยธิน ประตู4 เดินออกมาก็เห็นเลย อีกฝั่งเป็นห้างยูเนี่ยนมอล์ ของเยอะเดินสนุก จะเดินไปเซ็นทรัลลาดพร้าวก็ง่ายค่ะ พนง.บริการดี ห้องกว้างใช้ได้ อาหารเช้าดี มีให้เลือกเยอะ จะกลับไปใช้บริการอีกค่ะ
# ----------------------------------------------------
#
# 8.5
# รร.ใกล้รถไฟฟ้าใต้ดิน mrt สถานีพหลโยธิน ซ.4 เดินทางสะดวกมากค่ะ ตรงข้ามเป็นห้าง ยูเนี่ยนมอล เซ็นทรัลลาดพร้าว อาหารเช้ามีให้เลือกเยอะ พนง.บริการดีค่ะ
# 10
# พักสบายมากค่ะ ใกล้รถไฟฟ้าใต้ดิน
# 9.7
# ห้องพักใหม่ สะอาด ราคาไม่แพง แถมยังอยู่ใกล้สถานีรถไฟฟ้าmrt ห้างยูเนียนมอลล์ด้วย
# 9.7
# ห้องสะอาด พนักงานยิ้มแย้ม ต้อนรับดีมาก และที่สำคัญสะดวกต่อการเดินทาง
# 9.1
# ดีค่ะ พนักงานบริการดี ห้องพักกับราคาเหมาะสม เดินทางสะดวก ใกล้แหล่งช๊อปปิ้ง
# 10
# ดีมากๆเลยค่ะ ถึงจะเล็กแต่เตียงนอนสบายมาก เพราะเป็นเตียงคิงส์ไซส์ กลิ้งได้แบบไม่ตกเตียงเลย อาหารเช้าก็อร่อย จะกลับไปพักอีกแน่นอนค่ะ พนักงานฟร้อนเองก็น่ารัก พูกจาไพเราะ ยิ้มแย้มดี โอเคดีทุกอย่างเลยค่ะ
# 9.7
# ดีมากค่ะ บริการดี เดินทางสะดวก ประทับใจมากค่ะ
# 8.5
# ใหม่สะดวกสบาย บริการโอเค คุ้มค่าเกินราคา
# 9.7
# ดีมากดีทุกอย่าง แนะนำมากๆ เครื่องอำนวยความสะดวกครบครัน
# 10
# เยี่ยมเลย คุ้มจริงๆใหม่สะอาด สะดวก ติดmrt อาหารเช้าดี มีสระน้ำ สุด
# ----------------------------------------------------
#
# 10
# ดีที่สุด สะดวกที่สุด ทุกอย่างคือดี พักมา3รอบแล้ว ดีที่สุด ตรงข้ามยูเนี่ยนเลย เดินทางสะดวก บริการดี ห้องสะอาด วิวดี คือทุกอย่างดีมากๆ จบ
# 9.7
# ดีมากค่ะ นอนหลับสบาย น้ำไหลแรง เดินทางสะดวกมากๆ พนักงานยิ้มให้ตลอด
# 8.5
# บริการดีมากๆ ที่พักสะดวกในการเดินทาง อาหารเช้ามีให้เลือกเยอะ และอร่อยมากค่ะ ครั้งหลังจะไปพักอีก
# 9.7
# สวย สะอาด สะดวก สบาย สงบ พนักงานต้อนรับน่ารัก ^^
# 6
# ลืมสายชาร์ทโทรศัพท์ไว้ เช็คเอ้าท์วันที่12ออกไป1ชม โทรกลับมา บอกหาเจอเเล้วค่ะ จะมารับหรือยังไงด้ เลยบอกว่าฝากไว้ก่อนนะเที่ยวหน้าจะมารับคืน วันที่23โทรว่าจะเข้าไปรับ บอกไม่มีของ เเล้วไม่เจอ คืองงมากว่ายังไงกับของที่บอกเก็บไว้ให้เเล้ว แต่วันนี้บอกไม่มีของละ
# 8.2
# ก็ดีแหละค่ะ แต่ King Bed คือ เอาเตียงเล็ก 2 เตียงมาต่อกัน คิดว่าดีไหมล่ะคะ
# 9.4
# จองห้อง deluxe เตียงใหญ่ไป แต่ได้ห้องเอาเตียงคู่มาต่อกัน
# 9.7
# ห้องเหมือนในรูปเลยค่ะ สะอาด สะดวก สบาย อาหารเช้าก็มีให้เลือกหลากหลาย มีครั้งต่อไปแน่นอนค่ะ
# 8.5
# การเดินทางสะดวก ใต้โรงแรมมีเซเว่น ใกล้แหล่งช็อปปิ้ง
# 9.7
# บริการดี บรรยากาศดี เป็นครั้งที่2ของการพักที่นี่ และมั่นใจว่าจะมีครั้งที่3 หากบริการดีแบบนี้ต่อเนื่อง ควได้เป็นลูกค้าประจำแน่นอน
# ----------------------------------------------------
#
# 9.7
# ดีมากๆครับ ใกล้ยูเนียนมอล,Mrt สะดวกมี7-11อยู่ชั้นล่าง ห้องสวย พนักงานบริการดีครับ
# 10
# ห้องใหม่ สะอาด ขนาดกำลังดี ไม่อึดอัด อาหารอร่อยค่ะ เดินทางสะดวก ติดรถไฟฟ้า
# 9.4
#
# 9.7
# เดินทางสะดวก ติดรถไฟฟ้าMRT ห้องพักสะอาด อยู่ใกล้กับห้างเซ็นทรัลลาดพร้าว
# 8.7
# 👧🏻👧🏻ครอบครัวมีเด็กเล็กคะ👧🏻👧🏻 ข้อดี : พนักงานต้อนรับน้องผู้ชายดูแลดี พูดจาดีมากๆคะ ดูนอบน้อมดีมากๆ วันเช็คเอ้า ไปเที่ยวกลับมาเอารถ ยังทักทายและให้ขนมเด็กๆด้วย น่ารักมากคะ --- ที่พักใหม่เปิดยังไม่ถึงปีเลยคะ ห้องพักที่เตียงนอนสบายมากคะ ห้องน้ำแบ่งพื้นที่ได้ดีเลยคะ ---สิ่งอำนวยความสะดวก มีสระว่ายน้ำ มีฟิตเนส แล้วตรงข้ามห้างสรรพสินค้าชั่นนำด้วยคะ ใต้ตึกมี7/11 (แต่ไม่มีแอลกอฮอล์ขายนะคะ) เดินออกมาปากซอยนิดเดียวถึง ขนส่งสาธารณะ(รถไฟฟ้ามหานคร Mrt สถานี พหลโยธิน เลยคะ) พักที่นี้ไม่ได้ใช้รถเลยคะ จอดไว้โรงแรมตั้งแต่ไปถึงจนวันกลับเลยคะ ----พัก2คืนคะ คืนที่2จ่ายเงินสดคะเพราะต้องการใบกำกับภาษี☺️☺️ ---อาหารเช้ามีเยอะพอสมควรคะ รสชาติใช้ได้คะ ข้อควรปรับปรุง : พนักงานต้อนรับน้องผู้หญิง ควรพูดจาอ่อนกว่านี้จะน่ารักมากๆนะคะ พูดจาดูแข็งๆหรือดูเหมือนรำคาญคะเวลาถามเรื่องห้องและ ใบกำกับภาษีคะ ---หมอนหนุนในห้องแบนไปมากเลยคะ และนิ่ม นะจะเป็นแบบสูญญากาศจะดูโอเคและเข้ากับที่นอนมากคะ ที่นอนผ่าน หมอนไม่ผ่านคะ --- เรื่องน้ำที่ออกมาจากฝักบัวนะคะ แสบผิวมากคะเหมือนรีวิวอื่นๆที่ลงไว้เลยคะ (แต่ทางสามีชอบคะ😅😅) แต่เป็นเด็กกับผู้หญิงไม่ผ่านจ้า😊😊 ---เรื่องความสะอาดห้องจะมีเศษผมและขน....อยู่ตามซอกห้องและโซฟาข้างหน้าต่างเยอะเลยคะ (เด็กๆที่บ้านมีที่นอนไปกันเองเลยนอนพื่นคะ คือต้องเอาผ้ามาเช็ดพื้นอีกทีคะ ---ขอติเรื่องลงไปทานอาหารเช้านะคะ ทางฟร้อนท์ไม่ได้มีใบอะไรให้ไม่แนาใจลืมหรือไม่มีคะ พนักงานบาร์ต้องโทรถามกันเลยคะว่าห้องที่พัก ค่าห้องพร้อมอาหารเช้าไหม อันนี้ถือว่าไม่เรียบร้อยคะ 🛏🛏โดยรวมการเข้าพักครั้งนี้ประทับใจมากกว่าคะ🛏🛏😊😊😊😊
# 8.5
# อาหารเช้าหลากหลาย พนักงานดี ทีวีจอใหญ่ สระว่ายน้ำเป็นส่วนตัว เสียอย่างเดียวห้องยังเหม็นกลิ่นสีแรงมาก และหมอนบาง
# 6.5
# รอเช็คอินนานมากอยากให้ปรับปรุงจุดนี้
# 9.4
# ห้องสะอาด บรรยากาศดี ใจกลางแหล่งช้อปปิ้ง สะดวก พนักงานน่ารัก
# 8.5
# ห้องพักใหม่ ทำเลสะดวก ทีวีจอใหญ่ แนะนำๆ
# 9.7
#
# ----------------------------------------------------
#
# 8.5
# ดีมากๆค่ะ การเดินทางสะดวก พนักงานบริกาดี
# 9.7
#
# 9.1
# รร สบาย อาหารเช้า โดยรวมโอเค มี 7/11 ใต้ รร เสียหนึงอย่าง wifi ใช้ไม่ได้
# 10
# ห้องพักสะอาด อาหารอร่อย พนักงานบริการดีมาก ทีวีขนาดใหญ่ (ต่อเน็ตไว้ให้พร้อม)
# 8.5
#
# 9.4
# ดีทุกอย่างค่ะ ทั้งโลเคชั่น ความสะดวกสบาย พนักงานน่ารักตั้งแต่เบลบอยพนักงานตอนรับรวมถึงแม่บ้านด้วยนะคะ แต่ติดตรงที่ฝักบัวอาบน้ำค่ะ ตัวฝักบัวควรเปลี่ยนแบบดีกว่า ใช้แล้วน้ำที่กระจายออกมาทำให้เจ็บผิวนิดนึงค่ะ 🙂
# 9.7
# สะดวกสบายมากค่ะ ห้องสะอาด กว้าง
# 10
# ห้องสะอาด ติดรถไฟฟ้าใต้ดิน ติดที่ช้อปปิ้ง มีร้านสะดวกซื้อ 24ชั่วโมง สระว่ายน้ำและฟิตเนสบริการฟรี ตำหนิเรื่องเดียวประตูห้อง ควรเสริมเส้นยางกันกระแทกประตู หรือ ที่กั้นเสียงอีกนิด แล้วทุกอย่างจะดูดีมากๆ
# 8.8
#
# 9.7
# พักต่ออีกคืน บรรยากาศดี อยากพักเพิ่ม แต่ต้องไปที่อื่นต่อ เดินทางสะดวก เรื่องอาหาร สะดวกมาก เดินเที่ยวได้อีกฝั่ง
# ----------------------------------------------------
#
# 9.7
# เดินทางสะดวก ใกล้รถไฟฟ้าใต้ดินมากๆ ทางออกประตู4 ใต้ตึกมี7-11 ห้องกว้างใช้ได้ ใหม่ แอร์เย็น น้ำแรง ฝั่งตรงข้ามเป็นห้าง เดินสนุกค่ะ
# 10
# ห้องพักสะอาดสวยงาม ทำเลดีสะดวกมาก พนักงานบริการดีมากค่ะ
# 9.4
# โดยภาพรวมดี ใกล้ mrt และแหล่งช็อปปิ้ง ราคาเหมาะสม แต่ถ้าคุณจะแต่งหน้า ทำผม คุณต้องทำในห้องน้ำ เพราะกระจกมีบานเดียวในนั้น พนักงานต้อนรับที่เป็น ผญ บางคนดูไม่เป็นมิตรในน้ำเสียง ตอนระหว่างรอของมีพนักงานต้อนรับซึ่งเป็นเด็กใหม่มาขอข้อมูล ก็ทำท่าทีไม่พอใจและเหวี่ยงใส่รุ่นน้องต่อหน้าลูกค้า
# 6.3
# แอร์ไม่เย็นทั้งคืน เหม็นกลิ่นสี ไม่มีห้องเปลี่ยนให้ นอนดมกลิ่นสีทั้งคืน ปวดหัว และอาเจียน หลังจากเช็คเอาท์ ต้องหาหมอ ไม่สบาย
# 9.7
# เดินทางสะดวก ใกล้แหล่งท่องเที่ยว
# 9.1
# เป็นที่พักที่ดีมากค่ะ คุณพ่อไปหาหมอที่กรุงเทพ คุณแม่พาลูกๆเดินเล่น สบาย มีรถไฟฟ้าใต้ดิน ที่แบบเดินออกมาเข้ารถไฟฟ้าได้เลย สบายค่ะอาหารเช้าดีมาก โรงแรมสะอาด ที่นอนนี้แบบหลับไม่อยากลุกขึ้นเลยค่ะ เยี่ยมมาก
# 10
# สถานที่สะอาด พนักงานอัธยาศัยดี โรงแรมอยู่ใกล้ขนส่งสาธารณะ และแหล่งช๊อปปิ้ง
# 9.4
# สะดวกสบายมากค่ะ ที่พักอยู่ติดรถไฟฟ้า และห้างยูเนี่ยนมอลล์ เซ็นทรัลลาดพร้าว โรงแรมใหม่สะอาด แต่อาหารเช้าไม่ค่อยอร่อย
# 9.1
# ดีมากครับ คุ้มค่ากับราคาที่จ่ายไป ห้องสวย สะอาด ถูกใจมาก จะมาพักอีกแน่นอน
# 10
# ดีมากๆ ชอบมากเลยค่ะ ประทับใจทุกๆอย่างเลย
# ----------------------------------------------------
#
# 8.5
# โรงแรมดี เตียงนอนสบาย แต่พนักงานตอนรับไม่ค่อยรับแขกเท่าไหร่
# 8.5
# ห้องพักสะอาดพนักงานน่ารักอาหารเช้าเยอะหลากหลายความสะดวกครบครันค่ะมากรุงเทพอีกรอบจะกลับมาพักที่นี้ค่ะ
# 9.4
#
# 6
# เช็กอิน ห้อง 923 ห้องเหม็นอับ เหมือนกลิ่นสี แสบจมูก แสบตา จนปวดหัว แอร์ไม่เย็น ขอเปลี่ยนห้องเพราะมึนหัวกลิ่นมาก แต่ห้องเต็มไม่มีห้องเปลี่ยน ทาง รร.ไม่เผื่อห้องไว้เพื่อเผื่อเกิดปัญหากับลูกค้าเลย ทราบมาว่าทางห้องอื่นก็มีปัญหา และไม่มีห้องเปลี่ยนเหมือนกัน ทางฟร้อนท์ แจ้งช่างมารีเซตแอร์ ตั้งแต่หัวค่ำ ณ.เวลานี้ จะตีหนึ่ง รีเซตมาหลาย ชม.แล้ว ออกแต่ลม อุณภูมิไม่เย็น ในภาพระบุว่าอุณภูมิห้อง 27องศา ช่างเปิดไว้ให้ 19องศา แต่ในความจริง คือมันร้อน นอนแสบจมูกและร้อนทรมานมาก แย่จริงๆ แทนทีจะได้พักผ่อนอย่างสบาย ควรแจ้งให้ผู้จัดการ หรือ ผู้บริหาร รร.ให้ทราบ คืนนี้ทั้งคืนเราคงนอนไม่ได้
# 9.4
# อาหารเช้าดีมาก เตียงนอนสบาย ทำเลดีมากๆ อยากให้เพิ่มกระจกแต่งหน้าในห้องพัก และเปลี่ยนหัวฝักบัวค่ะ (น้ำไหลเป็นเส้นเล็กๆ ถ้าเปิดน้ำแรง โดนตัวแล้วเจ็บมากค่ะ)
# 9.7
# โรงแรมใหม่ สะดวกมาก ติดรถไฟฟ้า MRT พหลโยธิน มี7-11อยู่ใต้โรงแรม บริการประทับใจ
# 9.7
# โรงแรมใหม่ สะอาด อยู่ใกล้ mrt
# 9.7
# ที่พักสวยสบาย บริการดี ชอบมากค่ะ ระบบทันสมัยทั้งWiFi ระบบคีย์การ์ด
# 9.4
# ห้องพักใหม่ สะอาด สะดวกมากๆ ข้างหน้าโรงแรมมี7-11 มีรถไฟใต้ดิน ตรงข้ามยูเนียนมอ เซ็นทรัลลาดพร้าวว มีสระว่ายน้ำ ฟิตเนส ดีมาก ห้องเล็กไปนิดนึง ทำความสะอาดช้าไปนิดนึง โดยรวมโอเครมากคุ้มสุด ถ้ามา กรุงเทพฯ คงมาที่นี้ตลอด
# 8.5
# โรงแรมใหม่ สะอาด อาหารอร่อย เดินทางสะดวก ติด MRT
# ----------------------------------------------------

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 220
# Reviews_list : 220

# %%
Ratings_list
# Out:
# ['10',
#  '9.4',
#  '9.7',
#  '9.7',
#  '8.5',
#  '9.3',
#  '9.7',
#  '8.5',
#  '9.7',
#  '8.5',
#  '8.5',
#  '9.4',
#  '8.5',
#  '8.5',
#  '10',
#  '8.5',
#  '10',
#  '9.7',
#  '9.4',
#  '9.4',
#  '10',
#  '9.7',
#  '9.7',
#  '8.5',
#  '9.7',
#  '9.4',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '5.7',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '9.7',
#  '8.5',
#  '9.7',
#  '8.5',
#  '9.4',
#  '8.4',
#  '9.7',
#  '8.5',
#  '9.4',
#  '9.7',
#  '6.6',
#  '6',
#  '6',
#  '8.5',
#  '9.4',
#  '9.7',
#  '9.7',
#  '8.5',
#  '8.5',
#  '6',
#  '9.7',
#  '8.5',
#  '6',
#  '6',
#  '10',
#  '10',
#  '8.5',
#  '9.1',
#  '9.7',
#  '8.5',
#  '8.5',
#  '8.5',
#  '9.4',
#  '8.5',
#  '6.4',
#  '8.5',
#  '9.4',
#  '8.8',
#  '10',
#  '6.2',
#  '6',
#  '8.8',
#  '9.7',
#  '8.5',
#  '5.5',
#  '9.1',
#  '8.5',
#  '8.5',
#  '9.4',
#  '9.7',
#  '9.4',
#  '9.7',
#  '7.2',
#  '9.1',
#  '9.4',
#  '9.4',
#  '8.5',
#  '9.3',
#  '6.4',
#  '8.5',
#  '9.1',
#  '9.7',
#  '8.5',
#  '10',
#  '9.7',
#  '9.7',
#  '9.7',
#  '8.5',
#  '9.7',
#  '6',
#  '9.4',
#  '9.1',
#  '9.4',
#  '8.5',
#  '9.7',
#  '10',
#  '8.8',
#  '8.5',
#  '8.5',
#  '8.5',
#  '9.4',
#  '9.7',
#  '5.7',
#  '9.7',
#  '8.8',
#  '10',
#  '10',
#  '9.1',
#  '8.5',
#  '8.5',
#  '10',
#  '9.7',
#  '9.4',
#  '9.7',
#  '9.7',
#  '8.5',
#  '9.4',
#  '10',
#  '9.7',
#  '10',
#  '10',
#  '8.5',
#  '8.8',
#  '8.5',
#  '9.4',
#  '9.7',
#  '9.4',
#  '9.1',
#  '8.5',
#  '9.7',
#  '10',
#  '9.7',
#  '9.7',
#  '9.7',
#  '9.1',
#  '8.5',
#  '10',
#  '6.9',
#  '10',
#  '8.5',
#  '10',
#  '9.7',
#  '9.7',
#  '9.1',
#  '10',
#  '9.7',
#  '8.5',
#  '9.7',
#  '10',
#  '10',
#  '9.7',
#  '8.5',
#  '9.7',
#  '6',
#  '8.2',
#  '9.4',
#  '9.7',
#  '8.5',
#  '9.7',
#  '9.7',
#  '10',
#  '9.4',
#  '9.7',
#  '8.7',
#  '8.5',
#  '6.5',
#  '9.4',
#  '8.5',
#  '9.7',
#  '8.5',
#  '9.7',
#  '9.1',
#  '10',
#  '8.5',
#  '9.4',
#  '9.7',
#  '10',
#  '8.8',
#  '9.7',
#  '9.7',
#  '10',
#  '9.4',
#  '6.3',
#  '9.7',
#  '9.1',
#  '10',
#  '9.4',
#  '9.1',
#  '10',
#  '8.5',
#  '8.5',
#  '9.4',
#  '6',
#  '9.4',
#  '9.7',
#  '9.7',
#  '9.7',
#  '9.4',
#  '8.5']

# %%
Reviews_list
# Out:
# ['โรงแรมดีมากๆ เดินทางสะดวกใกล้รถไฟฟ้าห้าแยกลาดพร้าว หาของกิน ช็อปปิ้งก็สะดวกตรงข้ามยูเนี่ยนมอลเลยครับ คุ้มค่ากับราคา อาหารเช้าที่โรงแรมนี้อร่อยมาก มีหลากหลาย',
#  'ประทับใจพนักงานเช็คอินมาก หน้าตายิ้มแย้มต้อนรับดี พูดไพเราะ มีการติดต่อมาแจ้งเรื่องพยายามหาห้องที่ใกล้กันมากที่สุดให้เพราะจองมา 3 ห้อง',
#  'ดีมาก เดินทางสะดวกสบาย ใกล้ mrt',
#  'บริการดีค่า พนักงานพูดเพราะ ห้องสะอาด',
#  'พักที่นี่ประจำ พนักงานฟร้อนท์ ดีบ้างไม่ดีบ้าง ที่พักสะดวก เดินทาง',
#  'ห้องดีมากค่ะ พักหลายรอบมากเป็นที่แรกที่จะเลือกใกล้แหล่งช้อปปิ้งเดินทางสะดวกมาก เดินมายังได้ 😆',
#  'โรงแรมสะอาด บริการสะดวกสบาย พนักงานบริการด้วยความเป็นมิตรใส่ใจ',
#  'เป็นโรงแรมที่ดี เดินทางสะดวก ห้องพักสะอาดแต่ไม่ค่อยเก็บเสียง ถ้าอยู่บริเวณหน้าลิฟหรือทางเดินที่คนผ่านบ่อยจะเสียงดัง อาหารเช้าดี ใกล้ห้าง มี7-11 ด้านล่างโรงแรมและร้านกาแฟ ส่วนกลางดี มีทั้งฟิตเนสและสระว่ายน้ำ',
#  'ดีมากครับ มีโอกาสต้องกลับมาใช้บริการอีกแน่นอน',
#  'ชอบมากเรยค่ะ สะอาด พนักงานก็น่ารักค่ะ มารอบหน้า มาใช้บริการอีกแน่นอนค่ะ',
#  'ที่พักดีมากเหมาะสมกับราคา เดินทางสะดวกมีรถไฟฟ้าทั้ง MRT และ BTS โรงแรมมีบริการอาหารเช้า ที่หลากหลาย ห้องพักตกแต่งสวยงาม อุปกรณ์ในห้องครบครัน จะไปพักอีกครัั้งแน่นอน',
#  'สถานที่ตั้งดีมาก สะดวก ใกล้รถไฟฟ้าใต้ดินและแหล่งช้อปปิ้ง ห้องพักสะอาด อาหารเช้าดี สมราคาค่ะ',
#  'ทำเลดี พนักงานต้อนรับดี ห้องสะอาด ราคาเบาๆ',
#  'ทำเลสุดยอด สะดวกสบาย ห้องพักสะอาด ที่นอนดีมาก',
#  'ชอบ มาพักบ่อย เดินทางสะดวกมาก พนง.บริการดี',
#  '',
#  'ห้องพักสะอาด พนักงานบริการด้วยความเป็นมิตร อาหารเช้าหลากหลายรสชาติถูกปาก เครื่องดื่มต้อนรับสุดยอด สระว่ายน้ำสะอาด',
#  '',
#  'รร สวย สะอาด บริการดี เดินทางสะดวก ใกล้ mrt มากๆ ใกล้ห้าง พักบ่อยมากและจะมาใช้บริการอีก',
#  'อาหารเช้าดีมาก พนักงานบริการดี',
#  'สะดวก สะอาด ห้องดี คุ้มราคา เหมือนอยู่คอนโด มีสระว่ายน้ำ',
#  'ห้องสะอาด วิวสระว่ายน้ำดีมาก โปรดีอีก 1 แถมใกล้แหล่งของกินด้วย สะดวกสุดๆ',
#  'ยอดเยี่ยมมากครับ หรูหรา คุ้มค่าราคามากๆครับ 10/10 ครับผม',
#  'เดินทางสะดวก บริการดี ราคาดีครับ',
#  'สะอาด เป็นส่วนตัว สิ่งอำนวยความสะดวกมีครบ',
#  'ที่พักตรงปก สะอาด บรรยากาศชั้นสระว่ายคือดี มีเซเว่นใต้โรงแรม เดินทางสะดวกมาก ใกล้ Mrt สุดๆ',
#  '',
#  'ห้องพักสะอาด บรรยากาศดี แอร์เย็นมาก สะดวกในการเดินทาง ติดถนนใหญ่',
#  '',
#  'ห้องพักสะอาด ความปลอดภัยดีเยี่ยม',
#  'ห้องพักสะอาด พนักงานให้บริการดีมาก',
#  'ห้องพักสะอาด จัดได้สวยงาม สระว่ายน้ำวิวดี บริการอาหารเช้ายอดเยี่ยม',
#  'Location สะดวก ราคาดี ยกเว้นความสะอาดยังไม่เรียบร้อยเท่าที่ควร',
#  'ห้องดี เตียงกว่า ใกล้ยูเนี่ยนมาก',
#  'ห้อง ไม่ตรงตามต้องการ เลือกแบบมีระเบียงไป ครับ แต่ไม่ได้ห้องแบบมีระเบียง',
#  '',
#  'โรงแรมสวยบริการดีมากค่ะ พนักงานน่ารัก ยิ้มแย้มตลอด ห้องสวย สะอาด อยู่ใกล้แหล่งช๊อปปิ้ง สะดวกสะบาย ดีเยี่ยมทุกอย่าง เริศค่ะ😊❤',
#  'ห้องสะอาด พนักงานบริการดีมากๆค่ะ',
#  'ดีมาก ๆ สะดวกสบาย คราวหน้ากลับมาพักอีก เตียงนุ่ม',
#  'ได้ห้องวิวสระตามที่ request พนักงานบริการและอัศยาศัยดี',
#  '',
#  'สะดวกสุดๆชอบโลเคชั่นที่นี้มากๆ+ราคาก็โดน',
#  'ชอบมากครับมาพักหลายครั้งแล้ว ใกล้กับห้างและสะดวกในการเดินทาง ราคาจับต้องได้ ห้องกว้าง',
#  'เป็นที่พักที่ยอดเยี่ยมมากๆในทุกๆด้าน ห้องใหม่ สะอาด ทำเลดีเยี่ยม จนท.ทุกส่วนบริการดีสุดๆ มีสิ่งอำนวยความสะดวกมากมาย ใกล้ห้างสรรพสินค้า ติดรถไฟฟ้าใต้ดิน เดินทางสะดวกง่ายดาย ชอบและประทับใจที่สุด และจะพักโรงแรมนี้ตลอดไปหากยังคงรักษามาตรฐานได้ดีเช่นนี้ค่ะ',
#  'ดีมากๆค่ะ ใกล้ห้าง ใกล้ mrt bts ไปไหนมาไหนสะดวกค่ะ',
#  'เดินทางสะดวกใกล้ MRT พหลโยธิน มีร้านสะดวกซื้ออยู่ในตัวอาคารของโรงแรม',
#  'สถานที่คุ้มค่ากับราคามากๆ ค่ะ',
#  'ห้องกว้างปลอยภัยดี ที่เด่นสุดคืออยู่ใกล้รถไฟฟ้ามาก บีทีเอสมีทางเชื่อมแล้วด้วย เวลาหิวก็มีเซเว่นในตัวอาคาร ลงMRT ข้ามฝั่งไปยูเนี่ยนกับเซนทรัลลาดพร้าวรึจะต่อไปแถวเกษตรก็ได้ มีwelcome drinkด้วย ฟิตเนสก็ครบครันดี อุปกรณ์คุณภาพสูงกว่าทั่วไป แต่หักคะแนนเรื่องคีย์การ์ด มัดจำ500 เยอะไปหน่อยถือเป็นค่าตกใจ',
#  'สะดวกสบายใกล้รถไฟฟ้า ใกล้ห้างสรรพสินค้าต่างๆ',
#  '',
#  'ห้องพักดี สะอาด อาหารอร่อย มาพักเป็นประจำทุกเดือน',
#  'มีเสียงเคาะอะไรก็ไม่รู้ดังมาจากผนังห้องข้างๆ โทรไปถามที่ฟร้อน ฟร้อนบอกไม่มีคนพักนะ งงจะไม่มีคนพักได้ไง เสียงเคาะดังทั้งคืน ยิ่งช่วงดึกๆเคาะดังนึกว่าคนเมาทะเลาะกัน',
#  'ไฟตก น้ำไหลเอื่อยมาก ลงไปแจ้งปัญหาบอกเป็นทั้งตึก',
#  'พัก2วัน ทำคีย์การ์ดให้วันเดียว ต้องลงมาแจ้งใหม่เข้าห้องไม่ได้ ขอวิวสระ ก็ได้ห้องสุดท้ายแบบไม่เห็นวิวเลย มื้อเช้า รร. ก็แย่ลงทุกวัน อาหารมีให้เลือกน้อย',
#  'ห้องพักสะอาดได้มาตรฐาน เสียแต่วิวไม่ดีเท่าไร',
#  'โรงแรมดีมาก ดีเหมือนพนักงานเลย เตียงนุ่มสุด แนะนำให้มาพักเลย อย่างชอบ ไว้วันหลังจะไปอีก🥰',
#  'ห้องพักสะอาด การเดินทางสะดวกมากๆ ประทับใจคะ',
#  'ที่พัก ดีมาก สะอาด สวยงาม สิ่งอำนวยความสะดวกครบ เดินทางสะดวก ใกล้ห้างสรรพสินค้า พนักงานน่ารัก',
#  'ดีค่ะ สะอาด เดินทางสะดวกมีMRT อยุ่หน้ารร.',
#  'บริการดีมาก พนักงานยิ้มแย้ม ห้องสะอาด ติดรถไฟฟ้า ติดห้าง',
#  'ที่จอดรถหายากทุกครั้งที่ไป จนจำแล้วว่าไปพักที่นี่จะต้องขุ่นใจเรื่องที่จอดทุกครั้ง',
#  'เดินทางสะดวก ที่พักสบาย ใกล้เซนทรัลฯ หาของกินง่าย',
#  'ดีมาก ติดอย่างเดียวผนังบางไปนิด',
#  'พื้นที่ล็อบบี้แคบที่นั่งไม่พอ พอเวลารอก็นานแล้วพนักงานก็พูดไม่ค่อยโอเค ผ้าห่มมีกลิ่นเหม็น ชอบตรงแอร์เย็นสะใจ',
#  'ไม่ได้เรื่องค่ะ รีเซฟชั่นหน้าตาไม่รับแขกมาก รีเควสเตียงเดี่ยว ก็เอาเตียงคู่มาให้ พอโทรสอบถามตอบมาห้วนๆว่าเต็ม จะไม่กลับมาใช้บริการอีก',
#  'เดินทางสะดวก ใกล้ mrt อาหารอร่อย บริการประทับใจมากค่ะ',
#  'ดีมาก ถ้าเข้า กรุงเทพฯ อีก ก็จะเลือกที่นี่',
#  'วิวดี เดินทางสะดวก ใก้ mrt มากๆ มีเซเว่นข้างล่าง เวลาหิวกลางคืน ด้วย 55555 เดินข้ามสะพานก้เจอแหล่งช็อป ใกล้ยูเนี่ยนและเซนทรัลลาดพร้าว',
#  'พนักงานต้อนรับหน้าโรงแรมที่ดูแลกระเป๋าดูแลดีมากกกก พนักงานหน้าฟร้อนท์ควรจะอาย ไม่บอกอะไรนอกจากเบอร์ห้อง ลิฟท์ทางไหน พนักงานที่ส่งกระเป๋าต้องมาคอยบอกว่าห้องยิมอยู่ตรงไหนไปยังไง กินเช้าที่ไหน ห้องพักสะอาดสะอ้านดีมาก เตารีดมีบริการถ้าขอใช้ สถานที่ตั้งคือเป็นเลิศ อยู่ใกล้กับ MRT ตรงข้ามกับยูเนี่ยนมอลล์ กลับไปพักอีกแน่นอน',
#  'ได้ห้องตรงตามที่แจ้งขอไว้ทุกครั้งค่ะ',
#  '',
#  'ที่พักดี ห้องสวย สะดวกสบาย เดินทางง่าย มี MRT ฝั่งตรงข้ามเป็นยูเนี่ยนมอลล์ และเซ็นทรัลลาดพร้าว คุ้มค่ามากๆค่ะ',
#  'ทำเลดีมากครับ สะดวกมากในการเดินทาง',
#  'มาพักหลายครั้งและประทับใจทุกครั้งเลยค่ะ เดินทางสะดวกใกล้mrt เดินหาของกินง่าย พนง.บริการพูดดีทุกครั้งเลยค่ะ ห้องสวยสะอาดและดูใหม่จริงๆ',
#  'อยู่ติดmrt ตรงข้ามยูเนียนมอลล์ เดินทางสะดวก ปลอดภัย ห้องพักสะอาด พนักงานมีความสุภาพ ยิ้มแย้มแจ่มใส',
#  'ที่จอดรถมีน้อยมาก และให้จอดห้องพักละ 1 คัน มาสองคัน ต้องเสียค่าจอดรถรายชั่วโมง',
#  'โรงแรมบริการดีมากๆค่ะ ที่พักสะอาด',
#  'มาพักครั้งที่สองแล้วพนง.ต้อนรับดีมากๆ ให้ความช่วยเหลือได้ดี ห้องดีเหมือนเดิมแต่ติดตรงที่ในห้องน้ำมีเศษขยะนิดนึงแล้วก็ปลอกหมอนมีรอยเปื้อนนิดๆ เดินทางสะดวกเดินไปกินข้าวซื้อของได้สบายมากๆ',
#  'ไปพักหลายรอบแล้ว ห้องสบายสะอาด และเดินทางสะดวกมากๆ',
#  'ประทับใจมาก แต่วันเช็คอินค่อยข้างช้า อาจเพราะคนเยอะด้วย มี welcomedrink บัตรส่วนลดค่าอาหาร ห้องพักสะอาด หอมมาก อุปกรณ์ภายในห้องครบ ถ้ามีโอกาศจะมาเข้าพักที่นี้อีกเรื่อยๆ ใกล้ mrt มากที่สุดของที่สุด ลืมชม พนักงานที่นี้น่ารักนะคะ',
#  'ที่จอดรถน้อยมาก จอดรถยากมากถึงยากที่สุด',
#  'ระวังเขาจะว่าคุณทำผ้าเปื้อนแล้วซักไม่ออก คิดผืนละ 200 ผมเช็ดหน้ามีรองพื้นติดประมาณ จุดสองจุด แล้วฟร้อนยังบอกอีกว่าถ้าซักออกก็คิดผืนละ 100 อยู่ดี ผมเลยบอกว่างั้นผมเอาไปซักเอง ถ้าออกผมเอาเรื่อง ถึงยอมคืนมัดจำ แย่มาก ผมพักที่นี้หลายครั้งเพราะเดินทางสะดวก คงต้องหาที่อื่นแล้วละ',
#  '',
#  'ห้องพักสะอาดมาก มีสิ่งอำนวยความสะดวกครบครัน เตียงใหญ่มากๆ ห้องน้ำสะอาด มีโต๊ะให้นั่งทำงานด้วย บรรยากาศโดยรวมดีมาก พนักงานต้อนรับบริการดี',
#  'ห้องพักสะอาด บรรยากาศดี พนักงานต้อนรับบริการดีมาก',
#  'เช็กอิน จองเตียงคิงไซด์ หน้างานบอกเต็ม มื้อเช้าเปิดถึง 10.30 ลงไป 9.30 ไม่เติมอาหาร และของกินไม่หลากหลาย',
#  'ทุกอย่างดีหมด มาเสียตรงเป็นที่พักแท้ๆแต่หมอนไม่ไหวเลย แบนยิ่งกว่าอะไรดีนอนไม่สบายเอามากๆ',
#  'ดีงามมากหรูหราเกินราคา ชอบการบริการดี ห้องพักมีครบ มีได มีร่ม มีทุกอย่าง',
#  '',
#  'ได้ยินเสียงทีวีห้องข้างๆชัดมาก ทำให้รบกวนการนอน นอกนั้นดีหมดค่ะ',
#  'เดินทางสะดวก ใกล้ mrt โรงแรมสะอาด พนักงานบริการดี อยากให้มีเมนูอาหารเช้าที่หลากหลายกว่านี้ โดยรวมผ่านครับ',
#  'ดีมาก ห้องเป็นสัดส่วน อุปกรณ์ สิ่งอำนวยความสะดวกครบครัน สะอาด เดินทางสะดวก ใกล้ย่านการค้า',
#  'โรงแรมดีมากสะอาดต้อนรับดีมากค่ะ',
#  'ห้องไม่เก็บเสียง ได้ยินเสียงข้างห้องพูดคุยกันพอฟังเข้าใจ ควรปรับปรุงในจุดนี้ เรื่องความเก็บเสียงของห้องพัก',
#  'ห้องสะอาดดีครับ บริการก็ประทับใจ ห้องสวย ใหม่เอี๊ยม วิวดี มีโอกาสจะไปใช้บริการอีกครับ',
#  'ห้องพักสะอาด มีสิ่งอำนวยความสะดวกครบครัน การเดินทางด้วยระบบขนส่งสาธารณะสะดวกมาก',
#  'สิ่งอำนวยความสะดวกครบครัน ห้องสะอาด พนง.ต้อนรับพูดจาดีทั้งกะเช้าและเย็น เดินทางง่าย สะดวก ไม่ต้องเข้าซอยลึก',
#  'น้ำไหลแรง ห้องสวย พนักงานต้อนรับดี เงียบ สงบ เหมาะแก่การพักผ่อน',
#  'ได้ห้องตรงตามที่ระบุขอไว้"วิวสระว่ายน้ำ" ห้องสะอาดเรียบร้อย ครั้งนี้ได้ห้องหน้าลิฟต์ เสียงไม่ดังมาก ดีค่ะ',
#  'พัก10ครั้ง check in และ Check out ช้า10ครั้ง พนักงานในcounter 4-5คน ก็ยังช้า',
#  'ห้องสะอาด หรู ดูดี พักสบาย วิวสวย เซเว่นพร้อมมากกก แนะนำเลย พักสบาย ทำงานก็ได้',
#  '',
#  'เดินทางสะดวก ห้องพักสะอาด พนักงานบริการดีมาก',
#  '',
#  'มาพักครั้งที่ 2 แล้วถูกใจเหมือนเดิม พนักงานบริการดีทุกคน โดยเฉพาะน้องอุ้มกับน้องฉัตรพูดดีบริการดีมาก รอบหน้าต้องมาอีกแน่ๆ',
#  'ห้องพักดีมากเหมาะสมราคาที่สุด ไม่มีเสียงดังรบกวนหลับสบายมากๆ',
#  'ได้ห้องตามที่ต้องการ ได้เตียงตรงตามที่ขอ',
#  'ได้ห้องตามที่ขอไว้ในคำขอพิเศษ, check in ตามเวลาเท่านั้น 14.00น.',
#  'ผมมาพักที่นี่หลายครั้ง ข้อดีของที่นี่มากมายเริ่มตั้งแต่จุดที่ตั้งอยู่ในทำเลดีมากใกล้ห้างสรรพสินค้า สะดวกในการเดินทางและอาหารการกินขนาดของโรงแรมไม่เล็กและใหญ่อลังการเกินไป พนักงานปฏิบัติหน้าที่ได้มาตรฐานไม่มีข้อตำหนิ ระบบความปลอดภัยดีมาก ไม่มีการ์ดขึ้นลิฟท์ไม่ได้ ภายในห้องพักดีมากแม้จะไม่ใช่ห้องกว้างใหญ่แต่ไม่เล็กกำลังพอดี ในห้องมีทีวี ตู้เย็น โต๊ะทำงาน มินิบาร์ wifi ห้องน้ำสะอาด น้ำแรง อุปกรณ์ครบครัน ระบบไฟในห้องเพียบ ปลั๊กไฟมีให้หลายจุด เขียนชมมาหลายบรรทัดจนเมือยมือยังจาระนัยไม่ครบ เอาเป็นว่าที่นี่ดีที่สุดสำหรับผม สุดท้ายนี้ขอฝากชมแม่บ้านด้วย ผมยืมเตารีดทุกครั้งที่ไปพักโทรยืมปุ๊บมาปั๊บเลย ที่น่สุดยอดครับ',
#  'บริการดีมาก ห้องเงียบมากไม่มีเสียงรบกวน บรรยากาศดี ใกล้ MRT ทางออก 1 มีโอกาสจะกลับไปอีก',
#  'เช็กอิน เช็คเอ้า ช้าตลอด ทุกครั้ง',
#  'พนักงานบริการดีมาก อยู่ใกล้ mrt พหลโยธิน เดินทางสะดวก',
#  'มาพักหลายครั้งแล้ว ครั้งนี้ไม่ชอบที่สุด ตรงที่เสียงพนักงานแม่บ้านที่ทำความสะอาดห้องคุยกันเสียงดังมากและเป็นเวลานาน ตั้งแต่เริ่ม check in จนถึงเวลาประมาณ 18.00น. เสียงคุยกันจึงเงียบลง (พักชั้น 10)',
#  'พักหลายครั้งแล้ว รู้สึกดีที่มาพักทุกครั้ง ครั้งล่าสุด 3 มิ.ย.2563 แต่ไม่ได้ห้องวิวสระว่ายน้ำตามที่ระบุขอพิเศษไว้ ไม่เป็นไร 4 ก.ค.2563 จองใหม่และขอใหม่(อีกครั้ง) มาดูกันว่าจะได้หรือไม่',
#  'คือตอนนีราคาดีงาม อาหารเช้าดีเวอร์',
#  'ดีมากค่ะ ได้ห้องพักวิวหลักล้านแต่ราคาไม่ถึงพันค่ะ 💓 แล้วจะกลับมาพักใหม่ค่ะ ชอบที่สุด แต่เรามาช่วงโควิดเลยไม่ได้ลงสระน้ำ',
#  '',
#  'ดีค่ะโดยรวมทุกอย่างที่เป็นอยู่',
#  'ไปทำงานแถววิภาวดี ที่พักสะดวก ตรงข้ามห้างยูเนียนมอล มีสถานี MRT อยู่หน้าโรงแรม มีเซเว่นหน้าโรงแรม คือสะดวกทุกอย่าง อยู่10 วัน พนักงานน่ารัก แม่บ้านทำความสะอาดห้องเยฝนี่ยบมาก แต่ที่จอดรถ เดินไกลนิดนึงเพราะอยู่หลังตึก',
#  'โรงแรมสวย มีระดับ ใกล้MRT ยูเนี่ยนมอล์ เซ็นทรัลลาดพร้าว แต่ห้องไม่ค่อยเก็บเสียง ข้างๆห้องเปิด-ปิดประตูได้ยินหมดเลย',
#  'ห้องสะอาด ทำเลดี การต้อนรับที่เป็นกันเอง',
#  'บริการดี ห้องสะอาดเห็นวิวชัด ที่สำคัญอาหารอร่อยค่ะ',
#  'เดินทางสะดวก อยู่ติดกับ MRT อาหารเช้าดี',
#  'พนักงานทำหน้าตาไม่ค่อยดี ควรแจ้งรายละเอียดของโรงแรมให้เยอะกว่านี้',
#  'พนักงานต้อนรับสุภาพมากคับ แล้วก็ประทับใจมากเมื่อพนักงานรู้ว่าเราเคยมาพักที่นี่แล้ว เหมือนเขาเก็บข้อมูลลูกค้าไว้ด้วย',
#  'ห้องสะอาด บริการดี มีเซอร์วิสตลอด24',
#  'ขอบคุณคุณส้ม ขอบคุณ พนักงาน ที่ดูแลดีมาก ตั้งแต่ให้เช็คอินล่วงหน้า ค่ะ',
#  '',
#  'ห้องพักดีมาก สถานที่ก็ใกล้ ห้าง ใกล้ MRT เดินทางสะดวก แต่ห้องน้ำมีกลิ่นท่อระบายน้ำอับๆค่ะ',
#  'ห้องพักดี ทำเลดีมากติดรถไฟฟ้า mrt พหลโยธิน อาหารเช้าเย่อะ แต่ติดตรงทีแขกชาวจีนเสียงดังมาก 10/8',
#  'ห้องเหมือนในรูป กว้าง สบาย สะอาด ใกล้ยูเนี่ยนมอล มีเซเว่นหน้าตึก',
#  'นอนหลับสบายดีมากค่ะ เทคเเคร์ดีมาก',
#  'ใกล้แหล่งช้อปปิ้ง เดินทางง่าย พนักงานน่ารัก ห้องพักสะดวกสบาย อาหารเช้าอร่อยมีให้เลือกเยอะ สิ่งอำนวยความสะดวกครบครัน มีโอกาสอยากจะไปอีกคะ',
#  'พักเป็นครั้งที่สองแล้วประทับใจทุกครั้ง แต่ครั้งนี้แอบมีข้อเสียนิดหน่อย',
#  'ห้องกว้าง มีอุปกรณ์ครบครัน ตกแต่งดี อยู่ในทำเลที่ติดรถไฟใต้ดินพหลโยธิน สามารถเดินไปห้างเซนทรัลลาดพร้าว และยูเนี่ยนมอลล์ได้อย่างง่ายดาย มีร้านกาแฟ ร้านชาบู ร้านทำเล็บและเซเว่นอีเลฟเว่นอยู่ด้านล่าง และไม่ไกลจากร้านอาหารตามสั่ง หรือจะสั่งอาหารของทางโรงแรมไปทานบนห้องก็ได้ สะดวกปลอดภัย แต่อยากจะคอมเม้นเรื่องมีเสียงดังรบกวนจากคนเดินและห้องข้างๆมากไปหน่อย ทำให้พักผ่อนได้ไม่สนิท',
#  'ไปกรุงเทพทุกครั้งนึกถึงโรงแรมนี้เป็นอันดับแรก ประทับใจตั้งแต่ครั้งแรกที่ไป ที่ตั้งสะดวกสบาย ห้องสะอาด สบาย พนักงานบริการดียิ้มแย้ม ขอเสนอแนะนิดหนึ่งขอให้เพิ่มเสื้อคลุมในห้องพักก็จะดีมากค่ะ',
#  'ที่พักประจำ เดินทางสะดวก พนักงานน่ารัก กาแฟร้านข้าง อร่อย มี7-11ติด รร',
#  '',
#  'ประทับใจมากๆ พนักงานบริการดีมากยิ้มแย้มตลอด โดยเฉพาะน้องAUM เอาใจใส่มาก ทักทุกรอบที่เจอเลย ประทับใจมากเลยค่ะ',
#  'เดินทางสะดวกมากไกล้รถไฟฟ้าใต้ดิน ห้องกว้างเหมือนในรูปสะอาดมากบรรยายกาศดีมากค่ะ มีบริการทำความสะอาดห้องพักให้ถ้าพักหลายวัน อาหารหลากหลายรสชาติอร่อย แต่ติดนิดเดียวพนักงานต้อนรับช่วง05.00-06.00สีหน้าคำพูดไม่ค่อยโอเค พนักงานเก็บกระเป๋าบริการดีมากพูดจาดีมาก แต่โดยรวมโรงแรมดีมากๆค่ะ',
#  'ดีมาก ที่ตั้ง ความสะอาด พนักงาน อาหาร ให้ 10 คะแนนเต็ม',
#  'ห้องสะอาด พนักงานน่ารัก อยู่ใกล้ mrt bts เดินทางสะดวก',
#  'เป็นโรงแรมที่มาพักบ่อยที่สุด สะดวกไปหมดทุกอย่าง อาหารเช้าอร่อย ชั้นล่างมี7-11 คลีนิคทำฟัน ร้านกาแฟ คลีนิคเสริมความงาม ฝั่งตรงข้ามก็ยูเนียลมอล์ แค่นี้ก็สบายมากๆแล้ว',
#  'ใกล้mrtพหลโยธินมากๆ ห้องพักสะอาดดี แต่ผนังห้องค่อนข้างบาง เสียงห้องอื่นลอดเข้ามาบ้างรวมถึงเสียงคนเดิน',
#  'ทำเลดี เดินทางสะดวก ใกล้ห้าง พนง.บริการดี มาพักเป็นประจำค่ะ',
#  'สะดวกมากๆ เซเว่นก็อยู่ด้านล่างโรงแรมเลย จะเดินไปยูเนี่ยนก็รวดเร็ว mrt ก็ไม่ไกล',
#  'พนักงานต้อนรับดูแลดี คอยช่วยเหลือดีมาก',
#  'ห้องพักสวย ไม่มีเสียงรบกวน สะอาด จัดแต่งสไตล์โมเดิร์น เครื่องใช้อำนวยความสะดวกต่างๆพร้อมใช้งาน+ครบวงจร มีความปลอดภัยดี ที่สำคัญเดินทางสะดวก เพียงไม่กี่ก้าวถึง MRT station แล้ว และอยู่ใกล้ศูนย์การค้า หาร้านอาหารง่าย การบริการดี Check in -Check out รวดเร็ว',
#  'พนักงานน่ารักเหมือนเดิม รอบนี้มาตรงกับมีงานคอนเสิร์ตคนเยอะนิดนึง แต่ก็โอเครในความน่ารักของพนักงาน',
#  'สะดวก ใกล้ยูเนียน mrtพหลโยธินทางออก1',
#  'โรงแรมสะอาด สวยงามดังรูป ล็อบบี้โรงแรมหรูหรามาก ทางเดินภายในโรงแรมไม่ไกลเกินไป ไม่น่ากลัว ดูดี มีลิฟท์หลายตัว พนักการบริการดีมาก น่ารัก อัธยาศัยดี ห้องพักกว้างพอใช้ได้ มีโต๊ะทำงาน ตู้เย็น ทีวีขนาดใหญ่ มีไฟหลายดวงรวมทั้งโคมไฟแล้วแต่การเลือกใช้ แอร์เป็นแอร์ฝังกับผนัง ห้องน้ำไม่ใหญ่มากอุปกรณ์ภายในห้องน้ำดีครบครัน สบู่ น้ำยาสระผมให้มาเป็นขวดฝากดใช้ง่ายสะดวก ห้องอาหารอยู่ชั้น6 มีเวลคัมดริ้งให้ฟรี ถ้าซื้อในราคารวมอาหารเช้าด้วยก็คุ้มค่า มีสระไหว้น้ำ ฟิตเนส โรงแรมอยู่ตรงข้ามกับหน้ายูเนียนมอลเลยเดินทะลุmrtนิดเดียวก็ถึง เอาเป็นว่าสะดวกมากๆค่ะ ถ้าเต็ม10ก็ให้9.5ค่า หักค่าความไม่ถูกของค่าห้อง55 จริงๆเราว่าก็สมราคาแหละ ถ้ามา2คนก็หารกันออกไม่เกิน1000ต่อคืนแน่นนอนค่า (ปล.เราจองผ่านแอพนะคะ)',
#  'ห้องสะอาด อุปกรณ์ครบมาก พนักงานบริการดี เดินทางสะดวก มีเซเว่นอยู่ด้านล่างสะดวกมาก สรุปดีมากเว่อค่ะ',
#  'สะอาดดีครับ ห้องใหญ่กว่าที่คิดไว้ ติดกับรถไฟฟ้าใต้ดิน และใกล้กับบีทีเอสห้าแยกลาดพร้าวด้วย เดินทางไปไหนก็สะดวก',
#  'เดินทางสะดวกมากครับ MRT ประตู3 ติดกับโรงแรมเลย',
#  'เดินทางสะดวก พนักงานดูแลดี ⭐',
#  'สะอาด สะดวก สบาย very good service and nice location',
#  'บริการดีมากค่ะ ถ้าได้มา กทม. จะมาพักอีกแน่นอนค่ะ',
#  'ดีมาก เข้าพักกี่ครั้งไม่เคยผิดหวังเลยค่ะ ดีหมดทุกอย่าง ประทับใจมากๆ',
#  'น้ำร้อนเย็นของฝักบัวไม่สม่ำเสมอ ทำให้เกิดการลวกเมื่อคนอื่นปิดน้ำ แต่เรายังเปิดอาบอยู่ โดนไปหลายครั้งทั้งเจ็บและตกใจ',
#  'เดินทางสะดวก ติดรถไฟใต้ดิน mrt พหลโยธิน ประตู4 เดินออกมาก็เห็นเลย อีกฝั่งเป็นห้างยูเนี่ยนมอล์ ของเยอะเดินสนุก จะเดินไปเซ็นทรัลลาดพร้าวก็ง่ายค่ะ พนง.บริการดี ห้องกว้างใช้ได้ อาหารเช้าดี มีให้เลือกเยอะ จะกลับไปใช้บริการอีกค่ะ',
#  'รร.ใกล้รถไฟฟ้าใต้ดิน mrt สถานีพหลโยธิน ซ.4 เดินทางสะดวกมากค่ะ ตรงข้ามเป็นห้าง ยูเนี่ยนมอล เซ็นทรัลลาดพร้าว อาหารเช้ามีให้เลือกเยอะ พนง.บริการดีค่ะ',
#  'พักสบายมากค่ะ ใกล้รถไฟฟ้าใต้ดิน',
#  'ห้องพักใหม่ สะอาด ราคาไม่แพง แถมยังอยู่ใกล้สถานีรถไฟฟ้าmrt ห้างยูเนียนมอลล์ด้วย',
#  'ห้องสะอาด พนักงานยิ้มแย้ม ต้อนรับดีมาก และที่สำคัญสะดวกต่อการเดินทาง',
#  'ดีค่ะ พนักงานบริการดี ห้องพักกับราคาเหมาะสม เดินทางสะดวก ใกล้แหล่งช๊อปปิ้ง',
#  'ดีมากๆเลยค่ะ ถึงจะเล็กแต่เตียงนอนสบายมาก เพราะเป็นเตียงคิงส์ไซส์ กลิ้งได้แบบไม่ตกเตียงเลย อาหารเช้าก็อร่อย จะกลับไปพักอีกแน่นอนค่ะ พนักงานฟร้อนเองก็น่ารัก พูกจาไพเราะ ยิ้มแย้มดี โอเคดีทุกอย่างเลยค่ะ',
#  'ดีมากค่ะ บริการดี เดินทางสะดวก ประทับใจมากค่ะ',
#  'ใหม่สะดวกสบาย บริการโอเค คุ้มค่าเกินราคา',
#  'ดีมากดีทุกอย่าง แนะนำมากๆ เครื่องอำนวยความสะดวกครบครัน',
#  'เยี่ยมเลย คุ้มจริงๆใหม่สะอาด สะดวก ติดmrt อาหารเช้าดี มีสระน้ำ สุด',
#  'ดีที่สุด สะดวกที่สุด ทุกอย่างคือดี พักมา3รอบแล้ว ดีที่สุด ตรงข้ามยูเนี่ยนเลย เดินทางสะดวก บริการดี ห้องสะอาด วิวดี คือทุกอย่างดีมากๆ จบ',
#  'ดีมากค่ะ นอนหลับสบาย น้ำไหลแรง เดินทางสะดวกมากๆ พนักงานยิ้มให้ตลอด',
#  'บริการดีมากๆ ที่พักสะดวกในการเดินทาง อาหารเช้ามีให้เลือกเยอะ และอร่อยมากค่ะ ครั้งหลังจะไปพักอีก',
#  'สวย สะอาด สะดวก สบาย สงบ พนักงานต้อนรับน่ารัก ^^',
#  'ลืมสายชาร์ทโทรศัพท์ไว้ เช็คเอ้าท์วันที่12ออกไป1ชม โทรกลับมา บอกหาเจอเเล้วค่ะ จะมารับหรือยังไงด้ เลยบอกว่าฝากไว้ก่อนนะเที่ยวหน้าจะมารับคืน วันที่23โทรว่าจะเข้าไปรับ บอกไม่มีของ เเล้วไม่เจอ คืองงมากว่ายังไงกับของที่บอกเก็บไว้ให้เเล้ว แต่วันนี้บอกไม่มีของละ',
#  'ก็ดีแหละค่ะ แต่ King Bed คือ เอาเตียงเล็ก 2 เตียงมาต่อกัน คิดว่าดีไหมล่ะคะ',
#  'จองห้อง deluxe เตียงใหญ่ไป แต่ได้ห้องเอาเตียงคู่มาต่อกัน',
#  'ห้องเหมือนในรูปเลยค่ะ สะอาด สะดวก สบาย อาหารเช้าก็มีให้เลือกหลากหลาย มีครั้งต่อไปแน่นอนค่ะ',
#  'การเดินทางสะดวก ใต้โรงแรมมีเซเว่น ใกล้แหล่งช็อปปิ้ง',
#  'บริการดี บรรยากาศดี เป็นครั้งที่2ของการพักที่นี่ และมั่นใจว่าจะมีครั้งที่3 หากบริการดีแบบนี้ต่อเนื่อง ควได้เป็นลูกค้าประจำแน่นอน',
#  'ดีมากๆครับ ใกล้ยูเนียนมอล,Mrt สะดวกมี7-11อยู่ชั้นล่าง ห้องสวย พนักงานบริการดีครับ',
#  'ห้องใหม่ สะอาด ขนาดกำลังดี ไม่อึดอัด อาหารอร่อยค่ะ เดินทางสะดวก ติดรถไฟฟ้า',
#  '',
#  'เดินทางสะดวก ติดรถไฟฟ้าMRT ห้องพักสะอาด อยู่ใกล้กับห้างเซ็นทรัลลาดพร้าว',
#  '👧🏻👧🏻ครอบครัวมีเด็กเล็กคะ👧🏻👧🏻 ข้อดี : พนักงานต้อนรับน้องผู้ชายดูแลดี พูดจาดีมากๆคะ ดูนอบน้อมดีมากๆ วันเช็คเอ้า ไปเที่ยวกลับมาเอารถ ยังทักทายและให้ขนมเด็กๆด้วย น่ารักมากคะ --- ที่พักใหม่เปิดยังไม่ถึงปีเลยคะ ห้องพักที่เตียงนอนสบายมากคะ ห้องน้ำแบ่งพื้นที่ได้ดีเลยคะ ---สิ่งอำนวยความสะดวก มีสระว่ายน้ำ มีฟิตเนส แล้วตรงข้ามห้างสรรพสินค้าชั่นนำด้วยคะ ใต้ตึกมี7/11 (แต่ไม่มีแอลกอฮอล์ขายนะคะ) เดินออกมาปากซอยนิดเดียวถึง ขนส่งสาธารณะ(รถไฟฟ้ามหานคร Mrt สถานี พหลโยธิน เลยคะ) พักที่นี้ไม่ได้ใช้รถเลยคะ จอดไว้โรงแรมตั้งแต่ไปถึงจนวันกลับเลยคะ ----พัก2คืนคะ คืนที่2จ่ายเงินสดคะเพราะต้องการใบกำกับภาษี☺️☺️ ---อาหารเช้ามีเยอะพอสมควรคะ รสชาติใช้ได้คะ ข้อควรปรับปรุง : พนักงานต้อนรับน้องผู้หญิง ควรพูดจาอ่อนกว่านี้จะน่ารักมากๆนะคะ พูดจาดูแข็งๆหรือดูเหมือนรำคาญคะเวลาถามเรื่องห้องและ ใบกำกับภาษีคะ ---หมอนหนุนในห้องแบนไปมากเลยคะ และนิ่ม นะจะเป็นแบบสูญญากาศจะดูโอเคและเข้ากับที่นอนมากคะ ที่นอนผ่าน หมอนไม่ผ่านคะ --- เรื่องน้ำที่ออกมาจากฝักบัวนะคะ แสบผิวมากคะเหมือนรีวิวอื่นๆที่ลงไว้เลยคะ (แต่ทางสามีชอบคะ😅😅) แต่เป็นเด็กกับผู้หญิงไม่ผ่านจ้า😊😊 ---เรื่องความสะอาดห้องจะมีเศษผมและขน....อยู่ตามซอกห้องและโซฟาข้างหน้าต่างเยอะเลยคะ (เด็กๆที่บ้านมีที่นอนไปกันเองเลยนอนพื่นคะ คือต้องเอาผ้ามาเช็ดพื้นอีกทีคะ ---ขอติเรื่องลงไปทานอาหารเช้านะคะ ทางฟร้อนท์ไม่ได้มีใบอะไรให้ไม่แนาใจลืมหรือไม่มีคะ พนักงานบาร์ต้องโทรถามกันเลยคะว่าห้องที่พัก ค่าห้องพร้อมอาหารเช้าไหม อันนี้ถือว่าไม่เรียบร้อยคะ 🛏🛏โดยรวมการเข้าพักครั้งนี้ประทับใจมากกว่าคะ🛏🛏😊😊😊😊',
#  'อาหารเช้าหลากหลาย พนักงานดี ทีวีจอใหญ่ สระว่ายน้ำเป็นส่วนตัว เสียอย่างเดียวห้องยังเหม็นกลิ่นสีแรงมาก และหมอนบาง',
#  'รอเช็คอินนานมากอยากให้ปรับปรุงจุดนี้',
#  'ห้องสะอาด บรรยากาศดี ใจกลางแหล่งช้อปปิ้ง สะดวก พนักงานน่ารัก',
#  'ห้องพักใหม่ ทำเลสะดวก ทีวีจอใหญ่ แนะนำๆ',
#  '',
#  'ดีมากๆค่ะ การเดินทางสะดวก พนักงานบริกาดี',
#  '',
#  'รร สบาย อาหารเช้า โดยรวมโอเค มี 7/11 ใต้ รร เสียหนึงอย่าง wifi ใช้ไม่ได้',
#  'ห้องพักสะอาด อาหารอร่อย พนักงานบริการดีมาก ทีวีขนาดใหญ่ (ต่อเน็ตไว้ให้พร้อม)',
#  '',
#  'ดีทุกอย่างค่ะ ทั้งโลเคชั่น ความสะดวกสบาย พนักงานน่ารักตั้งแต่เบลบอยพนักงานตอนรับรวมถึงแม่บ้านด้วยนะคะ แต่ติดตรงที่ฝักบัวอาบน้ำค่ะ ตัวฝักบัวควรเปลี่ยนแบบดีกว่า ใช้แล้วน้ำที่กระจายออกมาทำให้เจ็บผิวนิดนึงค่ะ 🙂',
#  'สะดวกสบายมากค่ะ ห้องสะอาด กว้าง',
#  'ห้องสะอาด ติดรถไฟฟ้าใต้ดิน ติดที่ช้อปปิ้ง มีร้านสะดวกซื้อ 24ชั่วโมง สระว่ายน้ำและฟิตเนสบริการฟรี ตำหนิเรื่องเดียวประตูห้อง ควรเสริมเส้นยางกันกระแทกประตู หรือ ที่กั้นเสียงอีกนิด แล้วทุกอย่างจะดูดีมากๆ',
#  '',
#  'พักต่ออีกคืน บรรยากาศดี อยากพักเพิ่ม แต่ต้องไปที่อื่นต่อ เดินทางสะดวก เรื่องอาหาร สะดวกมาก เดินเที่ยวได้อีกฝั่ง',
#  'เดินทางสะดวก ใกล้รถไฟฟ้าใต้ดินมากๆ ทางออกประตู4 ใต้ตึกมี7-11 ห้องกว้างใช้ได้ ใหม่ แอร์เย็น น้ำแรง ฝั่งตรงข้ามเป็นห้าง เดินสนุกค่ะ',
#  'ห้องพักสะอาดสวยงาม ทำเลดีสะดวกมาก พนักงานบริการดีมากค่ะ',
#  'โดยภาพรวมดี ใกล้ mrt และแหล่งช็อปปิ้ง ราคาเหมาะสม แต่ถ้าคุณจะแต่งหน้า ทำผม คุณต้องทำในห้องน้ำ เพราะกระจกมีบานเดียวในนั้น พนักงานต้อนรับที่เป็น ผญ บางคนดูไม่เป็นมิตรในน้ำเสียง ตอนระหว่างรอของมีพนักงานต้อนรับซึ่งเป็นเด็กใหม่มาขอข้อมูล ก็ทำท่าทีไม่พอใจและเหวี่ยงใส่รุ่นน้องต่อหน้าลูกค้า',
#  'แอร์ไม่เย็นทั้งคืน เหม็นกลิ่นสี ไม่มีห้องเปลี่ยนให้ นอนดมกลิ่นสีทั้งคืน ปวดหัว และอาเจียน หลังจากเช็คเอาท์ ต้องหาหมอ ไม่สบาย',
#  'เดินทางสะดวก ใกล้แหล่งท่องเที่ยว',
#  'เป็นที่พักที่ดีมากค่ะ คุณพ่อไปหาหมอที่กรุงเทพ คุณแม่พาลูกๆเดินเล่น สบาย มีรถไฟฟ้าใต้ดิน ที่แบบเดินออกมาเข้ารถไฟฟ้าได้เลย สบายค่ะอาหารเช้าดีมาก โรงแรมสะอาด ที่นอนนี้แบบหลับไม่อยากลุกขึ้นเลยค่ะ เยี่ยมมาก',
#  'สถานที่สะอาด พนักงานอัธยาศัยดี โรงแรมอยู่ใกล้ขนส่งสาธารณะ และแหล่งช๊อปปิ้ง',
#  'สะดวกสบายมากค่ะ ที่พักอยู่ติดรถไฟฟ้า และห้างยูเนี่ยนมอลล์ เซ็นทรัลลาดพร้าว โรงแรมใหม่สะอาด แต่อาหารเช้าไม่ค่อยอร่อย',
#  'ดีมากครับ คุ้มค่ากับราคาที่จ่ายไป ห้องสวย สะอาด ถูกใจมาก จะมาพักอีกแน่นอน',
#  'ดีมากๆ ชอบมากเลยค่ะ ประทับใจทุกๆอย่างเลย',
#  'โรงแรมดี เตียงนอนสบาย แต่พนักงานตอนรับไม่ค่อยรับแขกเท่าไหร่',
#  'ห้องพักสะอาดพนักงานน่ารักอาหารเช้าเยอะหลากหลายความสะดวกครบครันค่ะมากรุงเทพอีกรอบจะกลับมาพักที่นี้ค่ะ',
#  '',
#  'เช็กอิน ห้อง 923 ห้องเหม็นอับ เหมือนกลิ่นสี แสบจมูก แสบตา จนปวดหัว แอร์ไม่เย็น ขอเปลี่ยนห้องเพราะมึนหัวกลิ่นมาก แต่ห้องเต็มไม่มีห้องเปลี่ยน ทาง รร.ไม่เผื่อห้องไว้เพื่อเผื่อเกิดปัญหากับลูกค้าเลย ทราบมาว่าทางห้องอื่นก็มีปัญหา และไม่มีห้องเปลี่ยนเหมือนกัน ทางฟร้อนท์ แจ้งช่างมารีเซตแอร์ ตั้งแต่หัวค่ำ ณ.เวลานี้ จะตีหนึ่ง รีเซตมาหลาย ชม.แล้ว ออกแต่ลม อุณภูมิไม่เย็น ในภาพระบุว่าอุณภูมิห้อง 27องศา ช่างเปิดไว้ให้ 19องศา แต่ในความจริง คือมันร้อน นอนแสบจมูกและร้อนทรมานมาก แย่จริงๆ แทนทีจะได้พักผ่อนอย่างสบาย ควรแจ้งให้ผู้จัดการ หรือ ผู้บริหาร รร.ให้ทราบ คืนนี้ทั้งคืนเราคงนอนไม่ได้',
#  'อาหารเช้าดีมาก เตียงนอนสบาย ทำเลดีมากๆ อยากให้เพิ่มกระจกแต่งหน้าในห้องพัก และเปลี่ยนหัวฝักบัวค่ะ (น้ำไหลเป็นเส้นเล็กๆ ถ้าเปิดน้ำแรง โดนตัวแล้วเจ็บมากค่ะ)',
#  'โรงแรมใหม่ สะดวกมาก ติดรถไฟฟ้า MRT พหลโยธิน มี7-11อยู่ใต้โรงแรม บริการประทับใจ',
#  'โรงแรมใหม่ สะอาด อยู่ใกล้ mrt',
#  'ที่พักสวยสบาย บริการดี ชอบมากค่ะ ระบบทันสมัยทั้งWiFi ระบบคีย์การ์ด',
#  'ห้องพักใหม่ สะอาด สะดวกมากๆ ข้างหน้าโรงแรมมี7-11 มีรถไฟใต้ดิน ตรงข้ามยูเนียนมอ เซ็นทรัลลาดพร้าวว มีสระว่ายน้ำ ฟิตเนส ดีมาก ห้องเล็กไปนิดนึง ทำความสะอาดช้าไปนิดนึง โดยรวมโอเครมากคุ้มสุด ถ้ามา กรุงเทพฯ คงมาที่นี้ตลอด',
#  'โรงแรมใหม่ สะอาด อาหารอร่อย เดินทางสะดวก ติด MRT']

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                 Review Rating
# 0    โรงแรมดีมากๆ เดินทางสะดวกใกล้รถไฟฟ้าห้าแยกลาดพ...     10
# 1    ประทับใจพนักงานเช็คอินมาก หน้าตายิ้มแย้มต้อนรั...    9.4
# 2                      ดีมาก เดินทางสะดวกสบาย ใกล้ mrt    9.7
# 3                บริการดีค่า พนักงานพูดเพราะ ห้องสะอาด    9.7
# 4    พักที่นี่ประจำ พนักงานฟร้อนท์ ดีบ้างไม่ดีบ้าง ...    8.5
# ..                                                 ...    ...
# 215  โรงแรมใหม่ สะดวกมาก ติดรถไฟฟ้า MRT พหลโยธิน มี...    9.7
# 216                      โรงแรมใหม่ สะอาด อยู่ใกล้ mrt    9.7
# 217  ที่พักสวยสบาย บริการดี ชอบมากค่ะ ระบบทันสมัยทั...    9.7
# 218  ห้องพักใหม่ สะอาด สะดวกมากๆ ข้างหน้าโรงแรมมี7-...    9.4
# 219   โรงแรมใหม่ สะอาด อาหารอร่อย เดินทางสะดวก ติด MRT    8.5
#
# [220 rows x 2 columns]

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#      index                                             Review Rating
# 0        0  โรงแรมดีมากๆ เดินทางสะดวกใกล้รถไฟฟ้าห้าแยกลาดพ...     10
# 1        1  ประทับใจพนักงานเช็คอินมาก หน้าตายิ้มแย้มต้อนรั...    9.4
# 2        2                    ดีมาก เดินทางสะดวกสบาย ใกล้ mrt    9.7
# 3        3              บริการดีค่า พนักงานพูดเพราะ ห้องสะอาด    9.7
# 4        4  พักที่นี่ประจำ พนักงานฟร้อนท์ ดีบ้างไม่ดีบ้าง ...    8.5
# ..     ...                                                ...    ...
# 194    215  โรงแรมใหม่ สะดวกมาก ติดรถไฟฟ้า MRT พหลโยธิน มี...    9.7
# 195    216                      โรงแรมใหม่ สะอาด อยู่ใกล้ mrt    9.7
# 196    217  ที่พักสวยสบาย บริการดี ชอบมากค่ะ ระบบทันสมัยทั...    9.7
# 197    218  ห้องพักใหม่ สะอาด สะดวกมากๆ ข้างหน้าโรงแรมมี7-...    9.4
# 198    219   โรงแรมใหม่ สะอาด อาหารอร่อย เดินทางสะดวก ติด MRT    8.5
#
# [199 rows x 3 columns]

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                 Review Rating
# 0    โรงแรมดีมากๆ เดินทางสะดวกใกล้รถไฟฟ้าห้าแยกลาดพ...     10
# 1    ประทับใจพนักงานเช็คอินมาก หน้าตายิ้มแย้มต้อนรั...    9.4
# 2                      ดีมาก เดินทางสะดวกสบาย ใกล้ mrt    9.7
# 3                บริการดีค่า พนักงานพูดเพราะ ห้องสะอาด    9.7
# 4    พักที่นี่ประจำ พนักงานฟร้อนท์ ดีบ้างไม่ดีบ้าง ...    8.5
# ..                                                 ...    ...
# 194  โรงแรมใหม่ สะดวกมาก ติดรถไฟฟ้า MRT พหลโยธิน มี...    9.7
# 195                      โรงแรมใหม่ สะอาด อยู่ใกล้ mrt    9.7
# 196  ที่พักสวยสบาย บริการดี ชอบมากค่ะ ระบบทันสมัยทั...    9.7
# 197  ห้องพักใหม่ สะอาด สะดวกมากๆ ข้างหน้าโรงแรมมี7-...    9.4
# 198   โรงแรมใหม่ สะอาด อาหารอร่อย เดินทางสะดวก ติด MRT    8.5
#
# [199 rows x 2 columns]

# %%
table.to_csv("Reviews&Ratings_6th.csv", encoding="utf-8")
