# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=07-11-2022.08-11-2022.1.1.HOTEL.1000000407357.%E0%B9%80%E0%B8%AD%E0%B8%9F%E0%B9%80%E0%B8%AD%E0%B9%87%E0%B8%81%E0%B8%8B%E0%B9%8C%20%E0%B9%80%E0%B8%A1%E0%B9%82%E0%B8%97%E0%B8%A3%E0%B8%A5%E0%B8%B4%E0%B8%87%E0%B8%84%E0%B9%8C%20%E0%B8%A1%E0%B8%B1%E0%B8%81%E0%B8%81%E0%B8%B0%E0%B8%AA%E0%B8%B1%E0%B8%99.1&contexts=%7B%22inventoryRateKey%22%3A%22sAKAURiLpiEan1NG0Q6hK%2B0DXZ%2BT%2Bqw8uON7NhQf%2Ft5M0tKsNUio4Rxug1zOzHJilcvZa8YdqqIySdppe7dolTIewZlxfjiOGz6oXLTucMvN0%2BgQ3yZPvZcoHwUFNN%2BZpcr%2F%2FNa8o9ElfN8zOYhzzZeg0X586laFpeUViPi9rxB%2FkA2U%2Bjg0kZ2frwcSMAyamhLDdV0WLeT%2FFKfQ0QL8LH02Dvlx%2F8PjYogEE5yzx6g6yOKyKeIDf7jO3GM45O1o1hmSkmz3HiZNSbS8gXb3CDW9nmlhkqLKa4lLkAkZpAGTcOmy5l4j7hGHKXWH0MtO45tYfbtBkBgYO99TxwF9DNVsBZohxEpYRFmg%2B%2BHLDKQAG%2F1rhZrd5ovib5W%2FOZIYjTE%2FGsBKQXKjBtgZDhjE4C5zlhNP3bbD3EkRDMDBFQ9BP91JaZBbzrgMh9kT8uRRLbpPqi9QWNDXrth51m8pUsXTrO7kmP1REoaFiJ8zCfvIWGULNNq2kq01LGJS4cUO6IoMhVKT4w7TwrTxbp%2FQ2iMn1qdaM1viWqCGwU1siX1ZIegdsZIo1sjlWnbsTcjefS6Pj3RtIU6lROCEB6QAgiS1WJabPNVEO7waQAXksTDyQHUY2wqyAfRzb44KOjG0poBVHSJ1fq5iJGt%2Fs2ROyG2r1yuKaZ4GSAmh5BaCjz8%3D%22%7D&prevSearchId=1748750315088280409&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]

time.sleep(3)
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div")
sel.click()
time.sleep(3)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()
time.sleep(3)
driver.execute_script("window.scrollTo(0,7770)")

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_18136\3929774867.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)
# 8.5
# - ที่พักอยู่ใกล้ทางลงรถไฟฟ้าใต้ดิน (MRT) เพชรบุรี และใกล้กับ Airport Link - มีลิฟท์บริการใช้การ์ดแตะก่อนขึ้นห้องพัก - ห้องพักผ่านการใช้งานมานานค่อนข้างโทรม แต่เตียงนอนนอนสบาย ห้องนอนและห้องน้ำขนาดกำลังดี แต่อุปกรณ์ในห้องน้ำบางอย่างดูไม่แข็งแรงและใกล้เสียหลายชิ้น เช่นก๊อกอ่างล้างหน้า - ห้องพักไม่เก็บเสียง ข้างห้องคุยกันได้ยินชัดเจน - มีที่จอดรถหน้าโรงแรม - การบริการดีใช้ได้ - อาหารเช้าโอเค มีความหลากหลยไม่มาก แต่รสชาดก็โอเค ข้อดี - ทำเลดี ใกล้ MRT ใกล้ Airport Link - ห้องพักแอร์เย็นฉ่ำ ข้อเสีย - ห้องไม่เก็บเสียงครับ - น้ำอุ่นทำงานไม่เสถียร น้ำไหลช้า แรงดันน้ำไม่ดี
# 8.5
# ราคาไม่แพง แอร์เย็นฉ่ำ ไร้เสียงรบกวนเวลานอน รูปตรงปก เดินทางสะดวกสำหรับคนต้องการความรวดเร็วในการเดินทางทำธุระที่ต้องเดินทางโดยรถไฟฟ้าเป็นอย่างมาก แนะนำเลย
# 9.1
# ติดสถานีใต้ดิน เพชรบุรี เดินทางไปกลับสยาม-ห้วยขวางสะดวก การบริการรวดเร็ว ห้องสะอาด โปร่งไม่อึดอัด
# 8.5
# เดินทางสะดวก โรงเเรมดูปลอดภัย
# 9.1
# โรงแรมดีครับ สะอาด ห้องสวย เดินทางสดวก
# 9.7
# เตียงเดียวห้องเล็ก เตียงคู่ห้องใหญ่กว่า everything good 👍 ใกล้ Mrt n รถไฟฟ้า
# 9.4
# ทำเลติดทางออก mrt เพชรบุรีทางออก 3 และใกล้ airport link มักกะสัน เช่าห้องคืนละ 700+ ห้องเล็กที่มีอุปกรณ์พื้นฐานครบเช่น ไดร์ น้ำอุ่น ทีวี โต๊ะทำงาน อินเตอร์เน็ต ข้อเสียมีเสียงทะลุเข้ามาเล็กน้อย (คนเดิน คนอาบน้ำ) แต่ไม่ใช่ปัญหาใหญ่และไม่มีบริการอาหารเช้า (ซื้อแยก) มีการก่อสร้างข้างโรงแรม ระวังการ WFH จะมีเสียงแทรกเข้าคอมได้
# 9.1
# พนักงานบริการดีมาก ในราคาหลักร้อยคุ้มเลย ใกล้ mrt เพชรบุรี airport link มักกะสัน เดินไปเซเว่นก็ไม่ไกล ตอนแรกตั้งใจจะว่ายน้ำ แต่ช่วงที่ไปปิดปรับปรุง
# 8.8
# ไปพัก 2 ครั้งแล้วค่ะ โอเคกับที่พักมากเพราะตืดกับ mrt เดินทางสะดวก
# 9.7
# ดีมาก สะอาด นอนสบาย การเดินทางสะดวกใกล้ mrt

# %%
driver.title
# Out:
# 'ค่าห้องพัก เอฟเอ็กซ์ เมโทรลิงค์ มักกะสัน (FX Hotel Metrolink Makkasan) มักกะสัน ตั้งแต่ 07-11-2022 ถึง 08-11-2022'

# %%
driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]').click()

# %%
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# ที่พักใกล้กับ MRT เพชรบุรี ออกประตู 3 เดินแค่แปปเดียวก็ถึง สะดวก ห้องสะอาด ไม่น่ากลัวเลยจ้า ไม่เสียงดังมาก รับเรื่องปัญหาเร็วมาก มีปัญหาไดร์เป่าผมเสีย นี่ก็โทรไปตอนตี 1 รู้ว่าดึกมาก แต่ลองโทรไปเค้าเตอร์ก่อน พนักงานรับเรื่องเร็วและรีบเอาไดร์มาเปลี่ยนใหม่ให้ ชอบมากเลย ครั้งหน้าถ้ามีโอกาสก็จะไปพักที่นี่อีก ปักธงไว้เลยละกัน เพราะสะดวกมากจริงๆ ใครที่รอขึ้นเครื่องที่สุวรรณภูมิ และอยากพักในเมือง แนะนำที่นี่ค่า ตื่นเช้ามาเดินไปต่อ ARL มักกะสันได้สบายๆ
# 9.7
# ใกล้ mrt เดินทางสะดวก good room service
# 9.4
# เดินทางสะดวกจากสนามบินสุวรรณภูมิ-MRTเพชรบุรี ประตู3
# 9.1
# ติด mrt ค่ะ ข้ามถนนก็ถึงแล้ว ที่พักปลอดภัย สะอาด แต่อยากให้ปรับปรุงฝักบัวค่ะ ปรับน้ำร้อนน้ำเย็นยังไงไม่รู้ น้ำไม่เสมอกันเลย แต่โดยรวมแล้วดีค่ะ นอนสบายมาก
# 5.7
# คีการ์ดเสียบไม่ติดเปิดไฟห้องไม่ได้ ตี4ไม่ได้แก้ไขอะไรเลย ไม่มีใครอยู่ฟ้อน ต้องไปกดช่วยเหลือในลิฟถึงจะตื่นมา
# 9.7
# โรงแรมนี้ดีกว่าทุกๆ ที่ที่เคยไป เดินทางสะดวก ห้องพักสะอาด วิวจากชั้น 7 ดีมากๆ พนักงานต้อนรับพูดจาสุภาพทุกคน แนะนำเลยค่ะ มีโอกาสจะกลับไปพักแน่นอน
# 8.8
# ดีค่ะ เงียบสงบ สะอาด เดินทางสะดวก ไม่ได้ลองอาหารเช้าเพราะต้องออกเดินทาง แต่เช้าควรเพิ่มกระจกสำหรับผู้หญิงแต่งหน้าบริเวณโต้ะค่ะไม่สะดวกที่กระจกใน/หน้าห้องน้ำ
# 8.5
# โรงแรมบรรยากาศดีมากครับ พนักงานพูดดีรวมไปถึงแม่บ้าน ประทับใจมากครับ
# 8.5
# ดีค่ะ ใกล้กับแอร์ลิ้ง เดินทางไปสุวรรณภูมิ สะดวกมากๆ
# 9.7
# มาพักซ้ำ เพราะใกล้ MRT เดินทางสะดวก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
sel.click()

# %%
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# จองไว้มางานวิ่ง ATMBKK2021 อยู่ติดสถานี MRT เพชรบุรี และ Airport Link มักกะสัน เดินไม่ถึง2-3 นาทีเอง ห้องพักขนาดกำลังดี ห้องน้ำเล็กไปนิด แต่เตียงนอนหลับสบายมาก ถือว่าคุ้มราคามากๆ เมื่อเทียบกับทำเล
# 9.7
# พนักงานบริการดี เตียงกว้างใหญ่สะอาด สุขภัณฑ์ในห้องน้ำใช้ได้ดี น้าไหลแรงร้อนเร็ว มีตู้เซพ ไดร์ โต๊ะทำงานเล็กๆ คุ้มมาก ออกจากโรงแรมเดินไปขึ้น MRTและแอร์พอตลิ้งสบายๆเลย คราวหน้าจะไปพักอีกครับ
# 8.5
# ห้องพักสะอาดบริการดีค่ะ รอบหน้าพักอีกแน่นอนค่ะ
# 10
# 10/10 ชอบมากค่ะ บริการดี ห้องพักสะอาด พนักงานต้อนรับพูดเพราะ แม่บ้านใจดี มาทุกครั้งก็จะมาพักแต่โรงแรมนี้ เดินทางสะดวกใกล้กับ MRT
# 8.5
#
# 8.5
# ดีคะสะดวกใกล้สถานีรถไฟ ห้องพักถือว่าโอเค
# 6.9
# พักห้อง 408 แอร์ไม่ค่อยเย็นครับ ปรับทั้งอุณหภูมิ และพัดลม แล้วแต่ก็ยังไม่เย็น ไม่ได้แจ้งเจ้าหน้าที่ เพราะพักคืนเดียว และใช้ห้องแค่ช่วงตอนนอนและเช็คเอ้าตอนเช้า แต่ยังชอบ location ของโรงแรม เพราะสะดวกกับการเดินทางมากครับ ขอบคุณครับ
# 10
# โอเคกว่าที่คิดไว้เยอะมาก คุ้มราคาจริง ๆ เดินทางสะดวก ที่นอนสบาย น้ำไม่เย็นเกินไป ถูกใจมาก อยากอาบน้ำนาน ๆ เลย 55555 พนักงานบริการดี
# 9.1
# ชอบมากค่ะ พนักงานบริการดี แถมที่พักยังเดินทางไปไหนมาไหนสะดวก ใกล้ mrt เพชรบุรี ส่วนภายในห้องพักก็ดีมากเลยค่ะ อุปกรณ์ครบ สะอาด แอร์เย็น 💝
# 9.7
# พนักงานตอนรับบริการดีมากห้องพักสะอาดเงียบสงบ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# ดีนะ สะอาด พรังงานน่ารัก พักรอบนี้รอน4คืน คืนแรกน้ำแอร์หยดเป็นน้ำเลย พอเช้าแจ้งพนังงานก็จัดการให้ จบนอนต่อได้สบาย คือดีราคาดีถ้าเทียบกับบริเวณนั้น ใกล้ที่สัมมนา ใกล้mrt ผ่าน กลับมาพักอีก ปล.ขึ้นจากmrtออกประตูฝั่งรร. เดินมาทางแยกแล้วเลี้ยวขาวเข้าซอย45 ถ้าเดินมาgoogle คืองง หาซอยยากมาก
# 8.5
# การเดินทางสะดวกใกล้mrtเพชรบุรี และแอร์พอร์ตเรลลิ่ง พนักงานบริการการดียิ้มแย้มแจ่มใส ห้องที่พักก็ดูดีตรงตามปกมีสิ่งอำนวยความสะดวกครบครันครั้งหน้าถ้ามากรุงเทพจะมาพักอีกแน่นอน
# 9.1
# พนักงานน่ารัก ที่พักสะอาด 3คืนแรกเสียงดังจากข้างนอกนึกว่าผนังห้องบาง พอคืนสุดท้าย พึ่งมาเจอ หน้าต่างตัวล็อคไม่สนิททำให้เสียงรอดเข้ามา พอแก้ไข ก็ไม่มีเวียงรบกวน ราคาถือว่าดี กับคุณภาพห้องกับรรข้างเคียง กลับไปพักอีกแน่นอน
# 9.7
# สะดวกในการเดินทางไปสนามบินสุวรรณภูมิโดยARL พนักงานอัธยาศัยดี ถ้ามีโอกาสจะแวะไปพักอีก
# 9.1
# ที่พักดีเดินทางสะดวกใกล้รถไฟฟ้า พนักงานต้อนรับดูแลเอาใจใส่ดีพร้อมแนะนำช่วยเหลือ ห้องกว้าง ราคาไม่แพง อาหารเช้าดี
# 10
# โรงแรมดีมากค่ะ บริการดี ห้องสะอาด สวย ใกล้mrt เพชรบุรีมาก เดินทางไปมศวใกล้มากค่ะ พักอีกแน่นอนค่ะ
# 9.4
# ห้องพักและการอำนวยความสะดวกได้ตามคำขอเลย ประทับใจมากค่ะ ห้องพักโอเคเลย ชอบค่ะ โรงแรมก็เดินทางสะดวก พนักงานต้อนรับทักทายดีมากๆ แต่อาหารเช้าอยากให้มีเมนูได้เลือกสักหน่อย เพราะไม่ใช่ทุกคนที่จะทานสิ่งที่โรงแรมเตรียมไว้ได้อ่ะค่ะ
# 9.1
# ที่พักดีมาก สะอาด พนักงานดีมากๆยิ้มแย้ม ครบครัน ทางเข้าแอบน่ากลัว แต่ปลอดภัย อยู่ในที่ชุมชน
# 10
# ทำเลที่ตั้งดีไปมาสะดวกอาหารเช้าอร่อยห้องพักดีสะอาดมาก
# 9.4
# พนักงานบริการดีค่ะ ห้องพักสะอาด ติด MRT ใกล้ แอร์พอร์ตลิ้งค์ เดินทางสะดวกค่ะ แต่สภาพแวดล้อมไม่ค่อยดีนักเพราะมีการก่อสร้างคอนโดเยอะค่ะ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# สะดวก สะอาด สบาย ราคาสบายกระเป๋า บริการดี
# 9.4
# โรงแรมหาไม่ยากครับ อยู่ติด MRTเพชรบุรี และ Airportlink มักกะสัน เดินทางมาไม่ยาก พนักงานบริการดี ห้องพักไฟเยอะดี ปลั๊กไฟอยู่ในที่ที่ควรมีทุกจุดเลยครับ โดยรวมแล้วผมว่าน่าพึงพอใจมากครับ
# 9.4
# อยู่ใกล้รถไฟฟ้า MRT เพชรบุรีมาก เดินทางสะดวกมาก ห้องสะอาดน่าอยู่ ห้องน้ำดี รวมๆโอเคค่ะ เป็นอีกทางเลือกการเที่ยวในเมือง
# 6.4
# พนักงานต้อนรับดูแลไม่ดี ไม่เทคแคร์แขก
# 9.7
# โรงแรมสบาย พนักงานบริการดีมาก อาหารเช้าอร่อย
# 8.5
# เดินทางสะดวก อาหารเช้าก็โอเค พนักงานน่ารักพักมาหลายรอบแล้วก็โอเคทุกครั้งเลย
# 8.7
# พนักงานบริการสุภาพ ห้องสะอาด แต่อับนิดหน่อย ห้องน้ำสะอาดแต่อ่างล้างหน้าน้ำระบายไม่ดี ล้นขึ้นมา โดยรวมใช้ได้ ยกเว้น wifi มีแต่ใช้ไม่ได้ต้องแชร์เน็ตจากมือถือเอง
# 9.4
# ดีมากๆคะ. สะอาด บริการดีคะ และอยุ่ใกล้รถไฟฟ้า การเดินทางสะดวกคะ ถ้ามีโอกาสไปทำธุระที่ กทม. จะแวะไปพักอีกแน่นอนคะ
# 9.7
# ที่พักดีมาก ใกล้mrtกับairport link มาก (เดินไปได้) บริการดีมาก ห้องสะอาด กว้าง แต่ไม่ค่อยเก็บเสียง พนง.พูดภาษาอังกฤษได้
# 9.1
# พนักงานบริการดี สุภาพ เป็นมิตร บริการดี ห้องโดยรวมโอเคร อับบ้างเล็กน้อย แต่สะอาด ห้องน้ำ ผ้าปูที่นอน พื้นห้องสะอาด เตียงและหมอนนุ่ม หลับสบาย

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# เดินทางสะดวก ใกล้รถไฟฟ้า และห้องพักสะอาดน่าอยู่
# 9.1
# สะดวกที่สุดคือทำเลที่ตั้งค่ะ ตั้งอยู่ที่mrtเพชรบุรี จุดเชื่อมต่อ airport railink มักกะสัน เดินทางไปไหนมาไหนง่ายมาก ห้องค่อนข้างแคบ และเตียงเล็กกว่าปกติ แต่ก็สะอาดดีค่ะ อีกอย่างคือเวลารถวิ่งอาจจะได้ยินเสียงแต่ก็น้อยมากค่ะ
# 9.1
# ที่พักดีมากๆ มีหมวกอาบน้ำให้ด้วย ปกติโรงแรมราคานี้จะไม่มีให้ 555 อาหารเช้ามีให้เลือกน้อยไปนิดแต่อร่อยดีค่ะ ห้องดี ห้องน้ำดี แยกโซนเปียกแห้ง อยู่ใกล้ห้าง ใกล้รถไฟฟัา ตอนเราไปโชคร้ายข้างๆ มีไซท์ก่อนสร้าง ตอนกลางวันเสียงดังตลอด แต่กลางคืนเงียบปกติค่ะ ข้อเสียคือเตียงแข็งไปนิดนึง
# 8.5
# ห้องสะอาด ดีมาก บริการดีมาก ห้องน้ำสะอาด
# 8.5
# ดีมากๆค่ะ ห้องพักสะอาด อุปกรณ์ครบ พนักงานที่นี่ทุกคนบริการด้วยหัวใจรักบริการ ดูแลแขกเหมือนเป็นคนในครอบครัว
# 9.7
# สะดวก สบาย ใกล้ Mrt และ Airport link
# 6.4
# ห้องพักคราวนี้เสียงแอร์ค่อนข้างดังค่ะ แถมมีการก่อสร้างเสียงดังมาถึงห้องเลย
# 10
# ถึงจะเป็นครั้งที่2ที่ได้ไปพักที่ FX แล้ว แต่บริการก็ยังดีเหมือนครั้งแรกที่เคยไปพักไม่เปลี่ยนเลยค่ะ อาหารก็อร่อย ที่พักก็สบาย คงจะได้ไปใช้บริการอีกบ่อยๆค่ะ
# 9.4
# ดี สะอาด เรียบหรู อยู่ใจกลางเมือง
# 6.6
# ได้กลิ่นห้องน้ำ ชยออกมาตอนนอนหลับบ่อยมาก แม้จะปิดประตูไว้ก็ตาม

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 5.9
# ห้องแคบมากๆ ได้ห้องตรงมุมๆ รีโมททีวีกดไม่ค่อยติด
# 8.5
# พักครั้งที่ 2 แล้วค่ะ เดินทางสะดวก เจ้าหน้าที่ใจดี
# 9.4
# มาพักประจำค่ะ สะดวกใกล้แอร์พอร์ตลิ้งค์กับMRT ห้องสะอาด อาหารเช้าดี
# 8.8
# เดินทางสะดวก ใกล้ mrt กับ airport link เตียงนุ่มดี อาหารเช้ามีให้เลือกน้อยไปหน่อย
# 9.7
# ในห้องดูดีกว่าในรูปถ่ายค่อนข้างมาก พนักงานก็ยิ้มแย้มแจ่มใสตลอด พร้อมบริการและสุภาพกันทุกคน อาหารเช้าอร่อยมากๆทั้ง2คืนที่ไปพักเลย ถ้ามีโอกาสก็อยากกลับไปใช้บริการอีกครั้งค่ะ
# 8.8
# ห้องพักดีครับการบริการดีโดยรวมดีครับ
# 9.4
# จัดห้องที่ต้องการให้คือ มีหน้าต่างเห็นวิวชั้นบน และไม่มีกลิ่นบุหรี่ จะมีที่ช่างเข้ามาช่วยคือ ประตูห้องน้ำล๊อคเองจากข้างนอก แจ้งให้ช่างมาซ่อมให้ใช้ได้เหมือนเดิมค่ะ
# 8.5
# สะดวก ใกล้ mrt เพชรบุรี ห้องสะอาด แต่ห้องไม่ค่อยเก็บเสียง พนักงานต้อนรับบริการดี ยิ้มแย้มแจ่มใส
# 10
# ห้องสะอาด พนักงานต้อนรับดีมาก สะดวกสบายใกล้รถไฟฟ้า เดินทางสะดวกสบาย
# 9.4
# ห้องดี กว้าง เตียงนอนหลับสบาย ที่พักใกล้ Mrt เพชรบุรี กับ แอร์พอร์ตเรลลิ้งค์ มักกะสัน เดินทางสะดวก ตอนเช้ามีอาหารเช้าบริการ มีให้เลือกไม่มากแต่อร่อยดีค่ะ ถึงว่าครบทั้งไทย ฝรั่งค่ะ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]/div[2]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.4
# โรงแรมอยู่ใกล้mrtเพชรบุรี ประตู3 เดินทางสะดวก พนักงานบริการดีน่ารัก
# 9.1
# ห้องพักมีอุปกรณ์และเครื่องใช้พื้นฐานครบ อาหารเช้าอร่อยและมีให้เลือกเยอะ ราคาสมเหตุสมผล
# 8.8
# การเดินทางสะดวกมากใกล้ mrt + airport link
# 8.5
# ใกล้ MRT ที่จอดรถน้อย 7-11 อยู่ในระยะที่เดินได้
# 9.4
# พนักงานสุภาพและให้ความช่วยเหลือดีมาก ห้องพักสะอาดเรียบร้อยดี
# 9.7
# ห้องพักดี พนักงานบริการดี อาหารอร่อย ใกล้รถไฟฟ้า
# 8.5
# โรงแรมทำเลดีอยู่ใกล้ mrt เพชรบุรี สะดวกสบาย
# 9.4
#
# 9.4
# ประทับใจ ทั้งเรื่องของห้องพักและงานบริการ
# 9.7
# สะดวกกับการเดินทาง ติดmrtเพชรบุรี ห้องพักสะอาด พนักงานบริการดีค่ะ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(3)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 5.2
# ห้องเหม็นอับ แอร์ร้อนและดัง พักหลายคืน แม่บ้านไม่ทำความสะอาดกับเติมของให้ ต้องค่อยแจ้ง
# 8.8
# ใกล้ MRT และ Airport Link พนักงานบริการดี มีอาหารเช้าหลากหลายให้เลือก ที่พักห้องกว้าง แต่มีกลิ่นเหมือนไม้อัด
# 9.7
# สะอาด สบาย ดูแลดีมากๆ ถ้ามีโอกาสกลับไปพักอีกแน่นอน
# 6.6
# พนักงานต้อนรับหญิงทำหนังหน้าไม่รับแขก พูดจาห้วนๆทำหน้าทำตาหมิ่น พูดจาเหมือนจะไม่มีมารยาท ส่วนห้องพัก อาหารทุกอย่างดีหมด
# 9.7
# ประทับใจกับพนักงานและสถานที่ สะดวกการเดินทาง หาไม่ยาก ห้องสะอาด
# 8.5
# สะอาด สะดวก มีครบครัน แต่ fitness สระว่ายน้ำปิดบริการเร็วไปหน่อย ทางเข้าเปลี่ยวเล็กน้อยแต่เป็นแค่ระยะทางสั้นๆ
# 8.5
# ห้องพักโอเคมากๆ แอร์เย็น พนักงานดี แต่สายชำระไม่ค่อยแรงเท่าไหร่
# 9.3
# ทำเลดี ใกล้ mrt เพชรบุรี เดินไม่ถึง 5 นาทีก็ถึงโรงแรม แต่ห้องค่อนข้างเก่าเล็กน้อย น้ำห้องน้ำไหลช้ามาก แต่รวมๆแล้วถือว่าดีค่ะ
# 8.5
# อยู่ใกล้ MRT เพชรบุรี เดินทางสะดวกมากค่ะ โรงแรมไซซ์ไม่ใหญ่เกินไป มีอาหารเช้าที่ไม่ใช่แค่บิสกิตด้วย แนะนำเลยค่ะ
# 6.6
# พัก 2 ห้อง ห้องนึงแอร์ไม่เย็น ห้องแคบไปนิด น้ำไหลเบาบ้างแรงบ้าง อาหารเช้าเมนูทั่วไป เมนูน้อยไปหน่อย รสชาติเฉยๆ เงียบดี ไม่ค่อยมีคนพลุกพล่าน ไปถ่ายงานแถวสุขุมวิท ที่พักใกล้ดี ราคาเหมาะสมค่ะ ห้องที่จองเต็ม พนักงานติดต่อกับโรงแรมเพื่อฟรีอัพเกรดห้องให้ น่ารักมากค่ะ พนักงานที่เคาน์เตอร์โรงแรมต้อนรับดีค่ะ พี่ รปภ. ช่วยขนกระเป๋าให้ค่ะ พนักงานห้องอาหารน่ารักค่ะ เติมอาหารตลอดค่ะ ประทับใจส่วนงานบริการค่ะ ถ้าแวะไปทำงานแถวนั้นจะใช้บริการอีกค่ะ (เสียดายพักแป๊บเดียว ไม่ได้เดินไปดูส่วน swimspa pool ค่ะ)

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]/div[2]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 6.6
# จากการที่เข้าพักอยู่หลายปี และเลือกที่นี่เพราะสะดวกและใกล้ที่ทำงานที่สุด เวลาไปทำงานที่กรุงเทพฯ ก็จะเลือกพักที่นี่ ทุกอย่างดีหมด ทั้งการบริการ พนักงานสุภาพ แต่ที่แย่สุดๆตอนนี้ ทางโรงแรมอาจต้องรีบแก้ไขคือเรื่องระบบน้ำ ยิ่งชั้น 7 น้ำแทบไม่มีเลย และเรื่องความสะอาดภายในห้องพัก บางห้องเหมือนแทบคิดว่าแค่ปัดเตียง ความสะอาดให้ระดับ 2 เรื่องระบบน้ำให้ระดับ 0 เห็นความแตกต่างได้ชัดตั้งแต่เข้าพักครั้งแรกเมื่อหลายปีก่อนตั้งแต่เปิดจนถึงปัจจุบัน ติดแค่เรื่องระบบน้ำกับความสะอาดแค่นั้นค่ะ
# 9.1
# ทำเลที่พักดีมาก มีที่จอดรถ ห้องพักสะอาด เตียงใหญ่ อาหารเช้าโอเค ยกเว้นอย่างเดียวคือหมอนแฟ่บ ต้องเอาอีกใบมาซ้อนรองนอน อย่างอื่นดีหมด คราวหน้าจะมาพักอีก
# 9.4
# โรงแรมใกล้รถไฟฟ้าใต้ดิน สถานีเพชรบุรี ประตู 3 มาก เดินทางสะดวก ห้องพักขนาดกำลังดี ผนังห้องไม่กันเสียงเท่าที่ควร จะได้ยินเสียงโทรทัศน์จากห้องข้าง ๆ ตลอดเวลา เนื่องจากเป็นห้อง Connecting Room ห้องพักสะอาด ที่นอนและหมอนไม่แข็งหรือนิ่มเกินไป คุ้มค่ากับราคา
# 9.4
# โดยรวมดีมาก ใกล้ MRT และ Airport Link เดินทางเข้าเมืองและไปสนามบินได้สะดวก แต่น้ำไหลบ้างไม่ไหลบ้างสลับกัน ทำให้น้ำเดี๋ยวอุ่นเดี๋ยวเย็น แต่อยู่ในระดับที่รับได้
# 9.4
# โดยรวมถือว่าดี แต่ระบบน้ำไม่ค่อยดี ความแรงของน้ำไม่สม่ำเสมอ ในห้องอาบน้ำ น้ำระบายออกได้ช้ามาก เหมือนท่อตัน
# 8.8
# สะดวก ใกล้สถานีรถไฟ แต่ห้องไม่กันเสียง
# 9.4
# ใกล้ mrt / airport link
# ห้องโอเค
# 8.8
# สะดวกในการเดินทางเพราะใกล้รถไฟฟ้าใต้ดิน แต่ควรปรับปรุงเรื่องผ้าปูที่นอน
# 8.5
# ห้องพักสะอาดดี ใกล้ mrt เสียดายที่เช็คอินก่อนเวลาไม่ได้แต่มีการแก้ปัญหาที่ดี
# 9.7
# ดีมาก พนักงานบริการดี โรงแรมสะอาด

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
# สะดวกมาก ใกล้ MRT และ ARL เสียดายที่ได้ Key card อันเดียว ไม่ค่อยสะดวก
# 9.7
# ดีมากๆ สะอาด สะดวก สบาย พนักงานน่ารัก
# 8.8
# ห้องพักโอเคค่ะ การบริการดี ห้องพักมีปัญหาก็เปลี่ยนให้ทันทีเลย แต่ติดนิดเดียวตรงพนักงานที่ห้องอาหารบริการช่วงค่ำไม่ค่อยโอเค แนะนำไม่ได้ หัวเราะตลอดเวลา ไม่คุ้มกับ 17% ที่ต้องจ่ายเพิ่ม
# 7.3
# เดินทางสะดวก ใกล้แอร์พอร์ตลิงก์
# 10
# ทุกอย่างดีมากค่ะ อาหารเช้าหลากหลายและอร่อย พนักงานบริการดี ห้องพักสะอาด เดินทางสะดวก
# 9.1
# ห้องพักสะอาด พนักงานบริการดีมาก ยิ้มแย้มตลอด เดินทางสะดวก ใกล้แอร์พอร์ตลิงก์กับเอ็มอาร์ที
# 9.4
# พนักงานยิ้มแย้มแจ่มใส ดูแลดีค่ะ ที่พักสะอาด
# 8.8
# ที่ตั้งใกล้ MRT สะดวกสบายมากในการเดินทาง
# 9.4
# เจ้าหน้าที่ฟรอนต์ดูแลและให้คำปรึกษาดีมากค่ะ ไม่โกหกลูกค้า ชอบๆ
# 8.5
# พนักงานต้อนรับอัธยาศัยดี มีน้ำใจให้ยืมร่มตอนฝนตก ห้องพักสะอาด ใหม่ น่าอยู่ ทำเลที่ตั้งติดกับสถานีรถไฟฟ้าใต้ดิน แอร์พอร์ตลิงก์ เดินทางสะดวก อาหารเช้าพอใช้ ปริมาณน้อยไปหน่อย แต่มีการทำมาเติมอยู่เรื่อยๆ โดยรวมถือว่าโอเค เหมาะสมกับราคา ถ้ามีโอกาสจะกลับมาใช้บริการอีก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# ดีค่ะ สะดวกและการบริการที่เป็นกันเอง พนักงานยิ้มแย้มแจ่มใส
# 8.5
# ใกล้ MRT เพชรบุรี เดินทางสะดวก
# 10
# ดีมาก ทุกอย่างค่ะ บริการดี ห้องสะอาด อาหารอร่อย
# 9.1
# ทำเลที่ตั้งสะดวก สบาย ห้องก็ได้มาตรฐาน
# 9.7
# แนะนำเลยค่ะ ดีทุกอย่าง ถูกใจมาก ไปมา 2 รอบแล้ว
# 9.1
# ทำเลดีมาก ใกล้เอ็มอาร์ที แอร์พอร์ตลิงก์ สะอาด ขนาดห้องกำลังดี ของใช้ในห้องน้ำครบครัน แต่เตียงแข็งไปนิด
# 8.7
# เดินทางสะดวก ใกล้เอ็มอาร์ทีและแอร์พอร์ตลิงก์
# 9.7
# สะดวก สะอาด สบาย สมราคา พนักงานดูแลดีมากค่ะ ทุกคนค่ะ
# 8.4
# อาหารเช้ามีให้เลือกน้อยมาก แต่สามารถสั่งเพิ่มได้
# 9.7
# สะดวก สบายมากค่ะ ไปพัก 2 รอบละ เดินทางสะดวกสุดๆ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
driver.execute_script("window.scrollTo(0,6600)")
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.7
# ห้องพักกว้าง สะอาด พนักงานยิ้มแย้มดีค่ะ แต่สระว่ายน้ำเล็กไปหน่อย อาหารเช้าก็ไม่ค่อยหลากหลาย แต่รวมๆแล้วถือว่าดีค่ะ ใกล้แอร์พอร์ตลิงก์และเอ็มอาร์ที สะดวกต่อการเดินทางมากๆค่ะ
# 9.3
# โดยรวมถือว่าดีมากตั้งแต่คุณลุงยามที่บริการเรื่องที่จอดรถ แต่พนักงานรีเซปชั่นผู้หญิงพูดจากไม่ดี กระแทกเสียง แถมมีการโทรเข้ามาในห้อง บอกว่าลูกค้าจองคืนเดียวนะคะ ฟีลเหมือนโดนไล่ไงไม่รู้
# 9.4
# พนักงานต้อนรับตอนกลางคืนไม่ค่อยโอเค เหมือนมองเหยียดๆว่าเราไม่มีตังค์เข้าพักอ่า เราไปกับเพื่อนต่างก็รู้สึกเหมือนกัน แต่พนักงานต้อนรับตอนเช้าแตกต่างกันมาก เทกแคร์ดี พูดจาดี ยิ้มแย้มแจ่มใส่ รวมๆประทับใจค่ะ
# 10
# ดีค่ะ สะดวก สบาย สะอาด ราคาเหมาะสมค่ะ
# 8.8
# ห้องพักสะอาด ทำเลดี ใกล้รถไฟฟ้าใต้ดิน เดินทางสะดวก
# 10
# สะดวก สะอาด สบายมาก เหมาะกับการเข้าพัก
# 6.9
# ใกล้แอร์พอร์ตลิงก์ เช็กอินได้ตลอดเวลา
# 9.7
# ดีมากครับ และชอบมากด้วย โรงแรมใหม่ สะอาด ที่ตั้งสะดวกในการเดินทาง บริการประทับใจครับ สมกับราคา ผมไปพักอีกแน่นอนครับ
# 7
# โอเค ดี ห้องอับและแคบไปนิดนึงค่ะ
# 10
# ใกล้รถไฟฟ้า สะดวก สะอาด สงบ พนักงานน่ารัก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
driver.execute_script("window.scrollTo(0,6600)")
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 10
# เตียงนุ่ม แอร์เย็น ทำเลที่ตั้งดี เดินทางสะดวก แต่ควรปรับปรุงอินเทอร์เน็ต ช้ามาก เล่นในห้องไม่ได้เลย แต่ที่ล็อบบี้เน็ตเร็วดีครับ
# 9.4
# พนักงานบริการดีมาก ไหว้ทุกรอบที่เดินผ่าน ห้องพักสะอาด ใหม่ รู้สึกดีและคุ้มค่า ประทับใจมากๆ เหมาะสำหรับผู้ที่ลงจากแอร์พอร์ตลิงก์มาแล้วไม่มีรถ เดินไม่ไกล เสียดายผมตื่นสาย เลยไม่ได้ลองชิมอาหาร
# 9.4
# พนักงานบริการดีมาก ใกล้เอ็มอาร์ที สะดวกในการเดินทาง
# 8.5
# ห้องพักสะอาด ใหม่ดี และทำเลดี ใกล้แอร์พอร์ตลิงก์ไปสนามบินสุวรรณภูมิ แต่เรื่องอาหารเช้าค่อนข้างน้อย
# 9.7
# พักที่นี่หลายครั้ง ประทับใจทุกครั้ง เดินทางสะดวก ที่พักสบาย พนักงานน่ารักค่ะ
# 9.1
# ดีมากค่ะ ไปพักที่นี่แทบทุกครั้งที่ต้องไปธุระที่กรุงเทพฯ หรือรอบินไปต่างประเทศ เดินทางสะดวกเพราะใกล้สถานีเอ็มอาร์ทีและแอร์พอร์ตลิงก์ พนักงานก็น่ารัก การบริการดีมากค่ะ
# 10
# เดินทางสะดวก ใกล้รถไฟฟ้า แอร์เย็นมาก เตียงนุ่ม น้ำไหลแรง เสียดายไวไฟไม่ค่อยแรง แต่อย่างอื่นดีหมด
# 9.4
# สะอาด สะดวกสำหรับคนที่ต้องใช้แอร์พอร์ตลิงก์และเอ็มอาร์ที
# 9.4
# บริการดีมากครับ อาหารอร่อย โดยรวมแล้วดีครับ
# 8.4
# อยู่ใกล้แอร์พอร์ตลิงก์ ถ้าไม่รู้เส้นทางจะงงทางเข้า เพราะถ้าเข้าด้านหลังอาจจะเลยซอย ป้ายไม่ชัดเจน อยู่ใกล้เซเว่น จองแบบรวมอาหารเช้า ตักอาหารกำลังจะทาน พนักงานเดินมาแจ้งว่าเราไม่ได้รวมอาหารเช้า เสียความรู้สึก ควรจะเช็กให้ดีเพราะชำระเงินแบบรวมอาหารเช้าไปแล้ว

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
driver.execute_script("window.scrollTo(0,6600)")
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# บริการดีมาก เดินทางสะดวก อาหารเช้าอร่อย
# 7
# ห้องพักสะอาด ใกล้แอร์พอร์ตลิงก์และเอ็มอาร์ที เดินทางสะดวก แต่ห้องมีกลิ่นบุหรี่
# 5.8
# สกปรก ควรพิจารณาตัวเลือกอื่น
# 9.3
# โดยรวมดีมากค่ะ แต่ขอให้ปรับปรุงเมนูอาหารเช้าด้วยค่ะ อยากให้มีอาหารให้เลือกหลากหลายประเภทมากกว่านี้ค่ะ
# 8
# ใกล้กับเอ็มอาร์ทีเพชรบุรี ทางออก 3 เพียง 100 เมตร ห้องกว้าง แอร์เย็น ยกเว้นน้ำไหลช้า และไหลไม่แรง ฝักบัวก็ไหลช้ามาก ต้องรอเป็นจังหวะ อาบน้ำไม่สะใจเลย พนักงานยิ้มแย้ม บริการดี ยกเว้นพนักงานห้องอาหาร หน้าตาไม่รับแขกเลย โดยรวมให้ 3 เต็ม 5
# 8.8
# ใกล้รถใต้ดิน เดินแป๊บเดียวถึง มีเซเว่นอยู่เลยไปนิดหน่อย แอร์พอร์ตลิงก์ก็เดินไม่ไกล
# 10
# ใกล้รถไฟฟ้า สะดวกในการเดินทาง ชอบ ดีมาก
# 10
# ไม่มี เพราะโรงแรมสะดวกในการเดินทาง ใกล้สถานีรถไฟฟ้า
# 8.5
# พนักงานบริการดี เดินทางสะดวก ปลอดภัย
# 9.7
# ดีทุกอย่างเลยครับ จะให้เต็มเลย ถ้าปรับปรุงลิฟต์

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
driver.execute_script("window.scrollTo(0,6600)")
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 6.3
# ที่ตั้งทำเลดี ใกล้แอร์พอร์ตลิงก์ เอ็มอาร์ที โรงแรมโอเคดี ปลอดภัย แต่ห้องไม่เก็บเสียงนะคะ แขกข้างห้องและแม่บ้านได้ยินหมด ต้องตื่นเช้าๆทุกวันค่ะ ส่วนห้องอาหารต้องปรับปรุงด่วน สั่งแตงโมปั่นและผัดไทย มีเราคนเดียวในห้องอาหาร แตงโมปั่นใช้เวลา 15 นาที ผัดไทยไม่มีกุยช่ายด้วย 40 นาที นานมากๆ
# 6.9
# พนักงานบริการดีและให้ความเคารพกับลูกค้า เป็นที่น่าประทับใจมากครับ
# 8.7
# ใกล้รถไฟฟ้าใต้ดินเพชรบุรี และแอร์พอร์ตลิงก์มักกะสัน สามารถเดินมาโรงแรมได้ ไม่ไกลมาก ห้องพักคุ้มค่ากับราคา อาหารเช้าอร่อย
# 5.8
# ได้ห้องเล็ก ห้องน้ำไม่สะอาด ห้องแคบไม่กว้าง ไม่คุ้มเงิน ดีอย่างเดียวคืออาหารอร่อย ไม่กลับไปพักอีกแน่นอน ครั้งเดียวพอ
# 7.3
# อยู่ใกล้กับแอร์พอร์ตลิงก์ เหมาะกับการเดินทางไปต่อเครื่อง พัก 3 คนจึงต้องเพิ่มเงินอีก 700 บาท อาหารเช้าดี แต่มีไม่มากและไม่หลากหลาย
# 9.7
# ทำเลสะดวก พนักงานบริการดีมากค่ะ
# 9.7
# ทุกอย่างดีมาก! พนักงานยังเป็นมิตรและยิ้มแย้มเสมอ ฉันชอบพักที่นี่ และฉันจะทำซ้ำอีกครั้ง ง่ายต่อการเข้าถึงสถานีรถไฟฟ้าใต้ดินและ 7e เพียง 200 ม. จากโรงแรม
# 9.7
# ห้องพักสะอาด ทำเลดี และอาหารเลิศรส ขอบคุณมากพนักงานของคุณทุกคน พวกเขาใจดีจริงๆ
# 9.7
# เกินคาด! เดินทางไปไหนก็สะดวก ใกล้ MRT พนักงานกระตือรือร้น มีความสุข ห้องพักได้รับการทำความสะอาดทุกวันแม้จะไม่จำเป็น ห้องก็สะอาด เป็นระเบียบเมื่อออกไปข้างนอก
# 9.7
# พนักงานให้ความช่วยเหลือดีมาก ใกล้ MRT สถานีเพชรบุรี เพียง 100 ม. และใกล้ท่าเรือไปยังประตูน้ำอีกด้วย ข้ามถนนเท่านั้น ห้องพักสะอาดมาก.

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 160
# Reviews_list : 160

# %%
Ratings_list
# Out:
# ['8.5',
#  '8.5',
#  '9.1',
#  '8.5',
#  '9.1',
#  '9.7',
#  '9.4',
#  '9.1',
#  '8.8',
#  '9.7',
#  '8.5',
#  '9.7',
#  '9.4',
#  '9.1',
#  '5.7',
#  '9.7',
#  '8.8',
#  '8.5',
#  '8.5',
#  '9.7',
#  '9.7',
#  '9.7',
#  '8.5',
#  '10',
#  '8.5',
#  '8.5',
#  '6.9',
#  '10',
#  '9.1',
#  '9.7',
#  '9.7',
#  '8.5',
#  '9.1',
#  '9.7',
#  '9.1',
#  '10',
#  '9.4',
#  '9.1',
#  '10',
#  '9.4',
#  '8.5',
#  '9.4',
#  '9.4',
#  '6.4',
#  '9.7',
#  '8.5',
#  '8.7',
#  '9.4',
#  '9.7',
#  '9.1',
#  '9.7',
#  '9.1',
#  '9.1',
#  '8.5',
#  '8.5',
#  '9.7',
#  '6.4',
#  '10',
#  '9.4',
#  '6.6',
#  '5.9',
#  '8.5',
#  '9.4',
#  '8.8',
#  '9.7',
#  '8.8',
#  '9.4',
#  '8.5',
#  '10',
#  '9.4',
#  '9.4',
#  '9.1',
#  '8.8',
#  '8.5',
#  '9.4',
#  '9.7',
#  '8.5',
#  '9.4',
#  '9.4',
#  '9.7',
#  '5.2',
#  '8.8',
#  '9.7',
#  '6.6',
#  '9.7',
#  '8.5',
#  '8.5',
#  '9.3',
#  '8.5',
#  '6.6',
#  '6.6',
#  '9.1',
#  '9.4',
#  '9.4',
#  '9.4',
#  '8.8',
#  '9.4',
#  '8.8',
#  '8.5',
#  '9.7',
#  '8.8',
#  '9.7',
#  '8.8',
#  '7.3',
#  '10',
#  '9.1',
#  '9.4',
#  '8.8',
#  '9.4',
#  '8.5',
#  '8.5',
#  '8.5',
#  '10',
#  '9.1',
#  '9.7',
#  '9.1',
#  '8.7',
#  '9.7',
#  '8.4',
#  '9.7',
#  '8.7',
#  '9.3',
#  '9.4',
#  '10',
#  '8.8',
#  '10',
#  '6.9',
#  '9.7',
#  '7',
#  '10',
#  '10',
#  '9.4',
#  '9.4',
#  '8.5',
#  '9.7',
#  '9.1',
#  '10',
#  '9.4',
#  '9.4',
#  '8.4',
#  '9.7',
#  '7',
#  '5.8',
#  '9.3',
#  '8',
#  '8.8',
#  '10',
#  '10',
#  '8.5',
#  '9.7',
#  '6.3',
#  '6.9',
#  '8.7',
#  '5.8',
#  '7.3',
#  '9.7',
#  '9.7',
#  '9.7',
#  '9.7',
#  '9.7']

# %%
Reviews_list
# Out:
# ['- ที่พักอยู่ใกล้ทางลงรถไฟฟ้าใต้ดิน (MRT) เพชรบุรี และใกล้กับ Airport Link - มีลิฟท์บริการใช้การ์ดแตะก่อนขึ้นห้องพัก - ห้องพักผ่านการใช้งานมานานค่อนข้างโทรม แต่เตียงนอนนอนสบาย ห้องนอนและห้องน้ำขนาดกำลังดี แต่อุปกรณ์ในห้องน้ำบางอย่างดูไม่แข็งแรงและใกล้เสียหลายชิ้น เช่นก๊อกอ่างล้างหน้า - ห้องพักไม่เก็บเสียง ข้างห้องคุยกันได้ยินชัดเจน - มีที่จอดรถหน้าโรงแรม - การบริการดีใช้ได้ - อาหารเช้าโอเค มีความหลากหลยไม่มาก แต่รสชาดก็โอเค ข้อดี - ทำเลดี ใกล้ MRT ใกล้ Airport Link - ห้องพักแอร์เย็นฉ่ำ ข้อเสีย - ห้องไม่เก็บเสียงครับ - น้ำอุ่นทำงานไม่เสถียร น้ำไหลช้า แรงดันน้ำไม่ดี',
#  'ราคาไม่แพง แอร์เย็นฉ่ำ ไร้เสียงรบกวนเวลานอน รูปตรงปก เดินทางสะดวกสำหรับคนต้องการความรวดเร็วในการเดินทางทำธุระที่ต้องเดินทางโดยรถไฟฟ้าเป็นอย่างมาก แนะนำเลย',
#  'ติดสถานีใต้ดิน เพชรบุรี เดินทางไปกลับสยาม-ห้วยขวางสะดวก การบริการรวดเร็ว ห้องสะอาด โปร่งไม่อึดอัด',
#  'เดินทางสะดวก โรงเเรมดูปลอดภัย',
#  'โรงแรมดีครับ สะอาด ห้องสวย เดินทางสดวก',
#  'เตียงเดียวห้องเล็ก เตียงคู่ห้องใหญ่กว่า everything good 👍 ใกล้ Mrt n รถไฟฟ้า',
#  'ทำเลติดทางออก mrt เพชรบุรีทางออก 3 และใกล้ airport link มักกะสัน เช่าห้องคืนละ 700+ ห้องเล็กที่มีอุปกรณ์พื้นฐานครบเช่น ไดร์ น้ำอุ่น ทีวี โต๊ะทำงาน อินเตอร์เน็ต ข้อเสียมีเสียงทะลุเข้ามาเล็กน้อย (คนเดิน คนอาบน้ำ) แต่ไม่ใช่ปัญหาใหญ่และไม่มีบริการอาหารเช้า (ซื้อแยก) มีการก่อสร้างข้างโรงแรม ระวังการ WFH จะมีเสียงแทรกเข้าคอมได้',
#  'พนักงานบริการดีมาก ในราคาหลักร้อยคุ้มเลย ใกล้ mrt เพชรบุรี airport link มักกะสัน เดินไปเซเว่นก็ไม่ไกล ตอนแรกตั้งใจจะว่ายน้ำ แต่ช่วงที่ไปปิดปรับปรุง',
#  'ไปพัก 2 ครั้งแล้วค่ะ โอเคกับที่พักมากเพราะตืดกับ mrt เดินทางสะดวก',
#  'ดีมาก สะอาด นอนสบาย การเดินทางสะดวกใกล้ mrt',
#  'ที่พักใกล้กับ MRT เพชรบุรี ออกประตู 3 เดินแค่แปปเดียวก็ถึง สะดวก ห้องสะอาด ไม่น่ากลัวเลยจ้า ไม่เสียงดังมาก รับเรื่องปัญหาเร็วมาก มีปัญหาไดร์เป่าผมเสีย นี่ก็โทรไปตอนตี 1 รู้ว่าดึกมาก แต่ลองโทรไปเค้าเตอร์ก่อน พนักงานรับเรื่องเร็วและรีบเอาไดร์มาเปลี่ยนใหม่ให้ ชอบมากเลย ครั้งหน้าถ้ามีโอกาสก็จะไปพักที่นี่อีก ปักธงไว้เลยละกัน เพราะสะดวกมากจริงๆ ใครที่รอขึ้นเครื่องที่สุวรรณภูมิ และอยากพักในเมือง แนะนำที่นี่ค่า ตื่นเช้ามาเดินไปต่อ ARL มักกะสันได้สบายๆ',
#  'ใกล้ mrt เดินทางสะดวก good room service',
#  'เดินทางสะดวกจากสนามบินสุวรรณภูมิ-MRTเพชรบุรี ประตู3',
#  'ติด mrt ค่ะ ข้ามถนนก็ถึงแล้ว ที่พักปลอดภัย สะอาด แต่อยากให้ปรับปรุงฝักบัวค่ะ ปรับน้ำร้อนน้ำเย็นยังไงไม่รู้ น้ำไม่เสมอกันเลย แต่โดยรวมแล้วดีค่ะ นอนสบายมาก',
#  'คีการ์ดเสียบไม่ติดเปิดไฟห้องไม่ได้ ตี4ไม่ได้แก้ไขอะไรเลย ไม่มีใครอยู่ฟ้อน ต้องไปกดช่วยเหลือในลิฟถึงจะตื่นมา',
#  'โรงแรมนี้ดีกว่าทุกๆ ที่ที่เคยไป เดินทางสะดวก ห้องพักสะอาด วิวจากชั้น 7 ดีมากๆ พนักงานต้อนรับพูดจาสุภาพทุกคน แนะนำเลยค่ะ มีโอกาสจะกลับไปพักแน่นอน',
#  'ดีค่ะ เงียบสงบ สะอาด เดินทางสะดวก ไม่ได้ลองอาหารเช้าเพราะต้องออกเดินทาง แต่เช้าควรเพิ่มกระจกสำหรับผู้หญิงแต่งหน้าบริเวณโต้ะค่ะไม่สะดวกที่กระจกใน/หน้าห้องน้ำ',
#  'โรงแรมบรรยากาศดีมากครับ พนักงานพูดดีรวมไปถึงแม่บ้าน ประทับใจมากครับ',
#  'ดีค่ะ ใกล้กับแอร์ลิ้ง เดินทางไปสุวรรณภูมิ สะดวกมากๆ',
#  'มาพักซ้ำ เพราะใกล้ MRT เดินทางสะดวก',
#  'จองไว้มางานวิ่ง ATMBKK2021 อยู่ติดสถานี MRT เพชรบุรี และ Airport Link มักกะสัน เดินไม่ถึง2-3 นาทีเอง ห้องพักขนาดกำลังดี ห้องน้ำเล็กไปนิด แต่เตียงนอนหลับสบายมาก ถือว่าคุ้มราคามากๆ เมื่อเทียบกับทำเล',
#  'พนักงานบริการดี เตียงกว้างใหญ่สะอาด สุขภัณฑ์ในห้องน้ำใช้ได้ดี น้าไหลแรงร้อนเร็ว มีตู้เซพ ไดร์ โต๊ะทำงานเล็กๆ คุ้มมาก ออกจากโรงแรมเดินไปขึ้น MRTและแอร์พอตลิ้งสบายๆเลย คราวหน้าจะไปพักอีกครับ',
#  'ห้องพักสะอาดบริการดีค่ะ รอบหน้าพักอีกแน่นอนค่ะ',
#  '10/10 ชอบมากค่ะ บริการดี ห้องพักสะอาด พนักงานต้อนรับพูดเพราะ แม่บ้านใจดี มาทุกครั้งก็จะมาพักแต่โรงแรมนี้ เดินทางสะดวกใกล้กับ MRT',
#  '',
#  'ดีคะสะดวกใกล้สถานีรถไฟ ห้องพักถือว่าโอเค',
#  'พักห้อง 408 แอร์ไม่ค่อยเย็นครับ ปรับทั้งอุณหภูมิ และพัดลม แล้วแต่ก็ยังไม่เย็น ไม่ได้แจ้งเจ้าหน้าที่ เพราะพักคืนเดียว และใช้ห้องแค่ช่วงตอนนอนและเช็คเอ้าตอนเช้า แต่ยังชอบ location ของโรงแรม เพราะสะดวกกับการเดินทางมากครับ ขอบคุณครับ',
#  'โอเคกว่าที่คิดไว้เยอะมาก คุ้มราคาจริง ๆ เดินทางสะดวก ที่นอนสบาย น้ำไม่เย็นเกินไป ถูกใจมาก อยากอาบน้ำนาน ๆ เลย 55555 พนักงานบริการดี',
#  'ชอบมากค่ะ พนักงานบริการดี แถมที่พักยังเดินทางไปไหนมาไหนสะดวก ใกล้ mrt เพชรบุรี ส่วนภายในห้องพักก็ดีมากเลยค่ะ อุปกรณ์ครบ สะอาด แอร์เย็น 💝',
#  'พนักงานตอนรับบริการดีมากห้องพักสะอาดเงียบสงบ',
#  'ดีนะ สะอาด พรังงานน่ารัก พักรอบนี้รอน4คืน คืนแรกน้ำแอร์หยดเป็นน้ำเลย พอเช้าแจ้งพนังงานก็จัดการให้ จบนอนต่อได้สบาย คือดีราคาดีถ้าเทียบกับบริเวณนั้น ใกล้ที่สัมมนา ใกล้mrt ผ่าน กลับมาพักอีก ปล.ขึ้นจากmrtออกประตูฝั่งรร. เดินมาทางแยกแล้วเลี้ยวขาวเข้าซอย45 ถ้าเดินมาgoogle คืองง หาซอยยากมาก',
#  'การเดินทางสะดวกใกล้mrtเพชรบุรี และแอร์พอร์ตเรลลิ่ง พนักงานบริการการดียิ้มแย้มแจ่มใส ห้องที่พักก็ดูดีตรงตามปกมีสิ่งอำนวยความสะดวกครบครันครั้งหน้าถ้ามากรุงเทพจะมาพักอีกแน่นอน',
#  'พนักงานน่ารัก ที่พักสะอาด 3คืนแรกเสียงดังจากข้างนอกนึกว่าผนังห้องบาง พอคืนสุดท้าย พึ่งมาเจอ หน้าต่างตัวล็อคไม่สนิททำให้เสียงรอดเข้ามา พอแก้ไข ก็ไม่มีเวียงรบกวน ราคาถือว่าดี กับคุณภาพห้องกับรรข้างเคียง กลับไปพักอีกแน่นอน',
#  'สะดวกในการเดินทางไปสนามบินสุวรรณภูมิโดยARL พนักงานอัธยาศัยดี ถ้ามีโอกาสจะแวะไปพักอีก',
#  'ที่พักดีเดินทางสะดวกใกล้รถไฟฟ้า พนักงานต้อนรับดูแลเอาใจใส่ดีพร้อมแนะนำช่วยเหลือ ห้องกว้าง ราคาไม่แพง อาหารเช้าดี',
#  'โรงแรมดีมากค่ะ บริการดี ห้องสะอาด สวย ใกล้mrt เพชรบุรีมาก เดินทางไปมศวใกล้มากค่ะ พักอีกแน่นอนค่ะ',
#  'ห้องพักและการอำนวยความสะดวกได้ตามคำขอเลย ประทับใจมากค่ะ ห้องพักโอเคเลย ชอบค่ะ โรงแรมก็เดินทางสะดวก พนักงานต้อนรับทักทายดีมากๆ แต่อาหารเช้าอยากให้มีเมนูได้เลือกสักหน่อย เพราะไม่ใช่ทุกคนที่จะทานสิ่งที่โรงแรมเตรียมไว้ได้อ่ะค่ะ',
#  'ที่พักดีมาก สะอาด พนักงานดีมากๆยิ้มแย้ม ครบครัน ทางเข้าแอบน่ากลัว แต่ปลอดภัย อยู่ในที่ชุมชน',
#  'ทำเลที่ตั้งดีไปมาสะดวกอาหารเช้าอร่อยห้องพักดีสะอาดมาก',
#  'พนักงานบริการดีค่ะ ห้องพักสะอาด ติด MRT ใกล้ แอร์พอร์ตลิ้งค์ เดินทางสะดวกค่ะ แต่สภาพแวดล้อมไม่ค่อยดีนักเพราะมีการก่อสร้างคอนโดเยอะค่ะ',
#  'สะดวก สะอาด สบาย ราคาสบายกระเป๋า บริการดี',
#  'โรงแรมหาไม่ยากครับ อยู่ติด MRTเพชรบุรี และ Airportlink มักกะสัน เดินทางมาไม่ยาก พนักงานบริการดี ห้องพักไฟเยอะดี ปลั๊กไฟอยู่ในที่ที่ควรมีทุกจุดเลยครับ โดยรวมแล้วผมว่าน่าพึงพอใจมากครับ',
#  'อยู่ใกล้รถไฟฟ้า MRT เพชรบุรีมาก เดินทางสะดวกมาก ห้องสะอาดน่าอยู่ ห้องน้ำดี รวมๆโอเคค่ะ เป็นอีกทางเลือกการเที่ยวในเมือง',
#  'พนักงานต้อนรับดูแลไม่ดี ไม่เทคแคร์แขก',
#  'โรงแรมสบาย พนักงานบริการดีมาก อาหารเช้าอร่อย',
#  'เดินทางสะดวก อาหารเช้าก็โอเค พนักงานน่ารักพักมาหลายรอบแล้วก็โอเคทุกครั้งเลย',
#  'พนักงานบริการสุภาพ ห้องสะอาด แต่อับนิดหน่อย ห้องน้ำสะอาดแต่อ่างล้างหน้าน้ำระบายไม่ดี ล้นขึ้นมา โดยรวมใช้ได้ ยกเว้น wifi มีแต่ใช้ไม่ได้ต้องแชร์เน็ตจากมือถือเอง',
#  'ดีมากๆคะ. สะอาด บริการดีคะ และอยุ่ใกล้รถไฟฟ้า การเดินทางสะดวกคะ ถ้ามีโอกาสไปทำธุระที่ กทม. จะแวะไปพักอีกแน่นอนคะ',
#  'ที่พักดีมาก ใกล้mrtกับairport link มาก (เดินไปได้) บริการดีมาก ห้องสะอาด กว้าง แต่ไม่ค่อยเก็บเสียง พนง.พูดภาษาอังกฤษได้ ',
#  'พนักงานบริการดี สุภาพ เป็นมิตร บริการดี ห้องโดยรวมโอเคร อับบ้างเล็กน้อย แต่สะอาด ห้องน้ำ ผ้าปูที่นอน พื้นห้องสะอาด เตียงและหมอนนุ่ม หลับสบาย',
#  'เดินทางสะดวก ใกล้รถไฟฟ้า และห้องพักสะอาดน่าอยู่',
#  'สะดวกที่สุดคือทำเลที่ตั้งค่ะ ตั้งอยู่ที่mrtเพชรบุรี จุดเชื่อมต่อ airport railink มักกะสัน เดินทางไปไหนมาไหนง่ายมาก ห้องค่อนข้างแคบ และเตียงเล็กกว่าปกติ แต่ก็สะอาดดีค่ะ อีกอย่างคือเวลารถวิ่งอาจจะได้ยินเสียงแต่ก็น้อยมากค่ะ',
#  'ที่พักดีมากๆ มีหมวกอาบน้ำให้ด้วย ปกติโรงแรมราคานี้จะไม่มีให้ 555 อาหารเช้ามีให้เลือกน้อยไปนิดแต่อร่อยดีค่ะ ห้องดี ห้องน้ำดี แยกโซนเปียกแห้ง อยู่ใกล้ห้าง ใกล้รถไฟฟัา ตอนเราไปโชคร้ายข้างๆ มีไซท์ก่อนสร้าง ตอนกลางวันเสียงดังตลอด แต่กลางคืนเงียบปกติค่ะ ข้อเสียคือเตียงแข็งไปนิดนึง',
#  'ห้องสะอาด ดีมาก บริการดีมาก ห้องน้ำสะอาด',
#  'ดีมากๆค่ะ ห้องพักสะอาด อุปกรณ์ครบ พนักงานที่นี่ทุกคนบริการด้วยหัวใจรักบริการ ดูแลแขกเหมือนเป็นคนในครอบครัว',
#  'สะดวก สบาย ใกล้ Mrt และ Airport link',
#  'ห้องพักคราวนี้เสียงแอร์ค่อนข้างดังค่ะ แถมมีการก่อสร้างเสียงดังมาถึงห้องเลย',
#  'ถึงจะเป็นครั้งที่2ที่ได้ไปพักที่ FX แล้ว แต่บริการก็ยังดีเหมือนครั้งแรกที่เคยไปพักไม่เปลี่ยนเลยค่ะ อาหารก็อร่อย ที่พักก็สบาย คงจะได้ไปใช้บริการอีกบ่อยๆค่ะ',
#  'ดี สะอาด เรียบหรู อยู่ใจกลางเมือง',
#  'ได้กลิ่นห้องน้ำ ชยออกมาตอนนอนหลับบ่อยมาก แม้จะปิดประตูไว้ก็ตาม',
#  'ห้องแคบมากๆ ได้ห้องตรงมุมๆ รีโมททีวีกดไม่ค่อยติด',
#  'พักครั้งที่ 2 แล้วค่ะ เดินทางสะดวก เจ้าหน้าที่ใจดี',
#  'มาพักประจำค่ะ สะดวกใกล้แอร์พอร์ตลิ้งค์กับMRT ห้องสะอาด อาหารเช้าดี',
#  'เดินทางสะดวก ใกล้ mrt กับ airport link เตียงนุ่มดี อาหารเช้ามีให้เลือกน้อยไปหน่อย',
#  'ในห้องดูดีกว่าในรูปถ่ายค่อนข้างมาก พนักงานก็ยิ้มแย้มแจ่มใสตลอด พร้อมบริการและสุภาพกันทุกคน อาหารเช้าอร่อยมากๆทั้ง2คืนที่ไปพักเลย ถ้ามีโอกาสก็อยากกลับไปใช้บริการอีกครั้งค่ะ',
#  'ห้องพักดีครับการบริการดีโดยรวมดีครับ',
#  'จัดห้องที่ต้องการให้คือ มีหน้าต่างเห็นวิวชั้นบน และไม่มีกลิ่นบุหรี่ จะมีที่ช่างเข้ามาช่วยคือ ประตูห้องน้ำล๊อคเองจากข้างนอก แจ้งให้ช่างมาซ่อมให้ใช้ได้เหมือนเดิมค่ะ',
#  'สะดวก ใกล้ mrt เพชรบุรี ห้องสะอาด แต่ห้องไม่ค่อยเก็บเสียง พนักงานต้อนรับบริการดี ยิ้มแย้มแจ่มใส',
#  'ห้องสะอาด พนักงานต้อนรับดีมาก สะดวกสบายใกล้รถไฟฟ้า เดินทางสะดวกสบาย',
#  'ห้องดี กว้าง เตียงนอนหลับสบาย ที่พักใกล้ Mrt เพชรบุรี กับ แอร์พอร์ตเรลลิ้งค์ มักกะสัน เดินทางสะดวก ตอนเช้ามีอาหารเช้าบริการ มีให้เลือกไม่มากแต่อร่อยดีค่ะ ถึงว่าครบทั้งไทย ฝรั่งค่ะ',
#  'โรงแรมอยู่ใกล้mrtเพชรบุรี ประตู3 เดินทางสะดวก พนักงานบริการดีน่ารัก',
#  'ห้องพักมีอุปกรณ์และเครื่องใช้พื้นฐานครบ อาหารเช้าอร่อยและมีให้เลือกเยอะ ราคาสมเหตุสมผล',
#  'การเดินทางสะดวกมากใกล้ mrt + airport link',
#  'ใกล้ MRT ที่จอดรถน้อย 7-11 อยู่ในระยะที่เดินได้',
#  'พนักงานสุภาพและให้ความช่วยเหลือดีมาก ห้องพักสะอาดเรียบร้อยดี',
#  'ห้องพักดี พนักงานบริการดี อาหารอร่อย ใกล้รถไฟฟ้า',
#  'โรงแรมทำเลดีอยู่ใกล้ mrt เพชรบุรี สะดวกสบาย',
#  '',
#  'ประทับใจ ทั้งเรื่องของห้องพักและงานบริการ',
#  'สะดวกกับการเดินทาง ติดmrtเพชรบุรี ห้องพักสะอาด พนักงานบริการดีค่ะ',
#  'ห้องเหม็นอับ แอร์ร้อนและดัง พักหลายคืน แม่บ้านไม่ทำความสะอาดกับเติมของให้ ต้องค่อยแจ้ง',
#  'ใกล้ MRT และ Airport Link พนักงานบริการดี มีอาหารเช้าหลากหลายให้เลือก ที่พักห้องกว้าง แต่มีกลิ่นเหมือนไม้อัด',
#  'สะอาด สบาย ดูแลดีมากๆ ถ้ามีโอกาสกลับไปพักอีกแน่นอน',
#  'พนักงานต้อนรับหญิงทำหนังหน้าไม่รับแขก พูดจาห้วนๆทำหน้าทำตาหมิ่น พูดจาเหมือนจะไม่มีมารยาท ส่วนห้องพัก อาหารทุกอย่างดีหมด',
#  'ประทับใจกับพนักงานและสถานที่ สะดวกการเดินทาง หาไม่ยาก ห้องสะอาด',
#  'สะอาด สะดวก มีครบครัน แต่ fitness สระว่ายน้ำปิดบริการเร็วไปหน่อย ทางเข้าเปลี่ยวเล็กน้อยแต่เป็นแค่ระยะทางสั้นๆ',
#  'ห้องพักโอเคมากๆ แอร์เย็น พนักงานดี แต่สายชำระไม่ค่อยแรงเท่าไหร่',
#  'ทำเลดี ใกล้ mrt เพชรบุรี เดินไม่ถึง 5 นาทีก็ถึงโรงแรม แต่ห้องค่อนข้างเก่าเล็กน้อย น้ำห้องน้ำไหลช้ามาก แต่รวมๆแล้วถือว่าดีค่ะ',
#  'อยู่ใกล้ MRT เพชรบุรี เดินทางสะดวกมากค่ะ โรงแรมไซซ์ไม่ใหญ่เกินไป มีอาหารเช้าที่ไม่ใช่แค่บิสกิตด้วย แนะนำเลยค่ะ',
#  'พัก 2 ห้อง ห้องนึงแอร์ไม่เย็น ห้องแคบไปนิด น้ำไหลเบาบ้างแรงบ้าง อาหารเช้าเมนูทั่วไป เมนูน้อยไปหน่อย รสชาติเฉยๆ เงียบดี ไม่ค่อยมีคนพลุกพล่าน ไปถ่ายงานแถวสุขุมวิท ที่พักใกล้ดี ราคาเหมาะสมค่ะ ห้องที่จองเต็ม พนักงานติดต่อกับโรงแรมเพื่อฟรีอัพเกรดห้องให้ น่ารักมากค่ะ พนักงานที่เคาน์เตอร์โรงแรมต้อนรับดีค่ะ พี่ รปภ. ช่วยขนกระเป๋าให้ค่ะ พนักงานห้องอาหารน่ารักค่ะ เติมอาหารตลอดค่ะ ประทับใจส่วนงานบริการค่ะ ถ้าแวะไปทำงานแถวนั้นจะใช้บริการอีกค่ะ (เสียดายพักแป๊บเดียว ไม่ได้เดินไปดูส่วน swimspa pool ค่ะ)',
#  'จากการที่เข้าพักอยู่หลายปี และเลือกที่นี่เพราะสะดวกและใกล้ที่ทำงานที่สุด เวลาไปทำงานที่กรุงเทพฯ ก็จะเลือกพักที่นี่ ทุกอย่างดีหมด ทั้งการบริการ พนักงานสุภาพ แต่ที่แย่สุดๆตอนนี้ ทางโรงแรมอาจต้องรีบแก้ไขคือเรื่องระบบน้ำ ยิ่งชั้น 7 น้ำแทบไม่มีเลย และเรื่องความสะอาดภายในห้องพัก บางห้องเหมือนแทบคิดว่าแค่ปัดเตียง ความสะอาดให้ระดับ 2 เรื่องระบบน้ำให้ระดับ 0 เห็นความแตกต่างได้ชัดตั้งแต่เข้าพักครั้งแรกเมื่อหลายปีก่อนตั้งแต่เปิดจนถึงปัจจุบัน ติดแค่เรื่องระบบน้ำกับความสะอาดแค่นั้นค่ะ',
#  'ทำเลที่พักดีมาก มีที่จอดรถ ห้องพักสะอาด เตียงใหญ่ อาหารเช้าโอเค ยกเว้นอย่างเดียวคือหมอนแฟ่บ ต้องเอาอีกใบมาซ้อนรองนอน อย่างอื่นดีหมด คราวหน้าจะมาพักอีก',
#  'โรงแรมใกล้รถไฟฟ้าใต้ดิน สถานีเพชรบุรี ประตู 3 มาก เดินทางสะดวก ห้องพักขนาดกำลังดี ผนังห้องไม่กันเสียงเท่าที่ควร จะได้ยินเสียงโทรทัศน์จากห้องข้าง ๆ ตลอดเวลา เนื่องจากเป็นห้อง Connecting Room ห้องพักสะอาด ที่นอนและหมอนไม่แข็งหรือนิ่มเกินไป คุ้มค่ากับราคา',
#  'โดยรวมดีมาก ใกล้ MRT และ Airport Link เดินทางเข้าเมืองและไปสนามบินได้สะดวก แต่น้ำไหลบ้างไม่ไหลบ้างสลับกัน ทำให้น้ำเดี๋ยวอุ่นเดี๋ยวเย็น แต่อยู่ในระดับที่รับได้',
#  'โดยรวมถือว่าดี แต่ระบบน้ำไม่ค่อยดี ความแรงของน้ำไม่สม่ำเสมอ ในห้องอาบน้ำ น้ำระบายออกได้ช้ามาก เหมือนท่อตัน',
#  'สะดวก ใกล้สถานีรถไฟ แต่ห้องไม่กันเสียง',
#  'ใกล้ mrt / airport link\nห้องโอเค',
#  'สะดวกในการเดินทางเพราะใกล้รถไฟฟ้าใต้ดิน แต่ควรปรับปรุงเรื่องผ้าปูที่นอน',
#  'ห้องพักสะอาดดี ใกล้ mrt เสียดายที่เช็คอินก่อนเวลาไม่ได้แต่มีการแก้ปัญหาที่ดี',
#  'ดีมาก พนักงานบริการดี โรงแรมสะอาด',
#  'สะดวกมาก ใกล้ MRT และ ARL เสียดายที่ได้ Key card อันเดียว ไม่ค่อยสะดวก',
#  'ดีมากๆ สะอาด สะดวก สบาย พนักงานน่ารัก',
#  'ห้องพักโอเคค่ะ การบริการดี ห้องพักมีปัญหาก็เปลี่ยนให้ทันทีเลย แต่ติดนิดเดียวตรงพนักงานที่ห้องอาหารบริการช่วงค่ำไม่ค่อยโอเค แนะนำไม่ได้ หัวเราะตลอดเวลา ไม่คุ้มกับ 17% ที่ต้องจ่ายเพิ่ม',
#  'เดินทางสะดวก ใกล้แอร์พอร์ตลิงก์',
#  'ทุกอย่างดีมากค่ะ อาหารเช้าหลากหลายและอร่อย พนักงานบริการดี ห้องพักสะอาด เดินทางสะดวก',
#  'ห้องพักสะอาด พนักงานบริการดีมาก ยิ้มแย้มตลอด เดินทางสะดวก ใกล้แอร์พอร์ตลิงก์กับเอ็มอาร์ที',
#  'พนักงานยิ้มแย้มแจ่มใส ดูแลดีค่ะ ที่พักสะอาด',
#  'ที่ตั้งใกล้ MRT สะดวกสบายมากในการเดินทาง',
#  'เจ้าหน้าที่ฟรอนต์ดูแลและให้คำปรึกษาดีมากค่ะ ไม่โกหกลูกค้า ชอบๆ',
#  'พนักงานต้อนรับอัธยาศัยดี มีน้ำใจให้ยืมร่มตอนฝนตก ห้องพักสะอาด ใหม่ น่าอยู่ ทำเลที่ตั้งติดกับสถานีรถไฟฟ้าใต้ดิน แอร์พอร์ตลิงก์ เดินทางสะดวก อาหารเช้าพอใช้ ปริมาณน้อยไปหน่อย แต่มีการทำมาเติมอยู่เรื่อยๆ โดยรวมถือว่าโอเค เหมาะสมกับราคา ถ้ามีโอกาสจะกลับมาใช้บริการอีก',
#  'ดีค่ะ สะดวกและการบริการที่เป็นกันเอง พนักงานยิ้มแย้มแจ่มใส',
#  'ใกล้ MRT เพชรบุรี เดินทางสะดวก',
#  'ดีมาก ทุกอย่างค่ะ บริการดี ห้องสะอาด อาหารอร่อย',
#  'ทำเลที่ตั้งสะดวก สบาย ห้องก็ได้มาตรฐาน',
#  'แนะนำเลยค่ะ ดีทุกอย่าง ถูกใจมาก ไปมา 2 รอบแล้ว',
#  'ทำเลดีมาก ใกล้เอ็มอาร์ที แอร์พอร์ตลิงก์ สะอาด ขนาดห้องกำลังดี ของใช้ในห้องน้ำครบครัน แต่เตียงแข็งไปนิด',
#  'เดินทางสะดวก ใกล้เอ็มอาร์ทีและแอร์พอร์ตลิงก์',
#  'สะดวก สะอาด สบาย สมราคา พนักงานดูแลดีมากค่ะ ทุกคนค่ะ',
#  'อาหารเช้ามีให้เลือกน้อยมาก แต่สามารถสั่งเพิ่มได้',
#  'สะดวก สบายมากค่ะ ไปพัก 2 รอบละ เดินทางสะดวกสุดๆ',
#  'ห้องพักกว้าง สะอาด พนักงานยิ้มแย้มดีค่ะ แต่สระว่ายน้ำเล็กไปหน่อย อาหารเช้าก็ไม่ค่อยหลากหลาย แต่รวมๆแล้วถือว่าดีค่ะ ใกล้แอร์พอร์ตลิงก์และเอ็มอาร์ที สะดวกต่อการเดินทางมากๆค่ะ',
#  'โดยรวมถือว่าดีมากตั้งแต่คุณลุงยามที่บริการเรื่องที่จอดรถ แต่พนักงานรีเซปชั่นผู้หญิงพูดจากไม่ดี กระแทกเสียง แถมมีการโทรเข้ามาในห้อง บอกว่าลูกค้าจองคืนเดียวนะคะ ฟีลเหมือนโดนไล่ไงไม่รู้',
#  'พนักงานต้อนรับตอนกลางคืนไม่ค่อยโอเค เหมือนมองเหยียดๆว่าเราไม่มีตังค์เข้าพักอ่า เราไปกับเพื่อนต่างก็รู้สึกเหมือนกัน แต่พนักงานต้อนรับตอนเช้าแตกต่างกันมาก เทกแคร์ดี พูดจาดี ยิ้มแย้มแจ่มใส่ รวมๆประทับใจค่ะ',
#  'ดีค่ะ สะดวก สบาย สะอาด ราคาเหมาะสมค่ะ',
#  'ห้องพักสะอาด ทำเลดี ใกล้รถไฟฟ้าใต้ดิน เดินทางสะดวก',
#  'สะดวก สะอาด สบายมาก เหมาะกับการเข้าพัก',
#  'ใกล้แอร์พอร์ตลิงก์ เช็กอินได้ตลอดเวลา',
#  'ดีมากครับ และชอบมากด้วย โรงแรมใหม่ สะอาด ที่ตั้งสะดวกในการเดินทาง บริการประทับใจครับ สมกับราคา ผมไปพักอีกแน่นอนครับ',
#  'โอเค ดี ห้องอับและแคบไปนิดนึงค่ะ',
#  'ใกล้รถไฟฟ้า สะดวก สะอาด สงบ พนักงานน่ารัก',
#  'เตียงนุ่ม แอร์เย็น ทำเลที่ตั้งดี เดินทางสะดวก แต่ควรปรับปรุงอินเทอร์เน็ต ช้ามาก เล่นในห้องไม่ได้เลย แต่ที่ล็อบบี้เน็ตเร็วดีครับ',
#  'พนักงานบริการดีมาก ไหว้ทุกรอบที่เดินผ่าน ห้องพักสะอาด ใหม่ รู้สึกดีและคุ้มค่า ประทับใจมากๆ เหมาะสำหรับผู้ที่ลงจากแอร์พอร์ตลิงก์มาแล้วไม่มีรถ เดินไม่ไกล เสียดายผมตื่นสาย เลยไม่ได้ลองชิมอาหาร',
#  'พนักงานบริการดีมาก ใกล้เอ็มอาร์ที สะดวกในการเดินทาง',
#  'ห้องพักสะอาด ใหม่ดี และทำเลดี ใกล้แอร์พอร์ตลิงก์ไปสนามบินสุวรรณภูมิ แต่เรื่องอาหารเช้าค่อนข้างน้อย',
#  'พักที่นี่หลายครั้ง ประทับใจทุกครั้ง เดินทางสะดวก ที่พักสบาย พนักงานน่ารักค่ะ',
#  'ดีมากค่ะ ไปพักที่นี่แทบทุกครั้งที่ต้องไปธุระที่กรุงเทพฯ หรือรอบินไปต่างประเทศ เดินทางสะดวกเพราะใกล้สถานีเอ็มอาร์ทีและแอร์พอร์ตลิงก์ พนักงานก็น่ารัก การบริการดีมากค่ะ',
#  'เดินทางสะดวก ใกล้รถไฟฟ้า แอร์เย็นมาก เตียงนุ่ม น้ำไหลแรง เสียดายไวไฟไม่ค่อยแรง แต่อย่างอื่นดีหมด',
#  'สะอาด สะดวกสำหรับคนที่ต้องใช้แอร์พอร์ตลิงก์และเอ็มอาร์ที',
#  'บริการดีมากครับ อาหารอร่อย โดยรวมแล้วดีครับ',
#  'อยู่ใกล้แอร์พอร์ตลิงก์ ถ้าไม่รู้เส้นทางจะงงทางเข้า เพราะถ้าเข้าด้านหลังอาจจะเลยซอย ป้ายไม่ชัดเจน อยู่ใกล้เซเว่น จองแบบรวมอาหารเช้า ตักอาหารกำลังจะทาน พนักงานเดินมาแจ้งว่าเราไม่ได้รวมอาหารเช้า เสียความรู้สึก ควรจะเช็กให้ดีเพราะชำระเงินแบบรวมอาหารเช้าไปแล้ว',
#  'บริการดีมาก เดินทางสะดวก อาหารเช้าอร่อย',
#  'ห้องพักสะอาด ใกล้แอร์พอร์ตลิงก์และเอ็มอาร์ที เดินทางสะดวก แต่ห้องมีกลิ่นบุหรี่',
#  'สกปรก ควรพิจารณาตัวเลือกอื่น',
#  'โดยรวมดีมากค่ะ แต่ขอให้ปรับปรุงเมนูอาหารเช้าด้วยค่ะ อยากให้มีอาหารให้เลือกหลากหลายประเภทมากกว่านี้ค่ะ',
#  'ใกล้กับเอ็มอาร์ทีเพชรบุรี ทางออก 3 เพียง 100 เมตร ห้องกว้าง แอร์เย็น ยกเว้นน้ำไหลช้า และไหลไม่แรง ฝักบัวก็ไหลช้ามาก ต้องรอเป็นจังหวะ อาบน้ำไม่สะใจเลย พนักงานยิ้มแย้ม บริการดี ยกเว้นพนักงานห้องอาหาร หน้าตาไม่รับแขกเลย โดยรวมให้ 3 เต็ม 5',
#  'ใกล้รถใต้ดิน เดินแป๊บเดียวถึง มีเซเว่นอยู่เลยไปนิดหน่อย แอร์พอร์ตลิงก์ก็เดินไม่ไกล',
#  'ใกล้รถไฟฟ้า สะดวกในการเดินทาง ชอบ ดีมาก',
#  'ไม่มี เพราะโรงแรมสะดวกในการเดินทาง ใกล้สถานีรถไฟฟ้า',
#  'พนักงานบริการดี เดินทางสะดวก ปลอดภัย',
#  'ดีทุกอย่างเลยครับ จะให้เต็มเลย ถ้าปรับปรุงลิฟต์',
#  'ที่ตั้งทำเลดี ใกล้แอร์พอร์ตลิงก์ เอ็มอาร์ที โรงแรมโอเคดี ปลอดภัย แต่ห้องไม่เก็บเสียงนะคะ แขกข้างห้องและแม่บ้านได้ยินหมด ต้องตื่นเช้าๆทุกวันค่ะ ส่วนห้องอาหารต้องปรับปรุงด่วน สั่งแตงโมปั่นและผัดไทย มีเราคนเดียวในห้องอาหาร แตงโมปั่นใช้เวลา 15 นาที ผัดไทยไม่มีกุยช่ายด้วย 40 นาที นานมากๆ',
#  'พนักงานบริการดีและให้ความเคารพกับลูกค้า เป็นที่น่าประทับใจมากครับ',
#  'ใกล้รถไฟฟ้าใต้ดินเพชรบุรี และแอร์พอร์ตลิงก์มักกะสัน สามารถเดินมาโรงแรมได้ ไม่ไกลมาก ห้องพักคุ้มค่ากับราคา อาหารเช้าอร่อย',
#  'ได้ห้องเล็ก ห้องน้ำไม่สะอาด ห้องแคบไม่กว้าง ไม่คุ้มเงิน ดีอย่างเดียวคืออาหารอร่อย ไม่กลับไปพักอีกแน่นอน ครั้งเดียวพอ',
#  'อยู่ใกล้กับแอร์พอร์ตลิงก์ เหมาะกับการเดินทางไปต่อเครื่อง พัก 3 คนจึงต้องเพิ่มเงินอีก 700 บาท อาหารเช้าดี แต่มีไม่มากและไม่หลากหลาย',
#  'ทำเลสะดวก พนักงานบริการดีมากค่ะ',
#  'ทุกอย่างดีมาก! พนักงานยังเป็นมิตรและยิ้มแย้มเสมอ ฉันชอบพักที่นี่ และฉันจะทำซ้ำอีกครั้ง ง่ายต่อการเข้าถึงสถานีรถไฟฟ้าใต้ดินและ 7e เพียง 200 ม. จากโรงแรม',
#  'ห้องพักสะอาด ทำเลดี และอาหารเลิศรส ขอบคุณมากพนักงานของคุณทุกคน พวกเขาใจดีจริงๆ',
#  'เกินคาด! เดินทางไปไหนก็สะดวก ใกล้ MRT พนักงานกระตือรือร้น มีความสุข ห้องพักได้รับการทำความสะอาดทุกวันแม้จะไม่จำเป็น ห้องก็สะอาด เป็นระเบียบเมื่อออกไปข้างนอก',
#  'พนักงานให้ความช่วยเหลือดีมาก ใกล้ MRT สถานีเพชรบุรี เพียง 100 ม. และใกล้ท่าเรือไปยังประตูน้ำอีกด้วย ข้ามถนนเท่านั้น ห้องพักสะอาดมาก.']

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                 Review Rating
# 0    - ที่พักอยู่ใกล้ทางลงรถไฟฟ้าใต้ดิน (MRT) เพชรบ...    8.5
# 1    ราคาไม่แพง แอร์เย็นฉ่ำ ไร้เสียงรบกวนเวลานอน รู...    8.5
# 2    ติดสถานีใต้ดิน เพชรบุรี เดินทางไปกลับสยาม-ห้วย...    9.1
# 3                        เดินทางสะดวก โรงเเรมดูปลอดภัย    8.5
# 4               โรงแรมดีครับ สะอาด ห้องสวย เดินทางสดวก    9.1
# ..                                                 ...    ...
# 155                    ทำเลสะดวก พนักงานบริการดีมากค่ะ    9.7
# 156  ทุกอย่างดีมาก! พนักงานยังเป็นมิตรและยิ้มแย้มเส...    9.7
# 157  ห้องพักสะอาด ทำเลดี และอาหารเลิศรส ขอบคุณมากพน...    9.7
# 158  เกินคาด! เดินทางไปไหนก็สะดวก ใกล้ MRT พนักงานก...    9.7
# 159  พนักงานให้ความช่วยเหลือดีมาก ใกล้ MRT สถานีเพช...    9.7
#
# [160 rows x 2 columns]

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#      index                                             Review Rating
# 0        0  - ที่พักอยู่ใกล้ทางลงรถไฟฟ้าใต้ดิน (MRT) เพชรบ...    8.5
# 1        1  ราคาไม่แพง แอร์เย็นฉ่ำ ไร้เสียงรบกวนเวลานอน รู...    8.5
# 2        2  ติดสถานีใต้ดิน เพชรบุรี เดินทางไปกลับสยาม-ห้วย...    9.1
# 3        3                      เดินทางสะดวก โรงเเรมดูปลอดภัย    8.5
# 4        4             โรงแรมดีครับ สะอาด ห้องสวย เดินทางสดวก    9.1
# ..     ...                                                ...    ...
# 153    155                    ทำเลสะดวก พนักงานบริการดีมากค่ะ    9.7
# 154    156  ทุกอย่างดีมาก! พนักงานยังเป็นมิตรและยิ้มแย้มเส...    9.7
# 155    157  ห้องพักสะอาด ทำเลดี และอาหารเลิศรส ขอบคุณมากพน...    9.7
# 156    158  เกินคาด! เดินทางไปไหนก็สะดวก ใกล้ MRT พนักงานก...    9.7
# 157    159  พนักงานให้ความช่วยเหลือดีมาก ใกล้ MRT สถานีเพช...    9.7
#
# [158 rows x 3 columns]

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                 Review Rating
# 0    - ที่พักอยู่ใกล้ทางลงรถไฟฟ้าใต้ดิน (MRT) เพชรบ...    8.5
# 1    ราคาไม่แพง แอร์เย็นฉ่ำ ไร้เสียงรบกวนเวลานอน รู...    8.5
# 2    ติดสถานีใต้ดิน เพชรบุรี เดินทางไปกลับสยาม-ห้วย...    9.1
# 3                        เดินทางสะดวก โรงเเรมดูปลอดภัย    8.5
# 4               โรงแรมดีครับ สะอาด ห้องสวย เดินทางสดวก    9.1
# ..                                                 ...    ...
# 153                    ทำเลสะดวก พนักงานบริการดีมากค่ะ    9.7
# 154  ทุกอย่างดีมาก! พนักงานยังเป็นมิตรและยิ้มแย้มเส...    9.7
# 155  ห้องพักสะอาด ทำเลดี และอาหารเลิศรส ขอบคุณมากพน...    9.7
# 156  เกินคาด! เดินทางไปไหนก็สะดวก ใกล้ MRT พนักงานก...    9.7
# 157  พนักงานให้ความช่วยเหลือดีมาก ใกล้ MRT สถานีเพช...    9.7
#
# [158 rows x 2 columns]

# %%
table.to_csv("Reviews&Ratings_4th.csv", encoding="utf-8")
