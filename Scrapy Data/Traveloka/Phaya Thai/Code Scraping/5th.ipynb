# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=07-11-2022.08-11-2022.1.1.HOTEL.1000000482890.Amaranta%20Hotel%20(SHA%20Plus%2B).1&contexts=%7B%22inventoryRateKey%22%3A%22povEwB3ZzsU2C6pd%2B6MdU2B9D%2BXTtnp8xBPheXkh8zdM0tKsNUio4Rxug1zOzHJilcvZa8YdqqIySdppe7dolTIewZlxfjiOGz6oXLTucMvN0%2BgQ3yZPvZcoHwUFNN%2BZpcr%2F%2FNa8o9ElfN8zOYhzzZeg0X586laFpeUViPi9rxAq4QCypiUAjW2wltSVvgpBmhLDdV0WLeT%2FFKfQ0QL8LH02Dvlx%2F8PjYogEE5yzx6g6yOKyKeIDf7jO3GM45O1o1hmSkmz3HiZNSbS8gXb3CDW9nmlhkqLKa4lLkAkZpAGTcOmy5l4j7hGHKXWH0MtO45tYfbtBkBgYO99TxwF9DNVsBZohxEpYRFmg%2B%2BHLDKQAG%2F1rhZrd5ovib5W%2FOZIYjTE%2FGsBKQXKjBtgZDhjE4C5zlhNP3bbD3EkRDMDBFQ9BP91JaZBbzrgMh9kT8uRRLbpPqi9QWNDXrth51m8pUsXTrO7kmP1REoaFiJ8zCfvIWGULNNq2kq01LGJS4cUO6IoMhVKT4w7TwrTxbp%2FQ2iMn1qdaM1viWqCGwU1siX1ZIegdsZIo1sjlWnbsTcjefS6Pj3RtIU6lROCEB6QAgiS1WJabPNVEO7waQAXksTDyQHUY2wqyAfRzb44KOjG0poBVHSJ1fq5iJGt%2Fs2ROyG2r1yuKaZ4GSAmh5BaCjz8%3D%22%7D&prevSearchId=1748750315088280409&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]

time.sleep(3)
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div")
sel.click()
time.sleep(3)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()
time.sleep(3)
driver.execute_script("window.scrollTo(0,7770)")

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_13980\2846912751.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)
# 9
# ดีทุกอย่าง เว้น กล่องคอนโทรลไฟพัง ทีวีเชื่อมต่อมือถือไม่ได้ ไม่มี เน็ตฟลิก
# 5.6
# ไม่สมราคา ใครเป็นภูมิแพ้ไม่แนะนำ ราคานี้หาที่อื่นนอนค่ะ แต่ต้องขอชมการแก้ไขของทางโรงแรม ข้อดีคือ ใกล้แหล่งของกิน แหล่งเสริมสวยมาก และห้องกว้างค่ะ มีพนักงานคอยช่วยคนของและพอแจ้งเรื่องห้องฝุ่นเยอะ ทางโรงแรมส่งคนมาทำความสะอาดให้เลยทันที แต่มันยิ่งกลายเป็นฝุ่นมาฟุ้งลงที่เตียงแทน วันที่ 2 ที่นอน โรงแรมเลยย้ายห้องให้ ดีขึ้นแต่ฝุ่นก็ยังเยอะอยุ่ดี ข้อเสีย สภาพห้องเก่าแล้ว ของในห้องโทรมหมดแล้ว ฝุ่นเยอะมากจิงๆ ต่อให้ย้ายห้องฝุ่นก็ยังเยอะ ควรปรับปรุงอย่างมาก ไม่สมราคา
# 8.7
# ห้องพักดี สะอาด สวย ทันสมัย แต่อาหารเช้าน้อย คิดว่าเป็นบุฟเฟ่ เสริฟให้แค่คนละเซต ไม่หลากหลาย แต่รูปที่โปรโมทในแอพ คือมีเหมือนบุฟเฟ่ ที่จองเพราะเข้าใจว่าเป็นบุฟเฟ่ ถ้าไม่มีโปรดนำรูปโปรโมทออกด้วยค่ะ ลูกค้าเข้าใจผิดแล้วจะเสียความรู้สึก
# 9.7
# ห้องสวยมาก วิวดีมาก มีอ่างอาบน้ำบริการ ห้องน้ำสวยและสะอาดมาก มีความเป็นส่วนตัวดีมาก เงียบ สงบ และราคาไม่แพง ไว้มีโอกาสจะกลับไปพักอีกแน่นอนค่ะ
# 6.7
# แอร์ไม่เย็น ตู้เย็นไม่ ชักโครกกดไม่ลง
# 8.5
# ชอบครับ พนักงานต้อนรับดีมากครับ โรงแรมห้องกว้าง มีอ่างอาบน้ำในห้อง ครับ
# 8.5
# ดีมาก นอนสบาย คุ้มมาก เตียงนุ่มสุดๆ
# 8.8
# ดีมากๆครับ เเนะนำ เพราะ โรงเเรมอยู่กลางเมือง อาหารเช้า อรอ่ย เเละ เดินทางสะดวก
# 8.5
# ห้องสวยมากครับ. บริการดี อาหารอร่อยครับ
# 9.4
# ประทับใจ. ทุกอย่าง Perfect ตั้งแต่เดินเข้าไป. พนักงานน่ารัก ห้องใหม่สวยสะอาด. ทำเลใกล้รถไฟฟ้า ของกินหาง่าย. มีโอกาสกลับไปอีกแน่นอน. 😍

# %%
driver.title
# Out:
# 'ค่าห้องพัก Amaranta Hotel (SHA Plus+) รัชดา ตั้งแต่ 07-11-2022 ถึง 08-11-2022'

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
driver.execute_script("window.scrollTo(0,6600)")
sel.click()

# %%
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
#  ทุกอย่างโดยรวมของโรงแรมดีมากครับ ราคาสมกับที่พักมากครับ ผมไม่ได้ใช้บริการไรมากนักของโรงแรมรวมถึงอาหารเพราะตื่นสาย เพราะตั้งใจไปเที่ยวจริงๆ แต่ได้ไปเดินดูทุกที่ของโรงแรม รวมถึงบาร์สกายวิว และสระน้ำ ห้องพัก ห้องน้ำ ห้องอาหาร สถานที่ สะอาด สงบ และเหมาะแก่การพักผ่อนมากๆครับ เกือบเทียบได้กับโรงแรม5ดาวเลยครับ ผมคิดว่า พนง.ผช รอบดึกเวลาคุยสายกับลูกค้ามีหางเสียงอีกนิด 3ผ่านเลยครับ พนง.ผญ รอบเช้า พูดจาดีน่ารักมากครับ. แน่ะนำเลยครับใครมองหาที่พักดีดี การบริการดีดี สิ่งอำนวยความสะดวกครบครับ ต้องที่นี่เลยครับ เทียบกับโรงแรมในกรุงเทพผมชอบที่นี่มากครับ ครั้งหน้าผมและเพื่อนๆจะกลับไปใช้บริการอีกครับ รอบหน้าจะใช่บริการของโรงแรมให้ครบเลยครับ ขอบคุณที่พักดีดีครับ
# 9.4
# ไม่ผิดหวังกับโรงเเรมนี้จริงๆภาพตรงปก บรรยากาศดี ห้องสอาด อาหารอร่อย พนักงานบริการเยี่ยม รู้สึกได้ผ่อนคลายเต็มคุ้มค่ากับราคาที่จ่าย ตอนเเรกจองไว้1คืนเเต่ต้องจองเพิ่มเป็น3คืน จะกลับมาพักอีกเเน่นอน
# 9.4
# พนักงานให้ความช่วยเหลือดี ไม่ไกลจาก MRT
# 9.7
# ขอบคุณที่ให้เราได้โปรepicsaleในราคาห้องละ550บาทพร้อมอาหารเช้า ห้องพักดีมากๆ ห้องกว้าง สะอาด ควบคุมไฟฟ้าต่างๆด้วยระบบทัชสกรีนทั้งหมด สระว่ายน้ำสวยมาก ทุกอย่างเพอร์เฟค พนักงานก็บริการดี ใกล้รถใต้ดินห้วยขวาง สามารถให้รถกอล์ฟของโรงแรมไปส่งที่รถใต้ดินได้ มีโอกาสจะกลับไปพักอีกแน่นอน
# 9.7
# เป็นโรงแรมที่ดีมาก ดีที่สุดตั้งแต่เคยเข้าพักมาเลย การบริการยกให้100คะแนนเต็ม ตั้งแต่พนักงานต้อนรับ พนักงานเชคอิน พนักงานยกกระเป๋า แม่บ้าน พนักงานในห้องทานอาหาร ทุกคนคือได้รับการอบรมดีมาก ทุกอย่างคือเพอร์เฟค ราคาห้องสมกับบริการระดับดีเลิศ อาหารเช้ามีให้เลือกหลายรายการ ขนมปังคุณภาพดี อาหารปรุงรสอร่อย ดีมากๆเลยค่ะ สัญญาว่าจะกลับมาพักอีกแน่นอน โรงแรมดีกว่าโรงแรม5ดาวบางแห่งเสียอีก และจะแนะนำให้เพื่อนๆมาใช้บริการด้วยค่ะ
# 9.7
# ที่พักดีค่ะ สวยงาม สะอาด การเดินทางก็สะดวกใกล้Mrt บริเวณโดยรอบของกินเยอะดีค่ะใกล้กับตลาดห้วยขวาง โดยรวมดีมากๆค่ะ มีโอกาสจะไปแวะพักอีกค่ะ
# 9.4
# ที่พักตรงปก ดีงามมากค่ะ อาหารอร่อย สระว่ายน้ำสวย พนักงานสุภาพให้บริการดีมาก เรียกถามได้ตลอด
# 9.4
# โรงแรมดี โรงแรมดีสะอาดห้องกว้างมาก ชอบที่สุด อยู่ใกล้สถานที่สำคัญ สะดวกเดินทางไปมา แถวโรงแรมมีเซเว่นมีร้านอาหารมากมายมีที่ให้แลกเงินเพอร์เฟคค่ะที่นี่แนะนำใครมีรถยนต์ส่วนตัวก็เอามาได้นะคะมีที่จอด
# 10
# เตียงนุ่ม นอนสบาย น้ำแรง อุปกรณ์ครบครัน ประทับใจทุกการบริการ
# 9.7
# ทุกอย่างดีมากๆ มีระบบเปิดปิดอัตโนมัติ ครบคลุมทั่วห้อง ห้องสะอาดมาก แอร์เย็นดี เสียอย่างเดียวคือ หารเช้าน้อยไปหน่อยค่ะ แต่โดยรวมถือว่าดีมาก คุ้มค่ามาก การเดินทางสะดวก แนะนำให้นั่ง mrt นะคะ เพราะเส้นทางห้วยทางรถติดมาก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
driver.execute_script("window.scrollTo(0,7300)")
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
#
# 9.7
# ชอบมากค่ะ บริการประทับใจห้องดีมาก คุ้มค่าคุ้มีราคา เสียดายม่านห้องน้ำรูดไม่ได้ค่ะ เลยไม่ได้นอนแช่อ่าง ห้อง 505 ถ้ามีโอกาสไปพักอีกแน่นอนค่ะ
# 8.5
#
# 8.4
# ห้องสวย กว้างขวาง บริการดี เตียงนอนสบาย
# 9.1
# ห้องสวย สะอาด ชอบอ่างในห้องนอน พนง.น่ารักแม่บ้านบริการดี เตียงนุ่มหลับสบาย น้ำแรงมากใข้ระบบดิจิตอลในการสั่งการทั้งหมด ปลิ้มมาก สระว่ายน้ำสวยมีกุชชี่ไว้แช่ น้องดูแลสระน้ำ เมื่อเห็นแขกไปก็เปิดน้ำพุให้ถ่ายรูป คือดีมาก และเลาบาร์ก็วิวสวย พนง.พูดเพราะเปิดเพลงน่าฟังมากR&B คือโดน ล็อบบี้สวยดูดี มีรถส่งMRTด้วยค่ะ แต่เสียงดายไม่อยู่ติดถนนดำ เข้าซอยมานิด โดยรวมถือว่าดีมาก ชอบคุ้มสุดๆค่ะ
# 9.7
#
# 9.4
#
# 8.5
# ชอบมากไปบ่อยครับ ยินดีที่ได้ไปพัก
# 8.8
#
# 9
# สะอาด บริการดีมาก ห้องสวยและกว้างขวาง

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
# ห้องใหญ่ ตกแต่งสวย สะอาด พนักงานบริการดี
# 9.7
# โรงแรมอยู่ห่าง MRT เพียงเล็กน้อย พอเดินได้ หน้าโรงแรมที่เซเว่น พนักงานบริการดีมาก ห้องพักสะอาด อาหารพอใช้ได้
# 9.7
# ประทับใจที่พักที่นี่มากเลยค่ะ สะดวก สบายมาก ตกแต่งสวยงาม ไฮเทคโนโลยีมาก สั่งเปิดปิดม่าน ระบบแอร์ ไฟ ด้วยจอทัชสกรีน มีอ่างแช่ในห้องด้วย ห้องน้ำก็จะได้สัดส่วน ทุกอย่างดีลงตัวทั้งห้องพักและสิ่งอำนวยความสะดวก รวมไปถึงพนักงาน แม่บ้าน ล็อบบี้ ทุกคนดูแลพวกเราอย่างดี เกิดเหตุขัดข้องในห้องนอนเวลาดึกแล้ว แต่ก็ประสานงานช่างระบบ อย่างรวดเร็ว ประทับใจที่นี่มากๆ จะกลับมาอีก เป็นการพักผ่อนที่ได้พักผ่อนจริงๆ
# 10
# ดีค่ะ บริการดี สะอาด ห้องใหญ่ ชอบค่ะ สบาย
# 8.5
# ห้องกว้างมาก และสะอาดดีค่ะ ชอบค่ะ
# 8.8
# ดีมากๆค่ะ ห้องพักและพนักงานดีมาก เดินทางสะดวกค่ะ
# 8.5
#
# 8.5
# โดยรวมแล้วดีค่ะ น้องๆบริการดีค่ะ
# 9.1
# สะดวก สบาย ใกล้รถไฟฟ้า สระว่ายน้ำสวย พนักงานน่ารักมากๆๆ
# 8.5
# ห้องพักสะอาด ทำเลดี พนักงานบริการดี ห้องรับประทานอาหารเช้าสวย

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 10
# ชอบที่นี่มาก ทุกอย่างลงตัวไปหมด ไปมา 2 ครั้ง แล้วจะกลับไปเที่ยวใหม่นะคะ
# 10
# ขอบคุณพนักงานทุกท่าน ไม่มีที่ติเลยครั้งนี้
# 8.5
# พนักงานบริการไม่ค่อยดีเท่าที่ควร เช็กอินได้ล่าช้า
# 10
# พนักงานรอยยิ้มดีมากค่ะ ครั้งหน้าไปอีกค่ะ
# 9.1
# ดีแต่อยู่ในซอยที่จอดรถยากมาก และเข้าออกไม่ค่อยสะดวก
# 9.7
# ดีมากๆๆ บริการดี พนักงานยิ้มแย้ม เสียแค่ไม่รู้คนที่ไหนโทรเข้าดึกๆ
# 9.7
# ห้องสวยมากค่ะ สะอาด สะดวก ใกล้สถานที่ต่างๆ พนักงานบริการดี จะกลับมาพักอีกแน่นอนค่ะ
# 9.7
# ดีมาก สะอาด สะดวก สบาย ทำเลดีมากๆๆ
# 9.7
# ห้องนอนสวยมาก นอนหลับสบายค่ะ แต่ให้เข้าเช็กอินช้าไปหน่อยค่ะ
# 8.5
# น้องๆ 5 ดาว ทันสมัย สวย หรู ตกแต่งดี บริการดี ประทับใจมาก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# น่าจะมีอาหารเช้าให้ด้วย จะครบทุกอย่างในการเข้าพัก
# 10
# ช่องทีวียังมีน้อยมากค่ะ รบกวนช่วยปรับปรุงด้วยค่ะ อย่างอื่นดีหมดทุกอย่างเลยค่ะ
# 8.5
# ที่พักสบายมาก เดินทางสะดวก ใกล้เอ็มอาร์ที มีร้านอาหารชั้นดาดฟ้า บรรยากาศดีมากๆค่ะ
# 9.7
# สวยค่ะ รัานอาหาร บาร์ บรรยากาศ คนไม่เยอะมากเกินไป
# 10
# เป็นโรงแรมที่น่าพักมากค่ะ สงบ สะอาด อาหารอร่อย พนักงานทุกคนดูแลต้อนรับดีมากค่ะ
# 8.9
# โรงแรมใหม่ อยู่ใกล้เอ็มอาร์ทีสี่แยกห้วยขวาง ซอยทางเข้าโรงแรมเล็ก มีรถรับส่งไปเอ็มอาร์ที พนักงานรับส่งนิสัยดี มีใจให้บริการ สระว่ายน้ำสวยแต่เล็ก มีบาร์ขายเครื่องดื่มบนชั้นดาดฟ้า สวยดี มีส่วนลดให้แขกที่พัก 30% โดยรวมดี ห้องพักทันสมัย จัดว่าสวยเลย แต่ดูข้างนอกโรงแรมจะเล็กมาก
# 10
# การบริการดี ห้องสวย อาหารอร่อย มีทุกอย่างครบวงจรภายในโรงแรมค่ะ
# 9.6
# โรงแรมมีความสะดวกสบาย ทันสมัย สะอาด ชอบดีไซน์ และเทคโนโลยีที่ใส่เข้าไปในห้องพัก
# 8.1
# ที่พักและที่ตั้งดี ใกล้ร้านอาหาร ห้องสะอาด ดูเหมือนจะดี ทุกอย่าง พักที่นั่น 3 คืน วันสุดท้ายเช็กเอาต์ เป็นอะไรที่แย่มาก เราต้องยกกระเป๋าเอง ไม่มีพนักงานสักคน พอเรายกกระเป๋าขึ้นรถเรียบร้อย พนักงานออกมายืนดู สงสัยทางโรงแรมต้องอบรมพนักงานใหม่นะคะ เป็นอะไรที่เสียความรู้สึกมาก และจะไม่กลับไปพักที่นั่นอีกแน่ๆ
# 10
# เดินทางสะดวก สะอาด พอใจกับการเข้าพักครั้งนี้มากครับ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 10
# เป็นห้องที่น่าอยู่เป็นอย่างมาก สะอาด พร้อมการบริการที่อบอุ่น และการเดินทางที่สะดวก
# 10
# ดีเยี่ยม ห้องพักออกแบบได้สวยงาม ทันสมัย
# 10
# พนักงานดูแลดีมากค่ะ ห้องพักสะอาด สวย เป็นส่วนตัวมากค่ะ อาหารอร่อยมากด้วยค่ะ
# 8.5
# อาหารเช้ามีให้เลือกน้อยไปหน่อย ทางโรงแรมเก็บค่ามัดจำแพงไป ห้องละ 3,000 พักมาหลายที่ไม่เคยเจอที่ไหนเก็บแพงขนาดนี้ ถึงจะได้เงินคืนก็ตาม แต่มันแพงเกินไป ถ้ามาพักกัน 5 ห้อง ไม่ต้องจ่ายเป็นหมื่นเหรอคะ อย่างอื่นค่อนข้างโอเค โรงแรมสวย ห้องสวย กว้าง สะอาด ให้ 6/10
# 10
# ชอบโรงแรมนี้ค่ะ ชอบทุกอย่างเลย
# 10
# พัก 3 คืนค่ะ ห้องพักสวยมาก มีสิ่งอำนวยความสะดวกครบค่ะ สระว่ายน้ำสวยด้วย เคาน์เตอร์ให้บริการตอบคำถามดีมาก บริการอาหารส่งถึงห้องก็อร่อยมากค่ะ ราคาไม่แพง สรุปดีทุกอย่างค่ะ ครั้งต่อไปก็จะเข้าพักอีกค่ะ
# 8.5
# ห้องสะอาด อาหารเช้าอร่อย มีปลาเห็น สระว่ายน้ำสวย นุมะไลลา
# 5.7
# ห้องของฉันคือ 701 แสงกระจกห้องน้ำไม่ทำงาน มันเป็นแหล่งกำเนิดแสงหลักดังนั้นจึงเป็นการยากที่จะเตรียมพร้อม ฝักบัวเหนือศีรษะหลักไม่ทำงานอย่างใดอย่างหนึ่ง มันเป็นสิ่งสกปรกโดยรวม คนอื่น ๆ ที่มีผมมีรอยเปื้อนและรอยเปื้อนบนเศษแก้วกระจก ฯลฯ แม้แต่รีโมทก็ต้องเช็ด บริเวณสระว่ายน้ำมีกลิ่นแปลก ๆ มันไม่ได้สนุกกับการพักผ่อนที่สระว่ายน้ำ อาหารเช้าก็โอเคเท่านั้น ฉันออกไป แต่เช้าแม้ว่ามันจะจองแล้วไม่สามารถขอคืนได้
# 9.7
# สวยใกล้กับ MRT ห้วยขวาง ใกล้กับระดับที่ง่ายต่อการมองหาอาหารพนักงานขายหลายคนยังอยู่โดยรอบห้องสะอาดอ่างอาบน้ำก็เย็นสบายด้วยตำแหน่งกึ่งร่วมกับห้องพักการออกแบบของห้องพักยอดเยี่ยมจริง ๆ อาหารเช้าอร่อย แต่ไม่แนะนำสำหรับชาวมุสลิมส่วนใหญ่มีเนื้อหมู ค่อนข้างแปลกใจที่พวกเขาควรจะสามารถให้บริการอาหารที่เป็นกลางไม่ใช่หมูโดยเฉพาะ แต่สำหรับผู้ที่ไม่ใช่มุสลิมคุณชอบมันมาก ในร้านอาหารมีตู้ปลาขนาดใหญ่ทำให้สะดวกสบาย
# 9.4
# ห้องพักกว้างขวางดีสะดวกสบาย ฉันประทับใจมาก พนักงานทุกคนเป็นมิตร มันเป็นเพียงอาหารเช้าที่มีความหลากหลายน้อย โดยรวมแล้วการพักที่นี่ก็น่าพอใจมาก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
# ห้องพักกว้างขวางมาก พนักงานทุกคนให้ความช่วยเหลือดีมาก
# 9.4
# สวยมากสะอาดโรงแรมสวยและพนักงานช่วยเหลือดี
# 9.4
# แม้ว่าโรงแรมจะค่อนข้างแคบ แต่การตกแต่งภายในห้องและห้องน้ำนั้นหรูหรามาก มีรีโมทคอนโทรลขนาดใหญ่เท่ากับ iPad ที่ติดกับผนังเพื่อควบคุมแสงของห้องเพื่อควบคุมอุณหภูมิของเครื่องปรับอากาศทีวียังควบคุมผ้าม่านของห้องเพื่อปิดและเปิดตัวเอง อีกข้อดีคือมินิบาร์และอ่างอาบน้ำฟรีที่ให้บริการผลิตภัณฑ์สปา (แม้ว่าจะชำระค่าสินค้าแล้ว) แต่หากไม่ได้ใช้เราจะไม่โดนผลิตภัณฑ์เงินสด นั่นคือทั้งหมดที่ การพักผ่อนที่สมบูรณ์แบบ
# 8.2
# ฉันมีความสุขกับการเข้าพักที่โรงแรมนี้ ห้องพักสะดวกสบายที่นอนดีแสงไฟในห้องก็โอเคอ่างอาบน้ำก็โอเคตามรูปภาพ การบริการไม่เป็นไรเพราะมีรถรับส่งไปยังรถไฟใต้ดิน ข้อเสียคือที่ตั้งอยู่บนขอบของเมืองดังนั้นจึงต้องการเงินเพิ่มเติมเพื่อไปและกลับไปที่โรงแรมนี้ ข้อเสียเปรียบอีกประการหนึ่งคืออาหารเช้าไม่เป็นไรและหมูมากมาย
# 9.4
# มันเป็นการพักที่ยอดเยี่ยม สิ่งอำนวยความสะดวกครบครัน แต่สายไม่ทำงาน มีแค่ชาน (ไทย) ในท้องถิ่นสิ่งที่ดีมันเป็นสมาร์ททีวีและสามารถโทรศัพท์มือถือกระจก ลูกสาวของฉันชอบอ่างอาบน้ำดังนั้นอ่างอาบน้ำที่หันหน้าเข้าหาทีวีจึงเป็นชัยชนะคู่ของเธอ สระว่ายน้ำชั้นบนก็ธรรมดาดีและผ่อนคลาย แต่ไม่มีพื้นที่ครอบคลุม ว่ายน้ำตอนกลางคืนเป็นสิ่งที่ดี บาร์ริมสระเปิดให้บริการจนถึงช่วงดึกและคุณสามารถสั่งซื้อได้ที่ริมสระ เพียงแค่ไม่ได้อยู่ในเลานจ์ภายในสระว่ายน้ำ พนักงานทุกคนสุภาพ มีจดหมายส่งถึงที่นี่ในระดับสูงและฉันเพิ่งอ้างว่าในขณะที่ฉันอยู่ที่นั่น แผนกต้อนรับเก็บไว้สำหรับฉันคุณคุณ! อาหารเช้าธรรมดา แต่อร่อยและเติม เรายังทานกันอยู่เพราะอาหารในกรุงเทพฯเป็นไฮไลท์สำหรับนักท่องเที่ยวทุกคน! 7/12 ฝั่งตรงข้าม A +! พวกเขามีรถรับส่งสีม่วงน่ารัก แต่เราไปที่สถานีรถไฟฟ้า MRT สองสามครั้ง ไม่สนุกที่เดิน ถนนไม่ว่าง ฉันหวังว่าพวกเขาจุดไฟรถรับส่งนั้นและใช้เวลาเดินทางไป / กลับสถานีเป็นประจำ นั่นเป็นข้อเสียเพียงอย่างเดียว เตียงนอนดีและใหญ่ใหญ่กว่าขนาดคิงไซส์ แรงดันน้ำดีมาก ห้องน้ำแยกจากอ่างอาบน้ำ เปิดเครื่องเป็นปกติ มีบริการรูมเซอร์วิสและราคาสมเหตุสมผล เงียบ ๆ ลูก ๆ ของฉันต้องทำวิดีโอ ASMR ที่สะอาด นอกเหนือจากการเดินจากสถานีทั้งหมดเป็นที่น่าพอใจอย่างมาก!
# 8.5
# ทุกอย่างดีเท่าราคา! บริการข้างหน้า (เด็กผู้หญิง) ไม่ดี! แต่พนักงานบริการทุกคนใจดีและสุภาพมาก
# 9.1
# โรงแรมสุดหรู, ห้องพักหรูหรา, หรูหรา, สะอาด, เรียบร้อย, ตามรูปภาพ, การบริการที่เป็นมิตร, ขั้นตอนการเช็คอินที่รวดเร็ว, ไม่มีเงินฝาก ดูน่าสนใจน้อยกว่า
# 8.3
# โรงแรมนี้อยู่ภายในเล็กน้อยสำหรับห้องพักโอเค บางทีควรปรับปรุงให้ดีขึ้นสำหรับเมนูอาหารเช้าไม่มีตัวเลือกมากมาย
# 7.2
# โดยรวมแล้วเป็นสิ่งที่ดีจริง ๆ แต่ฉันไม่ได้รับมันเมื่อเช็คเอาท์และถูกขอให้จ่ายค่าคิทแคทที่สามีของฉันและฉันไม่เคยกิน
# 9.7
# ใกล้กับเอ็มอาร์ทีบริการดีห้องพักสวยและสะอาด อย่างไรก็ตามมันจะสมบูรณ์แบบถ้าปิดล้อมห้องน้ำแทนที่จะเปิดครึ่งที่ด้านบนซึ่งทำให้ทั้งห้องพักค่อนข้างอึดอัดถ้าอยู่กับคู่ของคุณ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
# บริการห้องพักที่ดีและสิ่งอำนวยความสะดวก
# 9.7
# โรงแรมที่ดีโรงแรมควรเผาน้ำมันหอมระเหยมากขึ้นสำหรับน้ำมันหอมระเหยอาหารเช้าปกติสระว่ายน้ำแบบอินฟินิตี้
# 9.4
# โรงแรมที่ออกแบบอย่างทันสมัยและราคาสมเหตุสมผลล้อมรอบด้วยร้านนวดและร้านอาหารมากมาย / ร้านอาหารจีน ใกล้ Mrt และตลาดโต้รุ่ง
# 9.4
# การบริการที่ดีพนักงานกระตือรือร้นห้องพักสะอาดเรามีความยินดีมากและจะกลับมาอีกในวันที่ใกล้ที่สุด
# 6
# บริการลูกค้าแย่ทุกอย่างพูดถึงเรื่องเงิน
# 8.5
# สะอาดและสะดวกสบายมาก แนะนำ!
# 9.7
# ดีมากจริง ๆ แนะนำเป็นโรงแรมสุดยอดพร้อมอาหารเช้าที่หรูหราและการออกแบบห้องพักที่หรูหรา
# 9.4
# โรงแรมที่ดี อัญมณีที่ซ่อนอยู่ เพียง 30 นาทีจากสนามบินดอนเมือง
# 9.7
# ฉันตกหลุมรักกับ Amaranta Hotel ตั้งแต่ครั้งแรก !! ห้องนี้น่ามหัศจรรย์อย่างที่ฉันคาดไว้ พนักงานเป็นมิตรมาก สถานที่ตั้งโรงแรมอยู่ใกล้กับสถานีรถไฟใต้ดินห้วยขวางเพียงเดิน 3 นาที สระว่ายน้ำซาวน่าและคาเฟ่เป็นสิ่งที่ดีที่สุด! ฉันจะกลับมาเร็วมาก!
# 10
# บริการที่ยอดเยี่ยมและความสะอาดเลือกเมนูสำหรับอาหารเช้าจะแตกต่างกันมากไม่มีข้อร้องเรียนในช่วงพักของเราที่โรงแรม Amaranta

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.4
# โรงแรมที่ดีมากและพนักงานเป็นมิตรมาก
# 8.4
# พักอยู่ที่ Amaranta เป็นเวลา 4 วันกับสามีลูกสองคนและแม่ของฉัน เราอยู่ที่ห้องชุดของประธานาธิบดี ห้องที่ดีอาบน้ำเป็นสิ่งที่ดี อาหารเช้าเป็น amazingggg พวกเขาให้บริการบุฟเฟ่ต์ใหญ่และมีพิพิธภัณฑ์สัตว์น้ำที่ร้านอาหารเพื่อให้ลูก ๆ ของฉันรู้สึกตื่นเต้นมาก สระว่ายน้ำอินฟินิตี้เป็นสิ่งที่ดีไม่ใหญ่ แต่ก็ ok มี 7/11 ร้านค้า, สถานอาบอบนวด, เปลี่ยนเงิน, ร้านอาหาร ในวันสุดท้ายของเรามีปัญหากับ E-key ในห้องของเรา แต่ก็แก้ไขได้ทันที เช็คอิน - เช็คเอาท์ได้ง่ายและรวดเร็ว โดยรวมการเข้าพักของเราเป็นที่น่าพอใจบางทีสถานที่ไม่สมบูรณ์ดังนั้น เราใช้ GRAB ไปทุกที่ ค่าใช้จ่ายเรา 200-250 แต่ละครั้ง เราไม่ได้ใช้ระบบขนส่งสาธารณะเพราะเราเดินทางไปกับเด็ก ๆ
# 8.5
# โรงแรมที่ดีและสถานที่ยุทธศาสตร์
# 9.4
# ห้องพักสะดวกสบายสำหรับการเดินทางแสนโรแมนติกความสุขอาหารที่อร่อยด้วยคุณสมบัติที่สวยงาม โรงแรมอยู่ใกล้กับสถานีรถไฟฟ้าใต้ดินคุณเพียงแค่เดินประมาณ 5 นาทีเพื่อไปถึงสถานี มีบริการขนส่งท้องถิ่นฟรีเรียกว่า &quot;ตุ๊กตุ๊ก&quot; เพื่อให้คุณเพลิดเพลินกับเมือง แต่ฉันมีประสบการณ์ที่ไม่ดีเล็กน้อยมีเสียงออกมาจากห้องของฉันในเวลาเที่ยงคืนดังนั้นจึงรบกวนการนอนของฉัน อย่างไรก็ตามมันเป็นเพียงซอง วันหนึ่งฉันจะกลับไปที่โรงแรมแห่งนี้ถ้าฉันคิดถึงเมือง
# 9.4
# โรงแรมที่ดีและสถานที่ที่ดี ประมาณ 1.1 กม. ไปยังห้างสรรพสินค้าที่ใกล้ที่สุด (ถนน) และประมาณ 300 เมตรถึงสมบูรณแกงปู
# 9.7
# ห้องที่สวยงามมากมีอิสระและไม่มีไวน์ฟรีและคนดีมาก
# 9.1
# โปรดปรับปรุง 2 ข้อนี้ 1. ห้องซาวน่าควรตั้งไว้ที่อุณหภูมิสูงกว่า 90 องศาซึ่งช้า 2. ผ้าม่านควรปิดทึบทุกบานในช่วงเช้า
# 9.7
# แผนกต้อนรับส่วนหน้าใกล้ MRT
# 9.7
# คุ้มค่าหรูหราบริการที่ดีสะดวกและใกล้กับรถไฟฟ้าใต้ดิน
# 9.4
# ฉันพัก 5 คืนทุกอย่างดีที่นี่พนักงานยังเป็นมิตรมาก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# สถานที่ที่ดี ใกล้รถไฟใต้ดินและ 7 11 เฉพาะโรงแรมที่ไม่มีบริการรถรับส่งสนามบินต้องเช่ารถแท็กซี่ โดยรวมดีทั้งหมด
# 10
# ห้องพักที่ดี / บาร์ที่สมบูรณ์แบบ / การตกแต่งภายในที่งดงาม / สระว่ายน้ำบนท้องฟ้า จะไปเที่ยวที่นั่นอีกครั้ง
# 9.7
# ฉันรักที่นี่. ครั้งต่อไปฉันจะกลับมาที่นี่อีกครั้ง
# 10
# โรงแรมที่ดีและง่ายต่อการเดินทาง ผมได้มี 2 ครั้ง โรงแรมที่น่ารัก
# 9.4
# นีซ, รักสถานที่ห่างไกลนายพล แต่มันคุ้มค่ากับการบริการของเขา แนะนำ
# 9.4
# โรงแรมที่ดีมากด้วยเฟอร์นิเจอร์หรูหราสะอาดเงียบสงบและสะดวกสบายบริการลูกค้าที่เป็นมิตรและเป็นประโยชน์ที่พวกเขาช่วยฉันในการติดต่อสนามบินที่จะดูแลสัมภาระความเสียหายของฉันจนกว่าฉันจะได้รับสัมภาระใหม่โดยไม่เรียกร้องค่าใช้จ่ายใด ๆ กับฉันเป็นเพียงแค่อาหารที่ต้องเพิ่ม ความแปรปรวนโดยเฉพาะอย่างยิ่งสำหรับผมที่ไม่สามารถกินหมูโปรดเพิ่มมากขึ้นเมนูฟรีจากหมูผมจะแนะนำโรงแรมนี้ให้กับทุกคนในครอบครัวมุสลิมของฉันและเพื่อนร่วมงานขอบคุณ Amaranta โรงแรม
# 10
# ได้ตลอดเวลา! ทุกอย่างดีมาก
# 9.4
# ดีมาก แต่บิตไกลจากที่รับประทานอาหารที่สนุกและแหล่งช้อปปิ้ง
# 9.7
# ทำเลดีใกล้ MRT ดูปกติด้านนอก แต่หรูในตัว
# 7
# สระว่ายน้ำนิด ๆ หน่อย ๆ เล็ก ๆ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.1
# ดีสะอาดสะดวกสบายโรงแรมแนะนำ!
# 9.7
# การบริการที่ดีห้องพักสะดวกสบายและดีลอฟบาร์บนชั้นดาดฟ้า
# 10
# Super hotel บริการที่ดีเยี่ยมแน่นอนจะมาอีกครั้ง
# 9.7
# ทุกอย่างดีมากและการบริการที่ดี
# 9.4
# Hotel is convenient, near to night market and all amenities, 7-11 is just downstairs and hotel provide tuk tuk service to MRT 👍🏻

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 115
# Reviews_list : 115

# %%
Ratings_list
# Out:
# ['9',
#  '5.6',
#  '8.7',
#  '9.7',
#  '6.7',
#  '8.5',
#  '8.5',
#  '8.8',
#  '8.5',
#  '9.4',
#  '9.7',
#  '9.4',
#  '9.4',
#  '9.7',
#  '9.7',
#  '9.7',
#  '9.4',
#  '9.4',
#  '10',
#  '9.7',
#  '8.5',
#  '9.7',
#  '8.5',
#  '8.4',
#  '9.1',
#  '9.7',
#  '9.4',
#  '8.5',
#  '8.8',
#  '9',
#  '8.8',
#  '9.7',
#  '9.7',
#  '10',
#  '8.5',
#  '8.8',
#  '8.5',
#  '8.5',
#  '9.1',
#  '8.5',
#  '10',
#  '10',
#  '8.5',
#  '10',
#  '9.1',
#  '9.7',
#  '9.7',
#  '9.7',
#  '9.7',
#  '8.5',
#  '9.7',
#  '10',
#  '8.5',
#  '9.7',
#  '10',
#  '8.9',
#  '10',
#  '9.6',
#  '8.1',
#  '10',
#  '10',
#  '10',
#  '10',
#  '8.5',
#  '10',
#  '10',
#  '8.5',
#  '5.7',
#  '9.7',
#  '9.4',
#  '8.8',
#  '9.4',
#  '9.4',
#  '8.2',
#  '9.4',
#  '8.5',
#  '9.1',
#  '8.3',
#  '7.2',
#  '9.7',
#  '8.8',
#  '9.7',
#  '9.4',
#  '9.4',
#  '6',
#  '8.5',
#  '9.7',
#  '9.4',
#  '9.7',
#  '10',
#  '9.4',
#  '8.4',
#  '8.5',
#  '9.4',
#  '9.4',
#  '9.7',
#  '9.1',
#  '9.7',
#  '9.7',
#  '9.4',
#  '8.5',
#  '10',
#  '9.7',
#  '10',
#  '9.4',
#  '9.4',
#  '10',
#  '9.4',
#  '9.7',
#  '7',
#  '9.1',
#  '9.7',
#  '10',
#  '9.7',
#  '9.4']

# %%
Reviews_list
# Out:
# ['ดีทุกอย่าง เว้น กล่องคอนโทรลไฟพัง ทีวีเชื่อมต่อมือถือไม่ได้ ไม่มี เน็ตฟลิก',
#  'ไม่สมราคา ใครเป็นภูมิแพ้ไม่แนะนำ ราคานี้หาที่อื่นนอนค่ะ แต่ต้องขอชมการแก้ไขของทางโรงแรม ข้อดีคือ ใกล้แหล่งของกิน แหล่งเสริมสวยมาก และห้องกว้างค่ะ มีพนักงานคอยช่วยคนของและพอแจ้งเรื่องห้องฝุ่นเยอะ ทางโรงแรมส่งคนมาทำความสะอาดให้เลยทันที แต่มันยิ่งกลายเป็นฝุ่นมาฟุ้งลงที่เตียงแทน วันที่ 2 ที่นอน โรงแรมเลยย้ายห้องให้ ดีขึ้นแต่ฝุ่นก็ยังเยอะอยุ่ดี ข้อเสีย สภาพห้องเก่าแล้ว ของในห้องโทรมหมดแล้ว ฝุ่นเยอะมากจิงๆ ต่อให้ย้ายห้องฝุ่นก็ยังเยอะ ควรปรับปรุงอย่างมาก ไม่สมราคา',
#  'ห้องพักดี สะอาด สวย ทันสมัย แต่อาหารเช้าน้อย คิดว่าเป็นบุฟเฟ่ เสริฟให้แค่คนละเซต ไม่หลากหลาย แต่รูปที่โปรโมทในแอพ คือมีเหมือนบุฟเฟ่ ที่จองเพราะเข้าใจว่าเป็นบุฟเฟ่ ถ้าไม่มีโปรดนำรูปโปรโมทออกด้วยค่ะ ลูกค้าเข้าใจผิดแล้วจะเสียความรู้สึก',
#  'ห้องสวยมาก วิวดีมาก มีอ่างอาบน้ำบริการ ห้องน้ำสวยและสะอาดมาก มีความเป็นส่วนตัวดีมาก เงียบ สงบ และราคาไม่แพง ไว้มีโอกาสจะกลับไปพักอีกแน่นอนค่ะ',
#  'แอร์ไม่เย็น ตู้เย็นไม่ ชักโครกกดไม่ลง',
#  'ชอบครับ พนักงานต้อนรับดีมากครับ โรงแรมห้องกว้าง มีอ่างอาบน้ำในห้อง ครับ',
#  'ดีมาก นอนสบาย คุ้มมาก เตียงนุ่มสุดๆ',
#  'ดีมากๆครับ เเนะนำ เพราะ โรงเเรมอยู่กลางเมือง อาหารเช้า อรอ่ย เเละ เดินทางสะดวก',
#  'ห้องสวยมากครับ. บริการดี อาหารอร่อยครับ',
#  'ประทับใจ. ทุกอย่าง Perfect ตั้งแต่เดินเข้าไป. พนักงานน่ารัก ห้องใหม่สวยสะอาด. ทำเลใกล้รถไฟฟ้า ของกินหาง่าย. มีโอกาสกลับไปอีกแน่นอน. 😍',
#  ' ทุกอย่างโดยรวมของโรงแรมดีมากครับ ราคาสมกับที่พักมากครับ ผมไม่ได้ใช้บริการไรมากนักของโรงแรมรวมถึงอาหารเพราะตื่นสาย เพราะตั้งใจไปเที่ยวจริงๆ แต่ได้ไปเดินดูทุกที่ของโรงแรม รวมถึงบาร์สกายวิว และสระน้ำ ห้องพัก ห้องน้ำ ห้องอาหาร สถานที่ สะอาด สงบ และเหมาะแก่การพักผ่อนมากๆครับ เกือบเทียบได้กับโรงแรม5ดาวเลยครับ ผมคิดว่า พนง.ผช รอบดึกเวลาคุยสายกับลูกค้ามีหางเสียงอีกนิด 3ผ่านเลยครับ พนง.ผญ รอบเช้า พูดจาดีน่ารักมากครับ. แน่ะนำเลยครับใครมองหาที่พักดีดี การบริการดีดี สิ่งอำนวยความสะดวกครบครับ ต้องที่นี่เลยครับ เทียบกับโรงแรมในกรุงเทพผมชอบที่นี่มากครับ ครั้งหน้าผมและเพื่อนๆจะกลับไปใช้บริการอีกครับ รอบหน้าจะใช่บริการของโรงแรมให้ครบเลยครับ ขอบคุณที่พักดีดีครับ',
#  'ไม่ผิดหวังกับโรงเเรมนี้จริงๆภาพตรงปก บรรยากาศดี ห้องสอาด อาหารอร่อย พนักงานบริการเยี่ยม รู้สึกได้ผ่อนคลายเต็มคุ้มค่ากับราคาที่จ่าย ตอนเเรกจองไว้1คืนเเต่ต้องจองเพิ่มเป็น3คืน จะกลับมาพักอีกเเน่นอน',
#  'พนักงานให้ความช่วยเหลือดี ไม่ไกลจาก MRT',
#  'ขอบคุณที่ให้เราได้โปรepicsaleในราคาห้องละ550บาทพร้อมอาหารเช้า ห้องพักดีมากๆ ห้องกว้าง สะอาด ควบคุมไฟฟ้าต่างๆด้วยระบบทัชสกรีนทั้งหมด สระว่ายน้ำสวยมาก ทุกอย่างเพอร์เฟค พนักงานก็บริการดี ใกล้รถใต้ดินห้วยขวาง สามารถให้รถกอล์ฟของโรงแรมไปส่งที่รถใต้ดินได้ มีโอกาสจะกลับไปพักอีกแน่นอน',
#  'เป็นโรงแรมที่ดีมาก ดีที่สุดตั้งแต่เคยเข้าพักมาเลย การบริการยกให้100คะแนนเต็ม ตั้งแต่พนักงานต้อนรับ พนักงานเชคอิน พนักงานยกกระเป๋า แม่บ้าน พนักงานในห้องทานอาหาร ทุกคนคือได้รับการอบรมดีมาก ทุกอย่างคือเพอร์เฟค ราคาห้องสมกับบริการระดับดีเลิศ อาหารเช้ามีให้เลือกหลายรายการ ขนมปังคุณภาพดี อาหารปรุงรสอร่อย ดีมากๆเลยค่ะ สัญญาว่าจะกลับมาพักอีกแน่นอน โรงแรมดีกว่าโรงแรม5ดาวบางแห่งเสียอีก และจะแนะนำให้เพื่อนๆมาใช้บริการด้วยค่ะ',
#  'ที่พักดีค่ะ สวยงาม สะอาด การเดินทางก็สะดวกใกล้Mrt บริเวณโดยรอบของกินเยอะดีค่ะใกล้กับตลาดห้วยขวาง โดยรวมดีมากๆค่ะ มีโอกาสจะไปแวะพักอีกค่ะ',
#  'ที่พักตรงปก ดีงามมากค่ะ อาหารอร่อย สระว่ายน้ำสวย พนักงานสุภาพให้บริการดีมาก เรียกถามได้ตลอด',
#  'โรงแรมดี โรงแรมดีสะอาดห้องกว้างมาก ชอบที่สุด อยู่ใกล้สถานที่สำคัญ สะดวกเดินทางไปมา แถวโรงแรมมีเซเว่นมีร้านอาหารมากมายมีที่ให้แลกเงินเพอร์เฟคค่ะที่นี่แนะนำใครมีรถยนต์ส่วนตัวก็เอามาได้นะคะมีที่จอด',
#  'เตียงนุ่ม นอนสบาย น้ำแรง อุปกรณ์ครบครัน ประทับใจทุกการบริการ',
#  'ทุกอย่างดีมากๆ มีระบบเปิดปิดอัตโนมัติ ครบคลุมทั่วห้อง ห้องสะอาดมาก แอร์เย็นดี เสียอย่างเดียวคือ หารเช้าน้อยไปหน่อยค่ะ แต่โดยรวมถือว่าดีมาก คุ้มค่ามาก การเดินทางสะดวก แนะนำให้นั่ง mrt นะคะ เพราะเส้นทางห้วยทางรถติดมาก',
#  '',
#  'ชอบมากค่ะ บริการประทับใจห้องดีมาก คุ้มค่าคุ้มีราคา เสียดายม่านห้องน้ำรูดไม่ได้ค่ะ เลยไม่ได้นอนแช่อ่าง ห้อง 505 ถ้ามีโอกาสไปพักอีกแน่นอนค่ะ',
#  '',
#  'ห้องสวย กว้างขวาง บริการดี เตียงนอนสบาย',
#  'ห้องสวย สะอาด ชอบอ่างในห้องนอน พนง.น่ารักแม่บ้านบริการดี เตียงนุ่มหลับสบาย น้ำแรงมากใข้ระบบดิจิตอลในการสั่งการทั้งหมด ปลิ้มมาก สระว่ายน้ำสวยมีกุชชี่ไว้แช่ น้องดูแลสระน้ำ เมื่อเห็นแขกไปก็เปิดน้ำพุให้ถ่ายรูป คือดีมาก และเลาบาร์ก็วิวสวย พนง.พูดเพราะเปิดเพลงน่าฟังมากR&B คือโดน ล็อบบี้สวยดูดี มีรถส่งMRTด้วยค่ะ แต่เสียงดายไม่อยู่ติดถนนดำ เข้าซอยมานิด โดยรวมถือว่าดีมาก ชอบคุ้มสุดๆค่ะ',
#  '',
#  '',
#  'ชอบมากไปบ่อยครับ ยินดีที่ได้ไปพัก',
#  '',
#  'สะอาด บริการดีมาก ห้องสวยและกว้างขวาง',
#  'ห้องใหญ่ ตกแต่งสวย สะอาด พนักงานบริการดี',
#  'โรงแรมอยู่ห่าง MRT เพียงเล็กน้อย พอเดินได้ หน้าโรงแรมที่เซเว่น พนักงานบริการดีมาก ห้องพักสะอาด อาหารพอใช้ได้',
#  'ประทับใจที่พักที่นี่มากเลยค่ะ สะดวก สบายมาก ตกแต่งสวยงาม ไฮเทคโนโลยีมาก สั่งเปิดปิดม่าน ระบบแอร์ ไฟ ด้วยจอทัชสกรีน มีอ่างแช่ในห้องด้วย ห้องน้ำก็จะได้สัดส่วน ทุกอย่างดีลงตัวทั้งห้องพักและสิ่งอำนวยความสะดวก รวมไปถึงพนักงาน แม่บ้าน ล็อบบี้ ทุกคนดูแลพวกเราอย่างดี เกิดเหตุขัดข้องในห้องนอนเวลาดึกแล้ว แต่ก็ประสานงานช่างระบบ อย่างรวดเร็ว ประทับใจที่นี่มากๆ จะกลับมาอีก เป็นการพักผ่อนที่ได้พักผ่อนจริงๆ',
#  'ดีค่ะ บริการดี สะอาด ห้องใหญ่ ชอบค่ะ สบาย',
#  'ห้องกว้างมาก และสะอาดดีค่ะ ชอบค่ะ',
#  'ดีมากๆค่ะ ห้องพักและพนักงานดีมาก เดินทางสะดวกค่ะ',
#  '',
#  'โดยรวมแล้วดีค่ะ น้องๆบริการดีค่ะ',
#  'สะดวก สบาย ใกล้รถไฟฟ้า สระว่ายน้ำสวย พนักงานน่ารักมากๆๆ ',
#  'ห้องพักสะอาด ทำเลดี พนักงานบริการดี ห้องรับประทานอาหารเช้าสวย',
#  'ชอบที่นี่มาก ทุกอย่างลงตัวไปหมด ไปมา 2 ครั้ง แล้วจะกลับไปเที่ยวใหม่นะคะ',
#  'ขอบคุณพนักงานทุกท่าน ไม่มีที่ติเลยครั้งนี้',
#  'พนักงานบริการไม่ค่อยดีเท่าที่ควร เช็กอินได้ล่าช้า',
#  'พนักงานรอยยิ้มดีมากค่ะ ครั้งหน้าไปอีกค่ะ',
#  'ดีแต่อยู่ในซอยที่จอดรถยากมาก และเข้าออกไม่ค่อยสะดวก',
#  'ดีมากๆๆ บริการดี พนักงานยิ้มแย้ม เสียแค่ไม่รู้คนที่ไหนโทรเข้าดึกๆ',
#  'ห้องสวยมากค่ะ สะอาด สะดวก ใกล้สถานที่ต่างๆ พนักงานบริการดี จะกลับมาพักอีกแน่นอนค่ะ',
#  'ดีมาก สะอาด สะดวก สบาย ทำเลดีมากๆๆ',
#  'ห้องนอนสวยมาก นอนหลับสบายค่ะ แต่ให้เข้าเช็กอินช้าไปหน่อยค่ะ',
#  'น้องๆ 5 ดาว ทันสมัย สวย หรู ตกแต่งดี บริการดี ประทับใจมาก',
#  'น่าจะมีอาหารเช้าให้ด้วย จะครบทุกอย่างในการเข้าพัก',
#  'ช่องทีวียังมีน้อยมากค่ะ รบกวนช่วยปรับปรุงด้วยค่ะ อย่างอื่นดีหมดทุกอย่างเลยค่ะ',
#  'ที่พักสบายมาก เดินทางสะดวก ใกล้เอ็มอาร์ที มีร้านอาหารชั้นดาดฟ้า บรรยากาศดีมากๆค่ะ',
#  'สวยค่ะ รัานอาหาร บาร์ บรรยากาศ คนไม่เยอะมากเกินไป',
#  'เป็นโรงแรมที่น่าพักมากค่ะ สงบ สะอาด อาหารอร่อย พนักงานทุกคนดูแลต้อนรับดีมากค่ะ',
#  'โรงแรมใหม่ อยู่ใกล้เอ็มอาร์ทีสี่แยกห้วยขวาง ซอยทางเข้าโรงแรมเล็ก มีรถรับส่งไปเอ็มอาร์ที พนักงานรับส่งนิสัยดี มีใจให้บริการ สระว่ายน้ำสวยแต่เล็ก มีบาร์ขายเครื่องดื่มบนชั้นดาดฟ้า สวยดี มีส่วนลดให้แขกที่พัก 30% โดยรวมดี ห้องพักทันสมัย จัดว่าสวยเลย แต่ดูข้างนอกโรงแรมจะเล็กมาก',
#  'การบริการดี ห้องสวย อาหารอร่อย มีทุกอย่างครบวงจรภายในโรงแรมค่ะ',
#  'โรงแรมมีความสะดวกสบาย ทันสมัย สะอาด ชอบดีไซน์ และเทคโนโลยีที่ใส่เข้าไปในห้องพัก',
#  'ที่พักและที่ตั้งดี ใกล้ร้านอาหาร ห้องสะอาด ดูเหมือนจะดี ทุกอย่าง พักที่นั่น 3 คืน วันสุดท้ายเช็กเอาต์ เป็นอะไรที่แย่มาก เราต้องยกกระเป๋าเอง ไม่มีพนักงานสักคน พอเรายกกระเป๋าขึ้นรถเรียบร้อย พนักงานออกมายืนดู สงสัยทางโรงแรมต้องอบรมพนักงานใหม่นะคะ เป็นอะไรที่เสียความรู้สึกมาก และจะไม่กลับไปพักที่นั่นอีกแน่ๆ',
#  'เดินทางสะดวก สะอาด พอใจกับการเข้าพักครั้งนี้มากครับ',
#  'เป็นห้องที่น่าอยู่เป็นอย่างมาก สะอาด พร้อมการบริการที่อบอุ่น และการเดินทางที่สะดวก',
#  'ดีเยี่ยม ห้องพักออกแบบได้สวยงาม ทันสมัย',
#  'พนักงานดูแลดีมากค่ะ ห้องพักสะอาด สวย เป็นส่วนตัวมากค่ะ อาหารอร่อยมากด้วยค่ะ',
#  'อาหารเช้ามีให้เลือกน้อยไปหน่อย ทางโรงแรมเก็บค่ามัดจำแพงไป ห้องละ 3,000 พักมาหลายที่ไม่เคยเจอที่ไหนเก็บแพงขนาดนี้ ถึงจะได้เงินคืนก็ตาม แต่มันแพงเกินไป ถ้ามาพักกัน 5 ห้อง ไม่ต้องจ่ายเป็นหมื่นเหรอคะ อย่างอื่นค่อนข้างโอเค โรงแรมสวย ห้องสวย กว้าง สะอาด ให้ 6/10',
#  'ชอบโรงแรมนี้ค่ะ ชอบทุกอย่างเลย',
#  'พัก 3 คืนค่ะ ห้องพักสวยมาก มีสิ่งอำนวยความสะดวกครบค่ะ สระว่ายน้ำสวยด้วย เคาน์เตอร์ให้บริการตอบคำถามดีมาก บริการอาหารส่งถึงห้องก็อร่อยมากค่ะ ราคาไม่แพง สรุปดีทุกอย่างค่ะ ครั้งต่อไปก็จะเข้าพักอีกค่ะ',
#  'ห้องสะอาด อาหารเช้าอร่อย มีปลาเห็น สระว่ายน้ำสวย นุมะไลลา',
#  'ห้องของฉันคือ 701 แสงกระจกห้องน้ำไม่ทำงาน มันเป็นแหล่งกำเนิดแสงหลักดังนั้นจึงเป็นการยากที่จะเตรียมพร้อม ฝักบัวเหนือศีรษะหลักไม่ทำงานอย่างใดอย่างหนึ่ง มันเป็นสิ่งสกปรกโดยรวม คนอื่น ๆ ที่มีผมมีรอยเปื้อนและรอยเปื้อนบนเศษแก้วกระจก ฯลฯ แม้แต่รีโมทก็ต้องเช็ด บริเวณสระว่ายน้ำมีกลิ่นแปลก ๆ มันไม่ได้สนุกกับการพักผ่อนที่สระว่ายน้ำ อาหารเช้าก็โอเคเท่านั้น ฉันออกไป แต่เช้าแม้ว่ามันจะจองแล้วไม่สามารถขอคืนได้',
#  'สวยใกล้กับ MRT ห้วยขวาง ใกล้กับระดับที่ง่ายต่อการมองหาอาหารพนักงานขายหลายคนยังอยู่โดยรอบห้องสะอาดอ่างอาบน้ำก็เย็นสบายด้วยตำแหน่งกึ่งร่วมกับห้องพักการออกแบบของห้องพักยอดเยี่ยมจริง ๆ อาหารเช้าอร่อย แต่ไม่แนะนำสำหรับชาวมุสลิมส่วนใหญ่มีเนื้อหมู ค่อนข้างแปลกใจที่พวกเขาควรจะสามารถให้บริการอาหารที่เป็นกลางไม่ใช่หมูโดยเฉพาะ แต่สำหรับผู้ที่ไม่ใช่มุสลิมคุณชอบมันมาก ในร้านอาหารมีตู้ปลาขนาดใหญ่ทำให้สะดวกสบาย',
#  'ห้องพักกว้างขวางดีสะดวกสบาย ฉันประทับใจมาก พนักงานทุกคนเป็นมิตร มันเป็นเพียงอาหารเช้าที่มีความหลากหลายน้อย โดยรวมแล้วการพักที่นี่ก็น่าพอใจมาก',
#  'ห้องพักกว้างขวางมาก พนักงานทุกคนให้ความช่วยเหลือดีมาก',
#  'สวยมากสะอาดโรงแรมสวยและพนักงานช่วยเหลือดี',
#  'แม้ว่าโรงแรมจะค่อนข้างแคบ แต่การตกแต่งภายในห้องและห้องน้ำนั้นหรูหรามาก มีรีโมทคอนโทรลขนาดใหญ่เท่ากับ iPad ที่ติดกับผนังเพื่อควบคุมแสงของห้องเพื่อควบคุมอุณหภูมิของเครื่องปรับอากาศทีวียังควบคุมผ้าม่านของห้องเพื่อปิดและเปิดตัวเอง อีกข้อดีคือมินิบาร์และอ่างอาบน้ำฟรีที่ให้บริการผลิตภัณฑ์สปา (แม้ว่าจะชำระค่าสินค้าแล้ว) แต่หากไม่ได้ใช้เราจะไม่โดนผลิตภัณฑ์เงินสด นั่นคือทั้งหมดที่ การพักผ่อนที่สมบูรณ์แบบ',
#  'ฉันมีความสุขกับการเข้าพักที่โรงแรมนี้ ห้องพักสะดวกสบายที่นอนดีแสงไฟในห้องก็โอเคอ่างอาบน้ำก็โอเคตามรูปภาพ การบริการไม่เป็นไรเพราะมีรถรับส่งไปยังรถไฟใต้ดิน ข้อเสียคือที่ตั้งอยู่บนขอบของเมืองดังนั้นจึงต้องการเงินเพิ่มเติมเพื่อไปและกลับไปที่โรงแรมนี้ ข้อเสียเปรียบอีกประการหนึ่งคืออาหารเช้าไม่เป็นไรและหมูมากมาย',
#  'มันเป็นการพักที่ยอดเยี่ยม สิ่งอำนวยความสะดวกครบครัน แต่สายไม่ทำงาน มีแค่ชาน (ไทย) ในท้องถิ่นสิ่งที่ดีมันเป็นสมาร์ททีวีและสามารถโทรศัพท์มือถือกระจก ลูกสาวของฉันชอบอ่างอาบน้ำดังนั้นอ่างอาบน้ำที่หันหน้าเข้าหาทีวีจึงเป็นชัยชนะคู่ของเธอ สระว่ายน้ำชั้นบนก็ธรรมดาดีและผ่อนคลาย แต่ไม่มีพื้นที่ครอบคลุม ว่ายน้ำตอนกลางคืนเป็นสิ่งที่ดี บาร์ริมสระเปิดให้บริการจนถึงช่วงดึกและคุณสามารถสั่งซื้อได้ที่ริมสระ เพียงแค่ไม่ได้อยู่ในเลานจ์ภายในสระว่ายน้ำ พนักงานทุกคนสุภาพ มีจดหมายส่งถึงที่นี่ในระดับสูงและฉันเพิ่งอ้างว่าในขณะที่ฉันอยู่ที่นั่น แผนกต้อนรับเก็บไว้สำหรับฉันคุณคุณ! อาหารเช้าธรรมดา แต่อร่อยและเติม เรายังทานกันอยู่เพราะอาหารในกรุงเทพฯเป็นไฮไลท์สำหรับนักท่องเที่ยวทุกคน! 7/12 ฝั่งตรงข้าม A +! พวกเขามีรถรับส่งสีม่วงน่ารัก แต่เราไปที่สถานีรถไฟฟ้า MRT สองสามครั้ง ไม่สนุกที่เดิน ถนนไม่ว่าง ฉันหวังว่าพวกเขาจุดไฟรถรับส่งนั้นและใช้เวลาเดินทางไป / กลับสถานีเป็นประจำ นั่นเป็นข้อเสียเพียงอย่างเดียว เตียงนอนดีและใหญ่ใหญ่กว่าขนาดคิงไซส์ แรงดันน้ำดีมาก ห้องน้ำแยกจากอ่างอาบน้ำ เปิดเครื่องเป็นปกติ มีบริการรูมเซอร์วิสและราคาสมเหตุสมผล เงียบ ๆ ลูก ๆ ของฉันต้องทำวิดีโอ ASMR ที่สะอาด นอกเหนือจากการเดินจากสถานีทั้งหมดเป็นที่น่าพอใจอย่างมาก!',
#  'ทุกอย่างดีเท่าราคา! บริการข้างหน้า (เด็กผู้หญิง) ไม่ดี! แต่พนักงานบริการทุกคนใจดีและสุภาพมาก',
#  'โรงแรมสุดหรู, ห้องพักหรูหรา, หรูหรา, สะอาด, เรียบร้อย, ตามรูปภาพ, การบริการที่เป็นมิตร, ขั้นตอนการเช็คอินที่รวดเร็ว, ไม่มีเงินฝาก ดูน่าสนใจน้อยกว่า',
#  'โรงแรมนี้อยู่ภายในเล็กน้อยสำหรับห้องพักโอเค บางทีควรปรับปรุงให้ดีขึ้นสำหรับเมนูอาหารเช้าไม่มีตัวเลือกมากมาย',
#  'โดยรวมแล้วเป็นสิ่งที่ดีจริง ๆ แต่ฉันไม่ได้รับมันเมื่อเช็คเอาท์และถูกขอให้จ่ายค่าคิทแคทที่สามีของฉันและฉันไม่เคยกิน',
#  'ใกล้กับเอ็มอาร์ทีบริการดีห้องพักสวยและสะอาด อย่างไรก็ตามมันจะสมบูรณ์แบบถ้าปิดล้อมห้องน้ำแทนที่จะเปิดครึ่งที่ด้านบนซึ่งทำให้ทั้งห้องพักค่อนข้างอึดอัดถ้าอยู่กับคู่ของคุณ',
#  'บริการห้องพักที่ดีและสิ่งอำนวยความสะดวก',
#  'โรงแรมที่ดีโรงแรมควรเผาน้ำมันหอมระเหยมากขึ้นสำหรับน้ำมันหอมระเหยอาหารเช้าปกติสระว่ายน้ำแบบอินฟินิตี้',
#  'โรงแรมที่ออกแบบอย่างทันสมัยและราคาสมเหตุสมผลล้อมรอบด้วยร้านนวดและร้านอาหารมากมาย / ร้านอาหารจีน ใกล้ Mrt และตลาดโต้รุ่ง',
#  'การบริการที่ดีพนักงานกระตือรือร้นห้องพักสะอาดเรามีความยินดีมากและจะกลับมาอีกในวันที่ใกล้ที่สุด',
#  'บริการลูกค้าแย่ทุกอย่างพูดถึงเรื่องเงิน',
#  'สะอาดและสะดวกสบายมาก แนะนำ!',
#  'ดีมากจริง ๆ แนะนำเป็นโรงแรมสุดยอดพร้อมอาหารเช้าที่หรูหราและการออกแบบห้องพักที่หรูหรา',
#  'โรงแรมที่ดี อัญมณีที่ซ่อนอยู่ เพียง 30 นาทีจากสนามบินดอนเมือง',
#  'ฉันตกหลุมรักกับ Amaranta Hotel ตั้งแต่ครั้งแรก !! ห้องนี้น่ามหัศจรรย์อย่างที่ฉันคาดไว้ พนักงานเป็นมิตรมาก สถานที่ตั้งโรงแรมอยู่ใกล้กับสถานีรถไฟใต้ดินห้วยขวางเพียงเดิน 3 นาที สระว่ายน้ำซาวน่าและคาเฟ่เป็นสิ่งที่ดีที่สุด! ฉันจะกลับมาเร็วมาก!',
#  'บริการที่ยอดเยี่ยมและความสะอาดเลือกเมนูสำหรับอาหารเช้าจะแตกต่างกันมากไม่มีข้อร้องเรียนในช่วงพักของเราที่โรงแรม Amaranta',
#  'โรงแรมที่ดีมากและพนักงานเป็นมิตรมาก',
#  'พักอยู่ที่ Amaranta เป็นเวลา 4 วันกับสามีลูกสองคนและแม่ของฉัน เราอยู่ที่ห้องชุดของประธานาธิบดี ห้องที่ดีอาบน้ำเป็นสิ่งที่ดี อาหารเช้าเป็น amazingggg พวกเขาให้บริการบุฟเฟ่ต์ใหญ่และมีพิพิธภัณฑ์สัตว์น้ำที่ร้านอาหารเพื่อให้ลูก ๆ ของฉันรู้สึกตื่นเต้นมาก สระว่ายน้ำอินฟินิตี้เป็นสิ่งที่ดีไม่ใหญ่ แต่ก็ ok มี 7/11 ร้านค้า, สถานอาบอบนวด, เปลี่ยนเงิน, ร้านอาหาร ในวันสุดท้ายของเรามีปัญหากับ E-key ในห้องของเรา แต่ก็แก้ไขได้ทันที เช็คอิน - เช็คเอาท์ได้ง่ายและรวดเร็ว โดยรวมการเข้าพักของเราเป็นที่น่าพอใจบางทีสถานที่ไม่สมบูรณ์ดังนั้น เราใช้ GRAB ไปทุกที่ ค่าใช้จ่ายเรา 200-250 แต่ละครั้ง เราไม่ได้ใช้ระบบขนส่งสาธารณะเพราะเราเดินทางไปกับเด็ก ๆ',
#  'โรงแรมที่ดีและสถานที่ยุทธศาสตร์',
#  'ห้องพักสะดวกสบายสำหรับการเดินทางแสนโรแมนติกความสุขอาหารที่อร่อยด้วยคุณสมบัติที่สวยงาม โรงแรมอยู่ใกล้กับสถานีรถไฟฟ้าใต้ดินคุณเพียงแค่เดินประมาณ 5 นาทีเพื่อไปถึงสถานี มีบริการขนส่งท้องถิ่นฟรีเรียกว่า &quot;ตุ๊กตุ๊ก&quot; เพื่อให้คุณเพลิดเพลินกับเมือง แต่ฉันมีประสบการณ์ที่ไม่ดีเล็กน้อยมีเสียงออกมาจากห้องของฉันในเวลาเที่ยงคืนดังนั้นจึงรบกวนการนอนของฉัน อย่างไรก็ตามมันเป็นเพียงซอง วันหนึ่งฉันจะกลับไปที่โรงแรมแห่งนี้ถ้าฉันคิดถึงเมือง',
#  'โรงแรมที่ดีและสถานที่ที่ดี ประมาณ 1.1 กม. ไปยังห้างสรรพสินค้าที่ใกล้ที่สุด (ถนน) และประมาณ 300 เมตรถึงสมบูรณ\uf70eแกงปู\uf70a',
#  'ห้องที่สวยงามมากมีอิสระและไม่มีไวน์ฟรีและคนดีมาก',
#  'โปรดปรับปรุง 2 ข้อนี้ 1. ห้องซาวน่าควรตั้งไว้ที่อุณหภูมิสูงกว่า 90 องศาซึ่งช้า 2. ผ้าม่านควรปิดทึบทุกบานในช่วงเช้า',
#  'แผนกต้อนรับส่วนหน้าใกล้ MRT',
#  'คุ้มค่าหรูหราบริการที่ดีสะดวกและใกล้กับรถไฟฟ้าใต้ดิน',
#  'ฉันพัก 5 คืนทุกอย่างดีที่นี่พนักงานยังเป็นมิตรมาก',
#  'สถานที่ที่ดี ใกล้รถไฟใต้ดินและ 7 11 เฉพาะโรงแรมที่ไม่มีบริการรถรับส่งสนามบินต้องเช่ารถแท็กซี่ โดยรวมดีทั้งหมด',
#  'ห้องพักที่ดี / บาร์ที่สมบูรณ์แบบ / การตกแต่งภายในที่งดงาม / สระว่ายน้ำบนท้องฟ้า จะไปเที่ยวที่นั่นอีกครั้ง',
#  'ฉันรักที่นี่. ครั้งต่อไปฉันจะกลับมาที่นี่อีกครั้ง',
#  'โรงแรมที่ดีและง่ายต่อการเดินทาง ผมได้มี 2 ครั้ง โรงแรมที่น่ารัก',
#  'นีซ, รักสถานที่ห่างไกลนายพล แต่มันคุ้มค่ากับการบริการของเขา แนะนำ',
#  'โรงแรมที่ดีมากด้วยเฟอร์นิเจอร์หรูหราสะอาดเงียบสงบและสะดวกสบายบริการลูกค้าที่เป็นมิตรและเป็นประโยชน์ที่พวกเขาช่วยฉันในการติดต่อสนามบินที่จะดูแลสัมภาระความเสียหายของฉันจนกว่าฉันจะได้รับสัมภาระใหม่โดยไม่เรียกร้องค่าใช้จ่ายใด ๆ กับฉันเป็นเพียงแค่อาหารที่ต้องเพิ่ม ความแปรปรวนโดยเฉพาะอย่างยิ่งสำหรับผมที่ไม่สามารถกินหมูโปรดเพิ่มมากขึ้นเมนูฟรีจากหมูผมจะแนะนำโรงแรมนี้ให้กับทุกคนในครอบครัวมุสลิมของฉันและเพื่อนร่วมงานขอบคุณ Amaranta โรงแรม',
#  'ได้ตลอดเวลา! ทุกอย่างดีมาก',
#  'ดีมาก แต่บิตไกลจากที่รับประทานอาหารที่สนุกและแหล่งช้อปปิ้ง',
#  'ทำเลดีใกล้ MRT ดูปกติด้านนอก แต่หรูในตัว',
#  'สระว่ายน้ำนิด ๆ หน่อย ๆ เล็ก ๆ',
#  'ดีสะอาดสะดวกสบายโรงแรมแนะนำ!',
#  'การบริการที่ดีห้องพักสะดวกสบายและดีลอฟบาร์บนชั้นดาดฟ้า',
#  'Super hotel บริการที่ดีเยี่ยมแน่นอนจะมาอีกครั้ง',
#  'ทุกอย่างดีมากและการบริการที่ดี',
#  'Hotel is convenient, near to night market and all amenities, 7-11 is just downstairs and hotel provide tuk tuk service to MRT 👍🏻']

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                 Review Rating
# 0    ดีทุกอย่าง เว้น กล่องคอนโทรลไฟพัง ทีวีเชื่อมต่...      9
# 1    ไม่สมราคา ใครเป็นภูมิแพ้ไม่แนะนำ ราคานี้หาที่อ...    5.6
# 2    ห้องพักดี สะอาด สวย ทันสมัย แต่อาหารเช้าน้อย ค...    8.7
# 3    ห้องสวยมาก วิวดีมาก มีอ่างอาบน้ำบริการ ห้องน้ำ...    9.7
# 4                แอร์ไม่เย็น ตู้เย็นไม่ ชักโครกกดไม่ลง    6.7
# ..                                                 ...    ...
# 110                       ดีสะอาดสะดวกสบายโรงแรมแนะนำ!    9.1
# 111  การบริการที่ดีห้องพักสะดวกสบายและดีลอฟบาร์บนชั...    9.7
# 112    Super hotel บริการที่ดีเยี่ยมแน่นอนจะมาอีกครั้ง     10
# 113                     ทุกอย่างดีมากและการบริการที่ดี    9.7
# 114  Hotel is convenient, near to night market and ...    9.4
#
# [115 rows x 2 columns]

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#      index                                             Review Rating
# 0        0  ดีทุกอย่าง เว้น กล่องคอนโทรลไฟพัง ทีวีเชื่อมต่...      9
# 1        1  ไม่สมราคา ใครเป็นภูมิแพ้ไม่แนะนำ ราคานี้หาที่อ...    5.6
# 2        2  ห้องพักดี สะอาด สวย ทันสมัย แต่อาหารเช้าน้อย ค...    8.7
# 3        3  ห้องสวยมาก วิวดีมาก มีอ่างอาบน้ำบริการ ห้องน้ำ...    9.7
# 4        4              แอร์ไม่เย็น ตู้เย็นไม่ ชักโครกกดไม่ลง    6.7
# ..     ...                                                ...    ...
# 104    110                       ดีสะอาดสะดวกสบายโรงแรมแนะนำ!    9.1
# 105    111  การบริการที่ดีห้องพักสะดวกสบายและดีลอฟบาร์บนชั...    9.7
# 106    112    Super hotel บริการที่ดีเยี่ยมแน่นอนจะมาอีกครั้ง     10
# 107    113                     ทุกอย่างดีมากและการบริการที่ดี    9.7
# 108    114  Hotel is convenient, near to night market and ...    9.4
#
# [109 rows x 3 columns]

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                 Review Rating
# 0    ดีทุกอย่าง เว้น กล่องคอนโทรลไฟพัง ทีวีเชื่อมต่...      9
# 1    ไม่สมราคา ใครเป็นภูมิแพ้ไม่แนะนำ ราคานี้หาที่อ...    5.6
# 2    ห้องพักดี สะอาด สวย ทันสมัย แต่อาหารเช้าน้อย ค...    8.7
# 3    ห้องสวยมาก วิวดีมาก มีอ่างอาบน้ำบริการ ห้องน้ำ...    9.7
# 4                แอร์ไม่เย็น ตู้เย็นไม่ ชักโครกกดไม่ลง    6.7
# ..                                                 ...    ...
# 104                       ดีสะอาดสะดวกสบายโรงแรมแนะนำ!    9.1
# 105  การบริการที่ดีห้องพักสะดวกสบายและดีลอฟบาร์บนชั...    9.7
# 106    Super hotel บริการที่ดีเยี่ยมแน่นอนจะมาอีกครั้ง     10
# 107                     ทุกอย่างดีมากและการบริการที่ดี    9.7
# 108  Hotel is convenient, near to night market and ...    9.4
#
# [109 rows x 2 columns]

# %%
table.to_csv("Reviews&Ratings_5th.csv", encoding="utf-8")
