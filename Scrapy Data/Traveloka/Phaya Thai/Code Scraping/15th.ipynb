# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=18-11-2022.19-11-2022.1.1.HOTEL.3000010041018.%E0%B8%A5%E0%B8%B2%E0%B8%9F%20%E0%B8%AD%E0%B8%B2%E0%B8%A3%E0%B8%B5%E0%B8%A2%E0%B9%8C.1&contexts=%7B%22inventoryRateKey%22%3A%22EPSy2lMQRUbs4Z%2BpcPzDIQJS%2FRAEhuHYBZQl71KB9Kg%2BiqGLDk2uWjsyHUapF7H3WsIkBdgyaCd6cEzZvSrR%2F31OY7iP7XDpr8nlh5Tt88s%2FqwP5MiR9z%2FOijQGyMrqm8LFDqJMUAphQFLDVj%2FhuCxn2OOhcThrQtYt65LV3gKgmJ1pdc%2FQdHnwmv%2FNphfUL6a8w8WPEcZS8woVIvUlXdnQg%2BFKzoReBTwYQTK8N6J6Kjf4ODkSuwAEOm3yac10OdCD4UrOhF4FPBhBMrw3onh3u%2Bi8oFpkudVKu2VgkQRNy66awf2W5noWDTLR2%2B7OcmvntxFNyC0HWDeMiyeCMpR16LW%2FQMpcafzER5dqTAUobZ0xNAgFiMQ9W3rkb18f7Xya8r1wErXp1FTU3tRyyFMJ5bSNwHLCNpcDdin5vdJqa%2Be3EU3ILQdYN4yLJ4IylJZqxw7T8rwdLV5L3DYKzSeow%2F%2BB6MF6tehR4rMPKEeRfJryvXAStenUVNTe1HLIUx%2FTMlN%2BqG1bvkErD0c4j3Hzu8KYrVMWGTn%2BNXxngNuqtOwKauwWWU8by0ZLEWNyNuHyUQ2M4Yh8Qu16fA3EZLE5bHh8QF%2BrkqFytK8WGm7f0Pk5C29QiK%2Fr8GZBktsYNwv1PaneXgHaFX%2FhFGMk9R8L3x523Sc0nBf0MHp%2FKb%2Bckpp6uUHfWqJcOcUufo1AO%22%7D&prevSearchId=1749740416226322413&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_1420\580957357.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'ค่าห้องพัก ลาฟ อารีย์ (LAF Hotel Aree) สามเสนใน ตั้งแต่ 18-11-2022 ถึง 19-11-2022'

# %%
driver.execute_script("window.scrollTo(0,2900)")

# %%
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[3]/div/div[1]/div")
sel.click()

# %%
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()

# %%
time.sleep(2)
sel_order = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div/div[1]/div")
sel_order.click()

# %%
time.sleep(2)
ascending = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[1]/div/div[2]/div/div/div/div[2]')
ascending.click()

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 5.5
# ช่องแอร์ในห้องแคปซูลมีฝุ่นเต็มไปหมด
# 5.7
# ผ้าปู ผ้าห่ม ปลอกหมอน ไม่สะอาด สมกับเป็นที่พัก ห้องน้ำแย่มาก แคบเกิน อาหารเช้าทิพ
# 6
# ช่องแอร์บนหัวนอนมีแต่ราขึ้นเต็ม ไม่เห็นมีอาหารเช้าเลยค่ะ
# 6.5
# ส้วมตัน ตันมาก ตู้กดรหัสแปลกๆ ห้องน้ำแคบเกินไป
# 8.2
# บริเวณช่องแอร์ภายในห้องแคปซูลยังมีคราบสกปรกอยู่ ดาดฟ้ายังมีฝุ่นมากถอดรองเท้าเดินยังรู้สึกได้อยากให้มีการทำความสะอาด โดยรวมสถานที่สะดวกสบายดีครับ
# 8.4
# ห้องน้ำ แยกสัดส่วนไม่ดี แคบมาก อากาศไม่ถ่ายเท ยุงเยอะ แต่ห้องพักดีครับ โอเค ใช้ได้ ที่วางของเยอะดี
# 8.5
# มีความเป็นกันเอง ที่พักสบาย บรรยากาศเงียบสงบดีครับ
# 8.8
# ดีค่ะ การบริการดีเป็นไปตามที่ต้องการค่ะ นอนหลับแอร์เย็น ยิ้มแย้มแจ่มใสค่ะ
# 9
# ห้องอาบน้ำ ,ห้องสุขาแคบ ที่นอนยังมีฝุ่นและเส้นผมของผู้เข้าพักคนก่อน เจ้าของที่พักใจดี ใกล้btsอารีย์เดินไม่ไกล
# 9.1
# ห้องพักสะอาด ห้องน้ำสะอาด มีล็อครหัสหลายชั้นกว่าจะเข้าห้องพักและมีล็อกเกอร์ให้ยืมใช้ทำให้รู้สึกปลอดภัยในการเข้าพัก คุ้มค่ากับราคา คนมาพักที่นี่ต้องทำใจยอมรับในเรื่องของการไม่เป็นส่วนตัว เสียงในห้องคือส่วนรวมเลย พูดนิดหน่อยคือได้ยินกันทั่ว แต่พอเข้าไปในห้องแคปซูลแล้วปิดม่านคือรู้สึกเป็นส่วนตัวนะ จะทำอะไรก็ได้ในนั้น มีแค่เรื่องเสียงเท่านั้นเอง ทำเลดีติดกับถนนใหญ่ มีร้านอาหารใกล้ๆห้องพัก

# %%
driver.execute_script("window.scrollTo(0,5900)")
time.sleep(5)
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[6]')
next_page.click()

# %%
clear_list(ratings_list,reviews_list)

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 9.1
# พนักงานบริการดี ที่พักสะอาดมาก สงบ ปลอดภัย ไม่ต้องกังวลใจ แนะนำเป็นอย่างยิ่ง
# 9.1
# ใกล้ bts อารีย์ อยู่ต้นซอยพหลโยธิน 5 ทำให้การเดินทางสะดวกปลอดภัย การเข้าที่พักต้องใช้รหัสในการเปิดประตู บริการดี พนักงานอัธยาศัยดี เงียบสงบ(วันที่พักมีแค่ลูกค้า 2 คนในโซนที่พัก) ที่นอนสะอาด แอร์เย็นกำลังดี แต่ห้องน้ำกับห้องสุขาแคบไปไม่เหมาะกับคนอ้วนหรือตัวใหญ่ ล็อกเกอร์มีปัญหาแต่พนักงานดูแลแก้ไขปัญหาดี มีอาหารเช้าบริการตัวเอง (ไม่ได้ลอง) ได้ที่พักในราคาประมาณ 390 บาท จากราคาเต็ม 700 บาท อาจจะกลับมาใช้บริการอีกถ้ามีการลดราคา (ราคาเต็มรู้สึกแพงไป เพราะโรงแรมที่เป็นห้องส่วนตัวราคาสูงกว่านี้เล็กน้อย)
# 9.1
# ทุกอย่างดีหมด สะอาด พนักงานเป็นกันเอง
# 9.1
# พนังงานบริการดี สะอาด ปลอดภัย สะดวกกับการเดินทาง
# 9.1
# บริการดีมากๆ ลืมรหัส ลืมนั่นนู่นนี่ก็ช่วยเหลือตลอด ห้องพักก็โอเคมาก
# 9.4
# สะอาด พักสบาย ใกล้รถไฟฟ้า แต่อยากให้ปรับปรุงเรื่อง key lock ของตู้เก็บของและ access door
# 9.4
# พนักงานเอาใจใส่ดีมากค่ะ สะอาด สะดวก
# 9.4
# สะอาดมาก และเป็นส่วนตัวดีค่ะ ตินิดนึงคือ แอร์ในแคปซูลไม่ค่อยเย็น และวันที่เราไปพัก มีแขกที่พักอยู่เขาเปิดล็อกเกอร์ไม่ออก แล้วโวยวาย ก็เลยต้องสะดุ้งตื่นตั้งแต่ 7:00 น.
# 9.4
# เตียงนอนสบาย มีช่องแอร์ส่วนตัว
# 9.4
# สะอาด ปลอดภัย เดินทางสะดวกรวดเร็ว อยู่ใกล้สถานีรถไฟฟ้า

# %%
driver.execute_script("window.scrollTo(0,5900)")
time.sleep(5)
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[6]')
next_page.click()

time.sleep(5)
clear_list(ratings_list,reviews_list)
time.sleep(5)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 9.7
# ห้องน้ำสะอาด เเอร์เย็นสบาย พนักงานเป็นมิตรมากๆค่ะ ใกล้ bts มากๆ
# 9.7
# เป็นการนอนแบบรวมครั้งแรก ตอนแรกก็แอบหวั่นๆ แต่สรุปคือดีมาก รู้สึกปลอดภัย ที่พักด้านล่างเป็นบาร์คือดีมาก พนักงานก็บริการดี๊ดี ใครสายแบ็คแพ็คแนะนำที่นี่เลยคร่า ลาฟ อารีย์ 👍🏻 อีกอย่างคือเดินทางสะดวกมาก รถเมย์ผ่านเยอะมาก อยู่ไม่ไกลจากบีทีเอสอารีย์ด้วย
# 9.7
# ชอบ เดินทางสะดวก บริการดี สำคัญมีตู้ล็อกเกอติจิตอลที่ใช้งานสะดวก
# 9.7
# ที่พักเงียบสงบคนไม่เยอะ ที่นอนสบาย พนักงานบริการดี
# 9.7
# ที่พักสะอาด ที่นอนนอนสบาย เสียงเงียบ การเดินทางสะดวกปลอดภัย 1 ในโฮสเทลที่ควรลองไปนะคะ
# 10
# ใกล้ bts ห้องสะอาด เงียบ สงบ ปลอดภัย พนักงานดี กาแฟเยี่ยม
# 8.5
# ทำเลที่ตั้งดีใกล้ MRT อารีย์และพนักงานเป็นกันเองมาก
# 8.8
# ล็อกเกอร์ไม่ดีและเตียงนอนสบาย :)
# 8.8
# การออกแบบโรงแรมนั้นดี แต่พวกเขาไม่มีพนักงานบริการตลอด 24 ชั่วโมง หากคุณต้องการเช็คอินหลังเที่ยงคืนคุณควรต้องใช้ในขณะที่คุณจองห้องพัก และมีเสียงจากถนนเยอะมาก
# 8.8
# ทำเลดีราคาถูกสะอาด

# %%
driver.execute_script("window.scrollTo(0,5900)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[6]')
time.sleep(5)
next_page.click()

time.sleep(5)
clear_list(ratings_list,reviews_list)
time.sleep(5)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 9.7
# ห้องน้ำสะอาด เเอร์เย็นสบาย พนักงานเป็นมิตรมากๆค่ะ ใกล้ bts มากๆ
# 9.7
# เป็นการนอนแบบรวมครั้งแรก ตอนแรกก็แอบหวั่นๆ แต่สรุปคือดีมาก รู้สึกปลอดภัย ที่พักด้านล่างเป็นบาร์คือดีมาก พนักงานก็บริการดี๊ดี ใครสายแบ็คแพ็คแนะนำที่นี่เลยคร่า ลาฟ อารีย์ 👍🏻 อีกอย่างคือเดินทางสะดวกมาก รถเมย์ผ่านเยอะมาก อยู่ไม่ไกลจากบีทีเอสอารีย์ด้วย
# 9.7
# ชอบ เดินทางสะดวก บริการดี สำคัญมีตู้ล็อกเกอติจิตอลที่ใช้งานสะดวก
# 9.7
# ที่พักเงียบสงบคนไม่เยอะ ที่นอนสบาย พนักงานบริการดี
# 9.7
# ที่พักสะอาด ที่นอนนอนสบาย เสียงเงียบ การเดินทางสะดวกปลอดภัย 1 ในโฮสเทลที่ควรลองไปนะคะ
# 10
# ใกล้ bts ห้องสะอาด เงียบ สงบ ปลอดภัย พนักงานดี กาแฟเยี่ยม
# 8.5
# ทำเลที่ตั้งดีใกล้ MRT อารีย์และพนักงานเป็นกันเองมาก
# 8.8
# ล็อกเกอร์ไม่ดีและเตียงนอนสบาย :)
# 8.8
# การออกแบบโรงแรมนั้นดี แต่พวกเขาไม่มีพนักงานบริการตลอด 24 ชั่วโมง หากคุณต้องการเช็คอินหลังเที่ยงคืนคุณควรต้องใช้ในขณะที่คุณจองห้องพัก และมีเสียงจากถนนเยอะมาก
# 8.8
# ทำเลดีราคาถูกสะอาด

# %%
driver.execute_script("window.scrollTo(0,5900)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[6]')
next_page.click()

time.sleep(3)
clear_list(ratings_list,reviews_list)
time.sleep(3)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 9.1
# สะดวกสบาย แต่ไกลจากแหล่งอาหารประมาณ 800
# 9.1
# โดยรวมแล้วเป็นสิ่งที่ดีทำเลดีห้องพักดีและพนักงานใจดีมาก
# 9.4
# ทุกอย่างสะอาด แต่ความสูงของเพดานสำหรับห้องแคปซูลสั้นเกินไป
# 9.7
# ทำเลที่ตั้งของโรงแรมเป็นยุทธศาสตร์มากใกล้กับสถานีรถไฟและสถานที่กินมากมายและตลาดขนาดเล็กรอบ ๆ โรงแรม

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 34
# Reviews_list : 34

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0                 ช่องแอร์ในห้องแคปซูลมีฝุ่นเต็มไปหมด    5.5
# 1   ผ้าปู ผ้าห่ม ปลอกหมอน ไม่สะอาด สมกับเป็นที่พัก...    5.7
# 2   ช่องแอร์บนหัวนอนมีแต่ราขึ้นเต็ม ไม่เห็นมีอาหาร...      6
# 3      ส้วมตัน ตันมาก ตู้กดรหัสแปลกๆ ห้องน้ำแคบเกินไป    6.5
# 4   บริเวณช่องแอร์ภายในห้องแคปซูลยังมีคราบสกปรกอยู...    8.2
# 5   ห้องน้ำ แยกสัดส่วนไม่ดี แคบมาก อากาศไม่ถ่ายเท ...    8.4
# 6   มีความเป็นกันเอง ที่พักสบาย บรรยากาศเงียบสงบดี...    8.5
# 7   ดีค่ะ การบริการดีเป็นไปตามที่ต้องการค่ะ นอนหลั...    8.8
# 8   ห้องอาบน้ำ ,ห้องสุขาแคบ ที่นอนยังมีฝุ่นและเส้น...      9
# 9   ห้องพักสะอาด ห้องน้ำสะอาด มีล็อครหัสหลายชั้นกว...    9.1
# 10  พนักงานบริการดี ที่พักสะอาดมาก สงบ ปลอดภัย ไม่...    9.1
# 11  ใกล้ bts อารีย์ อยู่ต้นซอยพหลโยธิน 5 ทำให้การเ...    9.1
# 12              ทุกอย่างดีหมด สะอาด พนักงานเป็นกันเอง    9.1
# 13   พนังงานบริการดี สะอาด ปลอดภัย สะดวกกับการเดินทาง    9.1
# 14  บริการดีมากๆ ลืมรหัส ลืมนั่นนู่นนี่ก็ช่วยเหลือ...    9.1
# 15  สะอาด พักสบาย ใกล้รถไฟฟ้า แต่อยากให้ปรับปรุงเร...    9.4
# 16                พนักงานเอาใจใส่ดีมากค่ะ สะอาด สะดวก    9.4
# 17  สะอาดมาก และเป็นส่วนตัวดีค่ะ ตินิดนึงคือ แอร์ใ...    9.4
# 18                     เตียงนอนสบาย มีช่องแอร์ส่วนตัว    9.4
# 19  สะอาด ปลอดภัย เดินทางสะดวกรวดเร็ว อยู่ใกล้สถาน...    9.4
# 20  ห้องน้ำสะอาด เเอร์เย็นสบาย พนักงานเป็นมิตรมากๆ...    9.7
# 21  เป็นการนอนแบบรวมครั้งแรก ตอนแรกก็แอบหวั่นๆ แต่...    9.7
# 22  ชอบ เดินทางสะดวก บริการดี สำคัญมีตู้ล็อกเกอติจ...    9.7
# 23  ที่พักเงียบสงบคนไม่เยอะ ที่นอนสบาย พนักงานบริก...    9.7
# 24  ที่พักสะอาด ที่นอนนอนสบาย เสียงเงียบ การเดินทา...    9.7
# 25  ใกล้ bts ห้องสะอาด เงียบ สงบ ปลอดภัย พนักงานดี...     10
# 26  ทำเลที่ตั้งดีใกล้ MRT อารีย์และพนักงานเป็นกันเ...    8.5
# 27                   ล็อกเกอร์ไม่ดีและเตียงนอนสบาย :)    8.8
# 28  การออกแบบโรงแรมนั้นดี แต่พวกเขาไม่มีพนักงานบริ...    8.8
# 29                                 ทำเลดีราคาถูกสะอาด    8.8
# 30            สะดวกสบาย แต่ไกลจากแหล่งอาหารประมาณ 800    9.1
# 31  โดยรวมแล้วเป็นสิ่งที่ดีทำเลดีห้องพักดีและพนักง...    9.1
# 32  ทุกอย่างสะอาด แต่ความสูงของเพดานสำหรับห้องแคปซ...    9.4
# 33  ทำเลที่ตั้งของโรงแรมเป็นยุทธศาสตร์มากใกล้กับสถ...    9.7

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0                ช่องแอร์ในห้องแคปซูลมีฝุ่นเต็มไปหมด    5.5
# 1       1  ผ้าปู ผ้าห่ม ปลอกหมอน ไม่สะอาด สมกับเป็นที่พัก...    5.7
# 2       2  ช่องแอร์บนหัวนอนมีแต่ราขึ้นเต็ม ไม่เห็นมีอาหาร...      6
# 3       3     ส้วมตัน ตันมาก ตู้กดรหัสแปลกๆ ห้องน้ำแคบเกินไป    6.5
# 4       4  บริเวณช่องแอร์ภายในห้องแคปซูลยังมีคราบสกปรกอยู...    8.2
# 5       5  ห้องน้ำ แยกสัดส่วนไม่ดี แคบมาก อากาศไม่ถ่ายเท ...    8.4
# 6       6  มีความเป็นกันเอง ที่พักสบาย บรรยากาศเงียบสงบดี...    8.5
# 7       7  ดีค่ะ การบริการดีเป็นไปตามที่ต้องการค่ะ นอนหลั...    8.8
# 8       8  ห้องอาบน้ำ ,ห้องสุขาแคบ ที่นอนยังมีฝุ่นและเส้น...      9
# 9       9  ห้องพักสะอาด ห้องน้ำสะอาด มีล็อครหัสหลายชั้นกว...    9.1
# 10     10  พนักงานบริการดี ที่พักสะอาดมาก สงบ ปลอดภัย ไม่...    9.1
# 11     11  ใกล้ bts อารีย์ อยู่ต้นซอยพหลโยธิน 5 ทำให้การเ...    9.1
# 12     12              ทุกอย่างดีหมด สะอาด พนักงานเป็นกันเอง    9.1
# 13     13   พนังงานบริการดี สะอาด ปลอดภัย สะดวกกับการเดินทาง    9.1
# 14     14  บริการดีมากๆ ลืมรหัส ลืมนั่นนู่นนี่ก็ช่วยเหลือ...    9.1
# 15     15  สะอาด พักสบาย ใกล้รถไฟฟ้า แต่อยากให้ปรับปรุงเร...    9.4
# 16     16                พนักงานเอาใจใส่ดีมากค่ะ สะอาด สะดวก    9.4
# 17     17  สะอาดมาก และเป็นส่วนตัวดีค่ะ ตินิดนึงคือ แอร์ใ...    9.4
# 18     18                     เตียงนอนสบาย มีช่องแอร์ส่วนตัว    9.4
# 19     19  สะอาด ปลอดภัย เดินทางสะดวกรวดเร็ว อยู่ใกล้สถาน...    9.4
# 20     20  ห้องน้ำสะอาด เเอร์เย็นสบาย พนักงานเป็นมิตรมากๆ...    9.7
# 21     21  เป็นการนอนแบบรวมครั้งแรก ตอนแรกก็แอบหวั่นๆ แต่...    9.7
# 22     22  ชอบ เดินทางสะดวก บริการดี สำคัญมีตู้ล็อกเกอติจ...    9.7
# 23     23  ที่พักเงียบสงบคนไม่เยอะ ที่นอนสบาย พนักงานบริก...    9.7
# 24     24  ที่พักสะอาด ที่นอนนอนสบาย เสียงเงียบ การเดินทา...    9.7
# 25     25  ใกล้ bts ห้องสะอาด เงียบ สงบ ปลอดภัย พนักงานดี...     10
# 26     26  ทำเลที่ตั้งดีใกล้ MRT อารีย์และพนักงานเป็นกันเ...    8.5
# 27     27                   ล็อกเกอร์ไม่ดีและเตียงนอนสบาย :)    8.8
# 28     28  การออกแบบโรงแรมนั้นดี แต่พวกเขาไม่มีพนักงานบริ...    8.8
# 29     29                                 ทำเลดีราคาถูกสะอาด    8.8
# 30     30            สะดวกสบาย แต่ไกลจากแหล่งอาหารประมาณ 800    9.1
# 31     31  โดยรวมแล้วเป็นสิ่งที่ดีทำเลดีห้องพักดีและพนักง...    9.1
# 32     32  ทุกอย่างสะอาด แต่ความสูงของเพดานสำหรับห้องแคปซ...    9.4
# 33     33  ทำเลที่ตั้งของโรงแรมเป็นยุทธศาสตร์มากใกล้กับสถ...    9.7

# %%
table = table.drop(['index'],axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1420\883481712.py in <module>
# ----> 1 table = table.drop(['index'],axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4265         for axis, labels in axes.items():
#    4266             if labels is not None:
# -> 4267                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4268
#    4269         if inplace:
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4309                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4310             else:
# -> 4311                 new_axis = axis.drop(labels, errors=errors)
#    4312             indexer = axis.get_indexer(new_axis)
#    4313
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6659         if mask.any():
#    6660             if errors != "ignore":
# -> 6661                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6662             indexer = indexer[~mask]
#    6663         return self.delete(indexer)
#
# KeyError: "['index'] not found in axis"

# %%
table
# Out:
#                                                Review Rating
# 0                 ช่องแอร์ในห้องแคปซูลมีฝุ่นเต็มไปหมด    5.5
# 1   ผ้าปู ผ้าห่ม ปลอกหมอน ไม่สะอาด สมกับเป็นที่พัก...    5.7
# 2   ช่องแอร์บนหัวนอนมีแต่ราขึ้นเต็ม ไม่เห็นมีอาหาร...      6
# 3      ส้วมตัน ตันมาก ตู้กดรหัสแปลกๆ ห้องน้ำแคบเกินไป    6.5
# 4   บริเวณช่องแอร์ภายในห้องแคปซูลยังมีคราบสกปรกอยู...    8.2
# 5   ห้องน้ำ แยกสัดส่วนไม่ดี แคบมาก อากาศไม่ถ่ายเท ...    8.4
# 6   มีความเป็นกันเอง ที่พักสบาย บรรยากาศเงียบสงบดี...    8.5
# 7   ดีค่ะ การบริการดีเป็นไปตามที่ต้องการค่ะ นอนหลั...    8.8
# 8   ห้องอาบน้ำ ,ห้องสุขาแคบ ที่นอนยังมีฝุ่นและเส้น...      9
# 9   ห้องพักสะอาด ห้องน้ำสะอาด มีล็อครหัสหลายชั้นกว...    9.1
# 10  พนักงานบริการดี ที่พักสะอาดมาก สงบ ปลอดภัย ไม่...    9.1
# 11  ใกล้ bts อารีย์ อยู่ต้นซอยพหลโยธิน 5 ทำให้การเ...    9.1
# 12              ทุกอย่างดีหมด สะอาด พนักงานเป็นกันเอง    9.1
# 13   พนังงานบริการดี สะอาด ปลอดภัย สะดวกกับการเดินทาง    9.1
# 14  บริการดีมากๆ ลืมรหัส ลืมนั่นนู่นนี่ก็ช่วยเหลือ...    9.1
# 15  สะอาด พักสบาย ใกล้รถไฟฟ้า แต่อยากให้ปรับปรุงเร...    9.4
# 16                พนักงานเอาใจใส่ดีมากค่ะ สะอาด สะดวก    9.4
# 17  สะอาดมาก และเป็นส่วนตัวดีค่ะ ตินิดนึงคือ แอร์ใ...    9.4
# 18                     เตียงนอนสบาย มีช่องแอร์ส่วนตัว    9.4
# 19  สะอาด ปลอดภัย เดินทางสะดวกรวดเร็ว อยู่ใกล้สถาน...    9.4
# 20  ห้องน้ำสะอาด เเอร์เย็นสบาย พนักงานเป็นมิตรมากๆ...    9.7
# 21  เป็นการนอนแบบรวมครั้งแรก ตอนแรกก็แอบหวั่นๆ แต่...    9.7
# 22  ชอบ เดินทางสะดวก บริการดี สำคัญมีตู้ล็อกเกอติจ...    9.7
# 23  ที่พักเงียบสงบคนไม่เยอะ ที่นอนสบาย พนักงานบริก...    9.7
# 24  ที่พักสะอาด ที่นอนนอนสบาย เสียงเงียบ การเดินทา...    9.7
# 25  ใกล้ bts ห้องสะอาด เงียบ สงบ ปลอดภัย พนักงานดี...     10
# 26  ทำเลที่ตั้งดีใกล้ MRT อารีย์และพนักงานเป็นกันเ...    8.5
# 27                   ล็อกเกอร์ไม่ดีและเตียงนอนสบาย :)    8.8
# 28  การออกแบบโรงแรมนั้นดี แต่พวกเขาไม่มีพนักงานบริ...    8.8
# 29                                 ทำเลดีราคาถูกสะอาด    8.8
# 30            สะดวกสบาย แต่ไกลจากแหล่งอาหารประมาณ 800    9.1
# 31  โดยรวมแล้วเป็นสิ่งที่ดีทำเลดีห้องพักดีและพนักง...    9.1
# 32  ทุกอย่างสะอาด แต่ความสูงของเพดานสำหรับห้องแคปซ...    9.4
# 33  ทำเลที่ตั้งของโรงแรมเป็นยุทธศาสตร์มากใกล้กับสถ...    9.7

# %%
table.to_csv("Reviews&Ratings_15th.csv", encoding="utf-8")
