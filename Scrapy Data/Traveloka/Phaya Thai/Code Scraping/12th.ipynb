# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=11-11-2022.12-11-2022.1.1.HOTEL.9000000336409.%E0%B9%80%E0%B8%94%E0%B8%AD%E0%B8%B0%E0%B8%A7%E0%B8%B4%E0%B8%84%E0%B8%95%E0%B8%AD%E0%B8%A3%E0%B8%B5%E0%B9%88%20%E0%B8%A7%E0%B8%B4%E0%B8%A7.1&contexts=%7B%22inventoryRateKey%22%3A%22povEwB3ZzsU2C6pd%2B6MdUwKh3BcjHsHvQbV0EUcyDRFM0tKsNUio4Rxug1zOzHJilcvZa8YdqqIySdppe7dolTIewZlxfjiOGz6oXLTucMvN0%2BgQ3yZPvZcoHwUFNN%2BZpcr%2F%2FNa8o9ElfN8zOYhzzZeg0X586laFpeUViPi9rxAITwMfRXKOPPxoN7XgHx8WDKNfCuNpYoh%2BuNZYtkPMM8N0KRTJ4VFq4ShicQGXCAjUQQmOFyb69aqe8Hll6YWZ3I9RvKjk4IEo%2BSgm41melVlJUAwrC%2F%2B5QUCsG1s1QVIuc5YTT922w9xJEQzAwRUPzSl6dJQgogwyjt1c2VkcX9VsBZohxEpYRFmg%2B%2BHLDKSkPo4ALSUkZiC%2B1nbJmIVYjTE%2FGsBKQXKjBtgZDhjE4C5zlhNP3bbD3EkRDMDBFQ82dD0olqzZJfMIpa%2FP%2FPon1WwFmiHESlhEWaD74csMpIVg4uP%2BNd16M8XgjnTkiZCGixODei%2FNdx2RuCUEGmeMAUyxf%2BoM7B5yfJewzeVoU2%2FtVYQKI1lMuX%2BRaPNcBUAvSnVpp3982X8ufymNCG%2Bvqv3rBuUa%2BDAlSlNPC7rHF8TsYmOTADU69%2B%2B%2Fol8yLJTHHQhvr%2Bf5O5wjhPZDddaEMD1lhgrNFX59TpZvCV9M4rSDCIHqoFDFRnsCphC6IUw%3D%22%7D&prevSearchId=1749098357146539926&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)
driver.set_window_size(1000, 1000)
driver.execute_script("document.body.style.zoom='100%'")
Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]

driver.execute_script("window.scrollTo(0,3100)")
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_13204\3998870956.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[4]/div[3]")
sel.click()

# %%
time.sleep(2)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[4]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()

# %%
time.sleep(2)
sel_order = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[4]/div[1]/div")
sel_order.click()
ascending = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[4]/div[1]/div/div[2]/div/div/div/div[2]')
ascending.click()

# %%
driver.title
# Out:
# 'ค่าห้องพัก เดอะวิคตอรี่ วิว (The Victory View ) ราชเทวี ตั้งแต่ 11-11-2022 ถึง 12-11-2022'

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 4.8
# หลักๆเคเาเป็นแมนชั่น นศ. และคนทำงาน ไม่ใช่สไตล์โรงแรม เลยไม่ได้ต้อนรับคนมาพักรายวันอย่างเราๆการบริการเลยไม่ได้เป็นมาตรฐานของโรงแรม มีเสียงรบกวนตลอดเวลา ห้องไม่เก็บเสียง เราพัก 3 คืน 4 วัน ไม่มีดารทำความสะอาดห้อง แถมบอกว่าถ้าทำก็ได้ แต่ต้องจ่ายเพิ่มนะ พม่าเป็นคนพูด พูดน้ำเสียงไม่โอเคด้วยนะ เราถามเพราะไม่รุ้ แต่คิดว่าจะตามมาตรฐานทั่วไปคือมีทำห้องเปลี่ยนผ้าเช็ดตัว ทิ้งขยะ อะไรประมานนี้ เราพักห้องคืนละ5++ นะ ชั้น 9 ไม่ใช่พักห้องแคปซูล นี่มาพักเป็นครั้งที่2 ครั้งแรกแค่พักคืนเดียวเพื่อเตรียมเดินทางต่อเลยไม่ได้เห็นถึงปัญหา เลยเลือกมาพักครั้งที่ 2 และจะเป็นครั้งสุดท้าย
# 5.1
# ไปถึงมีปัญหาห้องพัก พนักงานไม่มีผ้าขนหนูให้ ผ้าห่มน่าจะใช้ผ้าห่มเก่า
# 6.2
# อยากให้ระบุว่าห้องน้ำรวมเนี่ย รวมแค่หญิง รวมแค่ชาย หรือรวมชายและหญิงด้วยค่ะ ถ้ารู้ก่อนว่ารวมชายหญิงจะไม่พักเลย แต่เสียเงินแล้วเลยอยู่ไปก่อน ส่วนห้องก็ดีค่ะ กว้าง เป็นห้องเดี่ยวแบบแคปซูล มีผ้าเช็ดตัวให้ด้วย ห้องน้ำสะดวกมีไดร์เป่าผมให้ น้ำอุ่นน้ำเย็นใช้ได้ตามปกติค่ะ ส่วนเบอร์ติดต่อ ช่วยอัพเดทเป็นปัจจุบันด้วยนะคะ ส่วนเบอร์ที่ใช้จริงก็ติดต่อไม่ได้เลย แม่บ้านกับรปภ. ยังใส่ใจลูกค้ากว่าเจ้าของตึกอีกค่ะ ขอบคุณ
# 8.5
# ที่พักดีมากค่ะ ดูน่ารัก น่าอยู่มากๆ
# 8.5
#
# 8.5
# ทุกอย่างโอเค service ดีเป็นกันเอง สะอาดสะดวกสบายซักผ้าได้แอร์เย็นห้องดีราคาดีงาม
# 8.5
# สะดวกมาก สะอาด แอน์เย็น แต่ป้าย โรงแรมเล็กไปนิดนึง หาไม่เจอ
# 8.5
# ดีมากค่ะ ที่พักสะอาดมากห้องดีมาก จัดสัดส่วนพื้นที่ดีมากค่ะ จะกลับไปพักอีกแน่นอน
# 8.5
# ที่พักสะอาดห้องน้ำสะอาด พนักงานน่ารัก แม่บ้านและยามน่ารักสุภาพ
# 8.5
# ที่พักดีค่ะ ไม่ไกล bts เดินจาก บีทีเอสมาเข้าซอย center one เดินอีกสักพักนึงก็จะถึงที่พักเลย หากเป็นเข้าพักตอนกลางคืนแนะนำให้เรียกแกรป แล้วแจ้งว่าไป ks resident ก็จะถึงที่พักค่ะ ลุงยามโอเคน่ารักนะคะนั่งรอให้เช็คอิน 5 ทุ่มก็ยังอยู่ ขอแค่แจ้งเขาไว้ก่อนว่าจะมาเช็คอินดึก เขาก็จะอยู่รอให้ พี่แม่บ้านก็น่ารักค่ะ เช็คเอาท์ออกได้เลยคืนกุญแจไม่ยุ่งยาก ภายในห้องพัก กว้างนะคะ แอร์เย็น พื้นที่ส่วนกลางคนจะเยอะนิดนึง ห้องน้ำรวมโอเคค่ะ มีครีมอาบน้ำแชมพูให้พร้อม มีไดร์ด้วย โดยรวมเหมาะกับการมา Backpackers มากๆ ค่า

# %%
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]")
sel.click()

# %%
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# โฮสเทลอยู่ชั้น10ของอพาร์ทเมนท์ เดินเข้าซอยหลังเซ็นจูรี่ตรงไปเรื่อยๆ ประมาณกลางๆซอย อาจจะเหมือนเปลี่ยวแต่ก็ไม่มาก มีวินวิ่งเข้าออกตลอด ห้องพักสะอาดแอร์เย็นค่ะ แต่กุญแจแอบไขยาก ต้องรุ้จังหวะ เราได้ห้องบนต้องปีนป่ายบันไดเล็กน้อยแต่บันไดแข็งแรงดีค่ะ ห้องน้ำเป็นห้องน้ำรวมแต่มีแยกเป็นห้องช-ญให้ค่ะ มีไดร์มีหวี มีน้ำดื่มตู้เย็นให้ใช้ ถือว่าสะดวกสบายดีค่ะ โอกาสหน้าจะไปใหม่
# 8.5
# ห้องพักแบบ 4 เตียง มีกุญแจลอคเกอร์ให้ แต่ไม่มีกุญแจห้อง
# 8.5
# ก็ตามราคานะ สะอาด เราจองแวะอาบน้ำจัดกระเป๋าเดินทางต่อ ไม่ได้พักค้างคืน โฮลเทลอยู่ด้านหลังเซ็นจูรี่ ตรงกันข้ามกับ รพ.ราชวิถี ซอยด้านซ้ายมือฝั่งเซ็นจูรี่ เดินเข้าซอยไปจะไกลหน่อย มีร้านค้าเยอะ ไม่ห่างจากบีทีเอสอนุสาวรีย์
# 8.5
# ดีมากค่ะ ไปพักบ่อยที่นี่ สะอาด มีความเป็นส่วนตัว
# 8.5
#
# 8.5
# โรงแรมสะอาด พนักงานบริการดีค่ะ ชอบค่ะ ถ้าเข้ากรุงเทพจะกลับไปพักอีกค่ะ ราคาไม่แพง เดินทางสะดวก
# 8.5
# สภาพดีน่ะห้องพัก แต่พนักงานไม่ค่อยอยากต้อนรับบอกเร่หลงมาได้ไง งงเลยเจอลูกค้าแทนจะดีใจกลับ เสียใจซ่ะงั้น
# 8.5
# ชอบค่ะ ที่พักสะดวกสบาย สะอาด ปลอดภัย เป็นกันเอง
# 8.5
# ห้องเป็นสัดส่วนดี ใกล้ BTS อนุสาวรีย์
# 8.5
# ชอบมากๆเลยค่ะ ว่างๆจะกลับไปพักอีกแน่นอนค่ะ

# %%
driver.execute_script("document.body.style.zoom='100%'")
driver.execute_script("window.scrollTo(0,7700)")

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]')

# %%
sel.click()

# %%
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# เดินทางสะดวก ใกล้อนุสาวรีย์ชัยสมรภูมิ เสียนิดเดียวคือ เตียงไม่ได้ติดกำแพง มีช่องห่างกำแพง ทำให้แสงไฟจากเตียงด้านบนส่องลงมา ผ้าม่านก็รูดปิดไม่หมด ไม่มีที่ให้แขวนผ้าหรือตากผ้า ต้องเอามาพาดไว้กับขอบเตียง
# 8.5
# ที่พักสะอาด พี่เจ้าของดูแลดีมากค่ะ ต้องไปพักอีกแน่นอน
# 8.5
#
# 8.5
#
# 8.7
# เจ้าของ และแม่บ้านน่ารักมาก อยูใกล้ center one เดินทางสะดวก
# 8.7
# วิวสวยดี ทำเลดี เดินทางสะดวก แต่เตียงชั้นสองค่อนข้างเล็กและมีร่องข้างเตียงประมาณ 20 ซม. ซึ่งทำให้ไม่เป็นส่วนตัว และเสี่ยงที่จะมีของร่วงหล่น
# 8.8
# ราคาประหยัด สะอาดดี ไม่เสียงดัง เป็นสัดเป็นส่วนดีค่ะ ชอบๆ
# 8.8
# ที่พักดี เดินทางสะดวก ใกล้bts โดยรวมคุ้มค่ากับราคามากค่ะ
# 8.8
# ที่พักดีมีความเป็นส่วนตัวเดินทางสะดวก
# 8.8

# %%
driver.execute_script("window.scrollTo(0,5900)")
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.1
# ที่พักสะอาดดีค่ะ เดินทางไม่ยากมาก แต่ก็แอบเดินไกลนิดนึง แต่นิดจริงค่ะ โดยรวมก็ถือว่าดี แต่ติดที่ห้องน้ำมีน้อยเกินไปค่ะ ไม่ค่อยสะดวกเท่าไหร่
# 9.1
# เคยพักที่นี่บ่อยค่ะ น้องที่ดูแลน่ารักมากเป็นกันเอง ที่พักสะอาด เดินทางสะดวกมาก เงียบไม่น่าเชื่อทั้งที่อยู่ใจกลางเมือง ราคาสบายกระเป๋าจริงๆ เหมาะสำหรับคนที่มารอต่อเครื่องหรือพักค่างชั่วคราว สะดวกทั้งเดินทาง ทั้งที่กิน ห้องน้อยไปหน่อย บางทีจองไม่ทันเต็ม
# 9.1
# ที่พักสะอาด หาของกอนง่าน เดินทางสะดวกไวไฟพร้อมคะ
# 9.1
#
# 9.1
#
# 9.3
# ห้องพักสะอาด ห้องน้ำสะอาด เดินสะดวก ใกล้อนุสาวรีย์
# 9.4
# ห้องน้ำสะอาดมาก บริการดี ที่พักสะอาด ปลอดภัย ที่นั่งเล่นดูดี เเละวิวตรงข้างนอกสวย
# 9.4
#
# 9.4
# อยากจะติ เรื่อง แผงไม้ที่ทำ มาจากไม้อะครับ มันดังเอียดอาด เวลามีคนเดิน พื้นก็จะสะเทือนแบบชัดๆ แต่ภาพรวมคือดีครับ เงียบสงบ คนไม่วุ่นวาย ห้องน้ำดี ทุกอย่างสะอาดเรียบร้อยครับ ถ้ามาอีกก็จะเลือกพักอีกครับ มีน้ำกาแฟ โอวัลติน ถ้ายจาน สบู่ แชมพู บริการ ไม่อั้นด้วย
# 9.4
# สะดวกมาก ที่พักดีใกล้ห้างเซนเตอร์วัน ใกล้บีทีเอส

# %%
for i in range(2):
    driver.execute_script("window.scrollTo(0,3600)")
    sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]')
    sel.click()
    time.sleep(2)
    clear_list(reviews_list,ratings_list)
    scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    print('---------------------------------------------------------------------------------------------','\n')
# Out:
# 9.4
# เป็นที่พักที่ดีมาก สำหรับการเป็นโฮลเทล มีความปลอดภัยสูง เพราะใช้ระบบคีการ์ดตั้งแต่หน้าประตูตึก และในลิฟต์ โฮลเทลตั้งอยู่ชั้น 10 มีระเบียงชมวิวกรุงเทพ ติดกับอนุสาวรีย์ เดินทางสะดวกมาก ห้องน้ำสะอาด พนักงานเป็นกันเอง
# 9.4
# ดีมากๆเลยค่ะ บริการเป็นกันเองมากๆ รู้สึกปลอดภัยสุดๆ ให้คำแนะนำดี แต่ว่าไปแรกๆอาจจะงงหน่อยเพราะเป็นที่พักรายวันที่อยู่บนอพาร์ทเม้นท์อีกทีค่ะ อยู่อารมณ์เหมือนห้องใต้หลังคา ภาพรวมดูดีมาก ถ้ามาแถวๆอนุสาวรีย์อีกคงพักที่เดิม (ที่กินหาง่ายมาก)
# 9.4
#
# 9.7
# ที่พักดีมากเลย สะดวกหลายอย่าง ใกล้แหล่งของกินการเดินทาง
# 9.7
# ชอบมากไว้จะไปพักใหม่สะดวกมาก ห้องน้ำสะอาด เดินทางสะดวกมาก💚
# 9.7
# ดีมากค่ะ คุ้มค่ากับราคา แอร์เย็น
# 9.7
# ห้องพักสะอาดเดินทางสะดวก ดีมากครับ
# 9.7
# ห้องดีมากๆ ส่วนกลางก็ดีมาก สะอาดน่าอยู่ ใกล้ห้างและร้านอาหาร ใกล้ bts สะดวกมาก
# 9.7
# ดีมาก ใกล้bts พักสบาย ห้องน้ำสะอาด
# 9.7
#
# ---------------------------------------------------------------------------------------------
#
# 9.7
# ที่ตั้งอยู่อนุเสาวรีย์ฝั่งเกาะพญาไท เดินทางสะดวก ที่พักใหม่และสะอาด พนักงานต้อนรับเป็นกันเอง ราคาคุ้มค่ามาก
# 9.7
# ห้องพักน่ารักมาก เป็นห้องแยกเดี่ยว มีแอร์ส่วนตัว-กระจกในห้อง ปลั๊กไฟอยู่ข้างหมอนพอดี แต่ห้องจะเล็กๆ ต้องย่อตัว ห้องน้ำสะอาด มีสบู่ แชมพู ไดร์เป่าผมให้ มีน้ำและกาแฟกับโอวันตินให้กินตลอด มีลิฟต์(อยู่ชั้น9) โซนนั่งเล่นมีหลายโซน พนักงานใจดีค่ะ
# 9.7
# ทุกอย่างสะดวกสบายมาก พนักงานเป็นกันเอง
# 9.7
# สะอาด ปลอดภัย ใกล้ BTS ห้องพักที่จองเป็นส่วนตัวมาก ห้องน้ำสะอาด ป้าแม่บ้านใจดี โดยรวมดีมาก ถ้ามีโอกาสกลับไปพักอีกแน่นอน
# 9.7
# ที่พักสะอาดมาก ทำเลที่ปลอดภัยมาก แม้จะเป็นผู้หญิงเดินทางคนเดียว เดินทางสะดวกมากจากรถไฟฟ้า ใกล้ๆ มี7-11 มีแม็คโดนัล หรือร้านอาหารที่สามารถลงมาหาอะไรกินได้ตลอดเลย
# 10
# ห้องเหมาะ เป็นสัดส่วน สำหรับพักง่ายๆ สบายๆ สะดวก อยู่หลัง Center One เลยค่ะ น้ำอาจจะมีกลิ่นแปลกๆ หน่อย แต่มุมนั่งเล่น พักผ่อนคือดีมาก ใช้ได้ทั้งคืน อาหารพร้อมทาน กาแฟ โอวันติล ถ้าสำหรับครอบครัวก็เหมาะมากๆ เราไป 2 คนกับน้อง ก็นอนสบาย แอร์เย็น ประตูจะเอี้ยดอาดนิดนึงค่ะ
# 10
# ที่พักดีมาก ชอบมาก พี่แม่บ้านกับลุงยามน่ารักมากค่ะ เจ้าของก็ใจดีมาก ชอบค่ะ คุ้มมาก
# 10
#
# 10
# พี่ๆบริการดีมากใจดี และช่วยเหลือทุกอย่างดีมาก ขอบคุณมากๆค่ะ โอกาสหน้าจะมาพักใหม่นะคะ
# 8.2
# Lobby ตามรูปครับ ด้านล่างเป็นแบบโรงแรมครับ ชั้น 10 เป็นหอพัก ห้องจะค่อนข้างลึกลับเพราะไม่มีหน้าต่างจึงมีกลิ่นไม้แรงมาก ที่เข้าห้องน้ำค่อนข้างไม่สะดวกเพราะผู้ชายและผู้หญิงใช้ห้องน้ำ 1 ห้องและอ่างอาบน้ำ
# ---------------------------------------------------------------------------------------------

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 60
# Reviews_list : 60

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   หลักๆเคเาเป็นแมนชั่น นศ. และคนทำงาน ไม่ใช่สไตล...    4.8
# 1   ไปถึงมีปัญหาห้องพัก พนักงานไม่มีผ้าขนหนูให้ ผ้...    5.1
# 2   อยากให้ระบุว่าห้องน้ำรวมเนี่ย รวมแค่หญิง รวมแค...    6.2
# 3                 ที่พักดีมากค่ะ ดูน่ารัก น่าอยู่มากๆ    8.5
# 4                                                 NaN    8.5
# 5   ทุกอย่างโอเค service ดีเป็นกันเอง สะอาดสะดวกสบ...    8.5
# 6   สะดวกมาก สะอาด แอน์เย็น แต่ป้าย โรงแรมเล็กไปนิ...    8.5
# 7   ดีมากค่ะ ที่พักสะอาดมากห้องดีมาก จัดสัดส่วนพื้...    8.5
# 8   ที่พักสะอาดห้องน้ำสะอาด พนักงานน่ารัก แม่บ้านแ...    8.5
# 9   ที่พักดีค่ะ ไม่ไกล bts เดินจาก บีทีเอสมาเข้าซอ...    8.5
# 10  โฮสเทลอยู่ชั้น10ของอพาร์ทเมนท์ เดินเข้าซอยหลัง...    8.5
# 11  ห้องพักแบบ 4 เตียง มีกุญแจลอคเกอร์ให้ แต่ไม่มี...    8.5
# 12  ก็ตามราคานะ สะอาด เราจองแวะอาบน้ำจัดกระเป๋าเดิ...    8.5
# 13   ดีมากค่ะ ไปพักบ่อยที่นี่ สะอาด มีความเป็นส่วนตัว    8.5
# 14                                                NaN    8.5
# 15  โรงแรมสะอาด พนักงานบริการดีค่ะ ชอบค่ะ ถ้าเข้าก...    8.5
# 16  สภาพดีน่ะห้องพัก แต่พนักงานไม่ค่อยอยากต้อนรับบ...    8.5
# 17    ชอบค่ะ ที่พักสะดวกสบาย สะอาด ปลอดภัย เป็นกันเอง    8.5
# 18              ห้องเป็นสัดส่วนดี ใกล้ BTS อนุสาวรีย์    8.5
# 19         ชอบมากๆเลยค่ะ ว่างๆจะกลับไปพักอีกแน่นอนค่ะ    8.5
# 20  เดินทางสะดวก ใกล้อนุสาวรีย์ชัยสมรภูมิ เสียนิดเ...    8.5
# 21  ที่พักสะอาด พี่เจ้าของดูแลดีมากค่ะ ต้องไปพักอี...    8.5
# 22                                                NaN    8.5
# 23                                                NaN    8.5
# 24  เจ้าของ และแม่บ้านน่ารักมาก อยูใกล้ center one...    8.7
# 25  วิวสวยดี ทำเลดี เดินทางสะดวก แต่เตียงชั้นสองค่...    8.7
# 26  ราคาประหยัด สะอาดดี ไม่เสียงดัง เป็นสัดเป็นส่ว...    8.8
# 27  ที่พักดี เดินทางสะดวก ใกล้bts โดยรวมคุ้มค่ากับ...    8.8
# 28              ที่พักดีมีความเป็นส่วนตัวเดินทางสะดวก    8.8
# 29                                                NaN    8.8
# 30  ที่พักสะอาดดีค่ะ เดินทางไม่ยากมาก แต่ก็แอบเดิน...    9.1
# 31  เคยพักที่นี่บ่อยค่ะ น้องที่ดูแลน่ารักมากเป็นกั...    9.1
# 32   ที่พักสะอาด หาของกอนง่าน เดินทางสะดวกไวไฟพร้อมคะ    9.1
# 33                                                NaN    9.1
# 34                                                NaN    9.1
# 35  ห้องพักสะอาด ห้องน้ำสะอาด เดินสะดวก ใกล้อนุสาว...    9.3
# 36  ห้องน้ำสะอาดมาก บริการดี ที่พักสะอาด ปลอดภัย ท...    9.4
# 37                                                NaN    9.4
# 38  อยากจะติ เรื่อง แผงไม้ที่ทำ มาจากไม้อะครับ มัน...    9.4
# 39   สะดวกมาก ที่พักดีใกล้ห้างเซนเตอร์วัน ใกล้บีทีเอส    9.4
# 40  เป็นที่พักที่ดีมาก สำหรับการเป็นโฮลเทล มีความป...    9.4
# 41  ดีมากๆเลยค่ะ บริการเป็นกันเองมากๆ รู้สึกปลอดภั...    9.4
# 42                                                NaN    9.4
# 43  ที่พักดีมากเลย สะดวกหลายอย่าง ใกล้แหล่งของกินก...    9.7
# 44  ชอบมากไว้จะไปพักใหม่สะดวกมาก ห้องน้ำสะอาด เดิน...    9.7
# 45                   ดีมากค่ะ คุ้มค่ากับราคา แอร์เย็น    9.7
# 46                 ห้องพักสะอาดเดินทางสะดวก ดีมากครับ    9.7
# 47  ห้องดีมากๆ ส่วนกลางก็ดีมาก สะอาดน่าอยู่ ใกล้ห้...    9.7
# 48                 ดีมาก ใกล้bts พักสบาย ห้องน้ำสะอาด    9.7
# 49                                                NaN    9.7
# 50  ที่ตั้งอยู่อนุเสาวรีย์ฝั่งเกาะพญาไท เดินทางสะด...    9.7
# 51  ห้องพักน่ารักมาก เป็นห้องแยกเดี่ยว มีแอร์ส่วนต...    9.7
# 52             ทุกอย่างสะดวกสบายมาก พนักงานเป็นกันเอง    9.7
# 53  สะอาด ปลอดภัย ใกล้ BTS ห้องพักที่จองเป็นส่วนตั...    9.7
# 54  ที่พักสะอาดมาก ทำเลที่ปลอดภัยมาก แม้จะเป็นผู้ห...    9.7
# 55  ห้องเหมาะ เป็นสัดส่วน สำหรับพักง่ายๆ สบายๆ สะด...     10
# 56  ที่พักดีมาก ชอบมาก พี่แม่บ้านกับลุงยามน่ารักมา...     10
# 57                                                NaN     10
# 58  พี่ๆบริการดีมากใจดี และช่วยเหลือทุกอย่างดีมาก ...     10
# 59  Lobby ตามรูปครับ ด้านล่างเป็นแบบโรงแรมครับ ชั้...    8.2

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  หลักๆเคเาเป็นแมนชั่น นศ. และคนทำงาน ไม่ใช่สไตล...    4.8
# 1       1  ไปถึงมีปัญหาห้องพัก พนักงานไม่มีผ้าขนหนูให้ ผ้...    5.1
# 2       2  อยากให้ระบุว่าห้องน้ำรวมเนี่ย รวมแค่หญิง รวมแค...    6.2
# 3       3                ที่พักดีมากค่ะ ดูน่ารัก น่าอยู่มากๆ    8.5
# 4       5  ทุกอย่างโอเค service ดีเป็นกันเอง สะอาดสะดวกสบ...    8.5
# 5       6  สะดวกมาก สะอาด แอน์เย็น แต่ป้าย โรงแรมเล็กไปนิ...    8.5
# 6       7  ดีมากค่ะ ที่พักสะอาดมากห้องดีมาก จัดสัดส่วนพื้...    8.5
# 7       8  ที่พักสะอาดห้องน้ำสะอาด พนักงานน่ารัก แม่บ้านแ...    8.5
# 8       9  ที่พักดีค่ะ ไม่ไกล bts เดินจาก บีทีเอสมาเข้าซอ...    8.5
# 9      10  โฮสเทลอยู่ชั้น10ของอพาร์ทเมนท์ เดินเข้าซอยหลัง...    8.5
# 10     11  ห้องพักแบบ 4 เตียง มีกุญแจลอคเกอร์ให้ แต่ไม่มี...    8.5
# 11     12  ก็ตามราคานะ สะอาด เราจองแวะอาบน้ำจัดกระเป๋าเดิ...    8.5
# 12     13   ดีมากค่ะ ไปพักบ่อยที่นี่ สะอาด มีความเป็นส่วนตัว    8.5
# 13     15  โรงแรมสะอาด พนักงานบริการดีค่ะ ชอบค่ะ ถ้าเข้าก...    8.5
# 14     16  สภาพดีน่ะห้องพัก แต่พนักงานไม่ค่อยอยากต้อนรับบ...    8.5
# 15     17    ชอบค่ะ ที่พักสะดวกสบาย สะอาด ปลอดภัย เป็นกันเอง    8.5
# 16     18              ห้องเป็นสัดส่วนดี ใกล้ BTS อนุสาวรีย์    8.5
# 17     19         ชอบมากๆเลยค่ะ ว่างๆจะกลับไปพักอีกแน่นอนค่ะ    8.5
# 18     20  เดินทางสะดวก ใกล้อนุสาวรีย์ชัยสมรภูมิ เสียนิดเ...    8.5
# 19     21  ที่พักสะอาด พี่เจ้าของดูแลดีมากค่ะ ต้องไปพักอี...    8.5
# 20     24  เจ้าของ และแม่บ้านน่ารักมาก อยูใกล้ center one...    8.7
# 21     25  วิวสวยดี ทำเลดี เดินทางสะดวก แต่เตียงชั้นสองค่...    8.7
# 22     26  ราคาประหยัด สะอาดดี ไม่เสียงดัง เป็นสัดเป็นส่ว...    8.8
# 23     27  ที่พักดี เดินทางสะดวก ใกล้bts โดยรวมคุ้มค่ากับ...    8.8
# 24     28              ที่พักดีมีความเป็นส่วนตัวเดินทางสะดวก    8.8
# 25     30  ที่พักสะอาดดีค่ะ เดินทางไม่ยากมาก แต่ก็แอบเดิน...    9.1
# 26     31  เคยพักที่นี่บ่อยค่ะ น้องที่ดูแลน่ารักมากเป็นกั...    9.1
# 27     32   ที่พักสะอาด หาของกอนง่าน เดินทางสะดวกไวไฟพร้อมคะ    9.1
# 28     35  ห้องพักสะอาด ห้องน้ำสะอาด เดินสะดวก ใกล้อนุสาว...    9.3
# 29     36  ห้องน้ำสะอาดมาก บริการดี ที่พักสะอาด ปลอดภัย ท...    9.4
# 30     38  อยากจะติ เรื่อง แผงไม้ที่ทำ มาจากไม้อะครับ มัน...    9.4
# 31     39   สะดวกมาก ที่พักดีใกล้ห้างเซนเตอร์วัน ใกล้บีทีเอส    9.4
# 32     40  เป็นที่พักที่ดีมาก สำหรับการเป็นโฮลเทล มีความป...    9.4
# 33     41  ดีมากๆเลยค่ะ บริการเป็นกันเองมากๆ รู้สึกปลอดภั...    9.4
# 34     43  ที่พักดีมากเลย สะดวกหลายอย่าง ใกล้แหล่งของกินก...    9.7
# 35     44  ชอบมากไว้จะไปพักใหม่สะดวกมาก ห้องน้ำสะอาด เดิน...    9.7
# 36     45                   ดีมากค่ะ คุ้มค่ากับราคา แอร์เย็น    9.7
# 37     46                 ห้องพักสะอาดเดินทางสะดวก ดีมากครับ    9.7
# 38     47  ห้องดีมากๆ ส่วนกลางก็ดีมาก สะอาดน่าอยู่ ใกล้ห้...    9.7
# 39     48                 ดีมาก ใกล้bts พักสบาย ห้องน้ำสะอาด    9.7
# 40     50  ที่ตั้งอยู่อนุเสาวรีย์ฝั่งเกาะพญาไท เดินทางสะด...    9.7
# 41     51  ห้องพักน่ารักมาก เป็นห้องแยกเดี่ยว มีแอร์ส่วนต...    9.7
# 42     52             ทุกอย่างสะดวกสบายมาก พนักงานเป็นกันเอง    9.7
# 43     53  สะอาด ปลอดภัย ใกล้ BTS ห้องพักที่จองเป็นส่วนตั...    9.7
# 44     54  ที่พักสะอาดมาก ทำเลที่ปลอดภัยมาก แม้จะเป็นผู้ห...    9.7
# 45     55  ห้องเหมาะ เป็นสัดส่วน สำหรับพักง่ายๆ สบายๆ สะด...     10
# 46     56  ที่พักดีมาก ชอบมาก พี่แม่บ้านกับลุงยามน่ารักมา...     10
# 47     58  พี่ๆบริการดีมากใจดี และช่วยเหลือทุกอย่างดีมาก ...     10
# 48     59  Lobby ตามรูปครับ ด้านล่างเป็นแบบโรงแรมครับ ชั้...    8.2

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   หลักๆเคเาเป็นแมนชั่น นศ. และคนทำงาน ไม่ใช่สไตล...    4.8
# 1   ไปถึงมีปัญหาห้องพัก พนักงานไม่มีผ้าขนหนูให้ ผ้...    5.1
# 2   อยากให้ระบุว่าห้องน้ำรวมเนี่ย รวมแค่หญิง รวมแค...    6.2
# 3                 ที่พักดีมากค่ะ ดูน่ารัก น่าอยู่มากๆ    8.5
# 4   ทุกอย่างโอเค service ดีเป็นกันเอง สะอาดสะดวกสบ...    8.5
# 5   สะดวกมาก สะอาด แอน์เย็น แต่ป้าย โรงแรมเล็กไปนิ...    8.5
# 6   ดีมากค่ะ ที่พักสะอาดมากห้องดีมาก จัดสัดส่วนพื้...    8.5
# 7   ที่พักสะอาดห้องน้ำสะอาด พนักงานน่ารัก แม่บ้านแ...    8.5
# 8   ที่พักดีค่ะ ไม่ไกล bts เดินจาก บีทีเอสมาเข้าซอ...    8.5
# 9   โฮสเทลอยู่ชั้น10ของอพาร์ทเมนท์ เดินเข้าซอยหลัง...    8.5
# 10  ห้องพักแบบ 4 เตียง มีกุญแจลอคเกอร์ให้ แต่ไม่มี...    8.5
# 11  ก็ตามราคานะ สะอาด เราจองแวะอาบน้ำจัดกระเป๋าเดิ...    8.5
# 12   ดีมากค่ะ ไปพักบ่อยที่นี่ สะอาด มีความเป็นส่วนตัว    8.5
# 13  โรงแรมสะอาด พนักงานบริการดีค่ะ ชอบค่ะ ถ้าเข้าก...    8.5
# 14  สภาพดีน่ะห้องพัก แต่พนักงานไม่ค่อยอยากต้อนรับบ...    8.5
# 15    ชอบค่ะ ที่พักสะดวกสบาย สะอาด ปลอดภัย เป็นกันเอง    8.5
# 16              ห้องเป็นสัดส่วนดี ใกล้ BTS อนุสาวรีย์    8.5
# 17         ชอบมากๆเลยค่ะ ว่างๆจะกลับไปพักอีกแน่นอนค่ะ    8.5
# 18  เดินทางสะดวก ใกล้อนุสาวรีย์ชัยสมรภูมิ เสียนิดเ...    8.5
# 19  ที่พักสะอาด พี่เจ้าของดูแลดีมากค่ะ ต้องไปพักอี...    8.5
# 20  เจ้าของ และแม่บ้านน่ารักมาก อยูใกล้ center one...    8.7
# 21  วิวสวยดี ทำเลดี เดินทางสะดวก แต่เตียงชั้นสองค่...    8.7
# 22  ราคาประหยัด สะอาดดี ไม่เสียงดัง เป็นสัดเป็นส่ว...    8.8
# 23  ที่พักดี เดินทางสะดวก ใกล้bts โดยรวมคุ้มค่ากับ...    8.8
# 24              ที่พักดีมีความเป็นส่วนตัวเดินทางสะดวก    8.8
# 25  ที่พักสะอาดดีค่ะ เดินทางไม่ยากมาก แต่ก็แอบเดิน...    9.1
# 26  เคยพักที่นี่บ่อยค่ะ น้องที่ดูแลน่ารักมากเป็นกั...    9.1
# 27   ที่พักสะอาด หาของกอนง่าน เดินทางสะดวกไวไฟพร้อมคะ    9.1
# 28  ห้องพักสะอาด ห้องน้ำสะอาด เดินสะดวก ใกล้อนุสาว...    9.3
# 29  ห้องน้ำสะอาดมาก บริการดี ที่พักสะอาด ปลอดภัย ท...    9.4
# 30  อยากจะติ เรื่อง แผงไม้ที่ทำ มาจากไม้อะครับ มัน...    9.4
# 31   สะดวกมาก ที่พักดีใกล้ห้างเซนเตอร์วัน ใกล้บีทีเอส    9.4
# 32  เป็นที่พักที่ดีมาก สำหรับการเป็นโฮลเทล มีความป...    9.4
# 33  ดีมากๆเลยค่ะ บริการเป็นกันเองมากๆ รู้สึกปลอดภั...    9.4
# 34  ที่พักดีมากเลย สะดวกหลายอย่าง ใกล้แหล่งของกินก...    9.7
# 35  ชอบมากไว้จะไปพักใหม่สะดวกมาก ห้องน้ำสะอาด เดิน...    9.7
# 36                   ดีมากค่ะ คุ้มค่ากับราคา แอร์เย็น    9.7
# 37                 ห้องพักสะอาดเดินทางสะดวก ดีมากครับ    9.7
# 38  ห้องดีมากๆ ส่วนกลางก็ดีมาก สะอาดน่าอยู่ ใกล้ห้...    9.7
# 39                 ดีมาก ใกล้bts พักสบาย ห้องน้ำสะอาด    9.7
# 40  ที่ตั้งอยู่อนุเสาวรีย์ฝั่งเกาะพญาไท เดินทางสะด...    9.7
# 41  ห้องพักน่ารักมาก เป็นห้องแยกเดี่ยว มีแอร์ส่วนต...    9.7
# 42             ทุกอย่างสะดวกสบายมาก พนักงานเป็นกันเอง    9.7
# 43  สะอาด ปลอดภัย ใกล้ BTS ห้องพักที่จองเป็นส่วนตั...    9.7
# 44  ที่พักสะอาดมาก ทำเลที่ปลอดภัยมาก แม้จะเป็นผู้ห...    9.7
# 45  ห้องเหมาะ เป็นสัดส่วน สำหรับพักง่ายๆ สบายๆ สะด...     10
# 46  ที่พักดีมาก ชอบมาก พี่แม่บ้านกับลุงยามน่ารักมา...     10
# 47  พี่ๆบริการดีมากใจดี และช่วยเหลือทุกอย่างดีมาก ...     10
# 48  Lobby ตามรูปครับ ด้านล่างเป็นแบบโรงแรมครับ ชั้...    8.2

# %%
table.to_csv("Reviews&Ratings_12th.csv", encoding="utf-8")
