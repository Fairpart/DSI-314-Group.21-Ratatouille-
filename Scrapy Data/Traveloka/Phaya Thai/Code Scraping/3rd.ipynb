# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=07-11-2022.08-11-2022.1.1.HOTEL.1000000170991.BAIYOKE%20SKY%20HOTEL.1&contexts=%7B%22inventoryRateKey%22%3A%22povEwB3ZzsU2C6pd%2B6MdU2B9D%2BXTtnp8xBPheXkh8zdM0tKsNUio4Rxug1zOzHJilcvZa8YdqqIySdppe7dolTIewZlxfjiOGz6oXLTucMvN0%2BgQ3yZPvZcoHwUFNN%2BZpcr%2F%2FNa8o9ElfN8zOYhzzZeg0X586laFpeUViPi9rxB0WbeBBruJ5NHX6N0MyaL9mhLDdV0WLeT%2FFKfQ0QL8LH02Dvlx%2F8PjYogEE5yzx6g6yOKyKeIDf7jO3GM45O1o1hmSkmz3HiZNSbS8gXb3CDW9nmlhkqLKa4lLkAkZpAGTcOmy5l4j7hGHKXWH0MtO45tYfbtBkBgYO99TxwF9DNVsBZohxEpYRFmg%2B%2BHLDKQAG%2F1rhZrd5ovib5W%2FOZIYjTE%2FGsBKQXKjBtgZDhjE4C5zlhNP3bbD3EkRDMDBFQ9BP91JaZBbzrgMh9kT8uRRLbpPqi9QWNDXrth51m8pUsXTrO7kmP1REoaFiJ8zCfvIWGULNNq2kq01LGJS4cUO6IoMhVKT4w7TwrTxbp%2FQ2iMn1qdaM1viWqCGwU1siX1ZIegdsZIo1sjlWnbsTcjefS6Pj3RtIU6lROCEB6QAgiS1WJabPNVEO7waQAXksTDyQHUY2wqyAfRzb44KOjG0poBVHSJ1fq5iJGt%2Fs2ROyG2r1yuKaZ4GSAmh5BaCjz8%3D%22%7D&prevSearchId=1748750315088280409&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]

time.sleep(3)
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div")
sel.click()
time.sleep(3)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()
time.sleep(3)
driver.execute_script("window.scrollTo(0,7770)")

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_23600\1229758597.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)
# 8.5
#
# การตอบกลับจากที่พัก
# 28 OCT 2022
# เรียน คุณตรัง
# ขอบคุณสำหรับความคิดเห็นของคุณ ดีใจที่ได้ยินจากคุณและเราหวังว่าคุณจะมีการเดินทางที่ดีกลับบ้าน เราหวังว่าคุณจะได้รับสิ่งที่ดีที่สุดและหวังว่าจะได้ให้บริการคุณอีกครั้ง
# ขอแสดงความนับถืออย่างสูง,
# ผู้อำนวยการฝ่ายบริการลูกค้าและทีม
# 8.5
# จะกลับไปพักอีกแน่นอนคะ ถ้าได้แวะไป กรุุงเทพฯ หัองพักใหญ่มาก ทำเลดี เหมาะกับการช๊อปปิ้ง และชอบการต้อนรับจากพนักงานที่ดีเยี่ยม 👍🏻
# การตอบกลับจากที่พัก
# 18 OCT 2022
# เรียน คุณThidarat,
#
# ทางโรงแรมขอขอบพระคุณที่เสียสละเวลาแบ่งปันประสบการณ์การเข้าพักที่โรงแรมใบหยกสกาย หวังเป็นอย่างยิ่งว่า จะได้มีโอกาสรับใช้ท่านอีกครั้ง
#
# ขอแสดงความนับถือ
# Customer Service Director
# 8.4
# รอเช็คอินนานมาก ไม่ประทับใจพนักงานต้อนรับผู้ชายน่าจะเป็นต่างชาติ บริการแย่มาก ผิดหวัง ส่วนพนักงานคนอื่นอื่นโอเคนะ ห้องพักกว้าง ห้องน้ำกว้างมาก ส่วนบุฟเฟ่โอเคค่ะ
# การตอบกลับจากที่พัก
# 06 SEP 2022
# เรียน คุณ Sasithorn
#
# ทางโรงแรมขอขอบพระคุณอย่างยิ่งที่สละเวลารีวิวประสบการณ์การเข้าพักที่โรงแรมใบหยกสกาย ทางทีมต้องขออภัยในความไม่สะดวกที่เกิดขึ้น และจะนำข้อติชมไปปรับปรุงพัฒนาและแก้ไขการให้บริการให้ดียิ่งขึ้น เพื่อให้ลูกค้าได้รับความสะดวกสบายในการเข้าพักกับทางโรงแรม หวังเป็นอย่างยิ่งว่า ทางโรงแรมจะมีโอกาสได้ต้อนรับคุณลูกค้าอีกครั้ง หากมีคำแนะนำติชมเพิ่มเติม สามารถแจ้งทีมได้โดยตรง
#
# ขอแสดงความนับถือ
# Customer Service Director
# 6.4
# ตอนแรกได้ห้องเก่าและเหม็น ไม่ตรงตามที่จองไว้ แต่าพนักงานเปลี่ยนห้องให้ พอรับได้ วิวสวย แต่ควรปรับปรุงห้องให้ดี จะน่าพักมากกว่านี้
# การตอบกลับจากที่พัก
# 29 AUG 2022
# เรียน คุณPimpat Reinwald,
#
# ทางโรงแรมขอขอบพระคุณอย่างยิ่งที่สละเวลารีวิวประสบการณ์การเข้าพักที่โรงแรมใบหยกสกาย ทางทีมต้องขออภัยในความไม่สะดวกที่เกิดขึ้น และจะนำข้อติชมไปปรับปรุงพัฒนาและแก้ไขการให้บริการให้ดียิ่งขึ้น เพื่อให้ลูกค้าได้รับความสะดวกสบายในการเข้าพักกับทางโรงแรม หวังเป็นอย่างยิ่งว่า ทางโรงแรมจะมีโอกาสได้ต้อนรับคุณลูกค้าอีกครั้ง หากมีคำแนะนำติชมเพิ่มเติม สามารถแจ้งทีมได้โดยตรง
# ขอแสดงความนับถือ
# Customer Service Director
# 8.5
# ห้องใหญ่กว้างมาก แบ่งเป็นโชนดีมาก
# การตอบกลับจากที่พัก
# 08 AUG 2022
# เรียน คุณ Malina
#
# ขอบพระคุณที่ได้มอบโอกาสให้โรงแรมใบหยกสกายต้อนรับและดูแล
# หวังเป็นอย่างยิ่งว่าเราจะได้มีโอกาสต้อนรับท่านอีกนะคะ
#
# ด้วยความเคารพ
# Customer Service Director and team
# 8.5
# ห้องสวย สะอาด ราคาไม่แพง วิวสวยรอบด้านค่ะ
# การตอบกลับจากที่พัก
# 20 MAY 2022
# เรียน คุณ Natcha
#
# ขอบพระคุณมากนะคะที่ได้มอบโอกาสให้โรงแรมใบหยกสกายต้อนรับและดูแล
# หวังเป็นอย่างยิ่งว่าเราจะได้มีโอกาสต้อนรับท่านอีกนะคะ
#
# Good health & stay safe นะคะ
# Customer Service Director and team
# 8.8
# ห้องสะอาดมาก ห้องใหญ่กว้างมาก ชอบๆ
# การตอบกลับจากที่พัก
# 28 APR 2022
# เรียน คุณ Jumpol
#
# ขอบพระคุณมากนะคะที่ได้มอบโอกาสให้โรงแรมใบหยกสกายต้อนรับและดูแล
# หวังเป็นอย่างยิ่งว่าเราจะได้มีโอกาสต้อนรับท่านอีกนะคะ
#
# Good health& stay safe นะคะ
# Customer Service Director and team
# 10
# ดีมากๆ ชอบค่ะ มีโอกาสจะไปอีกครั้งคุ้มราคา
# การตอบกลับจากที่พัก
# 28 APR 2022
# เรียนคุณ Bow
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการแสดงความคิดเห็นของคุณลูกค้า และหวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าคุณลูกค้าจะกลับเข้ามาใช้บริการโรงแรมใบหยกสกายอีกในครั้งต่อไป
#
# ขอบพระคุณค่ะ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 8.5
# ห้องพักสะอาด ราคาไม่แพง อาหารใช้ได้
# 10
# พนักงานบริการดี พูดจาสุภาพ ห้องกว้าง สะอาด

# %%
driver.title
# Out:
# 'ค่าห้องพัก BAIYOKE SKY HOTEL ประตูน้ำ ตั้งแต่ 07-11-2022 ถึง 08-11-2022'

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
sel.click()

# %%
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 10
# พนักงานบริการดีมากๆ ทุกอย่างดีมากๆ ต้องกลับมาพักอีกหลายๆ ครั้ง
# 5.7
# พนักงานต้อนรับที่ทำการ check in อยู่หน้าเคาน์เตอร์ควรจะยิ้มบ้าง งานบริการ
# 8.5
# ห้องดี วิวสวย ใกล้ที่ช้อป พนักงานบริการดี พูดจาไพเราะ ☺️👍🏼
# 8.5
#
# 9.7
# ห้องนี้เหมือนรูปที่จองไว้ สะอาด จะกลับมาใช้บริการอีกในไม่ช้า ราคาก็ประทับใจค่ะ
# 9.1
# ดีมากค่ะ พนักงานบริการดี ห้องพักกว้างขวาง
# 8.5
# พนักงานสุภาพเรียบร้อยให้บริการเป็นอย่างดี
# การตอบกลับจากที่พัก
# 25 APR 2021
# เรียนคุณ PARINYA,
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการแสดงความคิดเห็นของคุณลูกค้า และทางเรามีความยินดีที่ได้อำนวยความสะดวกสบายแก่คุณลูกค้าในการเข้ามาใช้บริการโรงแรมของเรา
# หวังเป็นอย่างยิ่งว่าจะได้ต้อนรับคุณลูกค้าอีกในครั้งต่อๆ ไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 9.7
#
# การตอบกลับจากที่พัก
# 20 APR 2021
# เรียนคุณ Apinya,
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการให้คะแนนของคุณลูกค้า ทางเราหวังเป็นอย่างยิ่งว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี และจะได้มีโอกาสต้อนรับคุณลูกค้าอีกในครั้งต่อๆไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 8.5
#
# การตอบกลับจากที่พัก
# 19 APR 2021
# เรียน คุณ Kanong,
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการให้คะแนนสำหรับการมาใช้บริการ
# ทางเราหวังเป็นอย่างยิ่งว่าจะได้มีโอกาสต้อนรับคุณลูกค้าอีกในครั้งต่อๆ ไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 9.1
# แต่ห้องน้ำเหม็น ได้ห้องมุม ติดห้องแม่บ้านทำความสะอาด
# การตอบกลับจากที่พัก
# 19 APR 2021
# เรียนคุณ Matarin,
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการแสดงความคิดเห็นของคุณลูกค้า และต้องขออภัยในความไม่สะดวกที่คุณลูกค้าได้รับในการใช้บริการครั้งนี้
# หวังว่าคุณลูกค้าจะกลับมาใช้บริการโรงแรมใบหยกสกายอีกในครั้งต่อไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
#
# การตอบกลับจากที่พัก
# 19 APR 2021
# เรียน คุณ Nattakun,
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการให้คะแนนสำหรับการมาใช้บริการ หวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าจะได้มีโอกาสต้อนรับคุณลูกค้าอีกในครั้งต่อๆ ไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 8.5
#
# การตอบกลับจากที่พัก
# 05 APR 2021
# เรียนคุณ RITTICHAI,
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการแสดงความคิดเห็นของคุณลูกค้า และหวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าจะได้ต้อนรับคุณลูกค้าอีกในครั้งต่อไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 8.5
#
# การตอบกลับจากที่พัก
# 05 APR 2021
# เรียนคุณ AKOM,
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการแสดงความคิดเห็นของคุณลูกค้า และหวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าคุณลูกค้าจะกลับเข้ามาใช้บริการโรงแรมใบหยกสกายอีกในครั้งต่อไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 10
#
# การตอบกลับจากที่พัก
# 28 MAR 2021
# เรียน คุณ Parkhin
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการให้คะแนนเต็ม 10 สำหรับการมาใช้บริการโรงแรมใบหยกสกาย หวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าจะได้มีโอกาสต้อนรับคุณลูกค้าอีกในครั้งต่อๆ ไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 8.5
# ดีจริง เทรนพนักงานมาดีมากครับ โดยรวมชอบครับ
# การตอบกลับจากที่พัก
# 16 MAR 2021
# เรียนคุณ Wutthipat
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการแสดงความคิดเห็นของคุณลูกค้า และหวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าจะได้ต้อนรับคุณลูกค้าอีกในครั้งต่อๆ ไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 8.5
# ห้องพักกว้างที่นอนหลับสบายไม่ปวดหลังอาหารเช้ามีให้เลือกเยอะดี
# การตอบกลับจากที่พัก
# 12 MAR 2021
# เรียนคุณ Supawadee
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการให้คะแนนและแสดงความคิดเห็นของคุณลูกค้า หวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าจะได้ต้อนรับคุณลูกค้าอีกในครั้งต่อๆไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 10
#
# การตอบกลับจากที่พัก
# 12 MAR 2021
# เรียนคุณ Phanwarod
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการให้คะแนนเต็ม 10 สำหรับการมาใช้บริการโรงแรมใบหยกสกายของคุณลูกค้า หวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี ทางเราหวังเป็นอย่างยิ่งว่าจะได้ต้อนรับคุณลูกค้าอีกในครั้งต่อๆ ไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 9.1
# มันโอเคมากเลยอ่ะ ดูแลเทคแคร์ดี
# การตอบกลับจากที่พัก
# 04 MAR 2021
# เรียนคุณ Phakkhaon Janbunrueang
#
# ในนามของพนักงานโรงแรมใบหยกสกายทุกแผนก ขอขอบพระคุณอย่างยิ่งสำหรับการแสดงความคิดเห็นของคุณลูกค้า และหวังว่าช่วงที่คุณลูกค้าเข้ามาใช้บริการจะได้รับการอำนวยความสะดวกสบายเป็นอย่างดี
# ทางเราหวังเป็นอย่างยิ่งว่าคุณลูกค้าจะกลับเข้ามาใช้บริการโรงแรมใบหยกสกายอีกในครั้งต่อไป
#
# ขอบคุณครับ
# เจ้าหน้าที่ลูกค้าสัมพันธ์ แผนกต้อนรับส่วนหน้า
# โรงแรมใบหยกสกาย
# 8.5
# ดีมากค่ะ. ราคาไม่แพง บริการดีงาม
# 8.5
# การบริการดีมาก ห้องพักก็โอเค วิวสวย

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
#
# 8.5
# ชอบมากห้องสะอาดเสียงเงียบดี ไว้มาพักอีกเเน่นอน
# 8.5
#
# 8.5
# ดีมาก คุ้มค่ามาก พนักงานบริการดีมากๆ ห้องพักสะอาด สิ่งอำนวยความสะดวกครบ
# 8.5
#
# 10
#
# 9.1
#
# 8.5
# ดีคะ เสียอย่างเดียวห้องพักมีกลิ่นบุหรี่
# การตอบกลับจากที่พัก
# 08 MAR 2020
# เรียนคุณ Bangonn,
# ทางโรงแรมใบหยกสกายต้องขอภัยสำหรับความไม่สะดวกในการเข้าพักของคุณลูกค้าเป็นอย่างยิ่ง เนื่องจากมีแขกผู้เข้าพักลักลอบสูบบุหรี่ภายในห้องพัก จึงทำให้เกิดกลิ่นไม่พึงประสงค์ ทั้งนี้ ทางโรงแรมใบหยกสกายกำลังปรับปรุงนโยบายจำกัดห้องพักและสถานที่ที่สามารถสูบบุหรี่ได้ เพื่อไม่ให้เกิดเหตุการณ์ลักษณะดังกล่าวขึ้นอีกครั้ง ขอขอบคุณสำหรับการให้คะแนนของคุณลูกค้า และหวังเป็นอย่างยิ่งว่าคุณลูกค้าจะกลับมาใช้บริการโรงแรมของเราอีกครั้ง
# ด้วยความเคารพ,
# ฝ่ายลูกค้าสัมพันธ์ โรงแรมใบหยกสกาย
# 8.8
#
# 8.5

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.1
# ประทับใจในบริการ ไปพักมาสองครั้งแล้วคุณพ่อชอบบุฟเฟต์ซีฟู้ดนาๆชาติค่ะ 👍🏻
# 9.7
#
# 8.5
#
# 9.7
#
# 8.5
#
# 10
#
# 10
#
# 6
# ห้องที่จองไว้ เวลาไปพักได้ห้องแบบอื่น เจ้าหน้าที่แจ้งว่าห้องพักเต็ม ทั้งที่จองไว้ล่วงหน้า งง! เลย
# 8.5
# วิวสวย เงียบดี หลับสนิท ห้องพักกว้างมาก อาหารเช้าชั้น81 มีบริการเยอะ หลากหลาย พนักงานแนะนำดี ลืมของไว้ทางโรงแรมช่วยเหลือตามหาให้และจัดส่งมาให้ถึงบ้านเรียบร้อย
# 9.7
# วิวสวยมาก พนักงานบริการดีมากค่ะ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.4
# ห้อง ok แต่การเดินทางไม่ค่อยสะดวก
# 6
#
# 9.7
# ห้องพักสะอาด บริการดี อาหารอร่อย ใกล้แหล่งช็อปปิ้ง
# 8.8
#
# 8.5
# รอเช็คอินใช้เวลานาน มีมัดจำห้องละ 3,000 บาท แพงมาก ไม่เคยเจอ ว่าต้องจ่าย มัดจำมากขนาดนี้ คนรอใช้ลิฟท์เยอะ ห้องพักสะอาดน้ำไหลแรง อาหารเช้ามีให้เลือกหลากหลายรสชาติอร่อย
# 9.7
#
# 10
#
# 9.1
# พนักงานให้บริการดีมากคะ ห้องพักสะอาด
# 9.1
#
# 10
# ไปพักคนเดียวแต่พนักงานอัพเกรดห้องเป็นห้อง Family ให้จากที่จ่ายพันกว่าบาท ได้ห้องเกือบห้าพัน คุ้มมากๆครับ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.1
#
# 10
#
# 8.8
#
# 9.1
# ห้องเก่า แต่สะอาด เตียงนอนสบาย วิวสวย อาหารเช้าใช้ได้
# 9.7
# ได้อัฟเกรดห้อง เพราะห้องที่จองเหม็นบุหรี่มาก ห้องใหญ่มาก สะอาด เตียงนอนสบาย วิวสวย แต่ห้องเก่า พรมเก่า อาหารเช้าหลากหลาย ไก่ตุ๋นอร่อย ได้ขึ้นชมวิวฟรีทั้งเย็นและเช้า
# 6.9
# จองห้องปลอดบุหรี่ไป แต่ห้องพักมีกลิ่นบุหรี่คลุ้งทั้งห้อง พนักงานฉีดสเปรย์ดับกลิ่นก็ยังไม่สามารถดับกลิ่นบุหรีในห้องได้เลย
# 6.2
# ห้องพักถือว่าโอเคเลย แต่วุ่นวายมาก มีแต่ทัวร์ ไม่ว่าจะทางขึ้นโรงแรม ลิฟต์ ดูวุ่นวายไปหมด เสียงดัง ความเป็นระเบียบไม่มี
# 8.5
# รร ห้องกว้าง. วิวดี. เตียงนอนสบาย แม้ไม่หรูหรา แต่ก็นอนหลับสบาย แขกสามารถ ขึ้นไปชมวิวบนชั้น80 กว่าๆ ได้ วิวดีมาก สามารถเดินมาขึ้น รถเมล์ที่วื่งไปสนามบินดอนเมืองได้ที่ป้ายหน้ารร อินทรา ถ้ามาจากดอนเมือง ก็นั่ง A3 มาลงแถวๆ หน้า รร ได้ สะดวกมาก ข้อเสีย สระว่ายน้ำเล็กและ ไม่สวย สรุป ถือว่าดีเลย
# 9.7
#
# 10
# ดีมากเลยค่ะ สะดวกสบาย พนักงานบริการดี

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# พนง.บริการดีมาก ห้องสะอาด แต่ที่ปรับอุณหภูมิของตู้เย็นเสีย ทำให้ตู้เย็นอุ่น ห้อง4801 แจ้งฟร้อนไปแล้ว ทำเลสะดวกมากค่ะ
# 9.4
#
# 10
# พนักงานบริการดีมากค่ะ ยิ้มแย้มทักทายตลอดเวลาที่เดินผ่าน อาหารเช้ารสชาติดีมีให้เลือกหลากหลาย ห้องพักสะอาด กว้างใหญ่ วิวสวย
# 9.1
#
# 9.7
# ห้องกว้างมาก สะอาด วิวสวย อาหารเช้าก็ดีมาก
# 10
#
# 8.5
# ห้องพักดีวิวเมืองสวย ห้องพักสะอาด ได้รับบริการที่ดีจากพนักงาน
# 8.5
#
# 8.5
# ห้องพักสบาย เช็คอินรวดเร็ว ใกล้รถไฟฟ้า มีตลาดนัด และห้างเดินได้ทั้งวัน อาหารเช้าเยอะมาก รสชาติอร่อยดี ห้องน้ำกว้างขวาง สะอาด พนักงานต้อนรับดี ขึ้นไปดาดฟ้าถ่ายรูปได้วิวสูง แต่ตอนนี้เขาทำหลังคาปิดด้านบนไว้ น่าจะเพราะที่เป็นข่าวมีคนปีนขึ้นไปบนยอด โดยรวมโอเค เหมาะสายช้อปปิ้ง
# 8.7
# ดีทุกอย่างยกเว้นทีวี อินเดียเยอะมากเหม็นมาก พนักงานดีพูดได้หลายภาษา

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
#
# 8.5
# พนักงานต้อนรับดี อาหารเยอะมากคะ
# 8.5
# ห้องพักกว้างมาก แบ่งโซนเป็นสัดส่วนดี วิวดี
# 10
#
# 9.1
# โรงแรมใจกลางเมือง เป็นโรงแรมที่อยู่ใจกลางเมืองรอบข้างจะมีบริเวณแขกมากมายแต่ก็ไม่ได้ทำให้เสียอารมณ์หรือบรรยากาศใดใดเพราะว่าโรงแรมมีไซด์ที่ที่ดีมากๆ ส่วนห้องพักค่อนข้างจะเก่า การบริการพนักงานดีมากๆเพราะว่าคุ้มค่ากับราคาที่จ่ายไปได้ถูกอัพเกรดเป็นห้องเดี๋ยวรถรูมทำให้ประทับใจมากแล้วก็ได้ขึ้นอยู่ไปชมวิวชั้นบนสุดส่งกรุงเทพยามค่ำคืนกลับบุฟเฟ่ก็ค่อนข้างจะคุมแล้ว
# 9.7
#
# 8.5
# ห้องพักโอเค ตามอายุโรงแรมแต่ก็ถือว่าสะอาด กลิ่นท่อแรงไปค่ะ นี่จองห้องซูพเรียสวีท ได้ชั้น31 สัญญานอินเตอร์เนตแย่มาก ทีวีเคเบิ้ลกระตุกบ่อย โรงแรม4ดาวควรจะปรับปรุงมากกว่สนี้ค่ะ แต่เจ้าหน้าทุกคนต้อนรับน่ารักมากค่ะ
# 8.5
#
# 9.7
# ห้องพักกว้างดีค่ะ วิวสวย ขึ้นไปชมวิวได้ฟรี พนง.บริการดีมากค่ะ ที่สำคัญฝากกระเป๋าได้ด้วย😊
# 9.7

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
#
# 9.4
#
# 8.5
#
# 8.8
#
# 8.4
# ห้องพักกว้างดี หมอนนุ่ม เตียงนุ่ม แต่ชาวต่างชาติเยอะมาก โรงแรมมีครบหมด วิวสวย
# 8.5
#
# 6.3
# ร้องขอเช็คอินตอนเที่ยง เพราะบินมาถึงเช้า แต่ก็ต้องมานั่งรออยู่ดี เพราะคำร้องขอไม่เป็นผล รอจนบ่าย2 ทั้งเหนื่อย ทั้งง่วงจ้า
# 8.5
#
# 10
# ดีมากคะ เตียงนุ่มหลับสบาย อาหารหลากหลาย ดีมากๆคะ
# 7
# พนักงานน่ารักมาก ดูแลดีมากค่ะ ช่วยเหลือตลอด บริการดีมาก ๆ ห้องพักดีไซน์ดีค่ะ ห้องน้ำกว้างดีมาก แอร์เย็นค่ะ วิวสวย แต่ทัวร์จีนลงเยอะไปหน่อยค่ะ โดยสรุปโรงแรมบรรยากาศดีค่ะ แต่ที่เรตไม่ดีเพราะ ทะเลาะกับแฟนแล้วรู้สึกแย่มากถึงมากที่สุดค่ะ เลยต้องลงมานั่งข้างล่างค่ะ บรรยากาศพังมากค่ะ แต่สถานที่และบริการโดยรวมดีมากค่ะ

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
#
# 10
#
# 10
#
# 10
#
# 8.5
#
# 9.7
# ประทับใจมากค่ะ ห้องพักกว้าง วิวสวยดีค่ะ จะมาพักอีกแน่นอนและจะแนะนำเพื่อนมาพักที่นี่ค่ะ
# 10
#
# 8.5
#
# 8.5
# ห้องพักกว้างดีค่ะ บรรยากาศดีเริ่ด และจะกลับมาพักอีกแน่นอนค่ะ
# 8.5

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# ห้องสวย สะอาด น่าอยู่ หลับสนิทตลอดคืน แถมวิวสวยมากๆเลยค่ะ สะดวกสบาย😊 ถ้ามีโอกาสจะกลับไปพักอีกครั้งคะ
# 8.5
#
# 8.5
#
# 8.5
#
# 8.5
#
# 8.8
# บรรยากาศดี ห้องพักสะอาด อาหารเช้าเยอะมาก เอาไปเลย 10 เต็ม ข้อเสีย นักท่องเที่ยวเยอะมาก เยอะจริงๆ
# 9.4
#
# 8.5
# มาพักกับแฟนครั้งที่ 3 แล้วประทับใจทุกครั้ง
# 10
#
# 9.7

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
#
# 8.5
# คิดว่าปานกลางค่ะ มีคนเยอะแต่ห้องเหม็นอับไปหน่อยคะ และค่ามัดจำสูงไปคะ 3000บาท
# 9.7
#
# 8.5
# อยากให้ทำที่จอดรถดีกว่านี้ ที่จอดรถดูเปลี่ยวเกินไป ดูน่ากลัว แต่ส่วนที่เหลือดีหมดทุกอย่างครับ
# 8.5
# ดีทุกอย่างยกเว้นรีเชฟชั่น เชคอินชื่อไม่ตรงกับบัตรมีปัณหานะคร้า ก็ไม่เข้าใจเราจองผ่านappแน่นอนอยุ่แล้วที่เราต้องใส่ชื่อเล่น หรือจะเถียง นางบอกผิดกฏคะไม่สามารถเชคอิน เราก็เถียงเรามีเอกสารทุกอย่างแต่ชื่อbook ไม่ตรงบัตรประชาชนแค่นั้น นี่จองตั่วไปตปท. รร.ที่ตปท.ไม่เคยมีปัณหาคะใช้มาหลายปีแล้ว งงมาก นางบอกให้เช้คอินแต่ต้องอีเมลไปเปลี่ยนชื่อ เราไม่คะ เปลี่ยนเพื่อ?
# 10
#
# 8.5
#
# 9.7
#
# 9.1
#
# 9.1

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 10
#
# 10
#
# 9.7
#
# 8.8
# Front desk เป็นกันเองน่ารัก ห้องไม่เก่าค่ะ
# 9.7
#
# 10
#
# 9.4
# สะดวก ปลอดภัย เดินทางง่าย ใกล้รถไฟฟ้าราชปรารภ
# 9.7
# พนักงานห้องอาหารบริการดีมากๆ แต่หน้าฟร้อนท์ไม่ค่อยประทับใจเท่าไหร่
# 10
# พนักงานต้อนรับดีมากๆๆค่ะ. โรงแรมสวย วิวดี และสะอาดมาก. อาหารเช้าหลากหลายดีค่ะ โดยรวม ดีมาก
# 9.4

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
#
# 10
#
# 8.5
#
# 8.4
#
# 8.8
#
# 9.4
#
# 9.7
#
# 8.5
#
# 9.4
#
# 9.1

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
# ห้องพักใหญ่ สะอาด วิวชนะเลิศ พนักงานบริการดีมาก แต่เป็นโรงแรมที่ต่างชาติเยอะมาก อาหารรสชาติกลาง ๆ และไม่เพียงพอ กว่าจะเติมอาหารรอนาน ยิ่งเป็นอาหารเช้าไม่คุ้มค่า เวลาเช็คเอาท์เร็วไป 11.00 น.
# 8.5
# ห้องกว้างสบายค่ะ แอบเหม็นอับนิดนึง อย่างอื่นหรูดูดีค่ะ
# 8.8
#
# 8.5
#
# 10
#
# 9.7
# บรรยากาศดีมาก อาหารเช้า ห้ามพลาด เยอะสุดๆ วิวสวยขาดใจ คุ้มต่าทุกบาททุกสตางค์ แนะนำเลยครับ มีค่ามัดจำ 3,000 บาทด้วยนะครับ
# 8.5
# ห้องพักกว้าง วิวสวย อาหารอร่อย
# 8.5
# ประทับใจมากคะ คุณแม่มีความสุขมาก ❤️
# 5.7
# กรณีที่เราลืมของพนักงานไม่ช่วยอะไรเลย และการขึ้นที่พักก็ลำบากต้องมาแย่งลีฟกับพวกลูกทัวร์ การจัดการเรื่องความสะดวกให้ลูกค้ายังไม่เพียงพอกับโรงแรมระดับ4ดาว
# 9.7

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
time.sleep(4)
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.8
#
# 9.7
#
# 9.7
#
# 8.5
#
# 9.4
# โอเคนะคะ ห้องดี อุปกรณ์ในห้องน้ำครบสะดวกสบาย แต่ห้องอาบน้ำระบายน้ำช้าทำให้ไหลออกมาข้างนอก พื้นเปียกค่อนข้างเยอะ ควรแก้ไขเพราะอาจจะลื่นล้มได้ ห้องนอนเตียงนอนสบาย มีพื้นที่แยกเป็นสัดส่วนนั่งทำงาน กินข้าวแยกกันดีค่ะ อาหารเช้าของเยอะดี รสชาติโอเค สรุปคือดีเลยค่ะ
# 6.2
#
# 8.5
# ห้องนึ้ดูสะอาด แต่ค่อนข้างเก่าคะ ห้องน้ำกว้างมาก มีอ่างและฝักบัว ผนังไม่กั้นเสียงตรงทางเดิน เวลามีเด็กวิ่งเล่นกันตอนกลางคืนจะเสียงดังคะ อาหารเช้าพอใช้ เน้นวิวเมืองมากกว่าคะ
# 8.7
# ดี แต่คนเยอะ ทัวร์เยอะ ลิฟต์เยอะ งง ไปหมด โดยรวมโอเค
# 6
# เรียกเก็บค่ามัดจำห้อง มากกว่าราคาค่าห้องพัก
# 8.5
# พนักงานบริการดีค่ะ ตั้งแต่กดลิฟท์จนถึงบริเวณเค้าท์เตอร์ ห้องพักเหมือนในรูปไม่มีกลิ่นอับ ห้องกว้างสบายมากค่ะ เพียงแต่ได้มุมห้องที่วิวไม่สวยเท่าไหร่ โดยรวมแล้วประทับใจค่ะ

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 190
# Reviews_list : 190

# %%
Ratings_list
# Out:
# ['8.5',
#  '8.5',
#  '8.4',
#  '6.4',
#  '8.5',
#  '8.5',
#  '8.8',
#  '10',
#  '8.5',
#  '10',
#  '10',
#  '5.7',
#  '8.5',
#  '8.5',
#  '9.7',
#  '9.1',
#  '8.5',
#  '9.7',
#  '8.5',
#  '9.1',
#  '8.5',
#  '8.5',
#  '8.5',
#  '10',
#  '8.5',
#  '8.5',
#  '10',
#  '9.1',
#  '8.5',
#  '8.5',
#  '6',
#  '8.2',
#  '8.5',
#  '9.7',
#  '8.5',
#  '8.5',
#  '6',
#  '6.1',
#  '8.5',
#  '9.7',
#  '9.7',
#  '8.5',
#  '10',
#  '9.7',
#  '9.7',
#  '9.7',
#  '9.7',
#  '8.5',
#  '10',
#  '8.5',
#  '9.7',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '10',
#  '9.1',
#  '8.5',
#  '8.8',
#  '8.5',
#  '9.1',
#  '9.7',
#  '8.5',
#  '9.7',
#  '8.5',
#  '10',
#  '10',
#  '6',
#  '8.5',
#  '9.7',
#  '8.4',
#  '6',
#  '9.7',
#  '8.8',
#  '8.5',
#  '9.7',
#  '10',
#  '9.1',
#  '9.1',
#  '10',
#  '9.1',
#  '10',
#  '8.8',
#  '9.1',
#  '9.7',
#  '6.9',
#  '6.2',
#  '8.5',
#  '9.7',
#  '10',
#  '8.5',
#  '9.4',
#  '10',
#  '9.1',
#  '9.7',
#  '10',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.7',
#  '8.8',
#  '8.5',
#  '8.5',
#  '10',
#  '9.1',
#  '9.7',
#  '8.5',
#  '8.5',
#  '9.7',
#  '9.7',
#  '8.8',
#  '9.4',
#  '8.5',
#  '8.8',
#  '8.4',
#  '8.5',
#  '6.3',
#  '8.5',
#  '10',
#  '7',
#  '9.7',
#  '10',
#  '10',
#  '10',
#  '8.5',
#  '9.7',
#  '10',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.5',
#  '8.8',
#  '9.4',
#  '8.5',
#  '10',
#  '9.7',
#  '8.5',
#  '8.5',
#  '9.7',
#  '8.5',
#  '8.5',
#  '10',
#  '8.5',
#  '9.7',
#  '9.1',
#  '9.1',
#  '10',
#  '10',
#  '9.7',
#  '8.8',
#  '9.7',
#  '10',
#  '9.4',
#  '9.7',
#  '10',
#  '9.4',
#  '9.7',
#  '10',
#  '8.5',
#  '8.4',
#  '8.8',
#  '9.4',
#  '9.7',
#  '8.5',
#  '9.4',
#  '9.1',
#  '8.8',
#  '8.5',
#  '8.8',
#  '8.5',
#  '10',
#  '9.7',
#  '8.5',
#  '8.5',
#  '5.7',
#  '9.7',
#  '8.8',
#  '9.7',
#  '9.7',
#  '8.5',
#  '9.4',
#  '6.2',
#  '8.5',
#  '8.7',
#  '6',
#  '8.5']

# %%
Reviews_list
# Out:
# ['',
#  'จะกลับไปพักอีกแน่นอนคะ ถ้าได้แวะไป กรุุงเทพฯ หัองพักใหญ่มาก ทำเลดี เหมาะกับการช๊อปปิ้ง และชอบการต้อนรับจากพนักงานที่ดีเยี่ยม 👍🏻',
#  'รอเช็คอินนานมาก ไม่ประทับใจพนักงานต้อนรับผู้ชายน่าจะเป็นต่างชาติ บริการแย่มาก ผิดหวัง ส่วนพนักงานคนอื่นอื่นโอเคนะ ห้องพักกว้าง ห้องน้ำกว้างมาก ส่วนบุฟเฟ่โอเคค่ะ',
#  'ตอนแรกได้ห้องเก่าและเหม็น ไม่ตรงตามที่จองไว้ แต่าพนักงานเปลี่ยนห้องให้ พอรับได้ วิวสวย แต่ควรปรับปรุงห้องให้ดี จะน่าพักมากกว่านี้',
#  'ห้องใหญ่กว้างมาก แบ่งเป็นโชนดีมาก',
#  'ห้องสวย สะอาด ราคาไม่แพง วิวสวยรอบด้านค่ะ',
#  'ห้องสะอาดมาก ห้องใหญ่กว้างมาก ชอบๆ',
#  'ดีมากๆ ชอบค่ะ มีโอกาสจะไปอีกครั้งคุ้มราคา',
#  'ห้องพักสะอาด ราคาไม่แพง อาหารใช้ได้',
#  'พนักงานบริการดี พูดจาสุภาพ ห้องกว้าง สะอาด',
#  'พนักงานบริการดีมากๆ ทุกอย่างดีมากๆ ต้องกลับมาพักอีกหลายๆ ครั้ง',
#  'พนักงานต้อนรับที่ทำการ check in อยู่หน้าเคาน์เตอร์ควรจะยิ้มบ้าง งานบริการ',
#  'ห้องดี วิวสวย ใกล้ที่ช้อป พนักงานบริการดี พูดจาไพเราะ ☺️👍🏼',
#  '',
#  'ห้องนี้เหมือนรูปที่จองไว้ สะอาด จะกลับมาใช้บริการอีกในไม่ช้า ราคาก็ประทับใจค่ะ',
#  'ดีมากค่ะ พนักงานบริการดี ห้องพักกว้างขวาง',
#  'พนักงานสุภาพเรียบร้อยให้บริการเป็นอย่างดี',
#  '',
#  '',
#  'แต่ห้องน้ำเหม็น ได้ห้องมุม ติดห้องแม่บ้านทำความสะอาด',
#  '',
#  '',
#  '',
#  '',
#  'ดีจริง เทรนพนักงานมาดีมากครับ โดยรวมชอบครับ',
#  'ห้องพักกว้างที่นอนหลับสบายไม่ปวดหลังอาหารเช้ามีให้เลือกเยอะดี',
#  '',
#  'มันโอเคมากเลยอ่ะ ดูแลเทคแคร์ดี',
#  'ดีมากค่ะ. ราคาไม่แพง บริการดีงาม',
#  'การบริการดีมาก ห้องพักก็โอเค วิวสวย',
#  '',
#  'ห้องสะอาด ที่นอนอุ่นดี นุ่มนวล บริการดีมาก',
#  '',
#  'พนักงานบริการดีมาก วิวสวย อยู่ในย่านการค้า ชอบครับ',
#  'สวยมากครับ พนักงานดูแลดี ตลอดเส้นทางครับ ชอบๆ',
#  '',
#  'ห้องพักเก่าไปหน่อยครับ ทำให้ใีกลิ่นอับ เหมือนไม่สะอาด',
#  'โรงแรมค่อนข้างเก่านิดนึง แอร์เย็นช้า ม่านเก็บแสงไม่มิดตอนเช้า',
#  '',
#  '',
#  '',
#  'บริการดี ทุกอย่าง สามารถเรียกได้ตลอด24ชม.',
#  'ประทับใจตั้งแต่เดินลงจากรถเลยค่ะ ทุกคนบริการดีมาก โรงแรมสวย ห้องสวย วิวคือที่สุด บุฟเฟ่ต์ก็อร่อย',
#  'พนักงานบริการดีมาก ห้องกว้างและสะอาด',
#  'พนักงานบริการดีมาก ห้องนอนดีบรรยากาศดีมาก',
#  'เป๊ะ! ทุกรายละเอียดการออกแบบ ยิ่งนานยิ่งแตกต่าง อบอุ่น หนักแน่นคงทน สวยงามจนน่าอัศจรรย์ใจ ชอบที่นี่จังค่ะ',
#  'พนักงานตอนรับดีมากตั้งแต่หน้าโรงแรมถึงล็อบบี้ค่ะ ห้องดีวิวเริ่ดมากแม่',
#  '',
#  'ห้องพักดี คุ้มราคา พนักงานอัพเกรดเวลคัมดริ้งให้ไปชั้น 83 คือดีมากก จุดชมวิวชั้น 84 ก็คือดี เสียดายเวลาน้อยไป เลยไม่ได้ทานอาหารเช้า พนักงานคือบริการดีมาก ทุกจุดค่ะ ประทับใจ ไว้จะไปพักอีกค่ะ',
#  'ห้องนอนห้องน้ำกว้าง เตียงหมอนนุ่มหลับสบาย อาหารเช้าเยอะ บุฟเฟต์ซีฟู้ดชั้น 77,78 อาหารให้เลือกกินเยอะ อาหารทะเลสด แม้ตัวจะเล็ก แต่กินไม่อั้น กินจนอิ่ม ยังไงก็คุ้มกับราคา แถมได้ชมวิวเมืองสวยอีก พนักงานบริการดีมากครับ เสริฟอาหารให้ถึงโต๊ะเลย จะกลับไป BAIYOKE SKY อีกครับ',
#  '',
#  'ชอบมากห้องสะอาดเสียงเงียบดี ไว้มาพักอีกเเน่นอน',
#  '',
#  'ดีมาก คุ้มค่ามาก พนักงานบริการดีมากๆ ห้องพักสะอาด สิ่งอำนวยความสะดวกครบ',
#  '',
#  '',
#  '',
#  'ดีคะ เสียอย่างเดียวห้องพักมีกลิ่นบุหรี่',
#  '',
#  '',
#  'ประทับใจในบริการ ไปพักมาสองครั้งแล้วคุณพ่อชอบบุฟเฟต์ซีฟู้ดนาๆชาติค่ะ 👍🏻',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ห้องที่จองไว้ เวลาไปพักได้ห้องแบบอื่น เจ้าหน้าที่แจ้งว่าห้องพักเต็ม ทั้งที่จองไว้ล่วงหน้า งง! เลย',
#  'วิวสวย เงียบดี หลับสนิท ห้องพักกว้างมาก อาหารเช้าชั้น81 มีบริการเยอะ หลากหลาย พนักงานแนะนำดี ลืมของไว้ทางโรงแรมช่วยเหลือตามหาให้และจัดส่งมาให้ถึงบ้านเรียบร้อย',
#  'วิวสวยมาก พนักงานบริการดีมากค่ะ',
#  'ห้อง ok แต่การเดินทางไม่ค่อยสะดวก',
#  '',
#  'ห้องพักสะอาด บริการดี อาหารอร่อย ใกล้แหล่งช็อปปิ้ง',
#  '',
#  'รอเช็คอินใช้เวลานาน มีมัดจำห้องละ 3,000 บาท แพงมาก ไม่เคยเจอ ว่าต้องจ่าย มัดจำมากขนาดนี้ คนรอใช้ลิฟท์เยอะ ห้องพักสะอาดน้ำไหลแรง อาหารเช้ามีให้เลือกหลากหลายรสชาติอร่อย',
#  '',
#  '',
#  'พนักงานให้บริการดีมากคะ ห้องพักสะอาด',
#  '',
#  'ไปพักคนเดียวแต่พนักงานอัพเกรดห้องเป็นห้อง Family ให้จากที่จ่ายพันกว่าบาท ได้ห้องเกือบห้าพัน คุ้มมากๆครับ',
#  '',
#  '',
#  '',
#  'ห้องเก่า แต่สะอาด เตียงนอนสบาย วิวสวย อาหารเช้าใช้ได้',
#  'ได้อัฟเกรดห้อง เพราะห้องที่จองเหม็นบุหรี่มาก ห้องใหญ่มาก สะอาด เตียงนอนสบาย วิวสวย แต่ห้องเก่า พรมเก่า อาหารเช้าหลากหลาย ไก่ตุ๋นอร่อย ได้ขึ้นชมวิวฟรีทั้งเย็นและเช้า',
#  'จองห้องปลอดบุหรี่ไป แต่ห้องพักมีกลิ่นบุหรี่คลุ้งทั้งห้อง พนักงานฉีดสเปรย์ดับกลิ่นก็ยังไม่สามารถดับกลิ่นบุหรีในห้องได้เลย',
#  'ห้องพักถือว่าโอเคเลย แต่วุ่นวายมาก มีแต่ทัวร์ ไม่ว่าจะทางขึ้นโรงแรม ลิฟต์ ดูวุ่นวายไปหมด เสียงดัง ความเป็นระเบียบไม่มี',
#  'รร ห้องกว้าง. วิวดี. เตียงนอนสบาย แม้ไม่หรูหรา แต่ก็นอนหลับสบาย แขกสามารถ ขึ้นไปชมวิวบนชั้น80 กว่าๆ ได้ วิวดีมาก สามารถเดินมาขึ้น รถเมล์ที่วื่งไปสนามบินดอนเมืองได้ที่ป้ายหน้ารร อินทรา ถ้ามาจากดอนเมือง ก็นั่ง A3 มาลงแถวๆ หน้า รร ได้ สะดวกมาก ข้อเสีย สระว่ายน้ำเล็กและ ไม่สวย สรุป ถือว่าดีเลย',
#  '',
#  'ดีมากเลยค่ะ สะดวกสบาย พนักงานบริการดี',
#  'พนง.บริการดีมาก ห้องสะอาด แต่ที่ปรับอุณหภูมิของตู้เย็นเสีย ทำให้ตู้เย็นอุ่น ห้อง4801 แจ้งฟร้อนไปแล้ว ทำเลสะดวกมากค่ะ',
#  '',
#  'พนักงานบริการดีมากค่ะ ยิ้มแย้มทักทายตลอดเวลาที่เดินผ่าน อาหารเช้ารสชาติดีมีให้เลือกหลากหลาย ห้องพักสะอาด กว้างใหญ่ วิวสวย',
#  '',
#  'ห้องกว้างมาก สะอาด วิวสวย อาหารเช้าก็ดีมาก',
#  '',
#  'ห้องพักดีวิวเมืองสวย ห้องพักสะอาด ได้รับบริการที่ดีจากพนักงาน',
#  '',
#  'ห้องพักสบาย เช็คอินรวดเร็ว ใกล้รถไฟฟ้า มีตลาดนัด และห้างเดินได้ทั้งวัน อาหารเช้าเยอะมาก รสชาติอร่อยดี ห้องน้ำกว้างขวาง สะอาด พนักงานต้อนรับดี ขึ้นไปดาดฟ้าถ่ายรูปได้วิวสูง แต่ตอนนี้เขาทำหลังคาปิดด้านบนไว้ น่าจะเพราะที่เป็นข่าวมีคนปีนขึ้นไปบนยอด โดยรวมโอเค เหมาะสายช้อปปิ้ง',
#  'ดีทุกอย่างยกเว้นทีวี อินเดียเยอะมากเหม็นมาก พนักงานดีพูดได้หลายภาษา',
#  '',
#  'พนักงานต้อนรับดี อาหารเยอะมากคะ',
#  'ห้องพักกว้างมาก แบ่งโซนเป็นสัดส่วนดี วิวดี',
#  '',
#  'โรงแรมใจกลางเมือง เป็นโรงแรมที่อยู่ใจกลางเมืองรอบข้างจะมีบริเวณแขกมากมายแต่ก็ไม่ได้ทำให้เสียอารมณ์หรือบรรยากาศใดใดเพราะว่าโรงแรมมีไซด์ที่ที่ดีมากๆ ส่วนห้องพักค่อนข้างจะเก่า การบริการพนักงานดีมากๆเพราะว่าคุ้มค่ากับราคาที่จ่ายไปได้ถูกอัพเกรดเป็นห้องเดี๋ยวรถรูมทำให้ประทับใจมากแล้วก็ได้ขึ้นอยู่ไปชมวิวชั้นบนสุดส่งกรุงเทพยามค่ำคืนกลับบุฟเฟ่ก็ค่อนข้างจะคุมแล้ว',
#  '',
#  'ห้องพักโอเค ตามอายุโรงแรมแต่ก็ถือว่าสะอาด กลิ่นท่อแรงไปค่ะ นี่จองห้องซูพเรียสวีท ได้ชั้น31 สัญญานอินเตอร์เนตแย่มาก ทีวีเคเบิ้ลกระตุกบ่อย โรงแรม4ดาวควรจะปรับปรุงมากกว่สนี้ค่ะ แต่เจ้าหน้าทุกคนต้อนรับน่ารักมากค่ะ',
#  '',
#  'ห้องพักกว้างดีค่ะ วิวสวย ขึ้นไปชมวิวได้ฟรี พนง.บริการดีมากค่ะ ที่สำคัญฝากกระเป๋าได้ด้วย😊',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ห้องพักกว้างดี หมอนนุ่ม เตียงนุ่ม แต่ชาวต่างชาติเยอะมาก โรงแรมมีครบหมด วิวสวย',
#  '',
#  'ร้องขอเช็คอินตอนเที่ยง เพราะบินมาถึงเช้า แต่ก็ต้องมานั่งรออยู่ดี เพราะคำร้องขอไม่เป็นผล รอจนบ่าย2 ทั้งเหนื่อย ทั้งง่วงจ้า',
#  '',
#  'ดีมากคะ เตียงนุ่มหลับสบาย อาหารหลากหลาย ดีมากๆคะ',
#  'พนักงานน่ารักมาก ดูแลดีมากค่ะ ช่วยเหลือตลอด บริการดีมาก ๆ ห้องพักดีไซน์ดีค่ะ ห้องน้ำกว้างดีมาก แอร์เย็นค่ะ วิวสวย แต่ทัวร์จีนลงเยอะไปหน่อยค่ะ โดยสรุปโรงแรมบรรยากาศดีค่ะ แต่ที่เรตไม่ดีเพราะ ทะเลาะกับแฟนแล้วรู้สึกแย่มากถึงมากที่สุดค่ะ เลยต้องลงมานั่งข้างล่างค่ะ บรรยากาศพังมากค่ะ แต่สถานที่และบริการโดยรวมดีมากค่ะ',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ประทับใจมากค่ะ ห้องพักกว้าง วิวสวยดีค่ะ จะมาพักอีกแน่นอนและจะแนะนำเพื่อนมาพักที่นี่ค่ะ',
#  '',
#  '',
#  'ห้องพักกว้างดีค่ะ บรรยากาศดีเริ่ด และจะกลับมาพักอีกแน่นอนค่ะ',
#  '',
#  'ห้องสวย สะอาด น่าอยู่ หลับสนิทตลอดคืน แถมวิวสวยมากๆเลยค่ะ สะดวกสบาย😊 ถ้ามีโอกาสจะกลับไปพักอีกครั้งคะ',
#  '',
#  '',
#  '',
#  '',
#  'บรรยากาศดี ห้องพักสะอาด อาหารเช้าเยอะมาก เอาไปเลย 10 เต็ม ข้อเสีย นักท่องเที่ยวเยอะมาก เยอะจริงๆ',
#  '',
#  'มาพักกับแฟนครั้งที่ 3 แล้วประทับใจทุกครั้ง',
#  '',
#  '',
#  '',
#  'คิดว่าปานกลางค่ะ มีคนเยอะแต่ห้องเหม็นอับไปหน่อยคะ และค่ามัดจำสูงไปคะ 3000บาท',
#  '',
#  'อยากให้ทำที่จอดรถดีกว่านี้ ที่จอดรถดูเปลี่ยวเกินไป ดูน่ากลัว แต่ส่วนที่เหลือดีหมดทุกอย่างครับ',
#  'ดีทุกอย่างยกเว้นรีเชฟชั่น เชคอินชื่อไม่ตรงกับบัตรมีปัณหานะคร้า ก็ไม่เข้าใจเราจองผ่านappแน่นอนอยุ่แล้วที่เราต้องใส่ชื่อเล่น หรือจะเถียง นางบอกผิดกฏคะไม่สามารถเชคอิน เราก็เถียงเรามีเอกสารทุกอย่างแต่ชื่อbook ไม่ตรงบัตรประชาชนแค่นั้น นี่จองตั่วไปตปท. รร.ที่ตปท.ไม่เคยมีปัณหาคะใช้มาหลายปีแล้ว งงมาก นางบอกให้เช้คอินแต่ต้องอีเมลไปเปลี่ยนชื่อ เราไม่คะ เปลี่ยนเพื่อ?',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'Front desk เป็นกันเองน่ารัก ห้องไม่เก่าค่ะ',
#  '',
#  '',
#  'สะดวก ปลอดภัย เดินทางง่าย ใกล้รถไฟฟ้าราชปรารภ',
#  'พนักงานห้องอาหารบริการดีมากๆ แต่หน้าฟร้อนท์ไม่ค่อยประทับใจเท่าไหร่',
#  'พนักงานต้อนรับดีมากๆๆค่ะ. โรงแรมสวย วิวดี และสะอาดมาก. อาหารเช้าหลากหลายดีค่ะ โดยรวม ดีมาก',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'ห้องพักใหญ่ สะอาด วิวชนะเลิศ พนักงานบริการดีมาก แต่เป็นโรงแรมที่ต่างชาติเยอะมาก อาหารรสชาติกลาง ๆ และไม่เพียงพอ กว่าจะเติมอาหารรอนาน ยิ่งเป็นอาหารเช้าไม่คุ้มค่า เวลาเช็คเอาท์เร็วไป 11.00 น.',
#  'ห้องกว้างสบายค่ะ แอบเหม็นอับนิดนึง อย่างอื่นหรูดูดีค่ะ',
#  '',
#  '',
#  '',
#  'บรรยากาศดีมาก อาหารเช้า ห้ามพลาด เยอะสุดๆ วิวสวยขาดใจ คุ้มต่าทุกบาททุกสตางค์ แนะนำเลยครับ มีค่ามัดจำ 3,000 บาทด้วยนะครับ',
#  'ห้องพักกว้าง วิวสวย อาหารอร่อย',
#  'ประทับใจมากคะ คุณแม่มีความสุขมาก ❤️',
#  'กรณีที่เราลืมของพนักงานไม่ช่วยอะไรเลย และการขึ้นที่พักก็ลำบากต้องมาแย่งลีฟกับพวกลูกทัวร์ การจัดการเรื่องความสะดวกให้ลูกค้ายังไม่เพียงพอกับโรงแรมระดับ4ดาว',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'โอเคนะคะ ห้องดี อุปกรณ์ในห้องน้ำครบสะดวกสบาย แต่ห้องอาบน้ำระบายน้ำช้าทำให้ไหลออกมาข้างนอก พื้นเปียกค่อนข้างเยอะ ควรแก้ไขเพราะอาจจะลื่นล้มได้ ห้องนอนเตียงนอนสบาย มีพื้นที่แยกเป็นสัดส่วนนั่งทำงาน กินข้าวแยกกันดีค่ะ อาหารเช้าของเยอะดี รสชาติโอเค สรุปคือดีเลยค่ะ',
#  '',
#  'ห้องนึ้ดูสะอาด แต่ค่อนข้างเก่าคะ ห้องน้ำกว้างมาก มีอ่างและฝักบัว ผนังไม่กั้นเสียงตรงทางเดิน เวลามีเด็กวิ่งเล่นกันตอนกลางคืนจะเสียงดังคะ อาหารเช้าพอใช้ เน้นวิวเมืองมากกว่าคะ',
#  'ดี แต่คนเยอะ ทัวร์เยอะ ลิฟต์เยอะ งง ไปหมด โดยรวมโอเค',
#  'เรียกเก็บค่ามัดจำห้อง มากกว่าราคาค่าห้องพัก',
#  'พนักงานบริการดีค่ะ ตั้งแต่กดลิฟท์จนถึงบริเวณเค้าท์เตอร์ ห้องพักเหมือนในรูปไม่มีกลิ่นอับ ห้องกว้างสบายมากค่ะ เพียงแต่ได้มุมห้องที่วิวไม่สวยเท่าไหร่ โดยรวมแล้วประทับใจค่ะ']

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                 Review Rating
# 0                                                  NaN    8.5
# 1    จะกลับไปพักอีกแน่นอนคะ ถ้าได้แวะไป กรุุงเทพฯ ห...    8.5
# 2    รอเช็คอินนานมาก ไม่ประทับใจพนักงานต้อนรับผู้ชา...    8.4
# 3    ตอนแรกได้ห้องเก่าและเหม็น ไม่ตรงตามที่จองไว้ แ...    6.4
# 4                    ห้องใหญ่กว้างมาก แบ่งเป็นโชนดีมาก    8.5
# ..                                                 ...    ...
# 185                                                NaN    6.2
# 186  ห้องนึ้ดูสะอาด แต่ค่อนข้างเก่าคะ ห้องน้ำกว้างม...    8.5
# 187  ดี แต่คนเยอะ ทัวร์เยอะ ลิฟต์เยอะ งง ไปหมด โดยร...    8.7
# 188        เรียกเก็บค่ามัดจำห้อง มากกว่าราคาค่าห้องพัก      6
# 189  พนักงานบริการดีค่ะ ตั้งแต่กดลิฟท์จนถึงบริเวณเค...    8.5
#
# [190 rows x 2 columns]

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       1  จะกลับไปพักอีกแน่นอนคะ ถ้าได้แวะไป กรุุงเทพฯ ห...    8.5
# 1       2  รอเช็คอินนานมาก ไม่ประทับใจพนักงานต้อนรับผู้ชา...    8.4
# 2       3  ตอนแรกได้ห้องเก่าและเหม็น ไม่ตรงตามที่จองไว้ แ...    6.4
# 3       4                  ห้องใหญ่กว้างมาก แบ่งเป็นโชนดีมาก    8.5
# 4       5          ห้องสวย สะอาด ราคาไม่แพง วิวสวยรอบด้านค่ะ    8.5
# ..    ...                                                ...    ...
# 85    184  โอเคนะคะ ห้องดี อุปกรณ์ในห้องน้ำครบสะดวกสบาย แ...    9.4
# 86    186  ห้องนึ้ดูสะอาด แต่ค่อนข้างเก่าคะ ห้องน้ำกว้างม...    8.5
# 87    187  ดี แต่คนเยอะ ทัวร์เยอะ ลิฟต์เยอะ งง ไปหมด โดยร...    8.7
# 88    188        เรียกเก็บค่ามัดจำห้อง มากกว่าราคาค่าห้องพัก      6
# 89    189  พนักงานบริการดีค่ะ ตั้งแต่กดลิฟท์จนถึงบริเวณเค...    8.5
#
# [90 rows x 3 columns]

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   จะกลับไปพักอีกแน่นอนคะ ถ้าได้แวะไป กรุุงเทพฯ ห...    8.5
# 1   รอเช็คอินนานมาก ไม่ประทับใจพนักงานต้อนรับผู้ชา...    8.4
# 2   ตอนแรกได้ห้องเก่าและเหม็น ไม่ตรงตามที่จองไว้ แ...    6.4
# 3                   ห้องใหญ่กว้างมาก แบ่งเป็นโชนดีมาก    8.5
# 4           ห้องสวย สะอาด ราคาไม่แพง วิวสวยรอบด้านค่ะ    8.5
# ..                                                ...    ...
# 85  โอเคนะคะ ห้องดี อุปกรณ์ในห้องน้ำครบสะดวกสบาย แ...    9.4
# 86  ห้องนึ้ดูสะอาด แต่ค่อนข้างเก่าคะ ห้องน้ำกว้างม...    8.5
# 87  ดี แต่คนเยอะ ทัวร์เยอะ ลิฟต์เยอะ งง ไปหมด โดยร...    8.7
# 88        เรียกเก็บค่ามัดจำห้อง มากกว่าราคาค่าห้องพัก      6
# 89  พนักงานบริการดีค่ะ ตั้งแต่กดลิฟท์จนถึงบริเวณเค...    8.5
#
# [90 rows x 2 columns]

# %%
table.to_csv("Reviews&Ratings_3rd.csv", encoding="utf-8")
