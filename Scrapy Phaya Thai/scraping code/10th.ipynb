# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=10-11-2022.11-11-2022.1.1.HOTEL.3000010023224.Bluefin%20Guesthouse.1&contexts=%7B%22inventoryRateKey%22%3A%22povEwB3ZzsU2C6pd%2B6MdUwKh3BcjHsHvQbV0EUcyDRFM0tKsNUio4Rxug1zOzHJilcvZa8YdqqIySdppe7dolTIewZlxfjiOGz6oXLTucMvN0%2BgQ3yZPvZcoHwUFNN%2BZpcr%2F%2FNa8o9ElfN8zOYhzzZeg0X586laFpeUViPi9rxCCuaBGGX9HZdhui4Z9ufe7DKNfCuNpYoh%2BuNZYtkPMM8N0KRTJ4VFq4ShicQGXCAjUQQmOFyb69aqe8Hll6YWZ3I9RvKjk4IEo%2BSgm41melVlJUAwrC%2F%2B5QUCsG1s1QVIuc5YTT922w9xJEQzAwRUPNnQ9KJas2SXzCKWvz%2Fz6J9VsBZohxEpYRFmg%2B%2BHLDKSFYOLj%2FjXdejPF4I505ImQjTE%2FGsBKQXKjBtgZDhjE4C5zlhNP3bbD3EkRDMDBFQ9xx9%2BYOSoJDN4kQ00BhAJQ1WwFmiHESlhEWaD74csMpMnQa0scGMjKKgUdFAeMZ1eGixODei%2FNdx2RuCUEGmeMAUyxf%2BoM7B5yfJewzeVoU2%2FtVYQKI1lMuX%2BRaPNcBUAvSnVpp3982X8ufymNCG%2Bvqv3rBuUa%2BDAlSlNPC7rHF8TsYmOTADU69%2B%2B%2Fol8yLJTHHQhvr%2Bf5O5wjhPZDddaEMD1lhgrNFX59TpZvCV9M4rSDCIHqoFDFRnsCphC6IUw%3D%22%7D&prevSearchId=1749093859430791925&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]

sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]")
sel.click()
time.sleep(2)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_5744\1200746048.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'ค่าห้องพัก Bluefin Guesthouse ถนนนครไชยศรี ตั้งแต่ 10-11-2022 ถึง 11-11-2022'

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 9.4
# ดูแลบริการดีมากๆเลยค่ะ ประทับใจมาก
# 9.7
# ที่พักสะอาด พนักงานเป็นกันเอง ใจดี ชอบมากๆ ค่ะ😍
# 8.8
# ห้องสะอาดดีครับ และป้าเจ้าของใจดีมากๆเป็นกันเองสุดๆ
# 9.7
# ห้องพักสะอาด การบริการดีเยี่ยม เป็นกันเองมากๆ ประทับใจและจะกลับมาใช้บริการอีก
# 9.7
# ที่พักดีมากสะอาดน่าอยู่แม่บ้านน่ารักใจดีคุยง่าย
# 9.7
# ห้องพักกว้างขวาง สะอาดดี เดินทางสะดวก
# 8.8
# บริการดีค่ะ แต่ห้องไม่มีที่ทิ้งขยะและกระดาษชำระ ผ้าเช็ดตัวมีกลิ่นอับๆ ค่ะ แต่แอร์เย็นมาก ห้องสะอาด
# 9.4
# ที่พักสะอาด เดินทางคนเดียวรู้สึกปลอดภัย มีป้าแม่บ้านดูแลอย่างดี แต่หากใครมีรถส่วนตัวอาจจะไม่ค่อยสะดวกเรื่องการจอดรถ โดยรวมโอเคค่ะ
# 9.1
# เจ้าของและพนักงานดูแลเป็นกันเองมาก มีเครื่องดื่มและของว่างให้
# 9
# บริการดี พนักงานน่ารักเป็นกันเอง นอนหลับสบาย

# %%
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[5]")
sel.click()

# %%
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# ภายในห้องสะอาด บริการดี ไว้มีโอกาสจะมาพักอีกเเน่ๆ
# 9.1
# เจ้าของที่พักใจดีและเป็นกันเองมากครับ
# 10
# บริการดีมากๆ ค่ะ ห้องพักสะอาด ราคาห้องถูกเจ้าของและแม่บ้านใจดีเป็นกันเองมากๆ ประทับใจและขอบคุณมากๆนะค่า 💕
# 8.5
# บริการดี พนักงานพูดจาไพเราะน่าฟัง
# 9.4
# ทั้งพี่เจ้าของทั้งพนักงาน น่ารัก เป็นกันเองมากครับ ดูแลลูกค้าเป็นอย่างดี
# 8.5
# การบริการดีมากๆ ค่ะ การคมนาคมและการติดต่อสื่อสารดีค่ะ
# 5.1
# ลำบากต่อการจอดรถยนต์ ห้องนำ้ไม่สะดวก กระดาษชำระไม่มีเลยทั้งห้องนำ้และห้องนอน นำ้ดื่มไม่มีให้ต้องหาซื้อไปเอาหมดทุกอย่างอุปกรณ์อาบนำ้คือไม่มีอะไรให้เลย
# 8.5
# เป็นกันเอง สบาย เจ้าของน่ารัก
# 8.4
# ห้องสะอาด สถานที่ โอเครมากเลยค่ะ เเต่ป้าเเม่บ้าน บริการเเย่หน่อย ไม่ค่อยรู้สึกได้รับการต้นรับเท่าที่ควร
# 5.7
# กลอนประตูก็ชำรุด เตียงนอนเวลาพลิกตัวก็มีเสียง

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[5]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# เจ้าหน้าที่บริการดี แนะนำดี ห้องพัดลมพักชั้นบน กลางวันห้องอากาศร้อน แต่กลางคืนเย็นสบายพอดี
# 6.6
# การบริการดี แนะนำดีมาก เป็นกันเอง
# 9.4
# เจ้าของที่พักเป็นกันเองมากๆ แถมใจดีอีก การเดินทางไปยังที่พักสะดวกสบาย
# 5.9
# ทำให้ร่างกายของคุณร้อนไม่มีเครื่องปรับอากาศในอากาศ อาหารเช้าไม่ได้มี ห้องพักชั้นล่างดีเลือก
# 9.7
# น่าพอใจมากใกล้กับเมืองพนักงานต้อนรับของโฮสเทลนางโอเลย์สามารถพูดภาษาอังกฤษได้ดังนั้นเธอจึงสามารถสื่อสารได้ห้องพักกว้างขวางสะอาดอากาศเย็นสบาย ... การทำอาหารเป็นเพียงตลาดในอนาคตมีทุกอย่างเปิดเช้าเที่ยง องค์กรรอบเป็นมิตรมากฉันไม่เสียใจสำหรับเควสต์บลูฟินเควสท์ฉันแน่ใจว่าจะอยู่ที่นั่นในปีนี้😍ฉันซื้อเครื่องสำอางที่นั่นด้วย ... ฉันไปที่พระบรมมหาราชวังในบริเวณใกล้เคียง ... T4 เป็นยุทธศาสตร์ฉันนั่งรถบัสเสมอ
# 9.7
# สะดวกสบายและสะอาดบริการเป็นที่น่าพอใจ
# 8.2
# ฉันชอบบ้านไทยแบบดั้งเดิมแม้ว่าจะไม่มีกระดาษชำระหรือสบู่และหมายเลขโทรศัพท์ไม่ถูกต้องตามที่อยู่ทำให้ยากมากที่จะหาคนขับรถแท็กซี่เพียงแค่พูดคุยกับคนไทยเพื่อรับคำแนะนำในการเดินทาง . มิฉะนั้นพอใจ
# 9.1
# นางสาวแม่บ้านเป็นมิตรจริงๆ ห้องพักค่อนข้างสวยและวินเทจ

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 28
# Reviews_list : 28

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0                  ดูแลบริการดีมากๆเลยค่ะ ประทับใจมาก    9.4
# 1     ที่พักสะอาด พนักงานเป็นกันเอง ใจดี ชอบมากๆ ค่ะ😍    9.7
# 2   ห้องสะอาดดีครับ และป้าเจ้าของใจดีมากๆเป็นกันเอ...    8.8
# 3   ห้องพักสะอาด การบริการดีเยี่ยม เป็นกันเองมากๆ ...    9.7
# 4     ที่พักดีมากสะอาดน่าอยู่แม่บ้านน่ารักใจดีคุยง่าย    9.7
# 5               ห้องพักกว้างขวาง สะอาดดี เดินทางสะดวก    9.7
# 6   บริการดีค่ะ แต่ห้องไม่มีที่ทิ้งขยะและกระดาษชำร...    8.8
# 7   ที่พักสะอาด เดินทางคนเดียวรู้สึกปลอดภัย มีป้าแ...    9.4
# 8   เจ้าของและพนักงานดูแลเป็นกันเองมาก มีเครื่องดื...    9.1
# 9        บริการดี พนักงานน่ารักเป็นกันเอง นอนหลับสบาย      9
# 10  ภายในห้องสะอาด บริการดี ไว้มีโอกาสจะมาพักอีกเเน่ๆ    9.7
# 11              เจ้าของที่พักใจดีและเป็นกันเองมากครับ    9.1
# 12  บริการดีมากๆ ค่ะ ห้องพักสะอาด ราคาห้องถูกเจ้าข...     10
# 13                  บริการดี พนักงานพูดจาไพเราะน่าฟัง    8.5
# 14  ทั้งพี่เจ้าของทั้งพนักงาน น่ารัก เป็นกันเองมาก...    9.4
# 15  การบริการดีมากๆ ค่ะ การคมนาคมและการติดต่อสื่อส...    8.5
# 16  ลำบากต่อการจอดรถยนต์ ห้องนำ้ไม่สะดวก กระดาษชำร...    5.1
# 17                      เป็นกันเอง สบาย เจ้าของน่ารัก    8.5
# 18  ห้องสะอาด สถานที่ โอเครมากเลยค่ะ เเต่ป้าเเม่บ้...    8.4
# 19     กลอนประตูก็ชำรุด เตียงนอนเวลาพลิกตัวก็มีเสียง     5.7
# 20  เจ้าหน้าที่บริการดี แนะนำดี ห้องพัดลมพักชั้นบน...    8.5
# 21                  การบริการดี แนะนำดีมาก เป็นกันเอง    6.6
# 22  เจ้าของที่พักเป็นกันเองมากๆ แถมใจดีอีก การเดิน...    9.4
# 23  ทำให้ร่างกายของคุณร้อนไม่มีเครื่องปรับอากาศในอ...    5.9
# 24  น่าพอใจมากใกล้กับเมืองพนักงานต้อนรับของโฮสเทลน...    9.7
# 25              สะดวกสบายและสะอาดบริการเป็นที่น่าพอใจ    9.7
# 26  ฉันชอบบ้านไทยแบบดั้งเดิมแม้ว่าจะไม่มีกระดาษชำร...    8.2
# 27  นางสาวแม่บ้านเป็นมิตรจริงๆ ห้องพักค่อนข้างสวยแ...    9.1

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0                 ดูแลบริการดีมากๆเลยค่ะ ประทับใจมาก    9.4
# 1       1    ที่พักสะอาด พนักงานเป็นกันเอง ใจดี ชอบมากๆ ค่ะ😍    9.7
# 2       2  ห้องสะอาดดีครับ และป้าเจ้าของใจดีมากๆเป็นกันเอ...    8.8
# 3       3  ห้องพักสะอาด การบริการดีเยี่ยม เป็นกันเองมากๆ ...    9.7
# 4       4    ที่พักดีมากสะอาดน่าอยู่แม่บ้านน่ารักใจดีคุยง่าย    9.7
# 5       5              ห้องพักกว้างขวาง สะอาดดี เดินทางสะดวก    9.7
# 6       6  บริการดีค่ะ แต่ห้องไม่มีที่ทิ้งขยะและกระดาษชำร...    8.8
# 7       7  ที่พักสะอาด เดินทางคนเดียวรู้สึกปลอดภัย มีป้าแ...    9.4
# 8       8  เจ้าของและพนักงานดูแลเป็นกันเองมาก มีเครื่องดื...    9.1
# 9       9       บริการดี พนักงานน่ารักเป็นกันเอง นอนหลับสบาย      9
# 10     10  ภายในห้องสะอาด บริการดี ไว้มีโอกาสจะมาพักอีกเเน่ๆ    9.7
# 11     11              เจ้าของที่พักใจดีและเป็นกันเองมากครับ    9.1
# 12     12  บริการดีมากๆ ค่ะ ห้องพักสะอาด ราคาห้องถูกเจ้าข...     10
# 13     13                  บริการดี พนักงานพูดจาไพเราะน่าฟัง    8.5
# 14     14  ทั้งพี่เจ้าของทั้งพนักงาน น่ารัก เป็นกันเองมาก...    9.4
# 15     15  การบริการดีมากๆ ค่ะ การคมนาคมและการติดต่อสื่อส...    8.5
# 16     16  ลำบากต่อการจอดรถยนต์ ห้องนำ้ไม่สะดวก กระดาษชำร...    5.1
# 17     17                      เป็นกันเอง สบาย เจ้าของน่ารัก    8.5
# 18     18  ห้องสะอาด สถานที่ โอเครมากเลยค่ะ เเต่ป้าเเม่บ้...    8.4
# 19     19     กลอนประตูก็ชำรุด เตียงนอนเวลาพลิกตัวก็มีเสียง     5.7
# 20     20  เจ้าหน้าที่บริการดี แนะนำดี ห้องพัดลมพักชั้นบน...    8.5
# 21     21                  การบริการดี แนะนำดีมาก เป็นกันเอง    6.6
# 22     22  เจ้าของที่พักเป็นกันเองมากๆ แถมใจดีอีก การเดิน...    9.4
# 23     23  ทำให้ร่างกายของคุณร้อนไม่มีเครื่องปรับอากาศในอ...    5.9
# 24     24  น่าพอใจมากใกล้กับเมืองพนักงานต้อนรับของโฮสเทลน...    9.7
# 25     25              สะดวกสบายและสะอาดบริการเป็นที่น่าพอใจ    9.7
# 26     26  ฉันชอบบ้านไทยแบบดั้งเดิมแม้ว่าจะไม่มีกระดาษชำร...    8.2
# 27     27  นางสาวแม่บ้านเป็นมิตรจริงๆ ห้องพักค่อนข้างสวยแ...    9.1

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0                  ดูแลบริการดีมากๆเลยค่ะ ประทับใจมาก    9.4
# 1     ที่พักสะอาด พนักงานเป็นกันเอง ใจดี ชอบมากๆ ค่ะ😍    9.7
# 2   ห้องสะอาดดีครับ และป้าเจ้าของใจดีมากๆเป็นกันเอ...    8.8
# 3   ห้องพักสะอาด การบริการดีเยี่ยม เป็นกันเองมากๆ ...    9.7
# 4     ที่พักดีมากสะอาดน่าอยู่แม่บ้านน่ารักใจดีคุยง่าย    9.7
# 5               ห้องพักกว้างขวาง สะอาดดี เดินทางสะดวก    9.7
# 6   บริการดีค่ะ แต่ห้องไม่มีที่ทิ้งขยะและกระดาษชำร...    8.8
# 7   ที่พักสะอาด เดินทางคนเดียวรู้สึกปลอดภัย มีป้าแ...    9.4
# 8   เจ้าของและพนักงานดูแลเป็นกันเองมาก มีเครื่องดื...    9.1
# 9        บริการดี พนักงานน่ารักเป็นกันเอง นอนหลับสบาย      9
# 10  ภายในห้องสะอาด บริการดี ไว้มีโอกาสจะมาพักอีกเเน่ๆ    9.7
# 11              เจ้าของที่พักใจดีและเป็นกันเองมากครับ    9.1
# 12  บริการดีมากๆ ค่ะ ห้องพักสะอาด ราคาห้องถูกเจ้าข...     10
# 13                  บริการดี พนักงานพูดจาไพเราะน่าฟัง    8.5
# 14  ทั้งพี่เจ้าของทั้งพนักงาน น่ารัก เป็นกันเองมาก...    9.4
# 15  การบริการดีมากๆ ค่ะ การคมนาคมและการติดต่อสื่อส...    8.5
# 16  ลำบากต่อการจอดรถยนต์ ห้องนำ้ไม่สะดวก กระดาษชำร...    5.1
# 17                      เป็นกันเอง สบาย เจ้าของน่ารัก    8.5
# 18  ห้องสะอาด สถานที่ โอเครมากเลยค่ะ เเต่ป้าเเม่บ้...    8.4
# 19     กลอนประตูก็ชำรุด เตียงนอนเวลาพลิกตัวก็มีเสียง     5.7
# 20  เจ้าหน้าที่บริการดี แนะนำดี ห้องพัดลมพักชั้นบน...    8.5
# 21                  การบริการดี แนะนำดีมาก เป็นกันเอง    6.6
# 22  เจ้าของที่พักเป็นกันเองมากๆ แถมใจดีอีก การเดิน...    9.4
# 23  ทำให้ร่างกายของคุณร้อนไม่มีเครื่องปรับอากาศในอ...    5.9
# 24  น่าพอใจมากใกล้กับเมืองพนักงานต้อนรับของโฮสเทลน...    9.7
# 25              สะดวกสบายและสะอาดบริการเป็นที่น่าพอใจ    9.7
# 26  ฉันชอบบ้านไทยแบบดั้งเดิมแม้ว่าจะไม่มีกระดาษชำร...    8.2
# 27  นางสาวแม่บ้านเป็นมิตรจริงๆ ห้องพักค่อนข้างสวยแ...    9.1

# %%
table.to_csv("Reviews&Ratings_10th.csv", encoding="utf-8")
