# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=11-11-2022.12-11-2022.1.1.HOTEL.3000010043827.%E0%B9%80%E0%B8%A5%E0%B8%AD%20%E0%B8%9A%E0%B8%AD%E0%B8%99%E0%B9%80%E0%B8%99%E0%B8%AD%E0%B8%A3%E0%B9%8C%20%E0%B8%9E%E0%B8%AD%E0%B8%8A%E0%B9%80%E0%B8%97%E0%B8%A5.1&contexts=%7B%22inventoryRateKey%22%3A%22povEwB3ZzsU2C6pd%2B6MdUwKh3BcjHsHvQbV0EUcyDRFM0tKsNUio4Rxug1zOzHJilcvZa8YdqqIySdppe7dolTIewZlxfjiOGz6oXLTucMvN0%2BgQ3yZPvZcoHwUFNN%2BZpcr%2F%2FNa8o9ElfN8zOYhzzZeg0X586laFpeUViPi9rxBdhpV%2FdbCTEP2P2MCCaYr5mhLDdV0WLeT%2FFKfQ0QL8LH02Dvlx%2F8PjYogEE5yzx6g6yOKyKeIDf7jO3GM45O1o1hmSkmz3HiZNSbS8gXb3CDW9nmlhkqLKa4lLkAkZpAGTcOmy5l4j7hGHKXWH0MtOLed6AZW%2BpBHwrYLGP2LypeR3YeBjsSIa7hzz9ziKH4xBz0bbP37DEgTr2mvXG4L6%2B6EJsWd3l3ySG7Noz64MEpNw6bLmXiPuEYcpdYfQy06%2Fns3BbenPjVnmtgE4pAyd5Hdh4GOxIhruHPP3OIofjEzUzLcXQJxlzkcDC6%2Fci4EqUKu6iA4vpZt64tziZTqoJbd7OF9Tfmn9fN2Jsreb4K2mOEeJroXhMG6udoM1cm9ZIT0XCc34JXGSCAp8seiHd9dYRzDxNlIpr2cGalY5xOKKBPSWuuiq2HLTL2pdzMlsmm6hutcJInnvy1grc0fuglrgvsLXN8itOmJQBMGbmrI%2FZcFIMBHyhTwFoQB0%2BxI%3D%22%7D&prevSearchId=1749099906993247824&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_19744\367408223.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'ค่าห้องพัก เลอ บอนเนอร์ พอชเทล (Le Bonheur Poshtel) สามเสนใน ตั้งแต่ 11-11-2022 ถึง 12-11-2022'

# %%
driver.execute_script("window.scrollTo(0,6000)")
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]")
sel.click()

# %%
driver.execute_script("window.scrollTo(0,6250)")
time.sleep(2)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div/div[2]/div/div/div/div[4]/div')
TH.click()

# %%
time.sleep(2)
driver.execute_script("window.scrollTo(0,6000)")
sel_order = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div/div[1]/div")
sel_order.click()
ascending = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div/div[2]/div/div/div/div[2]/div')
ascending.click()

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 5.4
# ห้องแคบ ไม่มีตู้เย็น รังหนูชัดๆ ตู้เย็นห้องละพันกว่า ขนาดเล็ก ลิฟต์ไม่มีเดินขึ้นห้องลำบาก ตู้เย็นใช้รวม โอ๊ย คือไม่สะดวกเหอะ แพงด้วย แล้วเยอะสิ่งกรอกนู้นนี้นั้น
# 5.5
# เซอร์วิสในโรงแรมยังค่อนข้างน้อยไปหน่อย เช่นไม่มีหมวกอาบน้ำ ไม่มีสำลีปั่นหู หันหัวเตียงไปอยู่ใต้ผ้าม่านซึ่งแดดจะเข้าตาเมื่อเวลาสายๆทันที (คิดว่าเจ้าของโรงแรมก็คงไม่นอนแบบนี้หรอก) ซึ่งเมื่อเทียบกับราคาแล้วเป็นเรื่องเล็กน้อยมากที่ทางโรงแรมมองข้ามไป
# 6.1
# ห้องพักแคบมากๆๆเลยครับ ลิฟต์ก็ไม่มี ตู้เย็นมินิก็ไม่มี
# 6.5
# ทำเลดี บริการดี แต่ห้องพักแคบมากไม่สมราคา น้ำดื่มไม่มีให้
# 6.5
# ห้องพักแคบมากเลย แต่ราคาแพง 1,135 บาท
# 8.5
# อาหารเช้าไม่หลากหลาย ห้องแคลไปหน่อย โดยรวมถึอว่าดี ใกล้bts
# 8.5
# ห้องอาจแคบไปหน่อย แต่สะอาด สะดวก หาของกินง่าย พนักงานน่ารัก เป็นกันเอง เป็นส่วนตัวดีคะ ประทับใจมาก จะไปใช้บริการอีก
# 8.5
# เจ้าของบริการดีมากค่ะ ช่วยแก้ไขปัญหาให้ ห้องพักสะอาด แยกชายหญิงชัดเจน ทำเลดี ใกล้ BTS สะพานควาย ใกล้ป้ายรถเมล์ ใกล้ตลาดนัดจตุจักร ใกล้ 7-11 ร้านอาหาร
# 8.5
# ดีมากค่ะ ที่พักใหม่ สะอาด ห้องไม่แคบ อยู่ใกล้ bts มาก เดินทางสะดวก บริการดี มีของอำนวยความสะดวกค่อนข้างครบ แนะนำสำหรับคนหาที่พักใกล้ bts เลยค่ะ
# 8.5
# ที่พักใกล้ bts เดินทางสะดวกมากๆค่ะ

# %%
driver.execute_script("document.body.style.zoom='50%'")
driver.execute_script("window.scrollTo(0,4500)")
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]")
driver.execute_script("document.body.style.zoom='100%'")
sel.click()
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
#
# 8.8
# ใกล้btsมากๆสะดวก แต่ห้องแคบไปนิด ผมพักแบบไม่มีหน้าต่าง อึดอัดนิดๆอาจจะไม่คุ้นชิน
# 8.8
# ห้องพักปานกลาง ได้ห้องไม่ตรงกับที่จอง
# 8.8
# เจ้าหน้าที่บริการเป็นกันเอง แต่ห้องแคบไปหน่อย โดยรวมถือว่าโอเค
# 8.8
# ทำเลดี เดินทางสะดวก แต่ฝักบัวอาบยากสำหรับผู้หญิง
# 9
# ที่พักทำเลดี เดินทางสะดวก ติดbtsสะพานควาย ใกล้ร้านสะดวกซื้อ พนักงานยิ้มแย้มดี แต่ห้องแคบมาก น้ำและตู้เย็นในห้องไม่มี ต้องใช้ส่วนรวมไม่ค่อยสะดวกเพราะต้องขึ้นลงบันใดหลายชั้น น่าจะมีในห้องส่วนตัวค่ะ
# 9.1
# ห้องพักดี สะอาด เตียงกว้าง แต่แคบมาก
# 9.1
# ใกล้ bts สะพานควายมาก เดินทางสะดวก แต่ห้องเล็กมาก
# 9.4
# ดีในระดับพอชเทล คือห้องเล็ก สะอาด เงียบ
# 9.4
# เดินทางสะดวกใกล้ BTS คะ ห้องพักสะอาด

# %%
driver.execute_script("document.body.style.zoom='50%'")
driver.execute_script("window.scrollTo(0,4500)")
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]")
driver.execute_script("document.body.style.zoom='100%'")
sel.click()
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.4
# ใกล้บีทีเอสสะพานควาย ห้องพักสะอาด เจ้าของเฟรนลี่ ส่วนตัวเคยพักทั้งแบบนอนรวมห้องหญิง มีสี่เตียง เตียงใหญ่ เมื่อวานพักแบบห้องเดี่ยวห้องสะอาด ห้องน้ำดี อาจจะแคบไปนิด สมราคาคะ แนะนำให้มาพักในราคาไม่แรงคะ
# 9.4
# เดินจากบีทีเอสสะพานควายแค่ไม่กี่เมตร เจ้าของอัธยาศัยดี ให้คำแนะนำดี ที่พักก็โอเค พอดีไปพักห้องรวมหญิง ที่นอนใหญ่ดี แต่ขนาดของห้องแคบไปนิดนึง โดยรวมดีมากๆคะ
# 9.4
# ห้องเล็กไปหน่อย แต่ทำเลดี เดินทางสะดวก เจ้าของใส่ใจลูกค้าดี เป็นแบบ service apartment ที่มีครัวรวม ตู้เย็น ไมโครเวฟและน้ำดื่มอยู่ข้างล่าง ในห้องมีแค่โทรศัพท์ให้ค่ะ
# 9.7
# บริการดีมากค่ะ ประทับใจ มาใช้บริการครั้งที่2แล้วค่ะ ดูแลดี ระบบความปลอยภัยดีมาก สะอาด พนักงานยิ้มแย้มดีค่ะ 💓🤗
# 9.7
# ห้องพักดีมากค่ะแต่แคบไปหน่อย แต่ทำเลเหมาะมาก ใกล้รถไฟฟ้าสุด ๆ เดินทางสะดวก
# 9.7
# โลเคชั่นดีมาก ติด BTS exit 3 มี 7-11 อยู่ข้างหน้า ปลอดภัย ที่พักใหม่ สะอาด
# 9.7
# "ห้องพักสะอาดมากๆ เตียงนอนสบาย บรรยากาศห้องดี นอนหลับสนิทค่ะ และเจ้าของน่ารัก พูดคุยสอบถามได้ตลอดค่ะ แต่ว่าขอหมอนสูงๆ และหลายๆใบก็ดีจ้ะ นอกนั้น Perfect ทุกอย่างค่ะ"
# 9.7
# ผมได้เข้าพักห้อง 332 ดีมากครับ ห้องสะอาดมาก บริการดีมาก แต่ผมว่าห้องนี้มีปัญหาอย่างนึงคือหัวเตียงจะหันออกไปทางหน้าต่างแล้วหน้าต่างนั้นมีม่านกั้น เป็นม่านที่สั้นเกินไป ทำไห้แสงไฟจากข้างนอกส่องแยงตาทั้งคืนจนนอนไม่หลับ
# 9.7
# เจ้าของที่พักดูแลดีมาก แนะนำที่พักทุกส่วนก่อนจะเดินพาขึ้นห้อง ห้องพักเล็กหน่อยแต่ไม่อึดอัด สิ่งอำนวยความสะดวกในห้องมีครบ ที่นอนสะอาด แอร์เย็นหลับสบาย วิวจากในห้องน่ารัก ใกล้บีทีเอส เดินทางสะดวกมาก
# 10
# สะอาด สะดวก ปลอดภัย บริการดี

# %%
driver.execute_script("document.body.style.zoom='50%'")
driver.execute_script("window.scrollTo(0,4500)")
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]")
driver.execute_script("document.body.style.zoom='100%'")
sel.click()
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# ห้องพักสะอาดพนักงานเป็นมิตร, AC เย็นเป็นไปตามราคา
# 8.5
# เจ้าของโฮสเทลที่เป็นมิตร, ห้องพักสะอาด, WiFi ได้อย่างรวดเร็วทางเลือกอาหารเช้าที่ดี .. โดยรวมดี n แนะนำ ..
# 8.8
# มีความสุขมากที่ได้พักที่นี่ แนะนำไม่เคยเบื่อ
# 8.8
# (+): ใกล้กับ BTS และตลาดจตุจักรมีร้านอาหารริมทางมากมายรอบ ๆ โฮสเทลห่างจากระดับ 100 เมตร (-): ผู้คนที่มีเสียงดังมากก็แค่อาบน้ำติดกับเสียง
# 9.1
# เรามีครอบครัวให้ได้ 4 คนมี 6 อันให้เรา ห้องพักสะอาดมาก ห้องน้ำรวมก็สะอาด พวกเขาทำห้องทุกวัน มันอยู่ด้านหน้ารถไฟและป้ายรถเมล์ไป / จากสนามบินดอนเมือง หากคุณต้องการไปที่ห้างสรรพสินค้า (สยามพาลาเดียมแพลตตินัม) มันอยู่ห่างออกไปประมาณ 4 กิโลเมตร โดยรวมแล้วความสะอาดนั้นยอดเยี่ยมมาก!
# 9.1
# ค่อนข้างพอใจแม้ว่าห้องพักค่อนข้างเล็กและสะอาด
# 9.1
# ใกล้ BTS และสะอาด แต่ห้องเล็ก ๆ และไม่มีลิฟท์
# 9.4
# ห้องและทางเดินอาจจะเล็กไปหน่อย แต่จริง ๆ แล้วเตียงนอนค่อนข้างสบายและใหญ่ ที่นี่ไม่มีลิฟท์ดังนั้นคุณอาจต้องการนำสัมภาระขึ้นเครื่องน้อยลงเมื่อมาถึง โดยรวมแล้วฉันมีความพึงพอใจในการพักที่นี่ แนะนำโดยสิ้นเชิงสำหรับแบ็คแพ็คเกอร์
# 9.7
# ฟังฉันหน่อยสิสำหรับผู้ที่ต้องการสำรวจตลาดจตุจักรตลอดวันหยุดสุดสัปดาห์ที่นี่เป็นที่พักที่ดี! เนื่องจากตลาดจตุจักรอยู่ห่างออกไป 500 เมตรเท่านั้นและคุณสามารถเข้าถึงได้โดยไม่รู้สึกเจ็บ นอกจากทำเลนั้นก็สมบูรณ์แบบ มันอยู่ใกล้สถานีสะพานควายสะพานควายดังนั้นคุณสามารถไปรอบ ๆ กรุงเทพฯได้อย่างอิสระ ฉันเอาห้องส่วนตัวพร้อมเตียงขนาดควีนไซส์ มันก็เพียงพอแล้วสำหรับฉัน ไม่โปร่ง แต่ไม่คับแคบ มันมีทุกสิ่งที่คุณต้องการสำหรับคนที่ใช้เวลาหนึ่งวันหลบซ่อนตัวอยู่รอบ ๆ กรุงเทพ ข้อเสียคือไม่มีลิฟท์เท่านั้นบันได พิจารณาสิ่งนี้ถ้าคุณนำกระเป๋าเดินทางขนาดใหญ่ อย่างไรก็ตามฉันมีความสุขกับการพักที่นี่
# 9.7
# ทุกอย่างดีมากบริการทำเลและผู้คนสุภาพมากห้องพักค่อนข้างเล็ก แต่มันสะอาดและสะดวกมากขอบคุณสำหรับการเป็นส่วนหนึ่งของวันหยุดของฉัน

# %%
driver.execute_script("window.scrollTo(0,5900)")
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.1
# ที่พักสะอาดดีค่ะ เดินทางไม่ยากมาก แต่ก็แอบเดินไกลนิดนึง แต่นิดจริงค่ะ โดยรวมก็ถือว่าดี แต่ติดที่ห้องน้ำมีน้อยเกินไปค่ะ ไม่ค่อยสะดวกเท่าไหร่
# 9.1
# เคยพักที่นี่บ่อยค่ะ น้องที่ดูแลน่ารักมากเป็นกันเอง ที่พักสะอาด เดินทางสะดวกมาก เงียบไม่น่าเชื่อทั้งที่อยู่ใจกลางเมือง ราคาสบายกระเป๋าจริงๆ เหมาะสำหรับคนที่มารอต่อเครื่องหรือพักค่างชั่วคราว สะดวกทั้งเดินทาง ทั้งที่กิน ห้องน้อยไปหน่อย บางทีจองไม่ทันเต็ม
# 9.1
# ที่พักสะอาด หาของกอนง่าน เดินทางสะดวกไวไฟพร้อมคะ
# 9.1
#
# 9.1
#
# 9.3
# ห้องพักสะอาด ห้องน้ำสะอาด เดินสะดวก ใกล้อนุสาวรีย์
# 9.4
# ห้องน้ำสะอาดมาก บริการดี ที่พักสะอาด ปลอดภัย ที่นั่งเล่นดูดี เเละวิวตรงข้างนอกสวย
# 9.4
#
# 9.4
# อยากจะติ เรื่อง แผงไม้ที่ทำ มาจากไม้อะครับ มันดังเอียดอาด เวลามีคนเดิน พื้นก็จะสะเทือนแบบชัดๆ แต่ภาพรวมคือดีครับ เงียบสงบ คนไม่วุ่นวาย ห้องน้ำดี ทุกอย่างสะอาดเรียบร้อยครับ ถ้ามาอีกก็จะเลือกพักอีกครับ มีน้ำกาแฟ โอวัลติน ถ้ายจาน สบู่ แชมพู บริการ ไม่อั้นด้วย
# 9.4
# สะดวกมาก ที่พักดีใกล้ห้างเซนเตอร์วัน ใกล้บีทีเอส

# %%
driver.execute_script("document.body.style.zoom='50%'")
driver.execute_script("window.scrollTo(0,4500)")
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]")
driver.execute_script("document.body.style.zoom='100%'")
sel.click()
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 9.7
# ทำเลดีห้องพักเล็ก แต่สะอาดเจ้าของเป็นกันเองและเฉพาะ
# 9.7
# สถานที่พักที่ดีเยี่ยม แนะนำเป็นอย่างยิ่ง เตียงนอนสบาย ห้องน้ำสะอาด เดินไม่ถึง 10 นาทีสู่บิ๊กซีจตุจักร 7Eleven สถานีรถไฟ พนักงานที่เป็นมิตร
# 9.7
# พนักงานดีห้องและห้องน้ำสะอาดใกล้กับตลาดนัดจตุจักรและสถานีสะพานควาย
# 9.7
# มันเป็นสถานที่ที่ดีมาก ใกล้รถไฟฟ้าสะดวกมาก
# 9.7
# พนักงานที่ดี! ทำความสะอาดห้อง! ฉันคิดว่าพวกเขาควรจะสร้างลิฟท์

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 45
# Reviews_list : 45

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   ห้องแคบ ไม่มีตู้เย็น รังหนูชัดๆ ตู้เย็นห้องละพ...    5.4
# 1   เซอร์วิสในโรงแรมยังค่อนข้างน้อยไปหน่อย เช่นไม่...    5.5
# 2   ห้องพักแคบมากๆๆเลยครับ ลิฟต์ก็ไม่มี ตู้เย็นมิน...    6.1
# 3   ทำเลดี บริการดี แต่ห้องพักแคบมากไม่สมราคา น้ำด...    6.5
# 4               ห้องพักแคบมากเลย แต่ราคาแพง 1,135 บาท    6.5
# 5   อาหารเช้าไม่หลากหลาย ห้องแคลไปหน่อย โดยรวมถึอว...    8.5
# 6   ห้องอาจแคบไปหน่อย แต่สะอาด สะดวก หาของกินง่าย ...    8.5
# 7   เจ้าของบริการดีมากค่ะ ช่วยแก้ไขปัญหาให้ ห้องพั...    8.5
# 8   ดีมากค่ะ ที่พักใหม่ สะอาด ห้องไม่แคบ อยู่ใกล้ ...    8.5
# 9                  ที่พักใกล้ bts เดินทางสะดวกมากๆค่ะ    8.5
# 10                                                NaN    8.5
# 11  ใกล้btsมากๆสะดวก แต่ห้องแคบไปนิด ผมพักแบบไม่มี...    8.8
# 12              ห้องพักปานกลาง ได้ห้องไม่ตรงกับที่จอง    8.8
# 13  เจ้าหน้าที่บริการเป็นกันเอง แต่ห้องแคบไปหน่อย ...    8.8
# 14   ทำเลดี เดินทางสะดวก แต่ฝักบัวอาบยากสำหรับผู้หญิง    8.8
# 15  ที่พักทำเลดี เดินทางสะดวก ติดbtsสะพานควาย ใกล้...      9
# 16               ห้องพักดี สะอาด เตียงกว้าง แต่แคบมาก    9.1
# 17  ใกล้ bts สะพานควายมาก เดินทางสะดวก แต่ห้องเล็กมาก    9.1
# 18            ดีในระดับพอชเทล คือห้องเล็ก สะอาด เงียบ    9.4
# 19               เดินทางสะดวกใกล้ BTS คะ ห้องพักสะอาด    9.4
# 20  ใกล้บีทีเอสสะพานควาย ห้องพักสะอาด เจ้าของเฟรนล...    9.4
# 21  เดินจากบีทีเอสสะพานควายแค่ไม่กี่เมตร เจ้าของอั...    9.4
# 22  ห้องเล็กไปหน่อย แต่ทำเลดี เดินทางสะดวก เจ้าของ...    9.4
# 23  บริการดีมากค่ะ ประทับใจ มาใช้บริการครั้งที่2แล...    9.7
# 24  ห้องพักดีมากค่ะแต่แคบไปหน่อย แต่ทำเลเหมาะมาก ใ...    9.7
# 25  โลเคชั่นดีมาก ติด BTS exit 3 มี 7-11 อยู่ข้างห...    9.7
# 26  "ห้องพักสะอาดมากๆ เตียงนอนสบาย บรรยากาศห้องดี ...    9.7
# 27  ผมได้เข้าพักห้อง 332 ดีมากครับ ห้องสะอาดมาก บร...    9.7
# 28  เจ้าของที่พักดูแลดีมาก แนะนำที่พักทุกส่วนก่อนจ...    9.7
# 29                       สะอาด สะดวก ปลอดภัย บริการดี     10
# 30  ห้องพักสะอาดพนักงานเป็นมิตร, AC เย็นเป็นไปตามราคา    8.5
# 31  เจ้าของโฮสเทลที่เป็นมิตร, ห้องพักสะอาด, WiFi ไ...    8.5
# 32       มีความสุขมากที่ได้พักที่นี่ แนะนำไม่เคยเบื่อ    8.8
# 33  (+): ใกล้กับ BTS และตลาดจตุจักรมีร้านอาหารริมท...    8.8
# 34  เรามีครอบครัวให้ได้ 4 คนมี 6 อันให้เรา ห้องพัก...    9.1
# 35      ค่อนข้างพอใจแม้ว่าห้องพักค่อนข้างเล็กและสะอาด    9.1
# 36      ใกล้ BTS และสะอาด แต่ห้องเล็ก ๆ และไม่มีลิฟท์    9.1
# 37  ห้องและทางเดินอาจจะเล็กไปหน่อย แต่จริง ๆ แล้วเ...    9.4
# 38  ฟังฉันหน่อยสิสำหรับผู้ที่ต้องการสำรวจตลาดจตุจั...    9.7
# 39  ทุกอย่างดีมากบริการทำเลและผู้คนสุภาพมากห้องพัก...    9.7
# 40  ทำเลดีห้องพักเล็ก แต่สะอาดเจ้าของเป็นกันเองและ...    9.7
# 41  สถานที่พักที่ดีเยี่ยม แนะนำเป็นอย่างยิ่ง เตียง...    9.7
# 42  พนักงานดีห้องและห้องน้ำสะอาดใกล้กับตลาดนัดจตุจ...    9.7
# 43         มันเป็นสถานที่ที่ดีมาก ใกล้รถไฟฟ้าสะดวกมาก    9.7
# 44  พนักงานที่ดี! ทำความสะอาดห้อง! ฉันคิดว่าพวกเขา...    9.7

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  ห้องแคบ ไม่มีตู้เย็น รังหนูชัดๆ ตู้เย็นห้องละพ...    5.4
# 1       1  เซอร์วิสในโรงแรมยังค่อนข้างน้อยไปหน่อย เช่นไม่...    5.5
# 2       2  ห้องพักแคบมากๆๆเลยครับ ลิฟต์ก็ไม่มี ตู้เย็นมิน...    6.1
# 3       3  ทำเลดี บริการดี แต่ห้องพักแคบมากไม่สมราคา น้ำด...    6.5
# 4       4              ห้องพักแคบมากเลย แต่ราคาแพง 1,135 บาท    6.5
# 5       5  อาหารเช้าไม่หลากหลาย ห้องแคลไปหน่อย โดยรวมถึอว...    8.5
# 6       6  ห้องอาจแคบไปหน่อย แต่สะอาด สะดวก หาของกินง่าย ...    8.5
# 7       7  เจ้าของบริการดีมากค่ะ ช่วยแก้ไขปัญหาให้ ห้องพั...    8.5
# 8       8  ดีมากค่ะ ที่พักใหม่ สะอาด ห้องไม่แคบ อยู่ใกล้ ...    8.5
# 9       9                 ที่พักใกล้ bts เดินทางสะดวกมากๆค่ะ    8.5
# 10     11  ใกล้btsมากๆสะดวก แต่ห้องแคบไปนิด ผมพักแบบไม่มี...    8.8
# 11     12              ห้องพักปานกลาง ได้ห้องไม่ตรงกับที่จอง    8.8
# 12     13  เจ้าหน้าที่บริการเป็นกันเอง แต่ห้องแคบไปหน่อย ...    8.8
# 13     14   ทำเลดี เดินทางสะดวก แต่ฝักบัวอาบยากสำหรับผู้หญิง    8.8
# 14     15  ที่พักทำเลดี เดินทางสะดวก ติดbtsสะพานควาย ใกล้...      9
# 15     16               ห้องพักดี สะอาด เตียงกว้าง แต่แคบมาก    9.1
# 16     17  ใกล้ bts สะพานควายมาก เดินทางสะดวก แต่ห้องเล็กมาก    9.1
# 17     18            ดีในระดับพอชเทล คือห้องเล็ก สะอาด เงียบ    9.4
# 18     19               เดินทางสะดวกใกล้ BTS คะ ห้องพักสะอาด    9.4
# 19     20  ใกล้บีทีเอสสะพานควาย ห้องพักสะอาด เจ้าของเฟรนล...    9.4
# 20     21  เดินจากบีทีเอสสะพานควายแค่ไม่กี่เมตร เจ้าของอั...    9.4
# 21     22  ห้องเล็กไปหน่อย แต่ทำเลดี เดินทางสะดวก เจ้าของ...    9.4
# 22     23  บริการดีมากค่ะ ประทับใจ มาใช้บริการครั้งที่2แล...    9.7
# 23     24  ห้องพักดีมากค่ะแต่แคบไปหน่อย แต่ทำเลเหมาะมาก ใ...    9.7
# 24     25  โลเคชั่นดีมาก ติด BTS exit 3 มี 7-11 อยู่ข้างห...    9.7
# 25     26  "ห้องพักสะอาดมากๆ เตียงนอนสบาย บรรยากาศห้องดี ...    9.7
# 26     27  ผมได้เข้าพักห้อง 332 ดีมากครับ ห้องสะอาดมาก บร...    9.7
# 27     28  เจ้าของที่พักดูแลดีมาก แนะนำที่พักทุกส่วนก่อนจ...    9.7
# 28     29                       สะอาด สะดวก ปลอดภัย บริการดี     10
# 29     30  ห้องพักสะอาดพนักงานเป็นมิตร, AC เย็นเป็นไปตามราคา    8.5
# 30     31  เจ้าของโฮสเทลที่เป็นมิตร, ห้องพักสะอาด, WiFi ไ...    8.5
# 31     32       มีความสุขมากที่ได้พักที่นี่ แนะนำไม่เคยเบื่อ    8.8
# 32     33  (+): ใกล้กับ BTS และตลาดจตุจักรมีร้านอาหารริมท...    8.8
# 33     34  เรามีครอบครัวให้ได้ 4 คนมี 6 อันให้เรา ห้องพัก...    9.1
# 34     35      ค่อนข้างพอใจแม้ว่าห้องพักค่อนข้างเล็กและสะอาด    9.1
# 35     36      ใกล้ BTS และสะอาด แต่ห้องเล็ก ๆ และไม่มีลิฟท์    9.1
# 36     37  ห้องและทางเดินอาจจะเล็กไปหน่อย แต่จริง ๆ แล้วเ...    9.4
# 37     38  ฟังฉันหน่อยสิสำหรับผู้ที่ต้องการสำรวจตลาดจตุจั...    9.7
# 38     39  ทุกอย่างดีมากบริการทำเลและผู้คนสุภาพมากห้องพัก...    9.7
# 39     40  ทำเลดีห้องพักเล็ก แต่สะอาดเจ้าของเป็นกันเองและ...    9.7
# 40     41  สถานที่พักที่ดีเยี่ยม แนะนำเป็นอย่างยิ่ง เตียง...    9.7
# 41     42  พนักงานดีห้องและห้องน้ำสะอาดใกล้กับตลาดนัดจตุจ...    9.7
# 42     43         มันเป็นสถานที่ที่ดีมาก ใกล้รถไฟฟ้าสะดวกมาก    9.7
# 43     44  พนักงานที่ดี! ทำความสะอาดห้อง! ฉันคิดว่าพวกเขา...    9.7

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   ห้องแคบ ไม่มีตู้เย็น รังหนูชัดๆ ตู้เย็นห้องละพ...    5.4
# 1   เซอร์วิสในโรงแรมยังค่อนข้างน้อยไปหน่อย เช่นไม่...    5.5
# 2   ห้องพักแคบมากๆๆเลยครับ ลิฟต์ก็ไม่มี ตู้เย็นมิน...    6.1
# 3   ทำเลดี บริการดี แต่ห้องพักแคบมากไม่สมราคา น้ำด...    6.5
# 4               ห้องพักแคบมากเลย แต่ราคาแพง 1,135 บาท    6.5
# 5   อาหารเช้าไม่หลากหลาย ห้องแคลไปหน่อย โดยรวมถึอว...    8.5
# 6   ห้องอาจแคบไปหน่อย แต่สะอาด สะดวก หาของกินง่าย ...    8.5
# 7   เจ้าของบริการดีมากค่ะ ช่วยแก้ไขปัญหาให้ ห้องพั...    8.5
# 8   ดีมากค่ะ ที่พักใหม่ สะอาด ห้องไม่แคบ อยู่ใกล้ ...    8.5
# 9                  ที่พักใกล้ bts เดินทางสะดวกมากๆค่ะ    8.5
# 10  ใกล้btsมากๆสะดวก แต่ห้องแคบไปนิด ผมพักแบบไม่มี...    8.8
# 11              ห้องพักปานกลาง ได้ห้องไม่ตรงกับที่จอง    8.8
# 12  เจ้าหน้าที่บริการเป็นกันเอง แต่ห้องแคบไปหน่อย ...    8.8
# 13   ทำเลดี เดินทางสะดวก แต่ฝักบัวอาบยากสำหรับผู้หญิง    8.8
# 14  ที่พักทำเลดี เดินทางสะดวก ติดbtsสะพานควาย ใกล้...      9
# 15               ห้องพักดี สะอาด เตียงกว้าง แต่แคบมาก    9.1
# 16  ใกล้ bts สะพานควายมาก เดินทางสะดวก แต่ห้องเล็กมาก    9.1
# 17            ดีในระดับพอชเทล คือห้องเล็ก สะอาด เงียบ    9.4
# 18               เดินทางสะดวกใกล้ BTS คะ ห้องพักสะอาด    9.4
# 19  ใกล้บีทีเอสสะพานควาย ห้องพักสะอาด เจ้าของเฟรนล...    9.4
# 20  เดินจากบีทีเอสสะพานควายแค่ไม่กี่เมตร เจ้าของอั...    9.4
# 21  ห้องเล็กไปหน่อย แต่ทำเลดี เดินทางสะดวก เจ้าของ...    9.4
# 22  บริการดีมากค่ะ ประทับใจ มาใช้บริการครั้งที่2แล...    9.7
# 23  ห้องพักดีมากค่ะแต่แคบไปหน่อย แต่ทำเลเหมาะมาก ใ...    9.7
# 24  โลเคชั่นดีมาก ติด BTS exit 3 มี 7-11 อยู่ข้างห...    9.7
# 25  "ห้องพักสะอาดมากๆ เตียงนอนสบาย บรรยากาศห้องดี ...    9.7
# 26  ผมได้เข้าพักห้อง 332 ดีมากครับ ห้องสะอาดมาก บร...    9.7
# 27  เจ้าของที่พักดูแลดีมาก แนะนำที่พักทุกส่วนก่อนจ...    9.7
# 28                       สะอาด สะดวก ปลอดภัย บริการดี     10
# 29  ห้องพักสะอาดพนักงานเป็นมิตร, AC เย็นเป็นไปตามราคา    8.5
# 30  เจ้าของโฮสเทลที่เป็นมิตร, ห้องพักสะอาด, WiFi ไ...    8.5
# 31       มีความสุขมากที่ได้พักที่นี่ แนะนำไม่เคยเบื่อ    8.8
# 32  (+): ใกล้กับ BTS และตลาดจตุจักรมีร้านอาหารริมท...    8.8
# 33  เรามีครอบครัวให้ได้ 4 คนมี 6 อันให้เรา ห้องพัก...    9.1
# 34      ค่อนข้างพอใจแม้ว่าห้องพักค่อนข้างเล็กและสะอาด    9.1
# 35      ใกล้ BTS และสะอาด แต่ห้องเล็ก ๆ และไม่มีลิฟท์    9.1
# 36  ห้องและทางเดินอาจจะเล็กไปหน่อย แต่จริง ๆ แล้วเ...    9.4
# 37  ฟังฉันหน่อยสิสำหรับผู้ที่ต้องการสำรวจตลาดจตุจั...    9.7
# 38  ทุกอย่างดีมากบริการทำเลและผู้คนสุภาพมากห้องพัก...    9.7
# 39  ทำเลดีห้องพักเล็ก แต่สะอาดเจ้าของเป็นกันเองและ...    9.7
# 40  สถานที่พักที่ดีเยี่ยม แนะนำเป็นอย่างยิ่ง เตียง...    9.7
# 41  พนักงานดีห้องและห้องน้ำสะอาดใกล้กับตลาดนัดจตุจ...    9.7
# 42         มันเป็นสถานที่ที่ดีมาก ใกล้รถไฟฟ้าสะดวกมาก    9.7
# 43  พนักงานที่ดี! ทำความสะอาดห้อง! ฉันคิดว่าพวกเขา...    9.7

# %%
table.to_csv("Reviews&Ratings_13th.csv", encoding="utf-8")
