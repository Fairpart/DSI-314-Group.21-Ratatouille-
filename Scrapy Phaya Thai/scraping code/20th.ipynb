# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/detail?spec=19-11-2022.20-11-2022.1.1.HOTEL.3000010032834.Aree%20Art%20Residence.1&contexts=%7B%22inventoryRateKey%22%3A%22povEwB3ZzsU2C6pd%2B6MdU13LUNuufACdbU0usK5vg0dM0tKsNUio4Rxug1zOzHJilcvZa8YdqqIySdppe7dolTIewZlxfjiOGz6oXLTucMvN0%2BgQ3yZPvZcoHwUFNN%2BZpcr%2F%2FNa8o9ElfN8zOYhzzZeg0X586laFpeUViPi9rxCwQ4ITJzKxdjASztFJD5MsDKNfCuNpYoh%2BuNZYtkPMM8N0KRTJ4VFq4ShicQGXCAjUQQmOFyb69aqe8Hll6YWZ3I9RvKjk4IEo%2BSgm41melVlJUAwrC%2F%2B5QUCsG1s1QVIuc5YTT922w9xJEQzAwRUPJUlU0oWZMOAtNu2YMOWeQNVsBZohxEpYRFmg%2B%2BHLDKSC0I%2B4MpT6AtjonGvWhSFYjTE%2FGsBKQXKjBtgZDhjE4C5zlhNP3bbD3EkRDMDBFQ%2BqbhLsKBvPaVGmTFK1NJs61WwFmiHESlhEWaD74csMpKQ%2BjgAtJSRmIL7WdsmYhViGixODei%2FNdx2RuCUEGmeMAUyxf%2BoM7B5yfJewzeVoU2%2FtVYQKI1lMuX%2BRaPNcBUAvSnVpp3982X8ufymNCG%2Bvqv3rBuUa%2BDAlSlNPC7rHF8TsYmOTADU69%2B%2B%2Fol8yLJTHHQhvr%2Bf5O5wjhPZDddaEMD1lhgrNFX59TpZvCV9M4rSDCIHqoFDFRnsCphC6IUw%3D%22%7D&prevSearchId=1749804225286663259&loginPromo=1'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_14032\2714136026.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'ค่าห้องพัก Aree Art Residence สามเสนใน ตั้งแต่ 19-11-2022 ถึง 20-11-2022'

# %%
driver.execute_script("window.scrollTo(0,2900)")

# %%
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[3]/div/div[1]/div")
sel.click()

# %%
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()

# %%
time.sleep(2)
sel_order = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div/div[1]/div")
sel_order.click()

# %%
time.sleep(2)
ascending = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[1]/div/div[2]/div/div/div/div[2]')
ascending.click()

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 4.8
# - ที่พักเก่า น่ากลัว แถมห้องที่เราได้คือประตูห้องอยู่ตรงทรงเดินบันได แบบเดินขึ้นมาเจอประตูห้องเราเลย ละเตียงก็อยู่ตรงประตูเลย เวลาอยู่ในห้องนี่รู้สึกเดียวกันกับแฟนเลย ว่าเหมือนมีอะไรคอยมองอยู่ตลอดเวลา - ไม่มีลิฟท์ - ระเบียงสกปรกมาก มีแต่ขี้นก เหมือนมาพักโรงแรมร้างเลย - การจัดวางเฟอร์นิเจอร์ไม่เหมาะสม เอากระจกไว้ปลายเตียง จัดห้องได้สะเปะ สะปะ มาก - บริการแย่ - ไฟเสียเป็นบางหลอด - น้ำมีกลิ่นเหม็น นี่เป็นครั้งแรกกับการที่ได้ที่พักห่วยขนาดนี้
# 4.8
# อยู่ในซอยลึก พนักงานพูดจาไม่สุภาพ
# 4.9
# ที่พักอยู่ไกลมาก ห้องพักไม่มีตู้เย็นในห้อง ข้าวแพงไป ไม่อร่อยเลย การเดินทางไม่สะดวก ไปไหนลำบาก บริการพอใช่ได้ ห้องด้านในสวย
# 5.1
# ห้องพักเก่าและโทรมมาก อุปกรณ์ต่างๆใกล้ชำรุด ห้องพักไม่สะอาด น่าจะปรับปรุงนะคะ
# 5.1
# พนักงานพูดจาไม่สุภาพ ไม่ให้เกียรติแขกที่เข้าพัก โรงแรมอยู่ในซอยลึกมาก
# 5.2
# ที่ตั้งไม่ดี เดินทางไม่สะดวกนัก
# 5.4
# การเดินทางเข้าออกไม่สะดวก พนักงานต้อนรับ ไม่ ok
# 5.8
# ที่พักเข้าซอยไปไกลลึกมาก เหมือนอยู่ในพื้นที่ที่พักอาศัย ห้องพักธรรมดา ถือว่าแพงเมื่อเทียบกับราคา
# 5.8
# ที่พักเข้าออกได้แค่ทางเดียว ทางเข้าลึกมาก มีรถออกมาส่ง แต่ตอนเข้าก็ต้องเข้าไปเองอยู่ดี พนักงานต้อนรับก็เฉยๆ ดีแค่ห้องนอนกว้างสบาย
# 6
# ห้องพักไม่สะอาด พนักงานบริการแย่มากค่ะ ไม่ประทับใจเลย

# %%
driver.execute_script("window.scrollTo(0,5900)")
time.sleep(5)
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
next_page.click()

# %%
clear_list(ratings_list,reviews_list)

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 6
# อยู่ลึกเกินไปยากต่อการออกไปข้างนอก
# 6
# 1.พนักงานไม่เต็มใจบริการที่หน้าเค้าเตอร์ 2.พนักงานไม่อกนวยความสะดวกให้ต้องลงไปเอาเองที่ข้างล่าง(เป่าผม) 3.ห้องพักสะอาด (ดี)
# 6
# ห้องพักดี แต่โรงแรมอยู่ลึกมากหายาก เจ้าหน้าที่ที่เคาเตอร์หน้าตาไม่ยิ้มแย้มเลย พอจะให้ไปส่งหน้าปากซอยก็ทำหน้าไม่พอใจทันที คือที่มาพักที่โรงแรมคุณก็เพราะคุณโฆษณาไว้ว่ารับส่งฟรี เราก็ขอใช้บริการไง เราผิดตรงไหน พักโรงแรมคุณคือเดินเหนื่อยมาก คนเดียวด้วย ถ้าไปพักที่นี่ต้องมีรถส่วนตัวค่ะ
# 6
# พนักงานเค้าเตอร์ ไม่เป็นมิตรเลยไม่ยิ้มแย้ม เรากดหมายเลขบันชีผิด ทำเหมือนกึงอารมใส่ ห้องดีสะอาด
# 6
# ที่พักดี แต่ไม่มีตู้เย็น แหล่งที่ตั้งไกลมากๆๆ ในซอยสุดๆๆ หายาก รอบๆ ไม่มีแหล่งที่กิน
# 6.1
# ไม่มีพนักงานที่หน้าเคาน์เตอร์เช็กอิน ต้องรอประมาณ 30 นาทีจึงจะได้เช็กอิน ที่นั่งรอไม่สะดวก โรงแรมอยู่ในซอยลึก ห้องกว้าง สะอาดดี
# 6.2
# โรงแรมอยู่ในซอยลึกมาก ถ้าหาโรงแรมไม่เจอโทรเรียกรถของโรงแรมได้ แต่ครั้งละ 20 บาทต่อคน ถ้านั่งรถออกจากซอยมาก็ขึ้นบีทีเอสไปไหนมาไหนได้ พนักงานขับรถไปส่งบริการดี ช่วยถือของเปิดประตู แต่คนบริการที่หน้าเคาน์เตอร์พูดจาเหมือนจะรำคาญ ไม่ค่อยยิ้ม เสียงพูดไม่ค่อยต้อนรับ ไม่มีบริการทำความสะอาดห้องที่ไปพัก ในเว็บบอกมีตู้เย็น แต่จริงๆถ้าถามว่าจะไปพักที่เดิมอีกมั้ย ถ้าไปอีก คิดว่าไม่แล้ว แต่โดยรวมก็ถือว่าได้ถ้าจำเป็นต้องพักที่นี่
# 6.6
# รร.ดี สวยมากๆ แต่เสียดาย ที่น้องที่เฝ้าหน้าฟร้อนท์อัทยาศัยไม่ค่อยดี ทำให้ความอยากมาพักซ้ำไม่มีค่ะ
# 8.2
# ห้องพักสะอาดค่ะ น่าอยู่ แต่ที่พักอาจจะอยู่ลึกหน่อยค่ะ
# 8.3
# โดยรวมโอเคเลย...

# %%
driver.execute_script("window.scrollTo(0,5900)")
time.sleep(5)
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
next_page.click()

time.sleep(5)
clear_list(ratings_list,reviews_list)
time.sleep(5)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 8.4
# ห้องพักสะอาด พนักงานบริการดีค่ะช
# 8.4
# ชอบห้องพักค่ะ แต่โรงแรมอยู่ในซอยลึกไปหน่อยค่ะ
# 8.4
# ทุกอย่างดีหมด แต่พนักงานต้อนรับ ไม่มี Service mind
# 8.4
# ที่พักสะอาด สบาย แต่อยู่ในซอยลึก มีบริการรถรับส่งหน้าปากซอย
# 8.5
# ห้องสวย บริการดีคับ ติดนิดเดียวไม่มีตู้เย็นในห้องและอยู่ลึกไปนิด
# 8.5
# ดีนะ แต่อยู่ลึก ไม่เหมาะกับคนที่ไม่มีรถ และต้องการเดินทางด้วย bts
# 8.5
# ดีมากๆค่ะ แต่ติดอยู่ในซอยลึกไปหน่อย
# 8.5
# เสียดายเข้าซอยลึกมากคะ แต่สถานที่สะอาด ปลอดภัย และสบายคะ
# 8.5
# ห้องพักดีค่ะ แต่อยู่ลึกไปหน่อย
# 8.5
# พนักงานน่ารัก ห้องน่ารักค่ะ สะอาด เงียบสงบ

# %%
driver.execute_script("window.scrollTo(0,5900)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
time.sleep(3)
next_page.click()

time.sleep(3)
clear_list(ratings_list,reviews_list)
time.sleep(3)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 8.5
# อยู่สุดซอยเลยค่ะ แต่โดยรวมดี ผ้าม่านห้องน้ำดูไม่ค่อยสะอาด เลอะๆนิดหน่อย ไม่มีตู้เย็นค่ะ อย่างอื่นดีหมดค่ะ
# 8.5
# ห้องพักสะอาดดีค่ะ บริการดีค่ะ พนักงานยิ้มแย้มดีค่ะ
# 8.5
# อยู่ในซอยลึก...
# 8.5
# ดีค่ะ โรงแรมสะอาดค่ะ ทางเข้าลึก แต่มีรถส่งค่ะ
# 8.7
# ที่พักเข้าไปจากหน้าซอยลึกพอควรค่ะ เดินเข้าไม่ไหวต้องนั่งวินหรือแท็กซี่เข้าไป แต่ตอนออกมาจากที่พักมีบริการรถส่งหน้าซอยฟรี ถึงบีทีเอส 20 บาทถือว่าดีค่ะ ส่วนเรื่องอื่น ความสะอาดดีค่ะ มีห้องโถงให้ใช้รวมดี ห้องโถงตกแต่งดีค่ะนั่งอ่านหนังสือกินข้าวนี่โอเคเลย
# 8.7
# ห้องกว้างและสะอาดมากเลยค่ะ พนักงานก็ตอนรับดีมาก ถือว่าที่พักน่าอยู่เลยติดแค่อยู่ลึกมาก
# 8.7
# ห้องกว้าง สะอาดดี แต่อยู่ในซอยลึกมาก
# 8.7
# อยู่ลึกไปหน่อย แต่พนักงานต้อนรับใจดี ขับรถออกมาส่งและเรียกแท็กซี่ให้ ภายในสวยมาก น่าพักผ่อน ให้คะแนนเต็มเลย
# 8.8
# พอดีว่าต้องมา รพ.รามา หลายวัน เลยต้องหาที่พักใกล้ๆ รพ. นี่คืออีกที่ที่แนะนำนะครับ ข้อดี 1.เงียบสงบ 2.มีที่จอดรถ 3.ห้องสอาด 4.พนักงานเป็นกันเองและบริการดี 5.ราคาประหยัด 6.ระบบความปลอดภัยดี ข้อเสีย 1.ทางเข้าจะลึกหน่อย ไม่สะดวกต่อผู้ไม่ได้นำรถมา 2.ไม่มีตู้เย็น สรุป ผมให้ 80%
# 8.8
# ห้องพักสบาย กว้าง สะอาดดี แต่แอบรู้สึกว่าห้องอับไปหน่อย เหมาะกับมาพักแค่คืนเดียว สำหรับคนไม่มีรถ อาจเดินทางเข้ามาลำบากหน่อย

# %%
driver.execute_script("window.scrollTo(0,5900)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
next_page.click()

time.sleep(3)
clear_list(ratings_list,reviews_list)
time.sleep(3)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)

    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 8.8
# พนักงานบริการดีมาก น่ารักทุกคน ห้องพักสะอาด แต่ไม่มีตู้เย็นค่ะ อยากได้อะไรขอพนักงานได้หมดเลยค่ะ ชอบที่นี่มาก ถ้ามีโอกาสจะกลับไปพักอีก
# 8.8
# ที่ตั้งอยู่ในซอยลึกมาก และเป็นซอยตันด้วย แต่โรงแรมก็แก้ปัญหาด้วยบริการรถรับส่งไปถึงบีทีเอสอารีย์ ก็โอเคอยู่ค่ะ
# 8.9
# เงียบดี สะอาด ไม่มีรถผ่าน อยู่ในซอยค่อนข้างลึก
# 9
# ทำเลที่ตั้งเข้าถึงยาก ต้องเข้าซอยลึก
# 9.1
# ดีมากเลยค่ะ มีบริการอำนวยความสะดวกให้ลูกค้า
# 9.1
# ห้องสบายมาก ในราคานี้ แต่เสียอย่างเดียว คืออยู่ลึกมากไปหน่อยค่ะ
# 9.1
# ห้องพักสะอาดมากค่ะ บริการประทับใจ
# 9.1
# สะอาดดี ราคากลางๆค่อนไปถูก คุ้มค่ากับราคา
# 9.4
# ดีมาก ห้องสะอาด ตกแต่งสวยมากๆ
# 9.4
# โรงเเรมถือว่าดีมากครับ เงียบ มีเเต่เสียงฝาท่อเล็กน้อย อยู่ในซอยลึกหน่อย ห้อง 21 แอร์เก่าครับเสียงแอร์ดังไม่ค่อยเย็นเท่าไหร่ครับ

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 50
# Reviews_list : 50

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   - ที่พักเก่า น่ากลัว แถมห้องที่เราได้คือประตูห...    4.8
# 1                   อยู่ในซอยลึก พนักงานพูดจาไม่สุภาพ    4.8
# 2   ที่พักอยู่ไกลมาก ห้องพักไม่มีตู้เย็นในห้อง ข้า...    4.9
# 3   ห้องพักเก่าและโทรมมาก อุปกรณ์ต่างๆใกล้ชำรุด ห้...    5.1
# 4   พนักงานพูดจาไม่สุภาพ ไม่ให้เกียรติแขกที่เข้าพั...    5.1
# 5                     ที่ตั้งไม่ดี เดินทางไม่สะดวกนัก    5.2
# 6     การเดินทางเข้าออกไม่สะดวก พนักงานต้อนรับ ไม่ ok    5.4
# 7   ที่พักเข้าซอยไปไกลลึกมาก เหมือนอยู่ในพื้นที่ที...    5.8
# 8   ที่พักเข้าออกได้แค่ทางเดียว ทางเข้าลึกมาก มีรถ...    5.8
# 9   ห้องพักไม่สะอาด พนักงานบริการแย่มากค่ะ ไม่ประท...      6
# 10                 อยู่ลึกเกินไปยากต่อการออกไปข้างนอก      6
# 11  1.พนักงานไม่เต็มใจบริการที่หน้าเค้าเตอร์ 2.พนั...      6
# 12  ห้องพักดี แต่โรงแรมอยู่ลึกมากหายาก เจ้าหน้าที่...      6
# 13  พนักงานเค้าเตอร์ ไม่เป็นมิตรเลยไม่ยิ้มแย้ม เรา...      6
# 14  ที่พักดี แต่ไม่มีตู้เย็น แหล่งที่ตั้งไกลมากๆๆ ...      6
# 15  ไม่มีพนักงานที่หน้าเคาน์เตอร์เช็กอิน ต้องรอประ...    6.1
# 16  โรงแรมอยู่ในซอยลึกมาก ถ้าหาโรงแรมไม่เจอโทรเรีย...    6.2
# 17  รร.ดี สวยมากๆ แต่เสียดาย ที่น้องที่เฝ้าหน้าฟร้...    6.6
# 18  ห้องพักสะอาดค่ะ น่าอยู่ แต่ที่พักอาจจะอยู่ลึกห...    8.2
# 19                                   โดยรวมโอเคเลย...    8.3
# 20                   ห้องพักสะอาด พนักงานบริการดีค่ะช    8.4
# 21      ชอบห้องพักค่ะ แต่โรงแรมอยู่ในซอยลึกไปหน่อยค่ะ    8.4
# 22  ทุกอย่างดีหมด แต่พนักงานต้อนรับ ไม่มี Service ...    8.4
# 23  ที่พักสะอาด สบาย แต่อยู่ในซอยลึก มีบริการรถรับ...    8.4
# 24  ห้องสวย บริการดีคับ ติดนิดเดียวไม่มีตู้เย็นในห...    8.5
# 25  ดีนะ แต่อยู่ลึก ไม่เหมาะกับคนที่ไม่มีรถ และต้อ...    8.5
# 26                ดีมากๆค่ะ แต่ติดอยู่ในซอยลึกไปหน่อย    8.5
# 27  เสียดายเข้าซอยลึกมากคะ แต่สถานที่สะอาด ปลอดภัย...    8.5
# 28                     ห้องพักดีค่ะ แต่อยู่ลึกไปหน่อย    8.5
# 29         พนักงานน่ารัก ห้องน่ารักค่ะ สะอาด เงียบสงบ    8.5
# 30  อยู่สุดซอยเลยค่ะ แต่โดยรวมดี ผ้าม่านห้องน้ำดูไ...    8.5
# 31  ห้องพักสะอาดดีค่ะ บริการดีค่ะ พนักงานยิ้มแย้มด...    8.5
# 32                                    อยู่ในซอยลึก...    8.5
# 33      ดีค่ะ โรงแรมสะอาดค่ะ ทางเข้าลึก แต่มีรถส่งค่ะ    8.5
# 34  ที่พักเข้าไปจากหน้าซอยลึกพอควรค่ะ เดินเข้าไม่ไ...    8.7
# 35  ห้องกว้างและสะอาดมากเลยค่ะ พนักงานก็ตอนรับดีมา...    8.7
# 36               ห้องกว้าง สะอาดดี แต่อยู่ในซอยลึกมาก    8.7
# 37  อยู่ลึกไปหน่อย แต่พนักงานต้อนรับใจดี ขับรถออกม...    8.7
# 38  พอดีว่าต้องมา รพ.รามา หลายวัน เลยต้องหาที่พักใ...    8.8
# 39  ห้องพักสบาย กว้าง สะอาดดี แต่แอบรู้สึกว่าห้องอ...    8.8
# 40  พนักงานบริการดีมาก น่ารักทุกคน ห้องพักสะอาด แต...    8.8
# 41  ที่ตั้งอยู่ในซอยลึกมาก และเป็นซอยตันด้วย แต่โร...    8.8
# 42     เงียบดี สะอาด ไม่มีรถผ่าน อยู่ในซอยค่อนข้างลึก    8.9
# 43               ทำเลที่ตั้งเข้าถึงยาก ต้องเข้าซอยลึก      9
# 44        ดีมากเลยค่ะ มีบริการอำนวยความสะดวกให้ลูกค้า    9.1
# 45  ห้องสบายมาก ในราคานี้ แต่เสียอย่างเดียว คืออยู...    9.1
# 46                  ห้องพักสะอาดมากค่ะ บริการประทับใจ    9.1
# 47          สะอาดดี ราคากลางๆค่อนไปถูก คุ้มค่ากับราคา    9.1
# 48                      ดีมาก ห้องสะอาด ตกแต่งสวยมากๆ    9.4
# 49  โรงเเรมถือว่าดีมากครับ เงียบ มีเเต่เสียงฝาท่อเ...    9.4

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  - ที่พักเก่า น่ากลัว แถมห้องที่เราได้คือประตูห...    4.8
# 1       1                  อยู่ในซอยลึก พนักงานพูดจาไม่สุภาพ    4.8
# 2       2  ที่พักอยู่ไกลมาก ห้องพักไม่มีตู้เย็นในห้อง ข้า...    4.9
# 3       3  ห้องพักเก่าและโทรมมาก อุปกรณ์ต่างๆใกล้ชำรุด ห้...    5.1
# 4       4  พนักงานพูดจาไม่สุภาพ ไม่ให้เกียรติแขกที่เข้าพั...    5.1
# 5       5                    ที่ตั้งไม่ดี เดินทางไม่สะดวกนัก    5.2
# 6       6    การเดินทางเข้าออกไม่สะดวก พนักงานต้อนรับ ไม่ ok    5.4
# 7       7  ที่พักเข้าซอยไปไกลลึกมาก เหมือนอยู่ในพื้นที่ที...    5.8
# 8       8  ที่พักเข้าออกได้แค่ทางเดียว ทางเข้าลึกมาก มีรถ...    5.8
# 9       9  ห้องพักไม่สะอาด พนักงานบริการแย่มากค่ะ ไม่ประท...      6
# 10     10                 อยู่ลึกเกินไปยากต่อการออกไปข้างนอก      6
# 11     11  1.พนักงานไม่เต็มใจบริการที่หน้าเค้าเตอร์ 2.พนั...      6
# 12     12  ห้องพักดี แต่โรงแรมอยู่ลึกมากหายาก เจ้าหน้าที่...      6
# 13     13  พนักงานเค้าเตอร์ ไม่เป็นมิตรเลยไม่ยิ้มแย้ม เรา...      6
# 14     14  ที่พักดี แต่ไม่มีตู้เย็น แหล่งที่ตั้งไกลมากๆๆ ...      6
# 15     15  ไม่มีพนักงานที่หน้าเคาน์เตอร์เช็กอิน ต้องรอประ...    6.1
# 16     16  โรงแรมอยู่ในซอยลึกมาก ถ้าหาโรงแรมไม่เจอโทรเรีย...    6.2
# 17     17  รร.ดี สวยมากๆ แต่เสียดาย ที่น้องที่เฝ้าหน้าฟร้...    6.6
# 18     18  ห้องพักสะอาดค่ะ น่าอยู่ แต่ที่พักอาจจะอยู่ลึกห...    8.2
# 19     19                                   โดยรวมโอเคเลย...    8.3
# 20     20                   ห้องพักสะอาด พนักงานบริการดีค่ะช    8.4
# 21     21      ชอบห้องพักค่ะ แต่โรงแรมอยู่ในซอยลึกไปหน่อยค่ะ    8.4
# 22     22  ทุกอย่างดีหมด แต่พนักงานต้อนรับ ไม่มี Service ...    8.4
# 23     23  ที่พักสะอาด สบาย แต่อยู่ในซอยลึก มีบริการรถรับ...    8.4
# 24     24  ห้องสวย บริการดีคับ ติดนิดเดียวไม่มีตู้เย็นในห...    8.5
# 25     25  ดีนะ แต่อยู่ลึก ไม่เหมาะกับคนที่ไม่มีรถ และต้อ...    8.5
# 26     26                ดีมากๆค่ะ แต่ติดอยู่ในซอยลึกไปหน่อย    8.5
# 27     27  เสียดายเข้าซอยลึกมากคะ แต่สถานที่สะอาด ปลอดภัย...    8.5
# 28     28                     ห้องพักดีค่ะ แต่อยู่ลึกไปหน่อย    8.5
# 29     29         พนักงานน่ารัก ห้องน่ารักค่ะ สะอาด เงียบสงบ    8.5
# 30     30  อยู่สุดซอยเลยค่ะ แต่โดยรวมดี ผ้าม่านห้องน้ำดูไ...    8.5
# 31     31  ห้องพักสะอาดดีค่ะ บริการดีค่ะ พนักงานยิ้มแย้มด...    8.5
# 32     32                                    อยู่ในซอยลึก...    8.5
# 33     33      ดีค่ะ โรงแรมสะอาดค่ะ ทางเข้าลึก แต่มีรถส่งค่ะ    8.5
# 34     34  ที่พักเข้าไปจากหน้าซอยลึกพอควรค่ะ เดินเข้าไม่ไ...    8.7
# 35     35  ห้องกว้างและสะอาดมากเลยค่ะ พนักงานก็ตอนรับดีมา...    8.7
# 36     36               ห้องกว้าง สะอาดดี แต่อยู่ในซอยลึกมาก    8.7
# 37     37  อยู่ลึกไปหน่อย แต่พนักงานต้อนรับใจดี ขับรถออกม...    8.7
# 38     38  พอดีว่าต้องมา รพ.รามา หลายวัน เลยต้องหาที่พักใ...    8.8
# 39     39  ห้องพักสบาย กว้าง สะอาดดี แต่แอบรู้สึกว่าห้องอ...    8.8
# 40     40  พนักงานบริการดีมาก น่ารักทุกคน ห้องพักสะอาด แต...    8.8
# 41     41  ที่ตั้งอยู่ในซอยลึกมาก และเป็นซอยตันด้วย แต่โร...    8.8
# 42     42     เงียบดี สะอาด ไม่มีรถผ่าน อยู่ในซอยค่อนข้างลึก    8.9
# 43     43               ทำเลที่ตั้งเข้าถึงยาก ต้องเข้าซอยลึก      9
# 44     44        ดีมากเลยค่ะ มีบริการอำนวยความสะดวกให้ลูกค้า    9.1
# 45     45  ห้องสบายมาก ในราคานี้ แต่เสียอย่างเดียว คืออยู...    9.1
# 46     46                  ห้องพักสะอาดมากค่ะ บริการประทับใจ    9.1
# 47     47          สะอาดดี ราคากลางๆค่อนไปถูก คุ้มค่ากับราคา    9.1
# 48     48                      ดีมาก ห้องสะอาด ตกแต่งสวยมากๆ    9.4
# 49     49  โรงเเรมถือว่าดีมากครับ เงียบ มีเเต่เสียงฝาท่อเ...    9.4

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   - ที่พักเก่า น่ากลัว แถมห้องที่เราได้คือประตูห...    4.8
# 1                   อยู่ในซอยลึก พนักงานพูดจาไม่สุภาพ    4.8
# 2   ที่พักอยู่ไกลมาก ห้องพักไม่มีตู้เย็นในห้อง ข้า...    4.9
# 3   ห้องพักเก่าและโทรมมาก อุปกรณ์ต่างๆใกล้ชำรุด ห้...    5.1
# 4   พนักงานพูดจาไม่สุภาพ ไม่ให้เกียรติแขกที่เข้าพั...    5.1
# 5                     ที่ตั้งไม่ดี เดินทางไม่สะดวกนัก    5.2
# 6     การเดินทางเข้าออกไม่สะดวก พนักงานต้อนรับ ไม่ ok    5.4
# 7   ที่พักเข้าซอยไปไกลลึกมาก เหมือนอยู่ในพื้นที่ที...    5.8
# 8   ที่พักเข้าออกได้แค่ทางเดียว ทางเข้าลึกมาก มีรถ...    5.8
# 9   ห้องพักไม่สะอาด พนักงานบริการแย่มากค่ะ ไม่ประท...      6
# 10                 อยู่ลึกเกินไปยากต่อการออกไปข้างนอก      6
# 11  1.พนักงานไม่เต็มใจบริการที่หน้าเค้าเตอร์ 2.พนั...      6
# 12  ห้องพักดี แต่โรงแรมอยู่ลึกมากหายาก เจ้าหน้าที่...      6
# 13  พนักงานเค้าเตอร์ ไม่เป็นมิตรเลยไม่ยิ้มแย้ม เรา...      6
# 14  ที่พักดี แต่ไม่มีตู้เย็น แหล่งที่ตั้งไกลมากๆๆ ...      6
# 15  ไม่มีพนักงานที่หน้าเคาน์เตอร์เช็กอิน ต้องรอประ...    6.1
# 16  โรงแรมอยู่ในซอยลึกมาก ถ้าหาโรงแรมไม่เจอโทรเรีย...    6.2
# 17  รร.ดี สวยมากๆ แต่เสียดาย ที่น้องที่เฝ้าหน้าฟร้...    6.6
# 18  ห้องพักสะอาดค่ะ น่าอยู่ แต่ที่พักอาจจะอยู่ลึกห...    8.2
# 19                                   โดยรวมโอเคเลย...    8.3
# 20                   ห้องพักสะอาด พนักงานบริการดีค่ะช    8.4
# 21      ชอบห้องพักค่ะ แต่โรงแรมอยู่ในซอยลึกไปหน่อยค่ะ    8.4
# 22  ทุกอย่างดีหมด แต่พนักงานต้อนรับ ไม่มี Service ...    8.4
# 23  ที่พักสะอาด สบาย แต่อยู่ในซอยลึก มีบริการรถรับ...    8.4
# 24  ห้องสวย บริการดีคับ ติดนิดเดียวไม่มีตู้เย็นในห...    8.5
# 25  ดีนะ แต่อยู่ลึก ไม่เหมาะกับคนที่ไม่มีรถ และต้อ...    8.5
# 26                ดีมากๆค่ะ แต่ติดอยู่ในซอยลึกไปหน่อย    8.5
# 27  เสียดายเข้าซอยลึกมากคะ แต่สถานที่สะอาด ปลอดภัย...    8.5
# 28                     ห้องพักดีค่ะ แต่อยู่ลึกไปหน่อย    8.5
# 29         พนักงานน่ารัก ห้องน่ารักค่ะ สะอาด เงียบสงบ    8.5
# 30  อยู่สุดซอยเลยค่ะ แต่โดยรวมดี ผ้าม่านห้องน้ำดูไ...    8.5
# 31  ห้องพักสะอาดดีค่ะ บริการดีค่ะ พนักงานยิ้มแย้มด...    8.5
# 32                                    อยู่ในซอยลึก...    8.5
# 33      ดีค่ะ โรงแรมสะอาดค่ะ ทางเข้าลึก แต่มีรถส่งค่ะ    8.5
# 34  ที่พักเข้าไปจากหน้าซอยลึกพอควรค่ะ เดินเข้าไม่ไ...    8.7
# 35  ห้องกว้างและสะอาดมากเลยค่ะ พนักงานก็ตอนรับดีมา...    8.7
# 36               ห้องกว้าง สะอาดดี แต่อยู่ในซอยลึกมาก    8.7
# 37  อยู่ลึกไปหน่อย แต่พนักงานต้อนรับใจดี ขับรถออกม...    8.7
# 38  พอดีว่าต้องมา รพ.รามา หลายวัน เลยต้องหาที่พักใ...    8.8
# 39  ห้องพักสบาย กว้าง สะอาดดี แต่แอบรู้สึกว่าห้องอ...    8.8
# 40  พนักงานบริการดีมาก น่ารักทุกคน ห้องพักสะอาด แต...    8.8
# 41  ที่ตั้งอยู่ในซอยลึกมาก และเป็นซอยตันด้วย แต่โร...    8.8
# 42     เงียบดี สะอาด ไม่มีรถผ่าน อยู่ในซอยค่อนข้างลึก    8.9
# 43               ทำเลที่ตั้งเข้าถึงยาก ต้องเข้าซอยลึก      9
# 44        ดีมากเลยค่ะ มีบริการอำนวยความสะดวกให้ลูกค้า    9.1
# 45  ห้องสบายมาก ในราคานี้ แต่เสียอย่างเดียว คืออยู...    9.1
# 46                  ห้องพักสะอาดมากค่ะ บริการประทับใจ    9.1
# 47          สะอาดดี ราคากลางๆค่อนไปถูก คุ้มค่ากับราคา    9.1
# 48                      ดีมาก ห้องสะอาด ตกแต่งสวยมากๆ    9.4
# 49  โรงเเรมถือว่าดีมากครับ เงียบ มีเเต่เสียงฝาท่อเ...    9.4

# %%
table.to_csv("Reviews&Ratings_20th.csv", encoding="utf-8")
