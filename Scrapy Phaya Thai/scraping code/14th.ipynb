# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.4)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/thailand/grand-tower-inn-rama-6-hotel-1000000308641'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_21344\997711878.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'ค่าห้องพัก แกรนด์ ทาวเวอร์ อินน์ พระราม 6 (Grand Tower Inn rama 6 Hotel) สามเสนใน ตั้งแต่ 17-11-2022 ถึง 18-11-2022'

# %%
driver.execute_script("window.scrollTo(0,3600)")

# %%
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[3]/div/div[1]/div")
sel.click()

# %%
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()

# %%
time.sleep(2)
driver.execute_script("window.scrollTo(0,3600)")
sel_order = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div/div[1]/div")
sel_order.click()

# %%
ascending = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div[1]/div/div[2]/div/div/div/div[2]')
ascending.click()

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 4.5
# เสียงดังมาก ขนาดอยู่ชั้นสูงๆแล้ว ก็ยังมีแม่บ้านเดินไปมาตลอดทั้งคืน ไม่ชอบ
# 5.4
# การเช็คอิน ช้า สอบถามจนปวดหัว ไม่มีการเตรียมข้อมูลลูกค้าที่จองมาแล้ว
# 5.4
# ห้องพักสามารถเชื่อมกับอีกห้องได้ ซึ่งเราเป็นผู้หญิงคนเดียว ข้างห้องพยายามเปิดห้องเราเพื่อจะเข้ามาทั้งคืน นอนไม่หลับ หวาดผวา กลัวเรื่องความปลอดภัย แจ้งพนักงานต้อนรับแล้ว แต่ไม่ได้รับการเปลี่ยนห้องให้ นักท่องเที่ยวออกมานอกห้องเพื่อแพ็คของ คุยกันเสียงดัง นอนหลับๆตื่นๆทั้งคืน ทางพนักงานต้อนรับควรจะแยกลูกค้าที่ไม่ได้มาจากทัวร์ให้อยู่คนละชั้น เพื่อความปลอดภัย และความเป็นส่วนตัว โดยอาจให้อยู่คนละชั้นกับทัวร์
# 6
# พนักงานบริการหน้าเคาเตอร์บริการไม่ดี
# การตอบกลับจากที่พัก
# 11 FEB 2020
# เรียน คุณ Pemika
# ทางโรงแรมต้องขออภัยในการบริการที่ไม่ดีของพนักงานจะทำการตักเตือนและจะนำคำติชมไปพัฒนาต่อไป
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 6
# เข้าใจว่าที่จองเป็นเตียงเดี่ยวแต่ทำไมมาถึงที่พักเป็นเตียงคู่
# 6
# ควรปรับปรุงในส่วนของพนักงานต้อนรับ บริเวณที่ทานอาหารยังไม่เป็นที่น่าพอใจ
# 6.6
# บอกว่า ขอชั้นไม่สูง จัดให้ซะ ชั้น 20
# 7.3
# ก็โอเค สมกับ 3 ดาว บริเวณโรงแรมสะอาด
# 8.4
# สะอาด สะดวก สมราคา แต่ฟูกนิ่มไปทำให้ปวดหลัง นอนไม่สบายตัว
# 8.4
# ไม่มีชา กาแฟ และกาน้ำร้อนไว้ในห้อง

# %%
driver.execute_script("window.scrollTo(0,6600)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
next_page.click()

# %%
clear_list(ratings_list,reviews_list)

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 8.5
# พนักงานบริการดีมากครับ ตอนเช็คอิน take care ลูกค้าได้ดีมากเลยครับ
# การตอบกลับจากที่พัก
# 01 SEP 2022
# ขอบคุณมากสำหรับความคิดเห็นของคุณ เราหวังว่าจะได้ต้อนรับคุณกลับมา
# 8.5
# ห้องกว้างสะอาด ราคาไม่แพง อยู่ติดศูนย์บริการทางการแพทย์รามา สะดวกมากค่ะ
# 8.5
# บริการดี ห้องพักสบาย แนะนะเลยค่ะ
# การตอบกลับจากที่พัก
# 13 DEC 2020
# เรียนคุณณัฐริณี
# ขอบคุณสำหรับความคิดเห็นของคุณโรงแรมหวังเป็นอย่างยิ่งว่าจะได้ต้อนรับคุณในครั้งต่อไป ^^
# ขอขอบคุณและขอแสดงความนับถือ
# กัญญากรทองนพเก้า
# ผู้จัดการแผนกต้อนรับส่วนหน้า
# 8.5
# ห้องพักสะอาด อาหารเช้าหลากหลายค่ะ
# การตอบกลับจากที่พัก
# 06 MAR 2020
# ทางโรงแรมขอขอบคุณสำหรับข้อติชมและหวังว่าในโอกาสหน้าจะได้ต้อนรับคุณอีกครั้งค่ะ
# ขอบคุณค่ะ
# 8.5
# ทำเลดี เดินทางสะดวกมีที่จอดรถ เตียงนอนนุ่มกำลังดีความสะอาดปานกลาง เข้าพัก2ครั้ง ครั้งเเรกมีชากาเเฟครบเเต่ครั้งล่าสุดไม่มีกระติกน้ำร้อนเเละกาเเฟในห้อง
# การตอบกลับจากที่พัก
# 13 JAN 2020
# เรียนคุณ Nantarak
# ทางโรงแรมขอขอบคุณสำหรับข้อติชม ทางโรงแรมจะนำไปพัฒนาและปรับปรุงต่อไป ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณในโอกาสต่อไป
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 8.5
# ถือว่าดีค่ะ พนักงานบริการดีค่ะ แต่เซเวนต้องเดินไปไกลหน่อย แต่ก็โอเค
# การตอบกลับจากที่พัก
# 13 JAN 2020
# เรียนคุณSukarin
# ทางโรงแรมขอขอบคุณสำหรับข้อติชม ทางโรงแรมจะนำไปพัฒนาและปรับปรุงต่อไป ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณในโอกาสต่อไป
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 8.5
# ห้องพักโอเคคุ้มค่าเงินมากถึงจะมีปัญหาเล็กน้อย
# การตอบกลับจากที่พัก
# 13 JAN 2020
# เรียนคุณ Gergkeat
# ทางโรงแรมขอขอบคุณสำหรับข้อติชม ทางโรงแรมจะนำไปพัฒนาและปรับปรุงต่อไป ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณในโอกาสต่อไป
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 8.5
# ห้องสะอาดดีค่ะ สวยมาก ใกล้ถนนใหญ่
# 8.5
# สะอาดมาก น่าพักใกล้ที่เที่ยวมากๆ
# 8.5
# พนักงาน front ควรแก้ปัญหาให้ลูกค้า และไม่ควรพูด สิ่งที่ไม่เกิดประโยชน์ และเรื่องที่ตัวเอง ไม่รู้จริง

# %%
driver.execute_script("window.scrollTo(0,6600)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
next_page.click()

time.sleep(5)
clear_list(ratings_list,reviews_list)
time.sleep(5)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 8.5
# ห้องสะอาดวิวสวยเดินทางสะดวกและสิ่งอำนวยความสะดวกครบ
# 8.5
#  ห้องสวย ราคาถูก แม่บ้านทำความสะอาดเนี๊ยบดี แต่สระว่ายน้ำอยู่ชั้นบนสุดไม่มีร่ม เลย ไม่มีไฟด้วย ร้อนกลางวัน และดูมืดเกินไปเมื่อตกเย็น ห่างไกลร้านค้าหน่อย ไม่ค่อยมีร้านค้า ค่ะ แต่ห้องถือว่ากว้างและโอเคราคาดีค่ะ อาหารโรงแรมก็อร่อยใช้ได้ค่ะ
# 8.5
# ทำเลดี ห้องได้มาตรฐาน ลุ้นตรงต้องใช้ลิฟต์รถยนต์ในการขึ้นลง ถ้าใครไม่เคยใช้ลิฟต์รถยนต์มาก่อนจะตื่นเต้นมากๆ
# 8.5
# ที่พักสะอาด อยู่ในย่านชุมชน บริการดี
# 8.5
# ดีมากครับ ปลอดภัยดี ประตูห้องเป็นคีย์การ์ด
# 8.5
# ห้องพักสะอาด สะดวกสบาย ราคาไม่แพงมาก การบริการดีครับ
# 8.5
# ที่พักสะอาด บรรยากาศดี การบริการดีครับ
# 8.6
# หากมีการสอบ/อบรม กรมบัญชีกลาง มันมีที่เดียวใกล้สุดแหละตุ๊กตุ๊ก 30 บาท ข้อดีบอกไปแหละ ข้อเสีย อยากให้เพิ่มเมนูอาหารจานเดียวหน่อย เมนูน้อย ตู้เย็นมีน้ำขวด 2 ขวดไม่มีกาแฟ ใส่อย่างอื่นในตู้เย็นก็ได้เดียวจ่าย บุฟเฟ่ต์แย่ในด้านบริหาร เห็นใจลูกค้าอื่นด้วยที่ไม่ใช่ทัวร์
# 8.7
# บริการดี มีความเป็นกันเองดีค่ะ
# 8.8
# พนักงานบริการดีมากทุกคนค่ะ
# การตอบกลับจากที่พัก
# 13 JAN 2020
# เรียนคุณ narisara
# ทางโรงแรมขอขอบคุณสำหรับข้อติชม ทางโรงแรมจะนำไปพัฒนาและปรับปรุงต่อไป ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณในโอกาสต่อไป
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER

# %%
driver.execute_script("window.scrollTo(0,6600)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
next_page.click()

time.sleep(5)
clear_list(ratings_list,reviews_list)
time.sleep(5)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 9
# ห้องดีมากครับ บรรยากาศสบาย ราคาเหมาะสมกับห้องครับ
# การตอบกลับจากที่พัก
# 06 MAR 2020
# ทางโรงแรมขอขอบคุณสำหรับข้อติชมและหวังว่าในโอกาสหน้าจะได้ต้อนรับคุณอีกครั้งค่ะ
# ขอบคุณค่ะ
# 9.1
# ห้องพักดี อุปกรณ์ครบ วิวดี สะอาด ชอบครับ
# 9.1
# รร. Ok. ที่จอด ลำบากนิดหน่อย. บุฟเฟต์เช้า พอได้
# การตอบกลับจากที่พัก
# 13 JAN 2020
# เรียนคุณ Puckapol
# ทางโรงแรมขอขอบคุณสำหรับข้อติชม ทางโรงแรมจะนำไปพัฒนาและปรับปรุงต่อไป ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณในโอกาสต่อไป
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 9.1
# โดยรวมดีมาก แต่ตอน Booking ขอเตียงใหญ่เตียงเดียว แต่พอเช็คอินเข้าไปกลับได้เตียงเดี่ยว 2 เตียง ทั้งๆ ที่หน้าเว็บที่จองระบุว่าเป็นเตียงใหญ่แท้ๆ
# การตอบกลับจากที่พัก
# 13 JAN 2020
# เรียนคุณKhomsant
# ทางโรงแรมขอขอบคุณสำหรับข้อติชม ทางโรงแรมจะนำไปพัฒนาและปรับปรุงต่อไป ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณในโอกาสต่อไป
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 9.1
# ห้องพักสะอาด พนักงานบริการดี
# การตอบกลับจากที่พัก
# 28 NOV 2019
# เรียนคุณ Nitinat
# ทางโรงแรมต้องขอภัยที่ตอบล่าช้านะคะ  ทางโรงแรมขอขอบคุณสำหรับข้อติชมค่ะ ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับท่านอีกครั้งในโอกาสต่อไปนะคะ
#
# ขอบคุณค่ะ
#
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 9.1
# โรงแรมใหม่ สะอาด วิวดี จองตอนโปรได้ราคา 650 บาท แต่ไม่มีอาหาร เลยไม่ได้ลองชิม อยู่พระราม 6 สะดวก
# 9.1
# เงียบสงบ มีโอกาสจะแวะไปใช้บริการอีกแน่นอน
# 9.1
# ห้องพักสะอาด  การเดินทางสะดวก น่าจะรวมอาหารเช้า จะดีมาก
# 9.1
# สะอาด ราคาไม่แพง เดินทางสะดวกมาก
# 9.4
# พนักงานดีมาก พนักงานทำความสะอาดห้องดีมาก ห้องพักสะอาด สะดวก เงียบ พัก 10 วัน คุ้มค่ามาก

# %%
driver.execute_script("window.scrollTo(0,6600)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
next_page.click()

time.sleep(5)
clear_list(ratings_list,reviews_list)
time.sleep(5)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 9.4
# สถานที่สะอาด สบาย พนักงานต้อนรับบริการดี
# 9.7
# พนักงานต้อนรับดีมาก บริการดีมาก พนักงานรักษาความปลอดภัยบริการดีมาก ห้องพักสะอาด อยู่ใกล้ BTS สะพานควาย เดินทางสะดวก
# การตอบกลับจากที่พัก
# 16 SEP 2020
# เรียน คุณ Kosee
# ทางโรงแรมขอขอบคุณสำหรับข้อติชมค่ะ หวังว่าทางโรงแรมจะมีโอกาสได้ต้อนรับคุณอีกครั้งในโอกาสต่อไปค่ะ
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# Front Office Manager
# 9.7
# ห้องพักสะอาด บริการดีมาก ที่จอดรถปลอดภัย ครั้งต่อไปจะไปใช้บริการอีก
# การตอบกลับจากที่พัก
# 15 JUL 2020
# ทางโรงแรมขอบคุณสำหรับคำติชมและหวังอย่างยิ่งว่าจะมีโอกาสได้ต้อนรับคุณในโอกาสต่อไปค่ะ
# ขอบคุณค่ะ
# 9.7
# ห้องสวยวิวดี ครับบริการดีเยี่ยมค่ะ
# การตอบกลับจากที่พัก
# 16 MAR 2020
# ขอบพระคุณสำหรับคำติชมค่ะ..ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณอีกครั้งในโอกาสต่อไปค่ะ
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 9.7
# ทำเลดี เดินทางสะดวกมาก ใกล้กับทางด่วน 2 สาย ได้ทั้งเข้าเมืองและออกนอกเมือง บรรยากาศภายในเป็นแบบ Contemporary เหมือนโรงแรมสมัยเด็กๆ ที่พ่อแม่พาไปเมื่อ 30 ปีที่แล้ว เฟอร์นิเจอร์ใหญ่ๆ หนักๆ แต่ทุกอย่างยังดูใหม่มาก ตื่นเต้นแรกกับที่จอดรถแบบลิฟท์รถยนต์ ตื่นเต้นที่สองคือ ห้องพักกว้างขวาง สะดวกสบาย เตียงนุ่ม มีหมอนสำรอง-ผ้าห่มสำรองไว้พร้อม สัญญาณทีวี HD คมชัด มีช่องหลักๆ ให้ดูไม่มีเบื่อ มีตู้เย็นขนาดกลางๆ กาต้มน้ำร้อน ชา กาแฟ มีน้ำร้อนทั้งอ่างอาบน้ำและอ่างล้างมือ ไฟในห้องพักเป็นโคมไฟตามจุดต่างๆ เลยไม่ค่อยสว่างมาก ไม่เหมาะแก่การอ่านหนังสือ ติดนิดเดียวตรงปลั๊กไฟมีน้อย ต้องไปถอดโคมไฟแล้วเสียบชาร์จมือถือ ไดร์เป่าผม แต่ก็ไม่ได้ลำบากอะไร ถ้าเลือกห้องพักพร้อมอาหารเช้ารับรองว่าคุ้ม จ่ายเพิ่มอีกนิดเดียว แต่มีอาหารให้เลือกทานเยอะมาก ทั้ง ABF และอาหารไทย ไข่ดาว ไส้กรอก หมูแฮม สลัด ซีเรียล โยเกิร์ต ขนมปัง ข้าวต้ม โจ๊ก เมนูกับข้าวประจำวัน เครื่อมดื่มชา กาแฟ น้ำเต้าหู้ น้ำส้ม สำหรับคนที่ทานอาหารเช้าแบบหนักๆ เน้นเป็นมื้อหลักๆ คิดว่าคุ้มกว่าการออกไปหาทานเองข้างนอก ถ้าเบื่ออยู่ในห้อง ชั้นบนยังมีสระว่ายน้ำ ฟิตเนส อุปกรณ์ดีงาม มีบ่อแช่ร้อนแช่เย็น เซาน่า มีผ้าเช็ดตัวให้ บริการ มีชุดว่ายน้ำให้เช่า หรือ จะออกมาหน้าโรงแรมก็มีร้านลาบ มีดนตรีสดให้ฟัง มีร้านขายของชำ ถ้าเดินเลียบฟุตบาทไปทางซ้ายอีกก็จะเจอร้านอาหาร เจอเซเว่น โดยรวมคือ 5/5 ดาว ประทับใจมากจากคนกรุงเทพแท้ๆ ที่ต้องมาอยู่โรงแรมในกรุงเทพยาวๆ 5 วัน 4 คืน เพื่อธุระส่วนตัวชั่วคราว :) ปล.เสียดายที่ไม่ได้ถ่ายภาพมาฝากกัน แต่ภาพโรงแรมในเว็บไซต์ตรงปกแน่นอนค่ะ
# 9.7
# สงบดี สบาย พนักงานน่ารัก เดินทางสะดวก
# 9.7
# บริการดี อาหารอร่อย แอร์เย็นดี แต่เสียงของรถดังวิ่งทั้งคืน น่าจะเพิ่มความหนาของกระจกกั้นจะได้เสียงไม่ดัง
# 9.7
# ห้องพักดี เตียงและหมอนนิ่มสบายค่ะ ไม่มีไฟเพดาน ทำให้ห้องไม่สว่างเท่าไหร่นัก แต่ก็มีไฟรอบๆห้อง ความสะอาดดีค่ะ
# 9.7
# ห้องพักสะอาด คุ้มค่ากับราคา เดินทางสะดวกปลอดภัย ใกล้สวนจตุจักร ส่วนตัวแล้วชอบมาก มีโอกาสจะเข้าพักอีก
# 10
# เตียงนุ่ม นอนสบาย ห้องน้ำสะอาด อาหารเช้าอร่อย พนักงานบริการดีมาก ขนาดมีปัญหานอกเหนือจากการบริการพื้นฐาน พนักงานก็ยังจัดการให้ น่ารักมากๆค่ะ ถ้ามีโอกาส กลับไปอุดหนุนอีกแน่นอนค่ะ

# %%
driver.execute_script("window.scrollTo(0,6600)")
next_page = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
next_page.click()

time.sleep(5)
clear_list(ratings_list,reviews_list)
time.sleep(5)

for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)
# Out:
# 10
# สะดวกสบาย ที่พักสะอากดีเลยครับ
# การตอบกลับจากที่พัก
# 13 JAN 2020
# เรียนคุณ NATTAWUT
# ทางโรงแรมขอขอบคุณสำหรับข้อติชม ทางโรงแรมหวังว่าจะมีโอกาสได้ต้อนรับคุณอีกครั้งนะคะ
# ขอบคุณค่ะ
# กันยกร ทองนพเก้า
# FRONT OFFICE MANAGER
# 10
# ประทับใจมาก จะกลับมาใช้บริการอีกค่ะ
# 7
# ไม่มีห้างสรรพสินค้าใกล้เคียงศูนย์การค้า ทุกคนต้องใช้คว้าหรือแท็กซี่ เฉพาะอาหารฮาลาลที่ Paradhipat เท่านั้น นักเรียนจำนวนมากที่เข้าพักในโรงแรมแห่งนี้ (พวกเขากำลังสวมชุดสูทสีดำและสีขาว) ฉันคิดว่าพวกเขาเป็นผู้เช่าระยะยาวหรือบางชั้นของโรงแรมนี้เป็นหอพัก
# 8.5
# ฉันพักที่นี่หนึ่งคืนฉันมาถึงแล้วตอนเช้าตรู่ฉันออกจากห้องพักใหญ่และสะอาดอาหารเช้าก็ปกติพนักงานดีมากฉันพักที่นี่เพราะมันอยู่ใกล้กับสถานีขนส่งหมอชิต
# 9.7
# ฉันและแม่ของฉันมาที่นี่เพื่อการแพทย์ที่โรงพยาบาลรามาธิบดี พนักงานมีจิตใจที่ดีที่สุดในการให้บริการ ดีใจที่ได้ช่วยแม่และแม่ทุกอย่างที่เราต้องการ ประเภทห้องพักของฉันคือ Junior suite ที่ชั้น 9 ห้องนี้มีขนาดใหญ่มากสะอาดมากและ WiFi รวดเร็วมาก! แต่ลิฟต์ไม่เพียงพอในตอนเช้า

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 55
# Reviews_list : 55

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                Review Rating
# 0   เสียงดังมาก ขนาดอยู่ชั้นสูงๆแล้ว ก็ยังมีแม่บ้า...    4.5
# 1   การเช็คอิน ช้า สอบถามจนปวดหัว ไม่มีการเตรียมข้...    5.4
# 2   ห้องพักสามารถเชื่อมกับอีกห้องได้ ซึ่งเราเป็นผู...    5.4
# 3                พนักงานบริการหน้าเคาเตอร์บริการไม่ดี      6
# 4   เข้าใจว่าที่จองเป็นเตียงเดี่ยวแต่ทำไมมาถึงที่พ...      6
# 5   ควรปรับปรุงในส่วนของพนักงานต้อนรับ บริเวณที่ทา...      6
# 6                บอกว่า ขอชั้นไม่สูง จัดให้ซะ ชั้น 20    6.6
# 7                ก็โอเค สมกับ 3 ดาว บริเวณโรงแรมสะอาด    7.3
# 8   สะอาด สะดวก สมราคา แต่ฟูกนิ่มไปทำให้ปวดหลัง นอ...    8.4
# 9                  ไม่มีชา กาแฟ และกาน้ำร้อนไว้ในห้อง    8.4
# 10  พนักงานบริการดีมากครับ ตอนเช็คอิน take care ลู...    8.5
# 11  ห้องกว้างสะอาด ราคาไม่แพง อยู่ติดศูนย์บริการทา...    8.5
# 12                   บริการดี ห้องพักสบาย แนะนะเลยค่ะ    8.5
# 13                  ห้องพักสะอาด อาหารเช้าหลากหลายค่ะ    8.5
# 14  ทำเลดี เดินทางสะดวกมีที่จอดรถ เตียงนอนนุ่มกำลั...    8.5
# 15  ถือว่าดีค่ะ พนักงานบริการดีค่ะ แต่เซเวนต้องเดิ...    8.5
# 16      ห้องพักโอเคคุ้มค่าเงินมากถึงจะมีปัญหาเล็กน้อย    8.5
# 17                  ห้องสะอาดดีค่ะ สวยมาก ใกล้ถนนใหญ่    8.5
# 18                   สะอาดมาก น่าพักใกล้ที่เที่ยวมากๆ    8.5
# 19  พนักงาน front ควรแก้ปัญหาให้ลูกค้า และไม่ควรพู...    8.5
# 20  ห้องสะอาดวิวสวยเดินทางสะดวกและสิ่งอำนวยความสะด...    8.5
# 21   ห้องสวย ราคาถูก แม่บ้านทำความสะอาดเนี๊ยบดี แต...    8.5
# 22  ทำเลดี ห้องได้มาตรฐาน ลุ้นตรงต้องใช้ลิฟต์รถยนต...    8.5
# 23               ที่พักสะอาด อยู่ในย่านชุมชน บริการดี    8.5
# 24         ดีมากครับ ปลอดภัยดี ประตูห้องเป็นคีย์การ์ด    8.5
# 25  ห้องพักสะอาด สะดวกสบาย ราคาไม่แพงมาก การบริการ...    8.5
# 26             ที่พักสะอาด บรรยากาศดี การบริการดีครับ    8.5
# 27  หากมีการสอบ/อบรม กรมบัญชีกลาง มันมีที่เดียวใกล...    8.6
# 28                     บริการดี มีความเป็นกันเองดีค่ะ    8.7
# 29                         พนักงานบริการดีมากทุกคนค่ะ    8.8
# 30  ห้องดีมากครับ บรรยากาศสบาย ราคาเหมาะสมกับห้องครับ      9
# 31           ห้องพักดี อุปกรณ์ครบ วิวดี สะอาด ชอบครับ    9.1
# 32    รร. Ok. ที่จอด ลำบากนิดหน่อย. บุฟเฟต์เช้า พอได้    9.1
# 33  โดยรวมดีมาก แต่ตอน Booking ขอเตียงใหญ่เตียงเดี...    9.1
# 34                       ห้องพักสะอาด พนักงานบริการดี    9.1
# 35  โรงแรมใหม่ สะอาด วิวดี จองตอนโปรได้ราคา 650 บา...    9.1
# 36          เงียบสงบ มีโอกาสจะแวะไปใช้บริการอีกแน่นอน    9.1
# 37  ห้องพักสะอาด  การเดินทางสะดวก น่าจะรวมอาหารเช้...    9.1
# 38                   สะอาด ราคาไม่แพง เดินทางสะดวกมาก    9.1
# 39  พนักงานดีมาก พนักงานทำความสะอาดห้องดีมาก ห้องพ...    9.4
# 40           สถานที่สะอาด สบาย พนักงานต้อนรับบริการดี    9.4
# 41  พนักงานต้อนรับดีมาก บริการดีมาก พนักงานรักษาคว...    9.7
# 42  ห้องพักสะอาด บริการดีมาก ที่จอดรถปลอดภัย ครั้ง...    9.7
# 43                 ห้องสวยวิวดี ครับบริการดีเยี่ยมค่ะ    9.7
# 44  ทำเลดี เดินทางสะดวกมาก ใกล้กับทางด่วน 2 สาย ได...    9.7
# 45              สงบดี สบาย พนักงานน่ารัก เดินทางสะดวก    9.7
# 46  บริการดี อาหารอร่อย แอร์เย็นดี แต่เสียงของรถดั...    9.7
# 47  ห้องพักดี เตียงและหมอนนิ่มสบายค่ะ ไม่มีไฟเพดาน...    9.7
# 48  ห้องพักสะอาด คุ้มค่ากับราคา เดินทางสะดวกปลอดภั...    9.7
# 49  เตียงนุ่ม นอนสบาย ห้องน้ำสะอาด อาหารเช้าอร่อย ...     10
# 50                     สะดวกสบาย ที่พักสะอากดีเลยครับ     10
# 51                ประทับใจมาก จะกลับมาใช้บริการอีกค่ะ     10
# 52  ไม่มีห้างสรรพสินค้าใกล้เคียงศูนย์การค้า ทุกคนต...      7
# 53  ฉันพักที่นี่หนึ่งคืนฉันมาถึงแล้วตอนเช้าตรู่ฉัน...    8.5
# 54  ฉันและแม่ของฉันมาที่นี่เพื่อการแพทย์ที่โรงพยาบ...    9.7

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#     index                                             Review Rating
# 0       0  เสียงดังมาก ขนาดอยู่ชั้นสูงๆแล้ว ก็ยังมีแม่บ้า...    4.5
# 1       1  การเช็คอิน ช้า สอบถามจนปวดหัว ไม่มีการเตรียมข้...    5.4
# 2       2  ห้องพักสามารถเชื่อมกับอีกห้องได้ ซึ่งเราเป็นผู...    5.4
# 3       3               พนักงานบริการหน้าเคาเตอร์บริการไม่ดี      6
# 4       4  เข้าใจว่าที่จองเป็นเตียงเดี่ยวแต่ทำไมมาถึงที่พ...      6
# 5       5  ควรปรับปรุงในส่วนของพนักงานต้อนรับ บริเวณที่ทา...      6
# 6       6               บอกว่า ขอชั้นไม่สูง จัดให้ซะ ชั้น 20    6.6
# 7       7               ก็โอเค สมกับ 3 ดาว บริเวณโรงแรมสะอาด    7.3
# 8       8  สะอาด สะดวก สมราคา แต่ฟูกนิ่มไปทำให้ปวดหลัง นอ...    8.4
# 9       9                 ไม่มีชา กาแฟ และกาน้ำร้อนไว้ในห้อง    8.4
# 10     10  พนักงานบริการดีมากครับ ตอนเช็คอิน take care ลู...    8.5
# 11     11  ห้องกว้างสะอาด ราคาไม่แพง อยู่ติดศูนย์บริการทา...    8.5
# 12     12                   บริการดี ห้องพักสบาย แนะนะเลยค่ะ    8.5
# 13     13                  ห้องพักสะอาด อาหารเช้าหลากหลายค่ะ    8.5
# 14     14  ทำเลดี เดินทางสะดวกมีที่จอดรถ เตียงนอนนุ่มกำลั...    8.5
# 15     15  ถือว่าดีค่ะ พนักงานบริการดีค่ะ แต่เซเวนต้องเดิ...    8.5
# 16     16      ห้องพักโอเคคุ้มค่าเงินมากถึงจะมีปัญหาเล็กน้อย    8.5
# 17     17                  ห้องสะอาดดีค่ะ สวยมาก ใกล้ถนนใหญ่    8.5
# 18     18                   สะอาดมาก น่าพักใกล้ที่เที่ยวมากๆ    8.5
# 19     19  พนักงาน front ควรแก้ปัญหาให้ลูกค้า และไม่ควรพู...    8.5
# 20     20  ห้องสะอาดวิวสวยเดินทางสะดวกและสิ่งอำนวยความสะด...    8.5
# 21     21   ห้องสวย ราคาถูก แม่บ้านทำความสะอาดเนี๊ยบดี แต...    8.5
# 22     22  ทำเลดี ห้องได้มาตรฐาน ลุ้นตรงต้องใช้ลิฟต์รถยนต...    8.5
# 23     23               ที่พักสะอาด อยู่ในย่านชุมชน บริการดี    8.5
# 24     24         ดีมากครับ ปลอดภัยดี ประตูห้องเป็นคีย์การ์ด    8.5
# 25     25  ห้องพักสะอาด สะดวกสบาย ราคาไม่แพงมาก การบริการ...    8.5
# 26     26             ที่พักสะอาด บรรยากาศดี การบริการดีครับ    8.5
# 27     27  หากมีการสอบ/อบรม กรมบัญชีกลาง มันมีที่เดียวใกล...    8.6
# 28     28                     บริการดี มีความเป็นกันเองดีค่ะ    8.7
# 29     29                         พนักงานบริการดีมากทุกคนค่ะ    8.8
# 30     30  ห้องดีมากครับ บรรยากาศสบาย ราคาเหมาะสมกับห้องครับ      9
# 31     31           ห้องพักดี อุปกรณ์ครบ วิวดี สะอาด ชอบครับ    9.1
# 32     32    รร. Ok. ที่จอด ลำบากนิดหน่อย. บุฟเฟต์เช้า พอได้    9.1
# 33     33  โดยรวมดีมาก แต่ตอน Booking ขอเตียงใหญ่เตียงเดี...    9.1
# 34     34                       ห้องพักสะอาด พนักงานบริการดี    9.1
# 35     35  โรงแรมใหม่ สะอาด วิวดี จองตอนโปรได้ราคา 650 บา...    9.1
# 36     36          เงียบสงบ มีโอกาสจะแวะไปใช้บริการอีกแน่นอน    9.1
# 37     37  ห้องพักสะอาด  การเดินทางสะดวก น่าจะรวมอาหารเช้...    9.1
# 38     38                   สะอาด ราคาไม่แพง เดินทางสะดวกมาก    9.1
# 39     39  พนักงานดีมาก พนักงานทำความสะอาดห้องดีมาก ห้องพ...    9.4
# 40     40           สถานที่สะอาด สบาย พนักงานต้อนรับบริการดี    9.4
# 41     41  พนักงานต้อนรับดีมาก บริการดีมาก พนักงานรักษาคว...    9.7
# 42     42  ห้องพักสะอาด บริการดีมาก ที่จอดรถปลอดภัย ครั้ง...    9.7
# 43     43                 ห้องสวยวิวดี ครับบริการดีเยี่ยมค่ะ    9.7
# 44     44  ทำเลดี เดินทางสะดวกมาก ใกล้กับทางด่วน 2 สาย ได...    9.7
# 45     45              สงบดี สบาย พนักงานน่ารัก เดินทางสะดวก    9.7
# 46     46  บริการดี อาหารอร่อย แอร์เย็นดี แต่เสียงของรถดั...    9.7
# 47     47  ห้องพักดี เตียงและหมอนนิ่มสบายค่ะ ไม่มีไฟเพดาน...    9.7
# 48     48  ห้องพักสะอาด คุ้มค่ากับราคา เดินทางสะดวกปลอดภั...    9.7
# 49     49  เตียงนุ่ม นอนสบาย ห้องน้ำสะอาด อาหารเช้าอร่อย ...     10
# 50     50                     สะดวกสบาย ที่พักสะอากดีเลยครับ     10
# 51     51                ประทับใจมาก จะกลับมาใช้บริการอีกค่ะ     10
# 52     52  ไม่มีห้างสรรพสินค้าใกล้เคียงศูนย์การค้า ทุกคนต...      7
# 53     53  ฉันพักที่นี่หนึ่งคืนฉันมาถึงแล้วตอนเช้าตรู่ฉัน...    8.5
# 54     54  ฉันและแม่ของฉันมาที่นี่เพื่อการแพทย์ที่โรงพยาบ...    9.7

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                Review Rating
# 0   เสียงดังมาก ขนาดอยู่ชั้นสูงๆแล้ว ก็ยังมีแม่บ้า...    4.5
# 1   การเช็คอิน ช้า สอบถามจนปวดหัว ไม่มีการเตรียมข้...    5.4
# 2   ห้องพักสามารถเชื่อมกับอีกห้องได้ ซึ่งเราเป็นผู...    5.4
# 3                พนักงานบริการหน้าเคาเตอร์บริการไม่ดี      6
# 4   เข้าใจว่าที่จองเป็นเตียงเดี่ยวแต่ทำไมมาถึงที่พ...      6
# 5   ควรปรับปรุงในส่วนของพนักงานต้อนรับ บริเวณที่ทา...      6
# 6                บอกว่า ขอชั้นไม่สูง จัดให้ซะ ชั้น 20    6.6
# 7                ก็โอเค สมกับ 3 ดาว บริเวณโรงแรมสะอาด    7.3
# 8   สะอาด สะดวก สมราคา แต่ฟูกนิ่มไปทำให้ปวดหลัง นอ...    8.4
# 9                  ไม่มีชา กาแฟ และกาน้ำร้อนไว้ในห้อง    8.4
# 10  พนักงานบริการดีมากครับ ตอนเช็คอิน take care ลู...    8.5
# 11  ห้องกว้างสะอาด ราคาไม่แพง อยู่ติดศูนย์บริการทา...    8.5
# 12                   บริการดี ห้องพักสบาย แนะนะเลยค่ะ    8.5
# 13                  ห้องพักสะอาด อาหารเช้าหลากหลายค่ะ    8.5
# 14  ทำเลดี เดินทางสะดวกมีที่จอดรถ เตียงนอนนุ่มกำลั...    8.5
# 15  ถือว่าดีค่ะ พนักงานบริการดีค่ะ แต่เซเวนต้องเดิ...    8.5
# 16      ห้องพักโอเคคุ้มค่าเงินมากถึงจะมีปัญหาเล็กน้อย    8.5
# 17                  ห้องสะอาดดีค่ะ สวยมาก ใกล้ถนนใหญ่    8.5
# 18                   สะอาดมาก น่าพักใกล้ที่เที่ยวมากๆ    8.5
# 19  พนักงาน front ควรแก้ปัญหาให้ลูกค้า และไม่ควรพู...    8.5
# 20  ห้องสะอาดวิวสวยเดินทางสะดวกและสิ่งอำนวยความสะด...    8.5
# 21   ห้องสวย ราคาถูก แม่บ้านทำความสะอาดเนี๊ยบดี แต...    8.5
# 22  ทำเลดี ห้องได้มาตรฐาน ลุ้นตรงต้องใช้ลิฟต์รถยนต...    8.5
# 23               ที่พักสะอาด อยู่ในย่านชุมชน บริการดี    8.5
# 24         ดีมากครับ ปลอดภัยดี ประตูห้องเป็นคีย์การ์ด    8.5
# 25  ห้องพักสะอาด สะดวกสบาย ราคาไม่แพงมาก การบริการ...    8.5
# 26             ที่พักสะอาด บรรยากาศดี การบริการดีครับ    8.5
# 27  หากมีการสอบ/อบรม กรมบัญชีกลาง มันมีที่เดียวใกล...    8.6
# 28                     บริการดี มีความเป็นกันเองดีค่ะ    8.7
# 29                         พนักงานบริการดีมากทุกคนค่ะ    8.8
# 30  ห้องดีมากครับ บรรยากาศสบาย ราคาเหมาะสมกับห้องครับ      9
# 31           ห้องพักดี อุปกรณ์ครบ วิวดี สะอาด ชอบครับ    9.1
# 32    รร. Ok. ที่จอด ลำบากนิดหน่อย. บุฟเฟต์เช้า พอได้    9.1
# 33  โดยรวมดีมาก แต่ตอน Booking ขอเตียงใหญ่เตียงเดี...    9.1
# 34                       ห้องพักสะอาด พนักงานบริการดี    9.1
# 35  โรงแรมใหม่ สะอาด วิวดี จองตอนโปรได้ราคา 650 บา...    9.1
# 36          เงียบสงบ มีโอกาสจะแวะไปใช้บริการอีกแน่นอน    9.1
# 37  ห้องพักสะอาด  การเดินทางสะดวก น่าจะรวมอาหารเช้...    9.1
# 38                   สะอาด ราคาไม่แพง เดินทางสะดวกมาก    9.1
# 39  พนักงานดีมาก พนักงานทำความสะอาดห้องดีมาก ห้องพ...    9.4
# 40           สถานที่สะอาด สบาย พนักงานต้อนรับบริการดี    9.4
# 41  พนักงานต้อนรับดีมาก บริการดีมาก พนักงานรักษาคว...    9.7
# 42  ห้องพักสะอาด บริการดีมาก ที่จอดรถปลอดภัย ครั้ง...    9.7
# 43                 ห้องสวยวิวดี ครับบริการดีเยี่ยมค่ะ    9.7
# 44  ทำเลดี เดินทางสะดวกมาก ใกล้กับทางด่วน 2 สาย ได...    9.7
# 45              สงบดี สบาย พนักงานน่ารัก เดินทางสะดวก    9.7
# 46  บริการดี อาหารอร่อย แอร์เย็นดี แต่เสียงของรถดั...    9.7
# 47  ห้องพักดี เตียงและหมอนนิ่มสบายค่ะ ไม่มีไฟเพดาน...    9.7
# 48  ห้องพักสะอาด คุ้มค่ากับราคา เดินทางสะดวกปลอดภั...    9.7
# 49  เตียงนุ่ม นอนสบาย ห้องน้ำสะอาด อาหารเช้าอร่อย ...     10
# 50                     สะดวกสบาย ที่พักสะอากดีเลยครับ     10
# 51                ประทับใจมาก จะกลับมาใช้บริการอีกค่ะ     10
# 52  ไม่มีห้างสรรพสินค้าใกล้เคียงศูนย์การค้า ทุกคนต...      7
# 53  ฉันพักที่นี่หนึ่งคืนฉันมาถึงแล้วตอนเช้าตรู่ฉัน...    8.5
# 54  ฉันและแม่ของฉันมาที่นี่เพื่อการแพทย์ที่โรงพยาบ...    9.7

# %%
table.to_csv("Reviews&Ratings_14th.csv", encoding="utf-8")
