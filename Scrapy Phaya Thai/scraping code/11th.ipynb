# %%
# !pip install selenium
# Out:
# Requirement already satisfied: selenium in c:\users\fair\anaconda3\lib\site-packages (4.6.0)
# Requirement already satisfied: trio~=0.17 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.22.0)
# Requirement already satisfied: certifi>=2021.10.8 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (2022.9.14)
# Requirement already satisfied: trio-websocket~=0.9 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (0.9.2)
# Requirement already satisfied: urllib3[socks]~=1.26 in c:\users\fair\anaconda3\lib\site-packages (from selenium) (1.26.11)
# Requirement already satisfied: exceptiongroup>=1.0.0rc9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.0.1)
# Requirement already satisfied: sortedcontainers in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (2.4.0)
# Requirement already satisfied: cffi>=1.14 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.15.1)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (21.4.0)
# Requirement already satisfied: idna in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (3.3)
# Requirement already satisfied: sniffio in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: outcome in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.2.0)
# Requirement already satisfied: async-generator>=1.9 in c:\users\fair\anaconda3\lib\site-packages (from trio~=0.17->selenium) (1.10)
# Requirement already satisfied: wsproto>=0.14 in c:\users\fair\anaconda3\lib\site-packages (from trio-websocket~=0.9->selenium) (1.2.0)
# Requirement already satisfied: PySocks!=1.5.7,<2.0,>=1.5.6 in c:\users\fair\anaconda3\lib\site-packages (from urllib3[socks]~=1.26->selenium) (1.7.1)
# Requirement already satisfied: pycparser in c:\users\fair\anaconda3\lib\site-packages (from cffi>=1.14->trio~=0.17->selenium) (2.21)
# Requirement already satisfied: h11<1,>=0.9.0 in c:\users\fair\anaconda3\lib\site-packages (from wsproto>=0.14->trio-websocket~=0.9->selenium) (0.14.0)

# %% [markdown]
# # Def & Scraping Methods

# %%
def save_comment2mainList(main_comment_List,sub_comment_List):
    for item in sub_comment_List:
        main_comment_List.append(str(item))
        
def save_rating2mainList(main_rating_List,sub_rating_List):
    for item in sub_rating_List:
        main_rating_List.append(str(item))

# %%
def check_list_size(list_1,list_2):
    if len(list_1) != len(list_2):
        if len(list_1) > len(list_2):
            list_1.pop(len(list_1)-1)
        else:
            list_2.pop(len(list_2)-1)
    else:
      return list_1,list_2

# %%
def NextPages():
    running = True
    while running:
        try:
            try:
                running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[7]').click()
            except:
                try:
                    running = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[8]').click()   
                except:
                    running = driver.find_elementh(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[8]/div/div[9]').click() 
        except:
             running = False
        print('-----------------------------------------------------------','\n')

# %%
def scraping_reviews(l_x1,l_x2,l_y1,l_y2): #scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    driver.execute_script("window.scrollTo(0,7770)")
    for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
        for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
            rate = score.text
            print(rate)
            l_x1.append(rate)

        for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
            criticism = comment.text
            print(criticism)
            l_x2.append(criticism)
    
        check_list_size(l_x1,l_x2)
    save_comment2mainList(l_y1, l_x1)
    save_rating2mainList(l_y2, l_x2)

# %%
def clear_list(l_1,l_2):
    reviews_list.clear()
    ratings_list.clear()

# %% [markdown]
# # Code Working

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
from selenium.webdriver.support.select import Select

path = "D:\python\Selenium\edgedriver_win64\msedgedriver.exe"
url = 'https://www.traveloka.com/th-th/hotel/thailand/t-hostel-victory-monument-3000010040644'
driver = webdriver.Edge(executable_path = path)
driver.get(url)

Reviews_list, reviews_list = [],[]
Ratings_list, ratings_list = [],[]

sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]")
sel.click()
time.sleep(2)
TH = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[3]/div/div[2]/div/div/div/div[4]')
TH.click()
# Out:
# C:\Users\FAIR\AppData\Local\Temp\ipykernel_11032\2767455829.py:8: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Edge(executable_path = path)

# %%
driver.title
# Out:
# 'ค่าห้องพัก T Hostel Victory Monument สามเสนใน ตั้งแต่ 10-11-2022 ถึง 11-11-2022'

# %%
sel_order = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]")
sel_order.click()

# %%
ascending = sel.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[5]/div[1]/div/div[2]/div/div/div/div[2]')
ascending.click()

# %%
for review in driver.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1guathk.r-1yzf0co'):
    for score in review.find_elements(By.CSS_SELECTOR,'div.css-901oao.r-1i6uqv8.r-1sixt3s.r-ubezar.r-majxgm.r-135wba7.r-fdjqy7'):
        rate = score.text
        print(rate)
        ratings_list.append(rate)

    for comment in review.find_elements(By.CSS_SELECTOR,'div.css-1dbjc4n.r-1wzrnnt.r-1udh08x'):
        criticism = comment.text
        print(criticism)
        reviews_list.append(criticism)
    
    check_list_size(ratings_list,reviews_list)
save_comment2mainList(Reviews_list, reviews_list)
save_rating2mainList(Ratings_list, ratings_list)

# %%
sel = driver.find_element(By.XPATH,"/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]")
sel.click()

# %%
clear_list(reviews_list,ratings_list)

# %%
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 6.8
# ห้องพักสะอาด ทำเลดี การเดินทางสะดวก แต่เสียอย่างนึงคือวันที่เข้าพักน้ำไม่ไหล และทางโรงแรมไม่มีปั๊มน้ำสำรองมาใช้ระหว่างที่น้ำไม่ไหล
# 8
# ไม่มีห้องน้ำในห้องไม่มีความเป็นส่วนตัว ไม่ชอบเลย
# 8.1
# ห้องแคบ แต่สะอาด ห้องน้ำและห้องอาบน้ำอย่างละ1ห้องต่อชั้น แยกชายหญิง แอร์เย็น ผนังห้องไม่ค่อยเก็บเสียง เดินจากbts อนุสาวรีย์ ลงจากsky walk ข้ามถนน2ครั้ง เดินต่ออีกนิดจะถึง
# 8.1
# ไวไฟที่ให้เล่นไม่ได้ ส่วนห้องพักและห้องน้ำสะอาดดี
# 8.2
# ข้อดี - ทำเลที่ตั้งดีมาก สามารถเดินไปขึ้นรถที่อนุเสาวรีย์ชัยฯ ได้ - อยู่ใกล้ร้านสะดวกซื้อ 7-11 - อยู่ติดถนนใหญ่ หาง่าย ไม่ซับซ้อน - มีมุมขนม น้ำเปล่าให้ดื่มฟรีตรงล็อบบี้ - ในห้องมี ทีวี กระจกบานใหญ่ (แนวนอน) ข้อเสีย - พนักงานไม่สนใจความต้องการของลูกค้า ต้องเล่าก่อนว่าก่อนเข้าพัก ได้มีการโทรไปคอนเฟิร์มการจองกับเจ้าหน้าที่โรงแรม และแจ้งว่าต้องการห้องที่ค่อนข้างเงียบ แต่เมื่อเข้าพัก พนักงานไม่ได้จัดห้องให้ตามคำขอ ทั้งๆที่ยังมีห้องว่างอื่นที่เงียบกว่า ต้องเสียเวลาลงไปเปลี่ยนห้องกับหน้าฟรอนต์ - ห้องน้ำน้อยมาก ห้องน้ำหญิงแบ่งเป็นห้องส้วม 1 ห้อง ห้องอาบน้ำ 1 ห้องต่อ 1 ชั้นต่อประมาณ 7 ห้อง เข้าพักครั้งนี้ก็ไม่ค่อยประทับใจเท่าไหร่
# 8.3
# ก็ดี แต่ไม่ประทับใจในบริการ จองห้องรวม เข้าเช็คอินประมาณ 16.00 น. ขอเตียงล่าง เพราะจะเช็คเอาท์ 18.30 น.วันเดียวกัน แต่ได้เตียงบน ทั้งๆ ที่มีเตียงล่างว่าง
# 8.3
# - เดินทางสะดวก ใกล้ 7-11 ใกล้แหล่งของกิน โดยรวมพื้นที่ของโรงแรมโอเคมากๆ พนักงานบริการดี มีคนเฝ้าตลอด 24 ชม.
# - เสียแต่ผนังห้องบางมาก ได้ยินเสียงรถผ่าน คนเดินผ่านห้อง แค่เสียงข้างห้องคุยกันก็ดัง ถ้าห้องเก็บเสียงได้ขึ้นอีกนิดนึงก็จะดีมากๆเลยค่ะ
# 8.3
# อยู่ใกล้ก๋วยเตี๋ยวเรืออนุ รถเมล แต่ bts อาจไกลออกมาหน่อย
# ห้องน้ำ ไม่แน่ใจทำความสะอาดกี่ช่วง ถ้าหลังช่วงคนใช้
# 8.4
# บันไดขึ้นลงลำบาก ภายในห้องมีกลิ่นอับ คุ้มกับราคา นอนชั่วคราว
# 8.4
# โฮลเทลน่ารักดูอบอุ่น แม่บ้านยิ้มแย้มน่ารักมากค่ะ แต่อยากฝากแผนกเช้คอินรับลูกค้า ให้ใจเย็นๆ ยิ้มแย้มมากกว่านี้ค่ะ ต้อนรับด้วยความเต็มใจ จะดูอบอุ่นน่าอยู่ขึ้นเยอะเลย อยากให้ดีขึ้นยิ่งๆไปอีก

# %%
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[7]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.4
# ทำเลต้องเดินผ่านถนนใหญ่ ไม่สะดวกนัก
# ห้องนอน ห้องน้ำ ดี แต่แชมพูในห้องน้ำทำให้ผมกระด้างมากค่ะ อยากให้เปลี่ยนยี่ห้อค่ะ
# 8.5
# ที่พักดี ราคาถูก ตรงตามปก ไม่มีกลิ่นอับ
# 8.5
# ชื่นชอบยังไงก็ยังคงชื่นชอบแบบนั้น มาพักซ้ำครั้งที่ 2 แล้วค่ะ ห้องน้ำก็สะอาด ห้องพักก็สะอาดค่ะ อยู่ใกล้ที่ขึ้นรถ สะดวกมากๆๆค่ะ
# 8.5
# ทำเลดี เดินทางสะดวก พนักงานตอนรับกะเช้าบริการดี พูดจาดีเป็นกันเองแนะนำดีค่ะ
# 8.5
# ดีมากครับแต่อยากให้มีบริการ เช็กอิน ได้ตลอด 24 ชม. ครับ
# 8.5
#
# 8.5
# ไปทุกครั้งก็ดีทุกครั้งพนักงานช่วยเหลือดีค่ะ สองคืนเเรกได้ห้องติดถนนนอนไม่ได้เลยพนักก็ใจดีให้เปลี่ยนห้อง ขอบคุณนะคะ
# 8.5
# โรงแรมอยู่ติดถนนเสียงรถค่อนข้างดัง
# 8.5
# โดยรวมดีค่ะ ห้องพักสะอาด บรรยากาศสบายๆน่าพักผ่อน ห้องน้ำถึงจะน้อย แต่ก็ไม่ต้องรอเข้าค่ะ แต่เวลาห้องอื่นปิดเปิดประตูเสียงดังมาถึงในห้องพักด้วยค่ะ
# 8.5

# %%
driver.execute_script("window.scrollTo(0,5900)")
sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[8]')
sel.click()
time.sleep(2)
clear_list(reviews_list,ratings_list)
scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
# Out:
# 8.5
# เงียบสงบ หลับสบาย แต่มีปัญหาเรื่องทีวีเปิดไม่ติด
# 8.5
# ห้องพักน่ารัก ห้องน้ำรวมถือว่าดีสะอาดมาก แต่ติดนิดเดียวเสียงรถขับผ่านไปมาเสียงแตรได้ยินชัดไปหน่อย
# 8.5
# ห้องพักสะอาด เดินทางสะดวก มีโอกาสจะไปพักอีกค่ะ
# 8.5
# ห้องพักสะอาด เดินทางได้สะดวกสบาย
# 8.5
# ดี ห้องสบายสำหรับนอนคนเดียว ห้องน้ำสะอาด
# 8.5
# โอเคดีค่ะ แต่ปลั๊กไฟแอบน้อยเกินไป
# 8.5
# สะดวก ใกล้ bts เเนะนำถ้ามีเพื่อน มานอนด้วย ให้จองห้อง 2 คน ( คิดราคาเพิ่มหากจอง 1 คน )
# 8.5
#
# 8.5
# ประทับใจทุกครั้งที่ไปพัก 2รอบแล้วไม่ผิดหวังเลย
# 8.5

# %%
for i in range(20):
    driver.execute_script("window.scrollTo(0,3600)")
    sel = driver.find_element(By.XPATH,'/html/body/div[1]/div[5]/div[2]/div/div/div[1]/div/div/div[9]/div/div[9]')
    sel.click()
    time.sleep(2)
    clear_list(reviews_list,ratings_list)
    scraping_reviews(ratings_list,reviews_list,Ratings_list,Reviews_list)
    print('---------------------------------------------------------------------------------------------','\n')
# Out:
# 8.5
# ที่พักดี เดินทางสะดวก ห้องน้ำสะอาด
# 8.5
# ดีค่ะ เดินทางสะดวก สะอาด ปลอดภัย :)
# 8.5
# ห้องพักสะอาด ทำเลดี แต่เช็คอินบ่ายสองเลยต้องรอนานหน่อยค่ะ
# 8.5
# เป็นโฮสเทลที่สะอาดมาก เดินทางสะดวกสบาย ห้องขนาดกะทัดรัด ชอบมากค่ะ
# 8.5
# เตียงนอนกว้าง สะอาด เป็นส่วนตัว พื้นที่รับรองชั้นล่างตกแต่งน่ารัก แนะนำปรับปรุงห้องน้ำมีกลิ่น ไม่ค่อยสะอาด
# 8.5
# ห้องสะอาด เดินทางสะดวกติดกับป้ายรถเมล์และbts
# 8.5
# ห้องสะอาด บรรยากาศดี พนักงานน่ารัก
# 8.5
# ชอบค่ะ เวลาไปทำงานที่กรุงเทพได้ที่พักนี้เลยค่ะ
# 8.5
# เดินทางสะดวก สะอาด มี WiFi ค่าห้องไม่แพง
# 8.5
# ห้องสะอาดดีค่ะ ประตูเป็นคีย์การ์ด ห้องน้ำรวมก็สะอาดดี มีห้องอาบน้ำ 1 ห้องต่อ 1 ชั้น มีผ้าขนหนู แชมพูและสบู่เหลวคุณภาพดีให้ใช้ มีไดร์เป่าผมด้วยค่ะ ขนมให้ทานฟรี ก็มีขนมปี๊บนิดหน่อย กาแฟและชา ไม่มีโอวัลติน
# ---------------------------------------------------------------------------------------------
#
# 8.5
# ห้องพักดีเลยสะอาดมาครั้งหน้าไม่พลาดเเน่นอน
# 8.5
# ห้องนอนใหม่ ห้องน้ำรวมแต่สะอาดดีแยกชายหญิง เลือกพักแบบห้องนอนเดี่ยว
# 8.5
# มาพักหลายครั้งแล้วดีมากเลยค่ะ ตอนแรกที่รีวิวห้องน้ำน้อย พอไปอีกครั้ง พนักงาน จะแจ้งทุกครั้งว่า ห้องน้ำใช้ได้ทุกชั้น ถ้าดูจากจำนวนก็ยังน้อยอยู่ แต่ก็ถือว่าสะดวกมากขึ้นค่ะ
# 8.5
# บริการ ที่พักสะอาด ติดตรงห้องน้ำแต่ละชั้นน้อยไปหน่อย ได้พักห้องที่ติดถนนเสียงรถดังมาในตอนกลางคืน
# 8.5
#
# 8.5
# ตั้งในทำเลที่เดินทางสะดวก พนักงานยิ้มแย้มแจ่มใส มีน้ำดื่ม ชา กาแฟ ขนมให้ทาน ห้องพักสะอาดและใหม่มาก แต่ถ้าเพิ่มจำนวนห้องสุขาและห้องอาบน้ำต่อชั้นให้มากกว่านี้จะดีมากค่ะ
# 8.5
# อยู่ใกล้บีทีเอสสนามเป้าค่ะ รถเมล์ก้อผ่านหน้าโรงแรม มีร้านอาหาร เซเว่นอยู่ข้างโรงแรม พนง.บริการดีค่ะ ห้องพักสะอาด ห้องน้ำสะอาดค่ะ
# 8.5
# ชอบมาก สะดวกสบาย เสียดาย เจอรูมเมทนอนกรน
# 8.5
# ค่อนข้างดีค่ะ เดินทางสะดวก ปลอดภัย
# 8.5
# ประทับใจ ห้องดี สะอาด ทำเลดี เดินทางสะดวก
# ---------------------------------------------------------------------------------------------
#
# 8.5
#
# 8.5
# พนักงานตอนรับ เป็นกันเองมาก ห้องพักสบาย ห้องน้ำน้อยไปหน่อย โดยรวมถืดว่าดีครับ ใกล้อนุเสาวรีย์เดินทางสะดวก!
# 8.5
# พักห้องรวมหญิงมี แค่ 4 เตียง เงียบสงบ ไม่วุ่นวายดี สะอาด แต่เริ่มมีฝุ่นในห้องพัก พื้นห้องอาบน้ำลื่นจากคราบสบู่ ที่แขวนฝักบัวฝักบัวชำรุด
# 8.5
#
# 8.5
# สะอาด เดินทางสะดวก ติดเซเว่น พนักงานบริการดีค่ะ
# 8.5
# ยังไม่ถึงเวลาเช็คเอาท์ แต่มีแม่บ้านเปิดประตูห้องเข้ามาโดยไม่ได้บอก
# 8.5
# สะดวก สบาย เงียบ รูมเมทไทย/ฝรั่งน่ารักมากค่ะ
# 8.5
# ห้องพักสะอาด เตียงนอนสบาย ราคาประหยัด
# 8.5
# มาพักหลายรอบแล้วค่ะ เดินทางสะดวก ที่นอนสบายเป็นสัดส่วน มีผ้าเช็ดตัว สบู่ยาสระผม และไดร์เป่าผม แต่ห้องน้ำน้อยค่ะ
# 8.5
# ห้องเตียงเดี่ยวราคาเท่าไรครับ
# ---------------------------------------------------------------------------------------------
#
# 8.5
# สะดวกในการเดินทาง และมีความส่วนตัวมาก
# 8.5
# ห้องพักดี แอร์เย็น ใกล้แหล่งกิน แหล่งเที่ยว
# 8.5
#
# 8.5
# อุปกรณ์ในห้องน้ำเริ่มชำรุด อยากให้มีการตรวจเช็คและซ่อมแซม
# 8.5
# ห้องพักสะอาดดี ห้องน้ำแคบไปนิด
# 8.5
# ครั้งนี้ลองพักแบบห้องรวมหญิง ไวไฟช้าเหมือนเดิม ผู้ร่วมห้องพักนี่แล้วแต่ดวง แต่ครั้งนี้น่าจะพกดวงมาน้อยเจอ 2 คนเสียงดังมากๆๆ ขยะเพียบ ตากกางเกงในโชว์เด่นเป็นสง่า เบียดเบียนล็อกเกอร์ไว้กระเป๋าเตียงอื่นด้วย ส่วนเตียงนี่เลือกหรือจองไม่ได้ค่ะ แล้วแต่ดวงว่างเตียงไหนก็เตียงนั้น ผู้พักเลือกกันเอง ทางโรงแรมไม่รู้ด้วยว่าว่างเตียงไหนต้องไปหาเอง ปลั๊กหัวเตียงมี 1 รูเท่านั้น แต่สวิตช์เปิดปิดไฟมี 2 ที่ ด้วยความที่ได้พักเตียงบนแม่บ้านอาจดูแลไม่ทั่วถึง หมอนและที่นอนมีฝุ่นเล็กน้อย แบบตบหมอนแล้วฝุ่นลอยละล่อง อาจด้วยเพราะเปิดไฟเลยเห็นชัด แต่โดยรวมพอใจกับครั้งนี้มากกว่าครั้งที่แล้ว
# 8.5
# สะอาด สะดวก ใกล้ BTS แต่ที่นอนแข็งไปค่ะ
# 8.5
# สะดวก สบาย สะอาด ติด BTS เดินทางสะดวกมากๆครับ
# 8.5
# สบายเหมือนอยู่บ้าน เดินทางสะดวก สะอาด ปลอดภัย ราคาไม่แพง
# 8.5
# ทำเลดีใกล้แหล่งช้อปปิ้ง ห้องสะอาด
# ---------------------------------------------------------------------------------------------
#
# 8.5
# ห้องพักสะอาด ห้องน้ำสะอาด เดินทางสะดวก
# 8.5
# เดินทางสะดวก คนพลุกพล่าน ไม่อันตราย ติดถนน โดยรวมถือว่าดี
# 8.5
# ดีค่ะ สะอาด ห้องน้ำห้องนอนไม่มีกลิ่นอับ
# 8.5
# ที่พักสะอาด เดินทางสะดวก พักมาหลายครั้ง ประทับใจทุกครั้งค่ะ
# 8.5
# ดีค่ะ สะอาด ไม่วุ่นวาย แถมโฮสต์ก็เป็นกันเอง
# 8.5
# พนักงานต้อนรับสุดยอดมากๆ จำลูกค้าได้ น่ารักเป็นกันเอง
# 8.5
# สะดวกในการเดินทาง อยู่ใกล้แหล่งชุมชน
# 8.5
# ดีมาก จนอยากมาอีก ถ้าได้มีโอกาสมาเที่ยวย่านอนุสาวรีย์ชัยฯ
# 8.7
# แอร์เย็น เดินทางสะดวก ข้างล่างที่พักมีกาแฟ น้ำดื่มบริการ เราเขียนไปขอชั้นล่างๆ แต่ได้ชั้นบนสุดแทน (อันนี้ทางtravelokaแจ้งไว้ก่อนแล้วว่าอาจไม่ได้อย่างที่ขอไป) เลยเหนื่อยเดินขึ้นบันได เพราะไม่มีลิฟท์
# 8.7
# ประทับใจมากๆ คับ ถ้ามีโอกาสจะเข้าไปพักแน่นอนครับ
# ---------------------------------------------------------------------------------------------
#
# 8.7
# คีย์การ์ด 1 ใบสามารถไปแตะเข้าห้องอื่นได้ เคยแตะผิดก็เปิดได้ ความปลอดภัยถือว่าอันตรายมากเลย
# 8.8
# มาพักที่นี่รอบที่สองแล้ว เตียงดี เดินทางสะดวก
# 8.8
# ที่พักสะอาด เดินทางสะดวก ทั้งBTS และป้ายรถเมล์ ครั้งหน้ามาพักอีกแน่นอน
# 8.8
# ห้องสวยน่านอน สะอาด คาเฟ่ด้านล่าง มัทฉะลาเต้ อร่อยมาก
# 8.8
# ห้องรวมหญิงดีมาก ตู้ล๊อคเกอร์ใหญ่เก็บกระเป๋า 28 นิ้วได้เลย ที่นอนนุ่มมาก ชอบมาก แต่เป็นบันได กระเป๋าค้องยกหนักหน่อย
# 8.8
#
# 8.8
# ห้องพักสะอาด ใกล้BTS อนุสาวรีย์ ด้านข้างมี7-11
# 8.8
#
# 8.8
# ห้องสะอาด อยู่ใกล้ป้ายรถเมล์ และบีทีเอส
# 8.8
# ที่พักสะดวก สบายใกล้สิ่งอำนวยความสะดวกต่างๆ ดีมากค่ะ ห้องพักสะอาด แต่ถ้าเพิ่มน้ำขวดภายในห้องให้จะดีมากๆ เลยค่ะ
# ---------------------------------------------------------------------------------------------
#
# 8.8
# ห้องพักสะอาด เหมือนในเว็บ เงียบสงบดี ระบบความปลอดภัยดีมาก ชอบพักชั้น 1 ค่ะ
# 8.8
# ที่พักสะอาด ห้องน้ำสะอาด ดูดีมีเดียวเลยค่ะ แต่เสียอย่างเดียวที่ไม่มีลิฟท์ค่ะ ให้ 9 เต็ม 10 เลยค่ะ
# 8.8
# ชอบมากๆครับ ทีเเรกก่อนจะเข้าไปก้ไม่อยากที่จะเข้าไปเพราะว่าห้องน้ำอยู่เเยก เเต่พอได้เข้าไปเเล้ว ดีมากๆเลยครับ ทางโรงเเรมน่ารักมากๆ โทรไปถามทางก็บอกเป็นกันเองที่สุด อยู่ไม่ไกลจากบีทีเอสเลยครับ ใครที่อยากหาโรงเเรมราคาไม่ถึงหลักพัน ที่นี้คือดีพูดเลยครับ #ความเห็นจากคนที่อยู่ยากเรื่องมากเรื่องที่พัก55 10 10 10 ไปเล้ย
# 8.8
#
# 8.8
#
# 8.8
# เป็นโฮสเทลที่เดินทางสะดวกค่ะ จากสนามบินดอนเมืองนั่ง A2 มาลงป้ายก่อนเข้าอนุสาวรีย์เดินไปไม่กี่ก้าวก็ถึงแล้ว ที่นอนห้องรวมหญิง 4 เตียงก็โอเคค่ะ พื้นที่ใช้สอยค่อนข้างเยอะ เตียงใหญ่ แอร์เย็น มีผ้าม่านกั้นให้ รู้สึกเป็นส่วนตัว พนักงานยิ้มแย้มเเจ่มใส ที่พักมีผ้าเช็ดตัวให้ สบู่แชมพูก็ดีค่ะ ไม่ไก่กา เรารู้สึกว่าแชมพูนี่น่าจะใช้ของซันซิลนะคะ เตรียมเเค่แปรงสีฟัน ยาสีฟันก็พอค่ะ ในส่วนของพื้นที่คาเฟ่ข้างล่าง อันนี้ประทับใจมาก ตกแต่งสวย น่านั่ง แต่ช่วงกลางวันจะคนเยอะนิดนึงเพราะว่าจะมีคนมาใช้บริการร้านคาเฟ่ มีขนม ชา กาแฟ น้ำเปล่าฟรีแบบบริการตนเอง ส่วนใครอยากซักเสื้อผ้า ถ้าซักอย่างเดียว 40 บาท อบร้อนด้วยอีก 60 บาท ค่ะ เราชอบนะคะ พนักงานให้ทิ้งเสื้อผ้าไว้ เดี๋ยวเขาจะซักให้เราเลย
# 8.8
# สะดวก แต่น่าจะมีน้ำให้ในห้องกับทิชชู อดทนกับเสียงรถนิดหน่อย เอาสะดวกเดินทางดีมาก
# 8.8
# ทำเลดี เดินทางสะดวก สะอาด มีระบบคีย์การ์ด
# 8.8
# สะดวกในการเดินทาง และการหาร้านอาหาร
# 8.9
# ห้องพักสะอาด มีร้านสะดวกซื้ออยู่ใกล้ๆ
# ---------------------------------------------------------------------------------------------
#
# 9
# ห้องพักสะอาด อยู่ใกล้อนุ แนะนำเลยค่ะ
# 9
# ดีหมดแต่ให้แม่บ้านมาเก็บห้องทั้งที่ยังไม่ได้เข็คเอ้าท์อันนี้แย่มากควรถามลูกค้าก่อนไม่ใช่คิดเอง
# 9
# ห้องน้ำเหม็น ในห้องนอนน่าจะมีทิชชู
# 9
# สะอาด เดินทางสะดวก ใกล้ 7-11 ใกล้อนุฯ
# 9
# อาหารเช้าไม่โอเคค่ะ อยากให้เพิ่มอาหารมากกว่านี้ เช่น ข้าวต้มก็ได้
# 9.1
# พนักงานต้อนรับน่ารักเเละเป็นกันเองมากๆ ทุกอย่างคือดี เเต่เเอบเสียดายที่มีปลั๊กไฟเอาไว้สำหรับชาร์จน้อยไปหน่อย ให้ 9/10 ไปเลย
# 9.1
# ขึ้นเครื่องบินมาต่อ Airport Shuttle Bus สาย A2ลงอนุเสาวรีชัยเดินมานิดเดียวถึงที่พักสะดวกมากเลย ที่พักราคารับได้ห้องสะอาดห้องน้ำรวม. ขากลับก็ขึ้น Airport Shuttle Bus สายA2ถึงสนามบินเลย
# 9.1
# ดีมาก สงบเงียบ ให้ความเป็นส่วนตัวสูง สะอาด
# 9.1
#
# 9.1
# ห้องสะอาด ที่พักยอดเยี่ยม เงียบ เหมาะแก่การพักผ่อน
# ---------------------------------------------------------------------------------------------
#
# 9.1
# ที่พักสะอาดดีค่ะ แม่บ้านน่ารัก อินเทอร์เน็ต wifiใช้ได้ดี มีบริการน้ำดื่มกาแฟขนมชั้นล่างน่ารักสุดๆค่ะ
# 9.1
# ห้องสวย สะอาด เป็นส่วนตัว เดินทางง่าย ใจกลางเมือง
# 9.1
# ห้องพักสบาย เดินทางสะดวก ข้างที่พักมีเซเว่น พนักงานยิ้มแย้ม มีไดร์เป่าผม
# 9.1
# เดินทางสะดวก สะอาด แอร์เย็น จำนวนเตียงกำลังดี ไม่เยอะเกินไป
# 9.1
# ดีครัช อยู่ในเมือง ใกล้ทุกที บริการดี รวดเร็ว และเป็นกันเอง น่ารักคับ
# 9.1
# ห้องพักชั้น2 ห้อง4 แอร์อยู่ตรงประตูทางเข้าซึ่งเตียงทึบและหันหลังให้แอร์ เวลานอนพอปิดม่านลมไม่เข้า ค่อนข้างร้อน ต้องนอนเปิดม่าน แต่มีพัดลม ก็ช่วยได้ ที่เหลือดี ที่ตั้งดี เดินทางง่าย สะอาดค่ะ
# 9.1
# ดีมากห้องน่ารักมาก พนักงานใจดีน่ารักที่สุด
# 9.1
# สะอาดกว่าที่คิดไว้มาก แม้ห้องอาบน้ำจะมีน้อยและแคบไปบ้าง แต่คก็ถือว่าโอเคมาก ๆ และบันไดค่อนข้างสูงชัน แนะนำให้ค่อย ๆ เดิน (ไม่มีลิฟต์)
# 9.1
# ใกล้อนุสาวรีย์ ราคาประหยัด ห้องใหม่
# 9.1
# ห้องพักดี สะอาด ใกล้แหล่งเดินทาง แต่น้ำในห้องน้ำไหลเบาไปหน่อยค่ะ
# ---------------------------------------------------------------------------------------------
# 9.1
# ที่พักใกล้แหล่งต่อรถ มาพักเป็นครั้งที่ 6 แล้ว อยู่ใกล้ bts และศูนย์รวมการต่อรถ ใกล้ห้างสรรพสินค้าและร้านสะดวกซื้อ ห้องนอนสะอาด แต่อาจมีกลิ่นอับ แต่ก็สมราคา 400-600 บาท ห้องน้ำรวม แต่ก็เป็นสัดส่วนดี มาทุกครั้ง ระยะ 2 ปีสภาพห้องจะรีโนเวทใหม่อยู่เสมอ หรือถ้าใครต้องต่อเครื่องบินทั้ง BKK or DMK ก็แนะนำ ถ้ารวมเวลาเดินทางทั้งหมดแล้ว 1 ชั่วโมง
# 9.1
# ข้างที่พักมี 7-11 ห้องพักและห้องน้ำสะอาดมาก ไม่มีลิฟต์ บริการดี เสียอยู่นิดนึงตรงห้องไม่เก็บเสียง เวลามีคนเดินผ่านคุยกันได้ยินชัด มีเสียงจากการจราจรบนถนนบ้าง แต่โดยรวมแล้วดีค่ะ ชอบ เป็นตัวเลือกที่ดีสำหรับคนที่ต้องไปธุระแถวอนุสาวรีย์หรือแถบรถไฟฟ้าค่ะ เพราะเดินทางสะดวกมาก
# 9.1
# สะอาด เป็นมิตร คุ้มราคา เสียแต่บันไดหลายชั้นนี่แหละ
# 9.1
# การเดินทางสะดวก หาง่าย หาของกินง่าย
# 9.1
# ที่ตั้งดีมาก เดินทางสะดวก อยู่ใกล้อนุสาวรีย์ชัย ป้ายรถเมล์อยู่ข้างหน้า ไม่ไกลจาก BTS อนุสาวรีย์ชัยสมรภูมิ พอเดินไหว ที่พักสะอาด ร้านอาหารเยอะมาก ใกล้แหล่งช๊อปปิ้ง
#
# ข้อเสีย -ห้องน้ำน้อย ห้องพักจะได้ยินเสียงรถวิ่งบ้าง (แต่ไม่มาก) ไม่มีลิฟต์ แต่เทียบกับราคาก็คุ้มค่า
# 9.1
# ห้องพักสะอาด แต่ไม่มีลิฟท์ มีทั้งหมด 5 ชั้น ตกแต่งสวยงาม น่านอน
# 9.1
# ห้องพักสะอาด แอร์เย็นดีค่ะ เตียงก็นุ่ม นอนหลับสบาย ข้างล่างมีขนมและกาแฟให้รับประทานด้วย ที่สำคัญอยู่ใกล้ 7 และ BTS ค่ะ สะดวกในการเดินทาง ไว้โอกาสหน้าจะมาพักอีกค่ะ so good 😋👍🏻😜
# 9.1
# ห้องเดี่ยวสะอาดดีค่ะ พนักงานอัธยาศัยดี ให้บริการและแก้ปัญหาได้ค่อนข้างดี ห้องน้ำและห้องอาบน้ำก็สะอาดดีค่ะ
# 9.1
# ชอบการตกแต่ง ความสะอาดมาก ทำเลดี ไม่ไกลจากอนุสาวรีย์ชัย ถ้ามาบีทีเอสจะเดินไกลหน่อยแต่พอไหว อยู่ใกล้แหล่งค้าขาย การเดินทางไปที่ต่างๆสะดวกมาก ห้องจะได้ยินเสียงรถบ้างเพราะอยู่ติดถนนใหญ่ มีป้ายรถเมล์ข้างหน้า ไม่มีลิฟต์ขึ้นลง เราพักห้องรวม 4 เตียง ข้อเสียคือห้องน้ำน้อยไป แต่รวมๆเมื่อเทียบราคาคุ้มค่า คิดว่าจะกลับไปพักอีกแน่นอน
# 9.1
# ห้องพักสบายมากๆ ครั้งหน้าจะไปพักอีกค่ะ
# ---------------------------------------------------------------------------------------------
#
# 9.1
# ที่พักสะอาด ใกล้รถประจำทาง และน่าอยู่
# 9.1
# สะดวก มา กทม. ทุกครั้งเลือกที่นี่อันดับต้นๆ
# 9.1
# แม่บ้านดีมากเลยค่ะ โรงแรมสะอาด
# 9.1
# อยู่ติด 7-11 แล้วใกล้ๆก็มีร้านก๋วยเตี๋ยวร้านอาหารตามสั่งเต็มเลย
# 9.1
# เดินทางสะดวก ห้องสะอาด ห้องน้ำก็สะอาด
# 9.1
# พนักงานให้บริการดี ห้องพักสะอาด เดินทางสะดวก
# 9.2
# ทำเลดีมาก แต่ห้องน้ำน้อย ราคาสูง อาหารเช้าเป็นแค่ขนมแห้งๆกับกาแฟ
# 9.3
# สะอาด เงียบสงบ มีร้านกาแฟใต้อาคาร
# 9.3
# พนักงานต้อนรับตอนกลางคืนที่เป็นผู้ชายบริการไม่ค่อยดีไม่มีหัวใจบริการห่วงแต่เล่นเกมส์มองแต่จอมือถือไม่สนใจลูกค้า ที่ไม่เคยมา โรงแรมดีเยี่ยม ทำเลสะดวก นอนสบาย ห้องน้ำแคบและอับจริง ไม่เพียงพอ ระบายอากาศยังไม่ดี เตียงนุ่มมาก นิ่มสบาย สะอาด อาหารอร่อย ดีเกือบครบทุกอย่าง ประทับใจราคาแบบนี้ คุ้มค่ามากๆ เดินทางสะดวก
# 9.3
# ทำเลที่ตั้งหาง่าย สะดวก ห้องพักสะอาดมาก บริการดี แต่มีเสียงรถวิ่งทั้งคืน แนะนำ เตรียมโฟมอุดหูไปด้วย
# ---------------------------------------------------------------------------------------------
#
# 9.4
# ห้องเหมือนในรีวิวเลยค่ะ สบาย สะอาด นอนสบาย ใกล้เสารีมากกก ข้าง7-11บอกเลยโ***สะดวก
# 9.4
# ทำเลดี ไม่ห่างจากรถไฟฟ้าBTSสามารถเลือกลงสถานีสนามเป้าหรืออนุสาวรีย์ มีรถเมล์ผ่านหลายสายทำให้เดินทางสะดวกไปที่ต่างๆของกรุงเทพ ร้านอาหารอร่อยเยอะมาก ใกล้แหล่งช๊อปปิ้งมากมาย ที่พักสะอาดมาก บริการประทับใจ คุ้มค่าราคา
# 9.4
# ห้องพักดีมากค่ะ สะอาด ห้องน้ำถึงเป็นห้องรวม ก็สะอาดดี ใกล้BTS ใกล้ป้ายรถเมล์ เดินแป๊บเดียวถึง หาของกินง่าย ถ้ามีโอกาสจะไปพักอีกค่ะ
# 9.4
# ห้องน้ำรวมก็จริงแต่สะอาดมากๆ แม่บ้านพูดจาดี พนักงานก็พูดจาดี เอาจริงๆอยากกลับไปจองอีกค่ะ แถวนั้นของกินเยอะ มีเซเว่นอีก สะดวกสบายสุดๆเลย
# 9.4
# เดินจากสถานีอนุสาวรีย์ประมาณไม่เกิน 10 นาที มี 7-11 ข้างๆ ล็อบบี้สะอาด มีร้านคาเฟ่ (ไม่ได้ลองชิม) มีให้ฝากกระเป๋าในกรณีที่มาถึงก่อนเวลาเช็คอิน พักห้องส่วนตัว ห้องสะอาดดี แต่ไม่ค่อยเก็บเสียงดังจากถนน (ไม่มีปัญหา นอนได้เหมือนเดิม) ห้องน้ำรวมก็สะอาดค่ะ ถ้ามีโอกาสได้ไปแถวนั้น จะกลับไปพักอีกค่ะ
# 9.4
# ห้องเหม็นอับตอนเริ่มเปิดแอร์ สักครึ่งชม.ก็หาย ห้องน้ำน้อยไปหน่อยสำหรับโฮสเทลห้องน้ำรวมค่ะ
# 9.4
# โรงแรมสะอาด เงียบสงบ พนักงานบริการดีมาก
# 9.4
# เคยพักมาแล้วครั้งนึง ไว้วางใจมาพักเป็นครั้งที่ 2 ถ้าจำเป็นต้องหาพัก ก็จะมาพักที่นี่อีกครึ้งแน่นอน เดินทางสะดวกสบาย ราคาประหยัด ครบครันไปหมด 👍
# 9.4
# พักหลายรอบแล้วว ดีมาก หลับสบาย
# 9.4
# ห้องพักแอร์ สะดวกสบาย มีwifi ห้องน้ำสะอาด ใกล้ป้ายรถเมล์และร้านสะดวกซื้อ ราคาประหยัด พักคนเดียวได้สะดวก บริการเป็นกันเอง
# ---------------------------------------------------------------------------------------------
#
# 9.4
# โรงเเรมดีมากๆ สะอาด สะดวก บริการคอยต้อนรับเป็นกันเอง
# 9.4
# โฮสเทลก็ก็ดี ที่พักดี เตียงดี เสียแต่ห้องน้ำมันอับไปหน่อย ไม่มีเครื่องดูดอากาศ หรือที่ระบายอากาศ ด้วยความที่เป็นห้องน้ำรวมแล้วคนใช้เยอะ มันเลยไม่มีที่ระบายความร้อน
# 9.4
# เดินทางสะดวกมากๆ คะ สะอาด ปลอดภัย
# 9.4
# สะอาด ใกล้ศูนย์คมนาคมขนส่ง ทุกอย่างลงตัว โดยเฉพาะพนักงานบริการดีมาก
# 9.4
# โรงเเรมหาง่ายอยู่ติดถนน ห้องพักห้องน้ำสะอาดน่าพักน่านอนสมราคา
# 9.4
# ที่พักทำเลดีเดินทางสะดวก ห้องพักสะอาด ห้องน้ำรวม แต่ห้องอาบน้ำแคบมากค่ะ อยากให้ปรับปรุงตรงนี้ค่ะ
# 9.4
# สถานที่น่าอยู่ สะอาด ครบครัน เดินทางสะดวสบาย
# 9.4
# สะอาด และเดินทางสะดวก ใกล้กับสถานีรถไฟฟ้าเพียง 5 นาที
# 9.4
# น่าจะมีรองเท้าแตะในห้องให้ค่ะ เพื่อที่จะได้ใส่ไปตอนเข้าห้องน้ำและอาบน้ำ ห้องสะอาดดี นอนหลับสบายค่ะ
# 9.4
# ตอนที่เข้าพัก พักเป็นsingle room ห้องน้ำรวมนะคะ ห้องสะอาดมากหอมด้วย ผ้าเช็ดตัวก็หอม ขนาดของห้องพอดี น่ารักมากๆ พนักงานบริการดีมากๆคะ ตอนที่ไปพักไปไม่ถูกโทรหาโรงแรมพี่ที่โรงเเรมเดินออกมารับเลยคะ บริการดีนะคะ ห้องน้ำน้อยไปแต่ตอนไปพักไม่มีคนแย่งนะคะ ห้องน้ำสะอาดคะ แชมพูสบู่หอมมากคะ รวมๆแล้วดีมากๆคะ
# ---------------------------------------------------------------------------------------------
#
# 9.4
# สะอาด ใกล้ BTS เดินทางสะดวก ใกล้เซเว่น
# 9.4
# ห้องพักสะอาดดีมากค่ะ ใกล้รถไฟฟ้า สะดวกแก่การเดินทาง
# 9.4
# ห้องพักนอนสบาย เงียบสงบดีมากครับ ห้องน้ำรวมแต่สะอาดมาก
# 9.4
#
# 9.4
# ห้องสวย ห้องน้ำสะอาด เดินทางสะดวกมากใกล้ป้ายรถเมล์ พนักงานใจดีมากๆค่ะ ครั้งหน้าจะไปพักอีก
# 9.4
# ห้องพักสะอาด เตียงนุ่ม ใกล้แหล่งกิน แหล่งชอปปิ้ง ค่ะ
# 9.4
# ห้องสะอาด สบายดีคะ ที่นอนนิ่ม ผ้าห่มอุ่น มีผ้าเช็ดตัวให้บนเตียง ชั้นที่พักห้องน้ำมี 1 ห้อง ห้องอาบน้ำ 1 ห้อง แยก ญ ช มีเตารีดให้ยืม โดยรวมถือว่าชอบคะ
# 9.4
# ที่พักสะดวก สะอาด และปลอดภัยดีค่ะ ครั้งนี้เป็นครั้งที่ 2 แล้ว ถ้ามาอีกก็จะไม่พลาดที่จะใช้บริการอีกค่ะ
# 9.4
# ห้องพักสะอาด หลับสบาย ห้องน้ำสะอาด
# 9.4
# ห้องนอนสะอาดสะอ้านน่านอน แอร์เย็น ห้องน้ำสะอาดน่าใช้งาน แต่อยากให้เพิ่มจำนวนห้องน้ำต่อชั้นค่ะ
# ---------------------------------------------------------------------------------------------
#
# 9.4
# ที่พักสะอาด สบาย เราเลือกเป็นเตียง 2 ชั้น แต่ไม่อึดอัดเลยค่ะ เตียงกว้าง ถึงนอนชั้นบนก็ไม่อึดอัด มีม่านกั้นเรียบร้อย ห้องน้ำเเยกชายหญิง แต่ห้องน้ำน้อยไปนะคะ ต้องรอคิวนิดหน่อย  โฮสเทลตั้งอยู่ในโลเคชั่นที่ดีมาก หาง่าย
# 9.4
# เดินทางสะดวก พนักงานใจดี สุภาพ
# 9.4
# ห้องพักดี สะอาด ใช้บริการเป็นประจำ แต่ห้องน้ำควรเปลี่ยนที่แขวนผ้าใหม่เพราะของเก่ามันเริ่มแขวนผ้าไม่ได้แล้ว
# 9.4
# ที่พักสะอาดเรียบร้อย ทำเลดีมาก อยู่ใกล้อนุสาวรีย์ชัยสมรภูมิ รถเมล์ผ่านหลายสาย ถ้าจะเดินทาง BTS ก็ได้ มีร้านอาหารอร่อย ใกล้แหล่งช้อปปิ้ง ราคาคุ้มค่า
# 9.4
# ไปพักมาหลายครั้งค่ะ ดีตลอด ทำเลดีมาก บริการดี
# 9.4
# ที่พักไม่ค่อยเก็บเสียง ได้ยินเสียงห้องข้างๆเปิดประตูเข้าออกตลอดเวลา ห้องพักสะอาดมาก ห้องน้ำสะอาด
# 9.4
# อยู่ตรงป้ายรถเมล์ เดินทางสะดวกมากๆ ใกล้ๆมี 7-11 และร้านอาหารตามสั่งอยู่ หาของกินได้ง่าย เตียงกว้างมาก ห้องสะอาดมากๆ พักห้อง 4 คนมีผ้าเช็ดตัวให้ มีโต๊ะให้นั่งเล่นด้วย ชอบค่ะ ด้านล่างเป็นคาเฟ่ให้นั่งชิลๆได้ มีกาแฟและขนมหยิบทานได้เลย ไม่ผิดหวังค่ะ มีโอกาสจะกลับไปแน่นอน
# 9.4
# พักแบบห้องรวม ดีมาก ที่นอนนุ่มสบาย เดินทางสะดวก เสียอย่างเดียวห้องน้ำน้อยไปหน่อย แต่ละชั้น ห้องน้ำชายหญิงจะมีแค่อย่างละห้องเท่านั้นเอง
# 9.4
# พนักงานบริการดีมาก ที่พักสะอาด อยู่ไม่ไกลจากบีทีเอส อยู่ติดถนน หาไม่ยาก
# 9.4
# พนักงานดีมาก ให้ความช่วยเหลือหลายอย่าง ห้องก็ดีมาก
# ---------------------------------------------------------------------------------------------
#
# 9.4
# ที่พักสวย น่ารัก ใหม่ สะอาดมาก ไม่วุ่นวาย รู้สึกปลอดภัย เอารวมๆว่าชอบมากค่ะ น้องพนักงานที่เคาน์เตอร์ต้อนรับก็อัธยาศัยดี ยินดีตอบคำถาม อยู่ติดริมถนนใหญ่ ใกล้อนุสาวรีย์ชัย เดินทางไปไหนมาไหนสะดวก เดินทางไปสนามบินดอนเมืองก็ง่าย มี 7-11 อยู่ใกล้ๆ พักห้องเดี่ยว ที่นอน หมอน ผ้าห่ม หอม นุ่ม หลับสบายมากค่ะ กระจกในห้องพักก็ใหญ่โต มีผ้าขนหนูให้ 2 ผืน ห้องน้ำ สะอาด มีแชมพู ครีมอาบน้ำ น้ำยาล้างมือ และไดร์เป่าผมให้บริการ ห้องน้ำแยกหญิง ชาย ห้องอาบน้ำ กับห้องน้ำก็แยกเป็นสัดส่วน ที่นั่งด้านล่าง มีชา กาแฟ ขนม บริการฟรี ที่นั่งก็น่ารักน่านั่ง มี WiFi บริการทุกห้องพัก สัญญาณแรงดี ชอบมาก เป็นประสบการณ์ที่ดีในการพักโฮสเทลครั้งแรก มีโอกาสจะมาพักอีกค่ะ
# 9.4
# ทำเลดี ใกล้รถไฟฟ้า ห้องพักสะอาด เตียงกว้าง พนักงานบริการดี แต่มีห้องน้ำน้อยไปหน่อย
# 9.4
# ยอดเยี่ยม เหมือนอยู่บ้านเลยครับ
# 9.4
# สะอาด เป็นส่วนตัวแม้พักห้องรวม แต่วันที่ไป WiFi ไม่สามารถใช้ได้ พนักงานบอกกำลังปรับปรุง โดยรวมดีมากครับ
# 9.4
# ทำเลดีมาก เดินทางสะดวก เมื่อเทียบกับราคาในย่านนี้
# 9.4
# ทำเลดี บริการยอดเยี่ยม พนักงานเอาใจใส่ดีมาก
# 9.4
# สะดวกสบาย พนักงานบริการดี แนะนำนิดหน่อย ห้องอาบน้ำการระบายน้ำช้าเหมือนจะตัน ส่วนรวมดีมากๆ
# 9.4
# เดินจากสถานีรถไฟฟ้าประมาณสิบนาที สะดวก สะอาดดี
# 9.4
# น่าจะมีราวแขวนผ้าเช็ดตัวในห้องพัก
# 9.4
# เดินทางสะดวก ห้องพักกว้าง สะอาดมาก
# ---------------------------------------------------------------------------------------------
#
# 9.6
# มีเตารีดและอุปกรณ์รีดผ้าให้ครบ ประทับใจมากค่ะ
# 9.7
# ห้องสะอาดมาก พนักงานพูดจาดี คอยสังเกตลูกค้าตลอด
# 9.7
# ทำเลสะดวกต่อการเดินทาง/ห้องพัก, ห้องน้ำสะอาด, พนักงานให้บริการที่ดีค่ะ
# 9.7
# มีโอกาสจะไปพักอีกคะ. สะอาดเรียบร้อย เงียบดีคะ
# 9.7
# ห้องสะอาด สบาย ดีมาก เดินทางก็สะดวก คิดอะไรไม่ออกก็มาพักที่นี่ แต่ห้องน้ำน้อยไปหน่อย โดยรวมคือโอเคมากๆ
# 9.7
# ตลอดการมาพักยังดีเสมอต้นเสมอปลายค่ะ มีความใส่ใจผู้เข้าพัก ด้วยความที่มาพักบ่อยจนพี่เค้าจำชื่อได้และรู้ว่าเราต้องการเตียงล่าง ทางโฮสเทลจะสำรองเตียงล่างไว้ให้เลย คือดีมากๆและสะดวกในการเดินทางไปมามากๆเช่นกัน
# 9.7
# ห้องสะอาดมาก กลิ่นหอมมาก ถึงจะเป็นห้องน้ำรวมแต่สะอาดมาก สะอาดตลอดวัน มีคาเฟ่ที่ชั้น 1 รสชาติกาแฟโอเค มีโอกาสจะใช้บริการอีกนะคะ
# 9.7
# ที่พักสะอาด สวย อยู่ใกล้BTS เดินทางสะดวกมาก รอบๆที่พักมีร้านอาหารเยอะ มีเซเว่นอยู่ข้างๆ
# 9.7
# เป็นโฮสเทลที่ดีมากๆเลยค่ะทั้งห้องพัก พนักงาน ห้องน้ำก็ดี เดินทางก็สะดวกมาก เหมาะสำหรับคนเดินทาง มาพักคนเดียวยังรู้สึกปลอดภัย เเนะนำที่นี่จริงๆค่ะ ไว้จะมาพักอีกครั้งถ้ามีโอกาส
# 9.7
# มาพักครั้งที่ 2 แล้วค่ะ สะอาด สะดวก สบาย
# ---------------------------------------------------------------------------------------------
#
# 9.7
# บริการดีมากครับ เเละที่พักสะอาดมากครับ
# 9.7
# ห้องพักดีมาก เป็นโฮสเทลที่กว้าง เตียงนอนหลับสบายมาก เตียงกว้าง พนักงานใจดีที่สุดเลย
# 9.7
# ห้องนอน(เดี่ยว)ดีมากนะคะ สะอาดตา กระจกในห้องสาวๆที่ต้องแต่งหน้า ทำผม สบายใจได้เลยค่ะ
# 9.7
# พักที่นี่หลายครั้ง บริการดี สะอาด เงียบ
# 9.7
# สะอาด ทำเลดี สิ่งอำนวยความสะดวกครบ (ผ้าเช็ดตัว สบู่ แชมพู) แต่หมอนเตี้ยไปหน่อย
# 9.7
# ห้องพักดีงาม ใหม่ สะอาด กว้าง อยู่ได้สบายๆ รวมทั้งห้องน้ำด้วย ถึงจะเป็นห้องน้ำรวมแต่ก็แยกชายหญิง ที่พักอยู่ติดถนนและมีเซเว่นอยู่ข้างๆ รวมทั้งป้ายรถเมล์ด้านหน้าที่พัก หรือจะเดินไปบีทีเอสก็ใกล้มากๆ สะดวกสบายสุดๆ พี่ๆโฮสเทลน่ารักมากค่ะ โดยรวมแล้วชอบมากๆเลย ไว้มีโอกาสจะไปพักอีกแน่นอนค่ะ
# 9.7
# เป็นโฮลเทลที่น่าอยู่มากคะ บริารดี เป็นกันเอง
# 9.7
# ที่พักน่ารักมากค่ะ สะอาดมาก ลงรถA2 มาจากเดือนเมืองแล้วเดินเข้าที่พักได้เลย
# 9.7
#
# 9.7
# ที่พักดี เหมาะสมกับราคา เดินทางสะดวก ใกล้อนุสาวรีย์ ปลอดภัย
# ---------------------------------------------------------------------------------------------
#
# 9.7
# ห้องดีมากๆ สะอาด มีโอกาสจะแวะไปพักอีกค่ะ
# 9.7
# ใกล้สถานีรถไฟฟ้าและคิวรถตู้อนุสาวรีย์ชัยสมรภูมิ เดินทางไปที่ต่างๆได้สะดวก
# 9.7
# สะอาดมาก ที่นอนนุ่มสะอาด ห้องน้ำสะอาด ใกล้อนุสาวรีย์มาก เดินทางสะดวก หาร้านอาหารง่าย มีของว่างให้ ราคาถูก
# 9.7
# สะดวกในการเดินทางมากค่ะ ไปพักมา 2 ครั้งแล้ว และจะมีครั้งต่อๆไปแน่นอนค่า
# 9.7
# ห้องพักดีมากคุ้มค่าคุ้มราคา เจ้าของและพนักงานน่ารัก บริการประทับใจค่ะ ไปพัก 2 ครั้ง แล้วไม่ผิดหวังเลย
# 9.7
#
# 9.7
# ห้องสะอาด การเดินทางสะดวก แต่ห้องน้ำน้อยไปหน่อย
# 9.7
# สะอาด สวยงาม บริการดี ชอบการตกแต่ง
# 9.7
# สะดวกสบาย บริการดี เงียบสงบ อุปกรณ์ครบ ใกล้รถไฟฟ้าและรถเมล์
# 9.7
# สะดวก สะอาด อยู่ใกล้รถไฟฟ้า หาอาหารได้ง่าย อยู่ใจกลางเมือง
# ---------------------------------------------------------------------------------------------
#
# 9.7
# ดีจริงๆ ใครที่ต้องการที่พักใกล้อนุสาวรีย์ เชิญที่ T Hotel พี่เค้าเป็นกันเองมากก แนะนำดี บริการเลิศ ถ้ามีโอกาสจะแวะกลับมาพักอีกครับ
# 9.7
# อยู่ใกล้อนุเสาวรีย์ชัยสมรภูมิมากๆ เดินแปปเดียว เดินทางสะดวก มีป้ายรถเมล์หน้าที่พักพอดีด้ลย เซเว่นก็อยู่ติดกันเลย สะดวกดีค่ะ ห้องพักสะอาด ห้องน้ำสามารถใช้ชั้นอื่นๆได้ด้วย ดีมากๆ ไว้จะไปใช้บริการอีกค่ะ
# 9.7
# ห้องสะอาด สะดวก หลับสบาย ไม่มีเสียงรบกวน ห้องน้ำสะอาดดี ไม่มีกลิ่นไม่พึงประสงค์ จัดได้สวยสไตล์Modern การเดินทางสะดวก ใกล้ BTS และศูนย์รวมรถเมย์ พนักงานน่ารัก บริการดี 😀😀👍🏻👍🏻
# 9.7
# สะอาด บริการดี มีขนมให้กินฟรี ใกล้อนุสาวรีย์ชัยฯ ชอบมาก
# 9.7
#
# 9.7
#
# 9.7
# เป็นกันเอง ที่พักสะอาดมาก สะดวกในการเดินทาง
# 9.7
# การเดินทางสะดวก บริการดี ห้องพักสะอาด รูมเมตน่ารัก
# 9.7
# ห้องพักสะดวกสบาย คาเฟ่ด้านล่างตกแต่งน่ารักมาก ราคาประหยัด บริการประทับใจ อยู่ใกล้อนุสาวรีย์
# 9.7
# โรงแรมสะอาดดีมาก ห้องสะอาดมาก พนง.บริการดีมากค่ะ
# ---------------------------------------------------------------------------------------------

# %%
print('Ratings_list :',len(Ratings_list))
print('Reviews_list :',len(Reviews_list))
# Out:
# Ratings_list : 230
# Reviews_list : 230

# %% [markdown]
# # Implement Data To Pandas

# %%
import pandas as pd
import numpy as np

table = pd.DataFrame([Reviews_list,Ratings_list]).T

# %%
table.columns = ['Review', 'Rating']

# %%
table['Review'].replace('', np.nan, inplace=True)

# %%
table
# Out:
#                                                 Review Rating
# 0    ห้องพักสะอาด ทำเลดี การเดินทางสะดวก แต่เสียอย่...    6.8
# 1     ไม่มีห้องน้ำในห้องไม่มีความเป็นส่วนตัว ไม่ชอบเลย      8
# 2    ห้องแคบ แต่สะอาด ห้องน้ำและห้องอาบน้ำอย่างละ1ห...    8.1
# 3    ไวไฟที่ให้เล่นไม่ได้ ส่วนห้องพักและห้องน้ำสะอาดดี    8.1
# 4    ข้อดี - ทำเลที่ตั้งดีมาก สามารถเดินไปขึ้นรถที่...    8.2
# ..                                                 ...    ...
# 225                                                NaN    9.7
# 226        เป็นกันเอง ที่พักสะอาดมาก สะดวกในการเดินทาง    9.7
# 227  การเดินทางสะดวก บริการดี ห้องพักสะอาด รูมเมตน่...    9.7
# 228  ห้องพักสะดวกสบาย คาเฟ่ด้านล่างตกแต่งน่ารักมาก ...    9.7
# 229   โรงแรมสะอาดดีมาก ห้องสะอาดมาก พนง.บริการดีมากค่ะ    9.7
#
# [230 rows x 2 columns]

# %%
table = table.dropna()
table.reset_index(inplace=True)
table
# Out:
#      index                                             Review Rating
# 0        0  ห้องพักสะอาด ทำเลดี การเดินทางสะดวก แต่เสียอย่...    6.8
# 1        1   ไม่มีห้องน้ำในห้องไม่มีความเป็นส่วนตัว ไม่ชอบเลย      8
# 2        2  ห้องแคบ แต่สะอาด ห้องน้ำและห้องอาบน้ำอย่างละ1ห...    8.1
# 3        3  ไวไฟที่ให้เล่นไม่ได้ ส่วนห้องพักและห้องน้ำสะอาดดี    8.1
# 4        4  ข้อดี - ทำเลที่ตั้งดีมาก สามารถเดินไปขึ้นรถที่...    8.2
# ..     ...                                                ...    ...
# 207    223  สะอาด บริการดี มีขนมให้กินฟรี ใกล้อนุสาวรีย์ชั...    9.7
# 208    226        เป็นกันเอง ที่พักสะอาดมาก สะดวกในการเดินทาง    9.7
# 209    227  การเดินทางสะดวก บริการดี ห้องพักสะอาด รูมเมตน่...    9.7
# 210    228  ห้องพักสะดวกสบาย คาเฟ่ด้านล่างตกแต่งน่ารักมาก ...    9.7
# 211    229   โรงแรมสะอาดดีมาก ห้องสะอาดมาก พนง.บริการดีมากค่ะ    9.7
#
# [212 rows x 3 columns]

# %%
table = table.drop(['index'],axis=1)

# %%
table
# Out:
#                                                 Review Rating
# 0    ห้องพักสะอาด ทำเลดี การเดินทางสะดวก แต่เสียอย่...    6.8
# 1     ไม่มีห้องน้ำในห้องไม่มีความเป็นส่วนตัว ไม่ชอบเลย      8
# 2    ห้องแคบ แต่สะอาด ห้องน้ำและห้องอาบน้ำอย่างละ1ห...    8.1
# 3    ไวไฟที่ให้เล่นไม่ได้ ส่วนห้องพักและห้องน้ำสะอาดดี    8.1
# 4    ข้อดี - ทำเลที่ตั้งดีมาก สามารถเดินไปขึ้นรถที่...    8.2
# ..                                                 ...    ...
# 207  สะอาด บริการดี มีขนมให้กินฟรี ใกล้อนุสาวรีย์ชั...    9.7
# 208        เป็นกันเอง ที่พักสะอาดมาก สะดวกในการเดินทาง    9.7
# 209  การเดินทางสะดวก บริการดี ห้องพักสะอาด รูมเมตน่...    9.7
# 210  ห้องพักสะดวกสบาย คาเฟ่ด้านล่างตกแต่งน่ารักมาก ...    9.7
# 211   โรงแรมสะอาดดีมาก ห้องสะอาดมาก พนง.บริการดีมากค่ะ    9.7
#
# [212 rows x 2 columns]

# %%
table.to_csv("Reviews&Ratings_11th.csv", encoding="utf-8")
